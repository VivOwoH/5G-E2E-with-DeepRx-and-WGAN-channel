# %% [markdown]
# # Neural Receiver for OFDM SIMO Systems

# %% [markdown]
# In this notebook, you will learn how to train a neural receiver that implements OFDM detection.
# The considered setup is shown in the figure below.
# As one can see, the neural receiver substitutes channel estimation, equalization, and demapping.
# It takes as input the post-DFT (discrete Fourier transform) received samples, which form the received resource grid, and computes log-likelihood ratios (LLRs) on the transmitted coded bits.
# These LLRs are then fed to the outer decoder to reconstruct the transmitted information bits.

# %% [markdown]
# ![System Model](data:image/png;base64,...)

# %% [markdown]
# Two baselines are considered for benchmarking, which are shown in the figure above.
# Both baselines use linear minimum mean square error (LMMSE) equalization and demapping assuming additive white Gaussian noise (AWGN).
# They differ by how channel estimation is performed:
#
# - **Pefect CSI**: Perfect channel state information (CSI) knowledge is assumed.
# - **LS estimation**: Uses the transmitted pilots to perform least squares (LS) estimation of the channel with nearest-neighbor interpolation.
#
# All the considered end-to-end systems use an LDPC outer code from the 5G NR specification, QPSK modulation, and a 3GPP CDL channel model simulated in the frequency domain.

# %% [markdown]
# * [GPU Configuration and Imports](#GPU-Configuration-and-Imports)
# * [Simulation Parameters](#Simulation-Parameters)
# * [Neural Receiver](#Neural-Receiver)
# * [End-to-end System](#End-to-end-System)
# * [End-to-end System as a Keras Model](#End-to-end-System-as-a-Keras-Model)
# * [Evaluation of the Baselines](#Evaluation-of-the-Baselines)
# * [Training the Neural Receiver](#Training-the-Neural-Receiver)
# * [Evaluation of the Neural Receiver](#Evaluation-of-the-Neural-Receiver)
# * [Pre-computed Results](#Pre-computed-Results)
# * [References](#References)

# %% [markdown]
# ## GPU Configuration and Imports <a class="anchor" id="GPU-Configuration-and-Imports"></a>

# %%
import os
gpu_num = 0 # Use "" to use the CPU
os.environ["CUDA_VISIBLE_DEVICES"] = f"{gpu_num}"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Import Sionna
try:
    import sionna
except ImportError as e:
    # Install Sionna if package is not already installed
    import os
    os.system("pip install sionna")
    import sionna

# Configure the notebook to use only a single GPU and allocate only as much memory as needed
# For more details, see https://www.tensorflow.org/guide/gpu
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e:
        print(e)
# Avoid warnings from TensorFlow
tf.get_logger().setLevel('ERROR')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pickle

from tensorflow.keras import Model
from tensorflow.keras.layers import Layer, Conv2D, LayerNormalization
from tensorflow.nn import relu

from sionna.channel.tr38901 import Antenna, AntennaArray, CDL
from sionna.channel import OFDMChannel
from sionna.mimo import StreamManagement
from sionna.ofdm import ResourceGrid, ResourceGridMapper, LSChannelEstimator, LMMSEEqualizer, RemoveNulledSubcarriers, ResourceGridDemapper
from sionna.utils import BinarySource, ebnodb2no, insert_dims, flatten_last_dims, log10, expand_to_rank
from sionna.fec.ldpc.encoding import LDPC5GEncoder
from sionna.fec.ldpc.decoding import LDPC5GDecoder
from sionna.mapping import Mapper, Demapper, Constellation
from sionna.utils.metrics import compute_ber
from sionna.utils import sim_ber

# %% [markdown]
# ## Simulation Parameters <a class="anchor" id="Simulation-Parameters"></a>

# %%
############################################
## Channel configuration
carrier_frequency = 3.5e9 # Hz
delay_spread = 100e-9 # s
cdl_model = "C" # CDL model to use
speed = 10.0 # Speed for evaluation and training [m/s]
# SNR range for evaluation and training [dB]
ebno_db_min = -5.0
ebno_db_max = 10.0

############################################
## OFDM waveform configuration
subcarrier_spacing = 30e3 # Hz
fft_size = 128 # Number of subcarriers forming the resource grid, including the null-subcarrier and the guard bands
num_ofdm_symbols = 14 # Number of OFDM symbols forming the resource grid
dc_null = True # Null the DC subcarrier
num_guard_carriers = [5, 6] # Number of guard carriers on each side
pilot_pattern = "kronecker" # Pilot pattern
pilot_ofdm_symbol_indices = [2, 11] # Index of OFDM symbols carrying pilots
cyclic_prefix_length = 0 # Simulation in frequency domain. This is useless

############################################
## Modulation and coding configuration
num_bits_per_symbol = 6 # 64-QAM
coderate = 0.5 # Coderate for LDPC code

############################################
## Neural receiver configuration
num_conv_channels = 128 # Number of convolutional channels for the convolutional layers forming the neural receiver

############################################
## Training configuration
num_training_iterations = 50000 # Number of training iterations
training_batch_size = 128 # Training batch size
model_weights_path_standard = "neural_receiver_weights_standard" # Location to save the neural receiver weights once training is done
model_weights_path_trained = "neural_receiver_weights_trained"

############################################
## Evaluation configuration
results_filename = "neural_receiver_results" # Location to save the results

# %% [markdown]
# The `StreamManagement` class is used to configure the receiver-transmitter association and the number of streams per transmitter.
# A SIMO system is considered, with a single transmitter equipped with a single non-polarized antenna.
# Therefore, there is only a single stream, and the receiver-transmitter association matrix is $[1]$.
# The receiver is equipped with an antenna array.

# %%
stream_manager = StreamManagement(np.array([[1]]), # Receiver-transmitter association matrix
                                  1)               # One stream per transmitter

# %% [markdown]
# The `ResourceGrid` class is used to configure the OFDM resource grid. It is initialized with the parameters defined above.

# %%
resource_grid = ResourceGrid(num_ofdm_symbols = num_ofdm_symbols,
                             fft_size = fft_size,
                             subcarrier_spacing = subcarrier_spacing,
                             num_tx = 1,
                             num_streams_per_tx = 1,
                             cyclic_prefix_length = cyclic_prefix_length,
                             dc_null = dc_null,
                             pilot_pattern = pilot_pattern,
                             pilot_ofdm_symbol_indices = pilot_ofdm_symbol_indices,
                             num_guard_carriers = num_guard_carriers)

# %% [markdown]
# Outer coding is performed such that all the databits carried by the resource grid with size `fft_size`x`num_ofdm_symbols` form a single codeword.

# %%
# Codeword length. It is calculated from the total number of databits carried by the resource grid, and the number of bits transmitted per resource element
# data symbols = 1392
n = int(resource_grid.num_data_symbols*num_bits_per_symbol)
# Number of information bits per codeword
k = int(n*coderate)
print(n)
print(k)
# Out:
# 8352
# 4176

# %% [markdown]
# The SIMO link is setup by considering an uplink transmission with one user terminal (UT) equipped with a single non-polarized antenna, and a base station (BS) equipped with an antenna array.
# One can try other configurations for the BS antenna array.

# %%
ut_antenna = Antenna(polarization="single",
                     polarization_type="V",
                     antenna_pattern="38.901",
                     carrier_frequency=carrier_frequency)

bs_array = AntennaArray(num_rows=1,
                        num_cols=1,
                        polarization="dual",
                        polarization_type="VH",
                        antenna_pattern="38.901",
                        carrier_frequency=carrier_frequency)

# %% [markdown]
# ## Neural Receiver <a class="anchor" id="Neural-Receiver"></a>

# %% [markdown]
# The next cell defines the Keras layers that implement the neural receiver.
# As in [1] and [2], a neural receiver using residual convolutional layers is implemented. Convolutional layers are leveraged to efficienly process the 2D resource grid, that is fed as an input to the neural receiver.
# Residual (skip) connections are used to avoid gradient vanishing [3].
#
# For convinience, a Keras layer that implements a *residual block* is first defined. The Keras layer that implements the neural receiver is built by stacking such blocks. The following figure shows the architecture of the neural receiver.

# %% [markdown]
# ![Neural RX](data:image/png;base64,...)

# %%
class ResidualBlock(Layer):
    r"""
    This Keras layer implements a convolutional residual block made of two convolutional layers with ReLU activation, layer normalization, and a skip connection.
    The number of convolutional channels of the input must match the number of kernel of the convolutional layers ``num_conv_channel`` for the skip connection to work.

    Input
    ------
    : [batch size, num time samples, num subcarriers, num_conv_channel], tf.float
        Input of the layer

    Output
    -------
    : [batch size, num time samples, num subcarriers, num_conv_channel], tf.float
        Output of the layer
    """

    def build(self, input_shape):

        # Layer normalization is done over the last three dimensions: time, frequency, conv 'channels'
        self._layer_norm_1 = LayerNormalization(axis=(-1, -2, -3))
        self._conv_1 = Conv2D(filters=num_conv_channels,
                              kernel_size=[3,3],
                              padding='same',
                              activation=None)
        # Layer normalization is done over the last three dimensions: time, frequency, conv 'channels'
        self._layer_norm_2 = LayerNormalization(axis=(-1, -2, -3))
        self._conv_2 = Conv2D(filters=num_conv_channels,
                              kernel_size=[3,3],
                              padding='same',
                              activation=None)

    def call(self, inputs):
        z = self._layer_norm_1(inputs)
        z = relu(z)
        z = self._conv_1(z)
        z = self._layer_norm_2(z)
        z = relu(z)
        z = self._conv_2(z) # [batch size, num time samples, num subcarriers, num_channels]
        # Skip connection
        z = z + inputs

        return z

class NeuralReceiver(Layer):
    r"""
    Keras layer implementing a residual convolutional neural receiver.

    This neural receiver is fed with the post-DFT received samples, forming a resource grid of size num_of_symbols x fft_size, and computes LLRs on the transmitted coded bits.
    These LLRs can then be fed to an outer decoder to reconstruct the information bits.

    As the neural receiver is fed with the entire resource grid, including the guard bands and pilots, it also computes LLRs for these resource elements.
    They must be discarded to only keep the LLRs corresponding to the data-carrying resource elements.

    Input
    ------
    y : [batch size, num rx antenna, num ofdm symbols, num subcarriers], tf.complex
        Received post-DFT samples.

    no : [batch size], tf.float32
        Noise variance. At training, a different noise variance value is sampled for each batch example.

    Output
    -------
    : [batch size, num ofdm symbols, num subcarriers, num_bits_per_symbol]
        LLRs on the transmitted bits.
        LLRs computed for resource elements not carrying data (pilots, guard bands...) must be discarded.
    """

    def build(self, input_shape):

        # Input convolution
        self._input_conv = Conv2D(filters=num_conv_channels,
                                  kernel_size=[3,3],
                                  padding='same',
                                  activation=None)
        # Residual blocks
        self._res_block_1 = ResidualBlock()
        self._res_block_2 = ResidualBlock()
        self._res_block_3 = ResidualBlock()
        self._res_block_4 = ResidualBlock()
        # self._res_block_5 = ResidualBlock()
        # self._res_block_6 = ResidualBlock()
        # self._res_block_7 = ResidualBlock()
        # self._res_block_8 = ResidualBlock()
        # self._res_block_9 = ResidualBlock()
        # self._res_block_10 = ResidualBlock()
        # self._res_block_11 = ResidualBlock()
        # self._res_block_12 = ResidualBlock()
        # Output conv
        self._output_conv = Conv2D(filters=num_bits_per_symbol,
                                   kernel_size=[3,3],
                                   padding='same',
                                   activation=None)

    def call(self, inputs):
        y, no = inputs

        # Feeding the noise power in log10 scale helps with the performance
        no = log10(no)

        # Stacking the real and imaginary components of the different antennas along the 'channel' dimension
        y = tf.transpose(y, [0, 2, 3, 1]) # Putting antenna dimension last
        no = insert_dims(no, 3, 1)
        no = tf.tile(no, [1, y.shape[1], y.shape[2], 1])
        # z : [batch size, num ofdm symbols, num subcarriers, 2*num rx antenna + 1]
        z = tf.concat([tf.math.real(y),
                       tf.math.imag(y),
                       no], axis=-1)
        # Input conv
        z = self._input_conv(z)
        # Residual blocks
        z = self._res_block_1(z)
        z = self._res_block_2(z)
        z = self._res_block_3(z)
        z = self._res_block_4(z)
        # z = self._res_block_5(z)
        # z = self._res_block_6(z)
        # z = self._res_block_7(z)
        # z = self._res_block_8(z)
        # z = self._res_block_9(z)
        # z = self._res_block_10(z)
        # z = self._res_block_11(z)
        # z = self._res_block_12(z)
        # Output conv
        z = self._output_conv(z)

        return z

# %% [markdown]
# ## End-to-end System <a class="anchor" id="End-to-end-System"></a>

# %% [markdown]
# The following cell defines the end-to-end system.
#
# Training is done on the bit-metric decoding (BMD) rate which is computed from the transmitted bits and LLRs:
#
# \begin{equation}
# R = 1 - \frac{1}{SNMK} \sum_{s = 0}^{S-1} \sum_{n = 0}^{N-1} \sum_{m = 0}^{M-1} \sum_{k = 0}^{K-1} \texttt{BCE} \left( B_{s,n,m,k}, \texttt{LLR}_{s,n,m,k} \right)
# \end{equation}
#
# where
#
# * $S$ is the batch size
# * $N$ the number of subcarriers
# * $M$ the number of OFDM symbols
# * $K$ the number of bits per symbol
# * $B_{s,n,m,k}$ the $k^{th}$ coded bit transmitted on the resource element $(n,m)$ and for the $s^{th}$ batch example
# * $\texttt{LLR}_{s,n,m,k}$ the LLR (logit) computed by the neural receiver corresponding to the $k^{th}$ coded bit transmitted on the resource element $(n,m)$ and for the $s^{th}$ batch example
# * $\texttt{BCE} \left( \cdot, \cdot \right)$ the binary cross-entropy in log base 2
#
# Because no outer code is required at training, the outer encoder and decoder are not used at training to reduce computational complexity.
#
# The BMD rate is known to be an achievable information rate for BICM systems, which motivates its used as objective function [4].

# %%
## Transmitter
binary_source = BinarySource()
mapper = Mapper("qam", num_bits_per_symbol)
rg_mapper = ResourceGridMapper(resource_grid)

## Channel
cdl = CDL(cdl_model, delay_spread, carrier_frequency,
          ut_antenna, bs_array, "uplink", min_speed=speed)
channel = OFDMChannel(cdl, resource_grid, normalize_channel=True, return_channel=True)

## Receiver
neural_receiver = NeuralReceiver()
rg_demapper = ResourceGridDemapper(resource_grid, stream_manager) # Used to extract data-carrying resource elements

# %% [markdown]
# The following cell performs one forward step through the end-to-end system:

# %%
batch_size = 128
ebno_db = tf.fill([batch_size], 5.0)
no = ebnodb2no(ebno_db, num_bits_per_symbol, coderate)

## Transmitter
# Generate codewords
c = binary_source([batch_size, 1, 1, n])
# print(c.numpy())
print("c shape: ", c.shape)

# Map bits to QAM symbols
x = mapper(c)
# print(x.numpy())
print("x shape: ", x.shape)

# Map the QAM symbols to a resource grid
x_rg = rg_mapper(x)
# print(x_rg.numpy())
print("x_rg shape: ", x_rg.shape)

######################################
## Channel
# A batch of new channel realizations is sampled and applied at every inference
no_ = expand_to_rank(no, tf.rank(x_rg))
y,_ = channel([x_rg, no_])
print("y shape: ", y.shape)

######################################
## Receiver
# The neural receover computes LLRs from the frequency domain received symbols and N0
y = tf.squeeze(y, axis=1)
llr = neural_receiver([y, no])
print("llr shape: ", llr.shape)
# Reshape the input to fit what the resource grid demapper is expected
llr = insert_dims(llr, 2, 1)
# Extract data-carrying resource elements. The other LLRs are discarded
llr = rg_demapper(llr)
llr = tf.reshape(llr, [batch_size, 1, 1, n])
print("Post RG-demapper LLRs: ", llr.shape)
# Out:
# c shape:  (128, 1, 1, 8352)
# x shape:  (128, 1, 1, 1392)
# x_rg shape:  (128, 1, 1, 14, 128)
# y shape:  (128, 1, 2, 14, 128)
# llr shape:  (128, 14, 128, 6)
# Post RG-demapper LLRs:  (128, 1, 1, 8352)

# %% [markdown]
# The BMD rate is computed from the LLRs and transmitted bits as follows:

# %%
bce = tf.nn.sigmoid_cross_entropy_with_logits(c, llr)
bce = tf.reduce_mean(bce)
rate = tf.constant(1.0, tf.float32) - bce/tf.math.log(2.)
print(f"Rate: {rate:.2E} bit")
# Out:
# Rate: -2.98E-01 bit

# %% [markdown]
# The rate is very poor (negative values means 0 bit) as the neural receiver is not trained.

# %% [markdown]
# ## End-to-end System as a Keras Model <a class="anchor" id="End-to-end-System-as-a-Keras-Model"></a>

# %% [markdown]
# The following Keras *Model* implements the three considered end-to-end systems (perfect CSI baseline, LS estimation baseline, and neural receiver).
#
# When instantiating the Keras model, the parameter ``system`` is used to specify the system to setup, and the parameter ``training`` is used to specified if the system is instantiated to be trained or to be evaluated. The ``training`` parameter is only relevant when the neural receiver is used.
#
# At each call of this model:
#
# * A batch of codewords is randomly sampled, modulated, and mapped to resource grids to form the channel inputs
# * A batch of channel realizations is randomly sampled and applied to the channel inputs
# * The receiver is executed on the post-DFT received samples to compute LLRs on the coded bits.
#   Which receiver is executed (baseline with perfect CSI knowledge, baseline with LS estimation, or neural receiver) depends on the specified ``system`` parameter.
# * If not training, the outer decoder is applied to reconstruct the information bits
# * If training, the BMD rate is estimated over the batch from the LLRs and the transmitted bits

# %%
class E2ESystem(Model):
    r"""
    Keras model that implements the end-to-end systems.

    As the three considered end-to-end systems (perfect CSI baseline, LS estimation baseline, and neural receiver) share most of
    the link components (transmitter, channel model, outer code...), they are implemented using the same Keras model.

    When instantiating the Keras model, the parameter ``system`` is used to specify the system to setup,
    and the parameter ``training`` is used to specified if the system is instantiated to be trained or to be evaluated.
    The ``training`` parameter is only relevant when the neural

    At each call of this model:
    * A batch of codewords is randomly sampled, modulated, and mapped to resource grids to form the channel inputs
    * A batch of channel realizations is randomly sampled and applied to the channel inputs
    * The receiver is executed on the post-DFT received samples to compute LLRs on the coded bits.
      Which receiver is executed (baseline with perfect CSI knowledge, baseline with LS estimation, or neural receiver) depends
      on the specified ``system`` parameter.
    * If not training, the outer decoder is applied to reconstruct the information bits
    * If training, the BMD rate is estimated over the batch from the LLRs and the transmitted bits

    Parameters
    -----------
    system : str
        Specify the receiver to use. Should be one of 'baseline-perfect-csi', 'baseline-ls-estimation' or 'neural-receiverstandard' or 'neural-receiver-trained'

    training : bool
        Set to `True` if the system is instantiated to be trained. Set to `False` otherwise. Defaults to `False`.
        If the system is instantiated to be trained, the outer encoder and decoder are not instantiated as they are not required for training.
        This significantly reduces the computational complexity of training.
        If training, the bit-metric decoding (BMD) rate is computed from the transmitted bits and the LLRs. The BMD rate is known to be
        an achievable information rate for BICM systems, and therefore training of the neural receiver aims at maximizing this rate.

    Input
    ------
    batch_size : int
        Batch size

    no : scalar or [batch_size], tf.float
        Noise variance.
        At training, a different noise variance should be sampled for each batch example.

    Output
    -------
    If ``training`` is set to `True`, then the output is a single scalar, which is an estimation of the BMD rate computed over the batch. It
    should be used as objective for training.
    If ``training`` is set to `False`, the transmitted information bits and their reconstruction on the receiver side are returned to
    compute the block/bit error rate.
    """

    def __init__(self, system, training=False):
        super().__init__()
        self._system = system
        self._training = training

        ######################################
        ## Transmitter
        self._binary_source = BinarySource()
        # To reduce the computational complexity of training, the outer code is not used when training,
        # as it is not required
        if not training:
            self._encoder = LDPC5GEncoder(k, n)

        if system == 'neural-receiver-trained':
            # Trainable constellation
            constellation = Constellation("qam", num_bits_per_symbol, trainable=True)
            self.constellation = constellation
            self._mapper = Mapper(constellation=constellation)
            self._rg_mapper = ResourceGridMapper(resource_grid)
            
        else:
            self._mapper = Mapper("qam", num_bits_per_symbol)
            self._rg_mapper = ResourceGridMapper(resource_grid)

        ######################################
        ## Channel
        # A 3GPP CDL channel model is used
        cdl = CDL(cdl_model, delay_spread, carrier_frequency,
                  ut_antenna, bs_array, "uplink", min_speed=speed)
        self._channel = OFDMChannel(cdl, resource_grid, normalize_channel=True, return_channel=True)

        ######################################
        ## Receiver
        # Three options for the receiver depending on the value of `system`
        if "baseline" in system:
            
            if system == 'baseline-perfect-csi': # Perfect CSI
                self._removed_null_subc = RemoveNulledSubcarriers(resource_grid)
                
            elif system == 'baseline-ls-estimation': # LS estimation
                self._ls_est = LSChannelEstimator(resource_grid, interpolation_type="nn")
            # Components required by both baselines
            self._lmmse_equ = LMMSEEqualizer(resource_grid, stream_manager, )
            self._demapper = Demapper("app", "qam", num_bits_per_symbol)
            
        elif "neural-receiver" in system: # Neural receiver
            self._neural_receiver = NeuralReceiver()
            self._rg_demapper = ResourceGridDemapper(resource_grid, stream_manager) # Used to extract data-carrying resource elements
            
        # To reduce the computational complexity of training, the outer code is not used when training,
        # as it is not required
        if not training:
            self._decoder = LDPC5GDecoder(self._encoder, hard_out=True)

    @tf.function
    def call(self, batch_size, ebno_db):

        # If `ebno_db` is a scalar, a tensor with shape [batch size] is created as it is what is expected by some layers
        if len(ebno_db.shape) == 0:
            ebno_db = tf.fill([batch_size], ebno_db)

        ######################################
        ## Transmitter
        no = ebnodb2no(ebno_db, num_bits_per_symbol, coderate)
        # Outer coding is only performed if not training
        if self._training:
            c = self._binary_source([batch_size, 1, 1, n])
        else:
            b = self._binary_source([batch_size, 1, 1, k])
            c = self._encoder(b)
        # Modulation
        x = self._mapper(c)
        x_rg = self._rg_mapper(x)

        ######################################
        ## Channel
        # A batch of new channel realizations is sampled and applied at every inference
        no_ = expand_to_rank(no, tf.rank(x_rg))
        y,h = self._channel([x_rg, no_])

        ######################################
        ## Receiver
        # Three options for the receiver depending on the value of ``system``
        if "baseline" in self._system:
            
            if self._system == 'baseline-perfect-csi':
                h_hat = self._removed_null_subc(h) # Extract non-null subcarriers
                err_var = 0.0 # No channel estimation error when perfect CSI knowledge is assumed
                
            elif self._system == 'baseline-ls-estimation':
                h_hat, err_var = self._ls_est([y, no]) # LS channel estimation with nearest-neighbor
            x_hat, no_eff = self._lmmse_equ([y, h_hat, err_var, no]) # LMMSE equalization
            no_eff_= expand_to_rank(no_eff, tf.rank(x_hat))
            llr = self._demapper([x_hat, no_eff_]) # Demapping
            
        elif "neural-receiver" in self._system:
            # The neural receover computes LLRs from the frequency domain received symbols and N0
            y = tf.squeeze(y, axis=1)
            llr = self._neural_receiver([y, no])
            llr = insert_dims(llr, 2, 1) # Reshape the input to fit what the resource grid demapper is expected
            llr = self._rg_demapper(llr) # Extract data-carrying resource elements. The other LLrs are discarded
            llr = tf.reshape(llr, [batch_size, 1, 1, n]) # Reshape the LLRs to fit what the outer decoder is expected

        # Outer coding is not needed if the information rate is returned
        if self._training:
            # Compute and return BMD rate (in bit), which is known to be an achievable
            # information rate for BICM systems.
            # Training aims at maximizing the BMD rate
            bce = tf.nn.sigmoid_cross_entropy_with_logits(c, llr)
            bce = tf.reduce_mean(bce)
            rate = tf.constant(1.0, tf.float32) - bce/tf.math.log(2.)
            return rate
        else:
            # Outer decoding
            b_hat = self._decoder(llr)
            return b,b_hat # Ground truth and reconstructed information bits returned for BER/BLER computation

# %% [markdown]
# ## Evaluation of the Baselines <a class="anchor" id="Evaluation-of-the-Baselines"></a>

# %% [markdown]
# We evaluate the BERs achieved by the baselines in the next cell.
#
# **Note:** Evaluation of the two systems can take a while. Therefore, we provide pre-computed results at the end of this notebook.

# %%
# Range of SNRs over which the systems are evaluated
ebno_dbs = np.arange(ebno_db_min, # Min SNR for evaluation
                     ebno_db_max, # Max SNR for evaluation
                     0.5) # Step

# %%
# Dictionnary storing the evaluation results
BLER = {}

model = E2ESystem('baseline-perfect-csi')
_,bler = sim_ber(model, ebno_dbs, batch_size=128, num_target_block_errors=50, max_mc_iter=1000)
BLER['baseline-perfect-csi'] = bler.numpy()

model = E2ESystem('baseline-ls-estimation')
_,bler = sim_ber(model, ebno_dbs, batch_size=128, num_target_block_errors=50, max_mc_iter=1000)
BLER['baseline-ls-estimation'] = bler.numpy()

with open(results_filename, 'wb') as f:
    pickle.dump((ebno_dbs, BLER), f)
# Out:
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#      -5.0 | 3.2193e-01 | 1.0000e+00 |      172081 |      534528 |          128 |         128 |         5.0 |reached target block errors
#      -4.5 | 3.1092e-01 | 1.0000e+00 |      166194 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -4.0 | 3.0283e-01 | 1.0000e+00 |      161872 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -3.5 | 2.9256e-01 | 1.0000e+00 |      156383 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -3.0 | 2.8026e-01 | 1.0000e+00 |      149809 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -2.5 | 2.6975e-01 | 1.0000e+00 |      144191 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -2.0 | 2.5869e-01 | 1.0000e+00 |      138277 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -1.5 | 2.4543e-01 | 1.0000e+00 |      131191 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -1.0 | 2.3405e-01 | 1.0000e+00 |      125105 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -0.5 | 2.2163e-01 | 1.0000e+00 |      118467 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       0.0 | 2.0627e-01 | 1.0000e+00 |      110257 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       0.5 | 1.9294e-01 | 1.0000e+00 |      103133 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.0 | 1.7521e-01 | 1.0000e+00 |       93657 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.5 | 1.5522e-01 | 1.0000e+00 |       82970 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.0 | 1.2443e-01 | 1.0000e+00 |       66509 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.5 | 5.4964e-02 | 9.9219e-01 |       29380 |      534528 |          127 |         128 |         0.3 |reached target block errors
#       3.0 | 2.8689e-03 | 2.7734e-01 |        3067 |     1069056 |           71 |         256 |         0.5 |reached target block errors
#       3.5 | 2.7510e-04 | 9.0843e-03 |        6323 |    22984704 |           50 |        5504 |        11.1 |reached target block errors
#       4.0 | 9.2345e-05 | 1.7323e-03 |       11353 |   122941440 |           51 |       29440 |        59.4 |reached target block errors
#       4.5 | 2.7799e-05 | 4.7348e-04 |       12259 |   440985600 |           50 |      105600 |       212.9 |reached target block errors
#       5.0 | 1.3236e-05 | 2.2656e-04 |        7075 |   534528000 |           29 |      128000 |       258.0 |reached max iter
#       5.5 | 3.8782e-06 | 7.0312e-05 |        2073 |   534528000 |            9 |      128000 |       258.0 |reached max iter
#       6.0 | 1.0888e-06 | 3.9063e-05 |         582 |   534528000 |            5 |      128000 |       257.9 |reached max iter
#       6.5 | 0.0000e+00 | 0.0000e+00 |           0 |   534528000 |            0 |      128000 |       258.0 |reached max iter
#
# Simulation stopped as no error occurred @ EbNo = 6.5 dB.
#
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#      -5.0 | 3.9697e-01 | 1.0000e+00 |      212193 |      534528 |          128 |         128 |         5.2 |reached target block errors
#      -4.5 | 3.8781e-01 | 1.0000e+00 |      207295 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -4.0 | 3.8005e-01 | 1.0000e+00 |      203150 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -3.5 | 3.6781e-01 | 1.0000e+00 |      196607 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -3.0 | 3.5942e-01 | 1.0000e+00 |      192120 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -2.5 | 3.4924e-01 | 1.0000e+00 |      186676 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -2.0 | 3.3902e-01 | 1.0000e+00 |      181216 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -1.5 | 3.2765e-01 | 1.0000e+00 |      175140 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -1.0 | 3.1545e-01 | 1.0000e+00 |      168615 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -0.5 | 3.0210e-01 | 1.0000e+00 |      161479 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       0.0 | 2.9097e-01 | 1.0000e+00 |      155530 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       0.5 | 2.7741e-01 | 1.0000e+00 |      148281 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.0 | 2.6452e-01 | 1.0000e+00 |      141392 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.5 | 2.5057e-01 | 1.0000e+00 |      133937 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.0 | 2.3724e-01 | 1.0000e+00 |      126812 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.5 | 2.2284e-01 | 1.0000e+00 |      119113 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       3.0 | 2.0845e-01 | 1.0000e+00 |      111420 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       3.5 | 1.9183e-01 | 1.0000e+00 |      102540 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       4.0 | 1.7525e-01 | 1.0000e+00 |       93678 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       4.5 | 1.5733e-01 | 1.0000e+00 |       84096 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       5.0 | 1.2946e-01 | 1.0000e+00 |       69198 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       5.5 | 6.3763e-02 | 9.9219e-01 |       34083 |      534528 |          127 |         128 |         0.3 |reached target block errors
#       6.0 | 6.8752e-03 | 4.2188e-01 |        3675 |      534528 |           54 |         128 |         0.3 |reached target block errors
#       6.5 | 3.7494e-04 | 1.7253e-02 |        4810 |    12828672 |           53 |        3072 |         6.2 |reached target block errors
#       7.0 | 1.1384e-04 | 2.2195e-03 |       10710 |    94076928 |           50 |       22528 |        45.6 |reached target block errors
#       7.5 | 4.1281e-05 | 6.7582e-04 |       12754 |   308957184 |           50 |       73984 |       149.7 |reached target block errors
#       8.0 | 2.0315e-05 | 3.4375e-04 |       10859 |   534528000 |           44 |      128000 |       259.1 |reached max iter
#       8.5 | 1.3816e-05 | 1.7187e-04 |        7385 |   534528000 |           22 |      128000 |       259.1 |reached max iter
#       9.0 | 4.0989e-06 | 6.2500e-05 |        2191 |   534528000 |            8 |      128000 |       259.0 |reached max iter
#       9.5 | 1.5939e-06 | 4.6875e-05 |         852 |   534528000 |            6 |      128000 |       259.0 |reached max iter

# %% [markdown]
# ## Training the Neural Receiver <a class="anchor" id="Training-the-Neural-Receiver"></a>

# %% [markdown]
# **Note:** For an introduction to the implementation of differentiable communication systems and their optimization through SGD and backpropagation with Sionna, please refer to [the Part 2 of the Sionna tutorial for Beginners](https://nvlabs.github.io/sionna/examples/Sionna_tutorial_part2.html).

# %% [markdown]
# Training consists in looping over SGD steps. The next cell implements a training loop.
#
# At each iteration:
# - A batch of SNRs $E_b/N_0$ is sampled
# - A forward pass through the end-to-end system is performed within a gradient tape
# - The gradients are computed using the gradient tape, and applied using the Adam optimizer
# - The achieved BMD rate is periodically shown
#
# After training, the weights of the models are saved in a file
#
# **Note:** Training can take a while. Therefore, [we have made pre-trained weights available](https://drive.google.com/drive/folders/1h2m_AD-t3qtWYifowChmWEY0DBbIj84Q?usp=sharing). Do not execute the next cell if you don't want to train the model from scratch.

# %%
# The end-to-end system equipped with the neural receiver is instantiated for training.
# When called, it therefore returns the estimated BMD rate
model = E2ESystem('neural-receiver-standard', training=True)

optimizer = tf.keras.optimizers.Adam()

for i in range(num_training_iterations):
    # Sampling a batch of SNRs
    ebno_db = tf.random.uniform(shape=[], minval=ebno_db_min, maxval=ebno_db_max)
    
    # Forward pass
    with tf.GradientTape() as tape:
        rate = model(training_batch_size, ebno_db)
        # Tensorflow optimizers only know how to minimize loss function.
        # Therefore, a loss function is defined as the additive inverse of the BMD rate
        loss = -rate

    # Perform one step of stochastic gradient descent (SGD)
    # Computing and applying gradients
    weights = model.trainable_weights
    grads = tape.gradient(loss, weights)
    optimizer.apply_gradients(zip(grads, weights))
    # Periodically printing the progress
    if i % 100 == 0:
        print('Iteration {}/{}  Rate: {:.4f} bit'.format(i, num_training_iterations, rate.numpy()))

# Save the weights in a file
weights = model.get_weights()
with open(model_weights_path_standard, 'wb') as f:
    pickle.dump(weights, f)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1706775290.515433  134541 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Iteration 0/50000  Rate: -0.5748 bit
# Iteration 100/50000  Rate: -0.0073 bit
# Iteration 200/50000  Rate: 0.0389 bit
# Iteration 300/50000  Rate: 0.0635 bit
# Iteration 400/50000  Rate: 0.0409 bit
# Iteration 500/50000  Rate: 0.0211 bit
# Iteration 600/50000  Rate: -0.0308 bit
# Iteration 700/50000  Rate: 0.1137 bit
# Iteration 800/50000  Rate: 0.0582 bit
# Iteration 900/50000  Rate: 0.1353 bit
# Iteration 1000/50000  Rate: 0.0262 bit
# Iteration 1100/50000  Rate: 0.1247 bit
# Iteration 1200/50000  Rate: 0.1528 bit
# Iteration 1300/50000  Rate: 0.0337 bit
# Iteration 1400/50000  Rate: 0.1612 bit
# Iteration 1500/50000  Rate: 0.1976 bit
# Iteration 1600/50000  Rate: 0.1267 bit
# Iteration 1700/50000  Rate: 0.0676 bit
# Iteration 1800/50000  Rate: 0.4406 bit
# Iteration 1900/50000  Rate: 0.2341 bit
# Iteration 2000/50000  Rate: 0.3741 bit
# Iteration 2100/50000  Rate: 0.4306 bit
# Iteration 2200/50000  Rate: 0.4399 bit
# Iteration 2300/50000  Rate: 0.4162 bit
# Iteration 2400/50000  Rate: 0.1782 bit
# Iteration 2500/50000  Rate: 0.2113 bit
# Iteration 2600/50000  Rate: 0.2283 bit
# Iteration 2700/50000  Rate: 0.1446 bit
# Iteration 2800/50000  Rate: 0.6224 bit
# Iteration 2900/50000  Rate: 0.1995 bit
# Iteration 3000/50000  Rate: 0.5539 bit
# Iteration 3100/50000  Rate: 0.4546 bit
# Iteration 3200/50000  Rate: 0.7188 bit
# Iteration 3300/50000  Rate: 0.5280 bit
# Iteration 3400/50000  Rate: 0.5497 bit
# Iteration 3500/50000  Rate: 0.3680 bit
# Iteration 3600/50000  Rate: 0.2089 bit
# Iteration 3700/50000  Rate: 0.7362 bit
# Iteration 3800/50000  Rate: 0.2404 bit
# Iteration 3900/50000  Rate: 0.2396 bit
# Iteration 4000/50000  Rate: 0.6129 bit
# Iteration 4100/50000  Rate: 0.4583 bit
# Iteration 4200/50000  Rate: 0.6157 bit
# Iteration 4300/50000  Rate: 0.4689 bit
# Iteration 4400/50000  Rate: 0.4054 bit
# Iteration 4500/50000  Rate: 0.2409 bit
# Iteration 4600/50000  Rate: 0.7500 bit
# Iteration 4700/50000  Rate: 0.3414 bit
# Iteration 4800/50000  Rate: 0.7239 bit
# Iteration 4900/50000  Rate: 0.6047 bit
# Iteration 5000/50000  Rate: 0.7883 bit
# Iteration 5100/50000  Rate: 0.6193 bit
# Iteration 5200/50000  Rate: 0.2578 bit
# Iteration 5300/50000  Rate: 0.6600 bit
# Iteration 5400/50000  Rate: 0.5092 bit
# Iteration 5500/50000  Rate: 0.6077 bit
# Iteration 5600/50000  Rate: 0.4772 bit
# Iteration 5700/50000  Rate: 0.6593 bit
# Iteration 5800/50000  Rate: 0.7035 bit
# Iteration 5900/50000  Rate: 0.5303 bit
# Iteration 6000/50000  Rate: 0.7713 bit
# Iteration 6100/50000  Rate: 0.6333 bit
# Iteration 6200/50000  Rate: 0.3691 bit
# Iteration 6300/50000  Rate: 0.5043 bit
# Iteration 6400/50000  Rate: 0.3633 bit
# Iteration 6500/50000  Rate: 0.4138 bit
# Iteration 6600/50000  Rate: 0.3337 bit
# Iteration 6700/50000  Rate: 0.3219 bit
# Iteration 6800/50000  Rate: 0.2235 bit
# Iteration 6900/50000  Rate: 0.4033 bit
# Iteration 7000/50000  Rate: 0.4535 bit
# Iteration 7100/50000  Rate: 0.2108 bit
# Iteration 7200/50000  Rate: 0.2146 bit
# Iteration 7300/50000  Rate: 0.7284 bit
# Iteration 7400/50000  Rate: 0.3855 bit
# Iteration 7500/50000  Rate: 0.4682 bit
# Iteration 7600/50000  Rate: 0.6722 bit
# Iteration 7700/50000  Rate: 0.2899 bit
# Iteration 7800/50000  Rate: 0.3664 bit
# Iteration 7900/50000  Rate: 0.6553 bit
# Iteration 8000/50000  Rate: 0.2261 bit
# Iteration 8100/50000  Rate: 0.4502 bit
# Iteration 8200/50000  Rate: 0.4270 bit
# Iteration 8300/50000  Rate: 0.5339 bit
# Iteration 8400/50000  Rate: 0.5297 bit
# Iteration 8500/50000  Rate: 0.6606 bit
# Iteration 8600/50000  Rate: 0.8143 bit
# Iteration 8700/50000  Rate: 0.5196 bit
# Iteration 8800/50000  Rate: 0.6539 bit
# Iteration 8900/50000  Rate: 0.2634 bit
# Iteration 9000/50000  Rate: 0.7472 bit
# Iteration 9100/50000  Rate: 0.4215 bit
# Iteration 9200/50000  Rate: 0.2727 bit
# Iteration 9300/50000  Rate: 0.5519 bit
# Iteration 9400/50000  Rate: 0.7618 bit
# Iteration 9500/50000  Rate: 0.4218 bit
# Iteration 9600/50000  Rate: 0.3763 bit
# Iteration 9700/50000  Rate: 0.7880 bit
# Iteration 9800/50000  Rate: 0.4123 bit
# Iteration 9900/50000  Rate: 0.6923 bit
# Iteration 10000/50000  Rate: 0.2748 bit
# Iteration 10100/50000  Rate: 0.2353 bit
# Iteration 10200/50000  Rate: 0.6219 bit
# Iteration 10300/50000  Rate: 0.2151 bit
# Iteration 10400/50000  Rate: 0.5988 bit
# Iteration 10500/50000  Rate: 0.3943 bit
# Iteration 10600/50000  Rate: 0.5229 bit
# Iteration 10700/50000  Rate: 0.7853 bit
# Iteration 10800/50000  Rate: 0.7866 bit
# Iteration 10900/50000  Rate: 0.8213 bit
# Iteration 11000/50000  Rate: 0.5670 bit
# Iteration 11100/50000  Rate: 0.7855 bit
# Iteration 11200/50000  Rate: 0.1712 bit
# Iteration 11300/50000  Rate: 0.4560 bit
# Iteration 11400/50000  Rate: 0.2969 bit
# Iteration 11500/50000  Rate: 0.3701 bit
# Iteration 11600/50000  Rate: 0.3277 bit
# Iteration 11700/50000  Rate: 0.4261 bit
# Iteration 11800/50000  Rate: 0.7773 bit
# Iteration 11900/50000  Rate: 0.8171 bit
# Iteration 12000/50000  Rate: 0.5466 bit
# Iteration 12100/50000  Rate: 0.3579 bit
# Iteration 12200/50000  Rate: 0.8237 bit
# Iteration 12300/50000  Rate: 0.6352 bit
# Iteration 12400/50000  Rate: 0.5511 bit
# Iteration 12500/50000  Rate: 0.5643 bit
# Iteration 12600/50000  Rate: 0.7664 bit
# Iteration 12700/50000  Rate: 0.6151 bit
# Iteration 12800/50000  Rate: 0.6399 bit
# Iteration 12900/50000  Rate: 0.4542 bit
# Iteration 13000/50000  Rate: 0.2044 bit
# Iteration 13100/50000  Rate: 0.3270 bit
# Iteration 13200/50000  Rate: 0.7137 bit
# Iteration 13300/50000  Rate: 0.3920 bit
# Iteration 13400/50000  Rate: 0.7005 bit
# Iteration 13500/50000  Rate: 0.6215 bit
# Iteration 13600/50000  Rate: 0.2142 bit
# Iteration 13700/50000  Rate: 0.7867 bit
# Iteration 13800/50000  Rate: 0.3673 bit
# Iteration 13900/50000  Rate: 0.8045 bit
# Iteration 14000/50000  Rate: 0.8311 bit
# Iteration 14100/50000  Rate: 0.5277 bit
# Iteration 14200/50000  Rate: 0.3881 bit
# Iteration 14300/50000  Rate: 0.3019 bit
# Iteration 14400/50000  Rate: 0.2142 bit
# Iteration 14500/50000  Rate: 0.2538 bit
# Iteration 14600/50000  Rate: 0.2412 bit
# Iteration 14700/50000  Rate: 0.8443 bit
# Iteration 14800/50000  Rate: 0.5811 bit
# Iteration 14900/50000  Rate: 0.4716 bit
# Iteration 15000/50000  Rate: 0.5153 bit
# Iteration 15100/50000  Rate: 0.2162 bit
# Iteration 15200/50000  Rate: 0.2277 bit
# Iteration 15300/50000  Rate: 0.5320 bit
# Iteration 15400/50000  Rate: 0.2962 bit
# Iteration 15500/50000  Rate: 0.4370 bit
# Iteration 15600/50000  Rate: 0.2069 bit
# Iteration 15700/50000  Rate: 0.1995 bit
# Iteration 15800/50000  Rate: 0.5057 bit
# Iteration 15900/50000  Rate: 0.6009 bit
# Iteration 16000/50000  Rate: 0.5546 bit
# Iteration 16100/50000  Rate: 0.7241 bit
# Iteration 16200/50000  Rate: 0.2046 bit
# Iteration 16300/50000  Rate: 0.3246 bit
# Iteration 16400/50000  Rate: 0.8213 bit
# Iteration 16500/50000  Rate: 0.5348 bit
# Iteration 16600/50000  Rate: 0.8329 bit
# Iteration 16700/50000  Rate: 0.3202 bit
# Iteration 16800/50000  Rate: 0.6493 bit
# Iteration 16900/50000  Rate: 0.5559 bit
# Iteration 17000/50000  Rate: 0.2574 bit
# Iteration 17100/50000  Rate: 0.2069 bit
# Iteration 17200/50000  Rate: 0.3721 bit
# Iteration 17300/50000  Rate: 0.8328 bit
# Iteration 17400/50000  Rate: 0.7805 bit
# Iteration 17500/50000  Rate: 0.5411 bit
# Iteration 17600/50000  Rate: 0.8358 bit
# Iteration 17700/50000  Rate: 0.2419 bit
# Iteration 17800/50000  Rate: 0.6218 bit
# Iteration 17900/50000  Rate: 0.3699 bit
# Iteration 18000/50000  Rate: 0.3851 bit
# Iteration 18100/50000  Rate: 0.5666 bit
# Iteration 18200/50000  Rate: 0.6846 bit
# Iteration 18300/50000  Rate: 0.6642 bit
# Iteration 18400/50000  Rate: 0.2791 bit
# Iteration 18500/50000  Rate: 0.2634 bit
# Iteration 18600/50000  Rate: 0.4397 bit
# Iteration 18700/50000  Rate: 0.4383 bit
# Iteration 18800/50000  Rate: 0.4960 bit
# Iteration 18900/50000  Rate: 0.4991 bit
# Iteration 19000/50000  Rate: 0.4082 bit
# Iteration 19100/50000  Rate: 0.6219 bit
# Iteration 19200/50000  Rate: 0.3326 bit
# Iteration 19300/50000  Rate: 0.7276 bit
# Iteration 19400/50000  Rate: 0.7803 bit
# Iteration 19500/50000  Rate: 0.3946 bit
# Iteration 19600/50000  Rate: 0.3078 bit
# Iteration 19700/50000  Rate: 0.2871 bit
# Iteration 19800/50000  Rate: 0.5572 bit
# Iteration 19900/50000  Rate: 0.2620 bit
# Iteration 20000/50000  Rate: 0.4769 bit
# Iteration 20100/50000  Rate: 0.3395 bit
# Iteration 20200/50000  Rate: 0.7382 bit
# Iteration 20300/50000  Rate: 0.6079 bit
# Iteration 20400/50000  Rate: 0.5025 bit
# Iteration 20500/50000  Rate: 0.6784 bit
# Iteration 20600/50000  Rate: 0.2446 bit
# Iteration 20700/50000  Rate: 0.3959 bit
# Iteration 20800/50000  Rate: 0.7980 bit
# Iteration 20900/50000  Rate: 0.5447 bit
# Iteration 21000/50000  Rate: 0.3313 bit
# Iteration 21100/50000  Rate: 0.7708 bit
# Iteration 21200/50000  Rate: 0.6082 bit
# Iteration 21300/50000  Rate: 0.4906 bit
# Iteration 21400/50000  Rate: 0.7581 bit
# Iteration 21500/50000  Rate: 0.6619 bit
# Iteration 21600/50000  Rate: 0.6751 bit
# Iteration 21700/50000  Rate: 0.7519 bit
# Iteration 21800/50000  Rate: 0.3181 bit
# Iteration 21900/50000  Rate: 0.5555 bit
# Iteration 22000/50000  Rate: 0.2211 bit
# Iteration 22100/50000  Rate: 0.7998 bit
# Iteration 22200/50000  Rate: 0.6302 bit
# Iteration 22300/50000  Rate: 0.4056 bit
# Iteration 22400/50000  Rate: 0.4890 bit
# Iteration 22500/50000  Rate: 0.3502 bit
# Iteration 22600/50000  Rate: 0.3550 bit
# Iteration 22700/50000  Rate: 0.7067 bit
# Iteration 22800/50000  Rate: 0.3656 bit
# Iteration 22900/50000  Rate: 0.2412 bit
# Iteration 23000/50000  Rate: 0.4921 bit
# Iteration 23100/50000  Rate: 0.6686 bit
# Iteration 23200/50000  Rate: 0.2144 bit
# Iteration 23300/50000  Rate: 0.6004 bit
# Iteration 23400/50000  Rate: 0.3610 bit
# Iteration 23500/50000  Rate: 0.2406 bit
# Iteration 23600/50000  Rate: 0.7796 bit
# Iteration 23700/50000  Rate: 0.3503 bit
# Iteration 23800/50000  Rate: 0.7850 bit
# Iteration 23900/50000  Rate: 0.5212 bit
# Iteration 24000/50000  Rate: 0.6871 bit
# Iteration 24100/50000  Rate: 0.2543 bit
# Iteration 24200/50000  Rate: 0.7563 bit
# Iteration 24300/50000  Rate: 0.6483 bit
# Iteration 24400/50000  Rate: 0.3753 bit
# Iteration 24500/50000  Rate: 0.6669 bit
# Iteration 24600/50000  Rate: 0.7595 bit
# Iteration 24700/50000  Rate: 0.8552 bit
# Iteration 24800/50000  Rate: 0.8502 bit
# Iteration 24900/50000  Rate: 0.6288 bit
# Iteration 25000/50000  Rate: 0.4704 bit
# Iteration 25100/50000  Rate: 0.2555 bit
# Iteration 25200/50000  Rate: 0.5458 bit
# Iteration 25300/50000  Rate: 0.2183 bit
# Iteration 25400/50000  Rate: 0.8677 bit
# Iteration 25500/50000  Rate: 0.5093 bit
# Iteration 25600/50000  Rate: 0.5074 bit
# Iteration 25700/50000  Rate: 0.2393 bit
# Iteration 25800/50000  Rate: 0.3459 bit
# Iteration 25900/50000  Rate: 0.7888 bit
# Iteration 26000/50000  Rate: 0.2302 bit
# Iteration 26100/50000  Rate: 0.4818 bit
# Iteration 26200/50000  Rate: 0.4030 bit
# Iteration 26300/50000  Rate: 0.2299 bit
# Iteration 26400/50000  Rate: 0.7520 bit
# Iteration 26500/50000  Rate: 0.4408 bit
# Iteration 26600/50000  Rate: 0.4270 bit
# Iteration 26700/50000  Rate: 0.3836 bit
# Iteration 26800/50000  Rate: 0.6148 bit
# Iteration 26900/50000  Rate: 0.6744 bit
# Iteration 27000/50000  Rate: 0.3606 bit
# Iteration 27100/50000  Rate: 0.4476 bit
# Iteration 27200/50000  Rate: 0.8462 bit
# Iteration 27300/50000  Rate: 0.5474 bit
# Iteration 27400/50000  Rate: 0.2784 bit
# Iteration 27500/50000  Rate: 0.7939 bit
# Iteration 27600/50000  Rate: 0.3185 bit
# Iteration 27700/50000  Rate: 0.4779 bit
# Iteration 27800/50000  Rate: 0.4600 bit
# Iteration 27900/50000  Rate: 0.4170 bit
# Iteration 28000/50000  Rate: 0.4899 bit
# Iteration 28100/50000  Rate: 0.5474 bit
# Iteration 28200/50000  Rate: 0.4701 bit
# Iteration 28300/50000  Rate: 0.4801 bit
# Iteration 28400/50000  Rate: 0.6914 bit
# Iteration 28500/50000  Rate: 0.8397 bit
# Iteration 28600/50000  Rate: 0.7795 bit
# Iteration 28700/50000  Rate: 0.7021 bit
# Iteration 28800/50000  Rate: 0.6117 bit
# Iteration 28900/50000  Rate: 0.2719 bit
# Iteration 29000/50000  Rate: 0.6796 bit
# Iteration 29100/50000  Rate: 0.5228 bit
# Iteration 29200/50000  Rate: 0.6538 bit
# Iteration 29300/50000  Rate: 0.2251 bit
# Iteration 29400/50000  Rate: 0.3682 bit
# Iteration 29500/50000  Rate: 0.4551 bit
# Iteration 29600/50000  Rate: 0.7761 bit
# Iteration 29700/50000  Rate: 0.7535 bit
# Iteration 29800/50000  Rate: 0.3065 bit
# Iteration 29900/50000  Rate: 0.3355 bit
# Iteration 30000/50000  Rate: 0.3805 bit
# Iteration 30100/50000  Rate: 0.5464 bit
# Iteration 30200/50000  Rate: 0.4208 bit
# Iteration 30300/50000  Rate: 0.3403 bit
# Iteration 30400/50000  Rate: 0.3673 bit
# Iteration 30500/50000  Rate: 0.2527 bit
# Iteration 30600/50000  Rate: 0.4193 bit
# Iteration 30700/50000  Rate: 0.6546 bit
# Iteration 30800/50000  Rate: 0.7599 bit
# Iteration 30900/50000  Rate: 0.5862 bit
# Iteration 31000/50000  Rate: 0.8354 bit
# Iteration 31100/50000  Rate: 0.8029 bit
# Iteration 31200/50000  Rate: 0.4989 bit
# Iteration 31300/50000  Rate: 0.8334 bit
# Iteration 31400/50000  Rate: 0.8452 bit
# Iteration 31500/50000  Rate: 0.8601 bit
# Iteration 31600/50000  Rate: 0.4417 bit
# Iteration 31700/50000  Rate: 0.5843 bit
# Iteration 31800/50000  Rate: 0.8073 bit
# Iteration 31900/50000  Rate: 0.4768 bit
# Iteration 32000/50000  Rate: 0.6351 bit
# Iteration 32100/50000  Rate: 0.7697 bit
# Iteration 32200/50000  Rate: 0.5003 bit
# Iteration 32300/50000  Rate: 0.7032 bit
# Iteration 32400/50000  Rate: 0.5498 bit
# Iteration 32500/50000  Rate: 0.5833 bit
# Iteration 32600/50000  Rate: 0.5531 bit
# Iteration 32700/50000  Rate: 0.7751 bit
# Iteration 32800/50000  Rate: 0.3405 bit
# Iteration 32900/50000  Rate: 0.4304 bit
# Iteration 33000/50000  Rate: 0.6889 bit
# Iteration 33100/50000  Rate: 0.7846 bit
# Iteration 33200/50000  Rate: 0.5152 bit
# Iteration 33300/50000  Rate: 0.3589 bit
# Iteration 33400/50000  Rate: 0.2909 bit
# Iteration 33500/50000  Rate: 0.3147 bit
# Iteration 33600/50000  Rate: 0.8541 bit
# Iteration 33700/50000  Rate: 0.4889 bit
# Iteration 33800/50000  Rate: 0.7096 bit
# Iteration 33900/50000  Rate: 0.3672 bit
# Iteration 34000/50000  Rate: 0.8450 bit
# Iteration 34100/50000  Rate: 0.2147 bit
# Iteration 34200/50000  Rate: 0.8249 bit
# Iteration 34300/50000  Rate: 0.8474 bit
# Iteration 34400/50000  Rate: 0.3508 bit
# Iteration 34500/50000  Rate: 0.6278 bit
# Iteration 34600/50000  Rate: 0.3523 bit
# Iteration 34700/50000  Rate: 0.7748 bit
# Iteration 34800/50000  Rate: 0.4760 bit
# Iteration 34900/50000  Rate: 0.8146 bit
# Iteration 35000/50000  Rate: 0.5003 bit
# Iteration 35100/50000  Rate: 0.6786 bit
# Iteration 35200/50000  Rate: 0.3007 bit
# Iteration 35300/50000  Rate: 0.4102 bit
# Iteration 35400/50000  Rate: 0.5581 bit
# Iteration 35500/50000  Rate: 0.3678 bit
# Iteration 35600/50000  Rate: 0.7492 bit
# Iteration 35700/50000  Rate: 0.6860 bit
# Iteration 35800/50000  Rate: 0.5885 bit
# Iteration 35900/50000  Rate: 0.4259 bit
# Iteration 36000/50000  Rate: 0.6181 bit
# Iteration 36100/50000  Rate: 0.8432 bit
# Iteration 36200/50000  Rate: 0.2276 bit
# Iteration 36300/50000  Rate: 0.2873 bit
# Iteration 36400/50000  Rate: 0.7593 bit
# Iteration 36500/50000  Rate: 0.3588 bit
# Iteration 36600/50000  Rate: 0.5224 bit
# Iteration 36700/50000  Rate: 0.7486 bit
# Iteration 36800/50000  Rate: 0.6739 bit
# Iteration 36900/50000  Rate: 0.2593 bit
# Iteration 37000/50000  Rate: 0.7200 bit
# Iteration 37100/50000  Rate: 0.4225 bit
# Iteration 37200/50000  Rate: 0.4165 bit
# Iteration 37300/50000  Rate: 0.3472 bit
# Iteration 37400/50000  Rate: 0.7990 bit
# Iteration 37500/50000  Rate: 0.7319 bit
# Iteration 37600/50000  Rate: 0.2415 bit
# Iteration 37700/50000  Rate: 0.2763 bit
# Iteration 37800/50000  Rate: 0.3256 bit
# Iteration 37900/50000  Rate: 0.7024 bit
# Iteration 38000/50000  Rate: 0.6975 bit
# Iteration 38100/50000  Rate: 0.7897 bit
# Iteration 38200/50000  Rate: 0.3084 bit
# Iteration 38300/50000  Rate: 0.3789 bit
# Iteration 38400/50000  Rate: 0.5740 bit
# Iteration 38500/50000  Rate: 0.5404 bit
# Iteration 38600/50000  Rate: 0.2888 bit
# Iteration 38700/50000  Rate: 0.6019 bit
# Iteration 38800/50000  Rate: 0.5745 bit
# Iteration 38900/50000  Rate: 0.3083 bit
# Iteration 39000/50000  Rate: 0.5515 bit
# Iteration 39100/50000  Rate: 0.5415 bit
# Iteration 39200/50000  Rate: 0.4402 bit
# Iteration 39300/50000  Rate: 0.6947 bit
# Iteration 39400/50000  Rate: 0.3201 bit
# Iteration 39500/50000  Rate: 0.8742 bit
# Iteration 39600/50000  Rate: 0.2170 bit
# Iteration 39700/50000  Rate: 0.5715 bit
# Iteration 39800/50000  Rate: 0.7888 bit
# Iteration 39900/50000  Rate: 0.6912 bit
# Iteration 40000/50000  Rate: 0.4565 bit
# Iteration 40100/50000  Rate: 0.4702 bit
# Iteration 40200/50000  Rate: 0.5586 bit
# Iteration 40300/50000  Rate: 0.6788 bit
# Iteration 40400/50000  Rate: 0.2149 bit
# Iteration 40500/50000  Rate: 0.3283 bit
# Iteration 40600/50000  Rate: 0.8501 bit
# Iteration 40700/50000  Rate: 0.8251 bit
# Iteration 40800/50000  Rate: 0.6993 bit
# Iteration 40900/50000  Rate: 0.6231 bit
# Iteration 41000/50000  Rate: 0.7231 bit
# Iteration 41100/50000  Rate: 0.6501 bit
# Iteration 41200/50000  Rate: 0.3806 bit
# Iteration 41300/50000  Rate: 0.6044 bit
# Iteration 41400/50000  Rate: 0.7000 bit
# Iteration 41500/50000  Rate: 0.4801 bit
# Iteration 41600/50000  Rate: 0.6598 bit
# Iteration 41700/50000  Rate: 0.8372 bit
# Iteration 41800/50000  Rate: 0.7195 bit
# Iteration 41900/50000  Rate: 0.3204 bit
# Iteration 42000/50000  Rate: 0.8275 bit
# Iteration 42100/50000  Rate: 0.3858 bit
# Iteration 42200/50000  Rate: 0.7392 bit
# Iteration 42300/50000  Rate: 0.5855 bit
# Iteration 42400/50000  Rate: 0.3824 bit
# Iteration 42500/50000  Rate: 0.3464 bit
# Iteration 42600/50000  Rate: 0.7487 bit
# Iteration 42700/50000  Rate: 0.5904 bit
# Iteration 42800/50000  Rate: 0.5635 bit
# Iteration 42900/50000  Rate: 0.2899 bit
# Iteration 43000/50000  Rate: 0.6683 bit
# Iteration 43100/50000  Rate: 0.4689 bit
# Iteration 43200/50000  Rate: 0.5049 bit
# Iteration 43300/50000  Rate: 0.7585 bit
# Iteration 43400/50000  Rate: 0.5404 bit
# Iteration 43500/50000  Rate: 0.2978 bit
# Iteration 43600/50000  Rate: 0.4705 bit
# Iteration 43700/50000  Rate: 0.3224 bit
# Iteration 43800/50000  Rate: 0.3038 bit
# Iteration 43900/50000  Rate: 0.2679 bit
# Iteration 44000/50000  Rate: 0.3014 bit
# Iteration 44100/50000  Rate: 0.6569 bit
# Iteration 44200/50000  Rate: 0.7973 bit
# Iteration 44300/50000  Rate: 0.4493 bit
# Iteration 44400/50000  Rate: 0.2478 bit
# Iteration 44500/50000  Rate: 0.3072 bit
# Iteration 44600/50000  Rate: 0.3478 bit
# Iteration 44700/50000  Rate: 0.7510 bit
# Iteration 44800/50000  Rate: 0.2962 bit
# Iteration 44900/50000  Rate: 0.3113 bit
# Iteration 45000/50000  Rate: 0.2430 bit
# Iteration 45100/50000  Rate: 0.8638 bit
# Iteration 45200/50000  Rate: 0.3324 bit
# Iteration 45300/50000  Rate: 0.7232 bit
# Iteration 45400/50000  Rate: 0.3460 bit
# Iteration 45500/50000  Rate: 0.4864 bit
# Iteration 45600/50000  Rate: 0.7654 bit
# Iteration 45700/50000  Rate: 0.5796 bit
# Iteration 45800/50000  Rate: 0.2174 bit
# Iteration 45900/50000  Rate: 0.8258 bit
# Iteration 46000/50000  Rate: 0.7604 bit
# Iteration 46100/50000  Rate: 0.4378 bit
# Iteration 46200/50000  Rate: 0.3716 bit
# Iteration 46300/50000  Rate: 0.3466 bit
# Iteration 46400/50000  Rate: 0.2507 bit
# Iteration 46500/50000  Rate: 0.8164 bit
# Iteration 46600/50000  Rate: 0.8450 bit
# Iteration 46700/50000  Rate: 0.4053 bit
# Iteration 46800/50000  Rate: 0.2395 bit
# Iteration 46900/50000  Rate: 0.5207 bit
# Iteration 47000/50000  Rate: 0.6717 bit
# Iteration 47100/50000  Rate: 0.6867 bit
# Iteration 47200/50000  Rate: 0.5838 bit
# Iteration 47300/50000  Rate: 0.6447 bit
# Iteration 47400/50000  Rate: 0.3884 bit
# Iteration 47500/50000  Rate: 0.2705 bit
# Iteration 47600/50000  Rate: 0.6546 bit
# Iteration 47700/50000  Rate: 0.4922 bit
# Iteration 47800/50000  Rate: 0.8122 bit
# Iteration 47900/50000  Rate: 0.8136 bit
# Iteration 48000/50000  Rate: 0.7715 bit
# Iteration 48100/50000  Rate: 0.5514 bit
# Iteration 48200/50000  Rate: 0.8597 bit
# Iteration 48300/50000  Rate: 0.4714 bit
# Iteration 48400/50000  Rate: 0.6186 bit
# Iteration 48500/50000  Rate: 0.8397 bit
# Iteration 48600/50000  Rate: 0.2130 bit
# Iteration 48700/50000  Rate: 0.8236 bit
# Iteration 48800/50000  Rate: 0.6636 bit
# Iteration 48900/50000  Rate: 0.5162 bit
# Iteration 49000/50000  Rate: 0.3101 bit
# Iteration 49100/50000  Rate: 0.7229 bit
# Iteration 49200/50000  Rate: 0.4327 bit
# Iteration 49300/50000  Rate: 0.8653 bit
# Iteration 49400/50000  Rate: 0.5370 bit
# Iteration 49500/50000  Rate: 0.8278 bit
# Iteration 49600/50000  Rate: 0.7692 bit
# Iteration 49700/50000  Rate: 0.3013 bit
# Iteration 49800/50000  Rate: 0.2794 bit
# Iteration 49900/50000  Rate: 0.8661 bit

# %%
# The end-to-end system equipped with the neural receiver is instantiated for training.
# When called, it therefore returns the estimated BMD rate
model = E2ESystem('neural-receiver-trained', training=True)

# learning_rate_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
#     initial_learning_rate=0.0005,
#     decay_steps=10000,
#     decay_rate=0.9
# )

# Create an optimizer with the learning rate schedule
optimizer = tf.keras.optimizers.Adam()
# optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate_schedule)

for i in range(num_training_iterations):
    # Sampling a batch of SNRs
    ebno_db = tf.random.uniform(shape=[], minval=ebno_db_min, maxval=ebno_db_max)
    
    # Forward pass
    with tf.GradientTape() as tape:
        rate = model(training_batch_size, ebno_db)
        # Tensorflow optimizers only know how to minimize loss function.
        # Therefore, a loss function is defined as the additive inverse of the BMD rate
        loss = -rate

    # Perform one step of stochastic gradient descent (SGD)
    # Computing and applying gradients
    weights = model.trainable_weights
    grads = tape.gradient(loss, weights)
    optimizer.apply_gradients(zip(grads, weights))
    
    # Periodically printing the progress
    if i % 100 == 0:
        print('Iteration {}/{}  Rate: {:.4f} bit   loss = {:.4f}'.format(i, num_training_iterations, rate.numpy(), loss))

# Save the weights in a file
weights = model.get_weights()
with open(model_weights_path_trained, 'wb') as f:
    pickle.dump(weights, f)
# Out:
# Iteration 0/50000  Rate: -0.4401 bit   loss = 0.4401
# Iteration 100/50000  Rate: -0.0005 bit   loss = 0.0005
# Iteration 200/50000  Rate: 0.1093 bit   loss = -0.1093
# Iteration 300/50000  Rate: 0.0429 bit   loss = -0.0429
# Iteration 400/50000  Rate: 0.1508 bit   loss = -0.1508
# Iteration 500/50000  Rate: 0.1889 bit   loss = -0.1889
# Iteration 600/50000  Rate: 0.2698 bit   loss = -0.2698
# Iteration 700/50000  Rate: 0.1603 bit   loss = -0.1603
# Iteration 800/50000  Rate: 0.2310 bit   loss = -0.2310
# Iteration 900/50000  Rate: 0.4873 bit   loss = -0.4873
# Iteration 1000/50000  Rate: 0.4423 bit   loss = -0.4423
# Iteration 1100/50000  Rate: 0.4882 bit   loss = -0.4882
# Iteration 1200/50000  Rate: 0.4516 bit   loss = -0.4516
# Iteration 1300/50000  Rate: 0.2118 bit   loss = -0.2118
# Iteration 1400/50000  Rate: 0.5710 bit   loss = -0.5710
# Iteration 1500/50000  Rate: 0.3502 bit   loss = -0.3502
# Iteration 1600/50000  Rate: 0.3469 bit   loss = -0.3469
# Iteration 1700/50000  Rate: 0.5835 bit   loss = -0.5835
# Iteration 1800/50000  Rate: 0.6511 bit   loss = -0.6511
# Iteration 1900/50000  Rate: 0.3516 bit   loss = -0.3516
# Iteration 2000/50000  Rate: 0.3071 bit   loss = -0.3071
# Iteration 2100/50000  Rate: 0.3378 bit   loss = -0.3378
# Iteration 2200/50000  Rate: 0.5709 bit   loss = -0.5709
# Iteration 2300/50000  Rate: 0.2302 bit   loss = -0.2302
# Iteration 2400/50000  Rate: 0.2036 bit   loss = -0.2036
# Iteration 2500/50000  Rate: 0.1763 bit   loss = -0.1763
# Iteration 2600/50000  Rate: 0.6552 bit   loss = -0.6552
# Iteration 2700/50000  Rate: 0.6532 bit   loss = -0.6532
# Iteration 2800/50000  Rate: 0.5987 bit   loss = -0.5987
# Iteration 2900/50000  Rate: 0.5927 bit   loss = -0.5927
# Iteration 3000/50000  Rate: 0.5091 bit   loss = -0.5091
# Iteration 3100/50000  Rate: 0.3816 bit   loss = -0.3816
# Iteration 3200/50000  Rate: 0.5611 bit   loss = -0.5611
# Iteration 3300/50000  Rate: 0.3227 bit   loss = -0.3227
# Iteration 3400/50000  Rate: 0.3094 bit   loss = -0.3094
# Iteration 3500/50000  Rate: 0.6987 bit   loss = -0.6987
# Iteration 3600/50000  Rate: 0.2165 bit   loss = -0.2165
# Iteration 3700/50000  Rate: 0.2381 bit   loss = -0.2381
# Iteration 3800/50000  Rate: 0.4415 bit   loss = -0.4415
# Iteration 3900/50000  Rate: 0.2026 bit   loss = -0.2026
# Iteration 4000/50000  Rate: 0.3833 bit   loss = -0.3833
# Iteration 4100/50000  Rate: 0.6320 bit   loss = -0.6320
# Iteration 4200/50000  Rate: 0.5382 bit   loss = -0.5382
# Iteration 4300/50000  Rate: 0.5469 bit   loss = -0.5469
# Iteration 4400/50000  Rate: 0.2033 bit   loss = -0.2033
# Iteration 4500/50000  Rate: 0.2812 bit   loss = -0.2812
# Iteration 4600/50000  Rate: 0.6137 bit   loss = -0.6137
# Iteration 4700/50000  Rate: 0.6619 bit   loss = -0.6619
# Iteration 4800/50000  Rate: 0.7247 bit   loss = -0.7247
# Iteration 4900/50000  Rate: 0.6787 bit   loss = -0.6787
# Iteration 5000/50000  Rate: 0.7167 bit   loss = -0.7167
# Iteration 5100/50000  Rate: 0.3596 bit   loss = -0.3596
# Iteration 5200/50000  Rate: 0.5580 bit   loss = -0.5580
# Iteration 5300/50000  Rate: 0.6504 bit   loss = -0.6504
# Iteration 5400/50000  Rate: 0.2994 bit   loss = -0.2994
# Iteration 5500/50000  Rate: 0.7412 bit   loss = -0.7412
# Iteration 5600/50000  Rate: 0.4998 bit   loss = -0.4998
# Iteration 5700/50000  Rate: 0.4771 bit   loss = -0.4771
# Iteration 5800/50000  Rate: 0.6936 bit   loss = -0.6936
# Iteration 5900/50000  Rate: 0.4694 bit   loss = -0.4694
# Iteration 6000/50000  Rate: 0.2769 bit   loss = -0.2769
# Iteration 6100/50000  Rate: 0.6833 bit   loss = -0.6833
# Iteration 6200/50000  Rate: 0.2681 bit   loss = -0.2681
# Iteration 6300/50000  Rate: 0.7539 bit   loss = -0.7539
# Iteration 6400/50000  Rate: 0.6132 bit   loss = -0.6132
# Iteration 6500/50000  Rate: 0.2448 bit   loss = -0.2448
# Iteration 6600/50000  Rate: 0.4502 bit   loss = -0.4502
# Iteration 6700/50000  Rate: 0.5420 bit   loss = -0.5420
# Iteration 6800/50000  Rate: 0.5518 bit   loss = -0.5518
# Iteration 6900/50000  Rate: 0.2878 bit   loss = -0.2878
# Iteration 7000/50000  Rate: 0.3824 bit   loss = -0.3824
# Iteration 7100/50000  Rate: 0.3885 bit   loss = -0.3885
# Iteration 7200/50000  Rate: 0.5283 bit   loss = -0.5283
# Iteration 7300/50000  Rate: 0.2471 bit   loss = -0.2471
# Iteration 7400/50000  Rate: 0.2649 bit   loss = -0.2649
# Iteration 7500/50000  Rate: 0.2121 bit   loss = -0.2121
# Iteration 7600/50000  Rate: 0.2785 bit   loss = -0.2785
# Iteration 7700/50000  Rate: 0.5845 bit   loss = -0.5845
# Iteration 7800/50000  Rate: 0.3147 bit   loss = -0.3147
# Iteration 7900/50000  Rate: 0.6188 bit   loss = -0.6188
# Iteration 8000/50000  Rate: 0.7140 bit   loss = -0.7140
# Iteration 8100/50000  Rate: 0.2388 bit   loss = -0.2388
# Iteration 8200/50000  Rate: 0.2826 bit   loss = -0.2826
# Iteration 8300/50000  Rate: 0.3924 bit   loss = -0.3924
# Iteration 8400/50000  Rate: 0.6971 bit   loss = -0.6971
# Iteration 8500/50000  Rate: 0.6600 bit   loss = -0.6600
# Iteration 8600/50000  Rate: 0.4718 bit   loss = -0.4718
# Iteration 8700/50000  Rate: 0.3693 bit   loss = -0.3693
# Iteration 8800/50000  Rate: 0.5160 bit   loss = -0.5160
# Iteration 8900/50000  Rate: 0.7381 bit   loss = -0.7381
# Iteration 9000/50000  Rate: 0.5524 bit   loss = -0.5524
# Iteration 9100/50000  Rate: 0.4630 bit   loss = -0.4630
# Iteration 9200/50000  Rate: 0.6274 bit   loss = -0.6274
# Iteration 9300/50000  Rate: 0.5282 bit   loss = -0.5282
# Iteration 9400/50000  Rate: 0.5236 bit   loss = -0.5236
# Iteration 9500/50000  Rate: 0.3462 bit   loss = -0.3462
# Iteration 9600/50000  Rate: 0.7459 bit   loss = -0.7459
# Iteration 9700/50000  Rate: 0.3022 bit   loss = -0.3022
# Iteration 9800/50000  Rate: 0.6508 bit   loss = -0.6508
# Iteration 9900/50000  Rate: 0.3773 bit   loss = -0.3773
# Iteration 10000/50000  Rate: 0.2641 bit   loss = -0.2641
# Iteration 10100/50000  Rate: 0.7336 bit   loss = -0.7336
# Iteration 10200/50000  Rate: 0.2454 bit   loss = -0.2454
# Iteration 10300/50000  Rate: 0.2969 bit   loss = -0.2969
# Iteration 10400/50000  Rate: 0.5258 bit   loss = -0.5258
# Iteration 10500/50000  Rate: 0.5809 bit   loss = -0.5809
# Iteration 10600/50000  Rate: 0.5079 bit   loss = -0.5079
# Iteration 10700/50000  Rate: 0.6846 bit   loss = -0.6846
# Iteration 10800/50000  Rate: 0.7412 bit   loss = -0.7412
# Iteration 10900/50000  Rate: 0.4514 bit   loss = -0.4514
# Iteration 11000/50000  Rate: 0.1820 bit   loss = -0.1820
# Iteration 11100/50000  Rate: 0.6906 bit   loss = -0.6906
# Iteration 11200/50000  Rate: 0.4665 bit   loss = -0.4665
# Iteration 11300/50000  Rate: 0.2096 bit   loss = -0.2096
# Iteration 11400/50000  Rate: 0.7382 bit   loss = -0.7382
# Iteration 11500/50000  Rate: 0.6921 bit   loss = -0.6921
# Iteration 11600/50000  Rate: 0.7637 bit   loss = -0.7637
# Iteration 11700/50000  Rate: 0.6123 bit   loss = -0.6123
# Iteration 11800/50000  Rate: 0.4254 bit   loss = -0.4254
# Iteration 11900/50000  Rate: 0.3736 bit   loss = -0.3736
# Iteration 12000/50000  Rate: 0.3078 bit   loss = -0.3078
# Iteration 12100/50000  Rate: 0.5108 bit   loss = -0.5108
# Iteration 12200/50000  Rate: 0.3373 bit   loss = -0.3373
# Iteration 12300/50000  Rate: 0.2430 bit   loss = -0.2430
# Iteration 12400/50000  Rate: 0.7249 bit   loss = -0.7249
# Iteration 12500/50000  Rate: 0.2496 bit   loss = -0.2496
# Iteration 12600/50000  Rate: 0.5713 bit   loss = -0.5713
# Iteration 12700/50000  Rate: 0.2643 bit   loss = -0.2643
# Iteration 12800/50000  Rate: 0.4141 bit   loss = -0.4141
# Iteration 12900/50000  Rate: 0.2349 bit   loss = -0.2349
# Iteration 13000/50000  Rate: 0.6259 bit   loss = -0.6259
# Iteration 13100/50000  Rate: 0.3794 bit   loss = -0.3794
# Iteration 13200/50000  Rate: 0.6437 bit   loss = -0.6437
# Iteration 13300/50000  Rate: 0.8285 bit   loss = -0.8285
# Iteration 13400/50000  Rate: 0.3244 bit   loss = -0.3244
# Iteration 13500/50000  Rate: 0.4814 bit   loss = -0.4814
# Iteration 13600/50000  Rate: 0.5766 bit   loss = -0.5766
# Iteration 13700/50000  Rate: 0.3307 bit   loss = -0.3307
# Iteration 13800/50000  Rate: 0.4579 bit   loss = -0.4579
# Iteration 13900/50000  Rate: 0.7446 bit   loss = -0.7446
# Iteration 14000/50000  Rate: 0.2509 bit   loss = -0.2509
# Iteration 14100/50000  Rate: 0.7791 bit   loss = -0.7791
# Iteration 14200/50000  Rate: 0.6598 bit   loss = -0.6598
# Iteration 14300/50000  Rate: 0.3438 bit   loss = -0.3438
# Iteration 14400/50000  Rate: 0.4910 bit   loss = -0.4910
# Iteration 14500/50000  Rate: 0.4496 bit   loss = -0.4496
# Iteration 14600/50000  Rate: 0.6201 bit   loss = -0.6201
# Iteration 14700/50000  Rate: 0.5332 bit   loss = -0.5332
# Iteration 14800/50000  Rate: 0.7832 bit   loss = -0.7832
# Iteration 14900/50000  Rate: 0.7314 bit   loss = -0.7314
# Iteration 15000/50000  Rate: 0.7195 bit   loss = -0.7195
# Iteration 15100/50000  Rate: 0.2059 bit   loss = -0.2059
# Iteration 15200/50000  Rate: 0.5019 bit   loss = -0.5019
# Iteration 15300/50000  Rate: 0.6873 bit   loss = -0.6873
# Iteration 15400/50000  Rate: 0.6325 bit   loss = -0.6325
# Iteration 15500/50000  Rate: 0.6156 bit   loss = -0.6156
# Iteration 15600/50000  Rate: 0.2119 bit   loss = -0.2119
# Iteration 15700/50000  Rate: 0.3208 bit   loss = -0.3208
# Iteration 15800/50000  Rate: 0.2313 bit   loss = -0.2313
# Iteration 15900/50000  Rate: 0.6221 bit   loss = -0.6221
# Iteration 16000/50000  Rate: 0.3897 bit   loss = -0.3897
# Iteration 16100/50000  Rate: 0.7923 bit   loss = -0.7923
# Iteration 16200/50000  Rate: 0.5810 bit   loss = -0.5810
# Iteration 16300/50000  Rate: 0.3144 bit   loss = -0.3144
# Iteration 16400/50000  Rate: 0.6343 bit   loss = -0.6343
# Iteration 16500/50000  Rate: 0.2466 bit   loss = -0.2466
# Iteration 16600/50000  Rate: 0.4830 bit   loss = -0.4830
# Iteration 16700/50000  Rate: 0.3250 bit   loss = -0.3250
# Iteration 16800/50000  Rate: 0.5506 bit   loss = -0.5506
# Iteration 16900/50000  Rate: 0.4870 bit   loss = -0.4870
# Iteration 17000/50000  Rate: 0.8281 bit   loss = -0.8281
# Iteration 17100/50000  Rate: 0.2217 bit   loss = -0.2217
# Iteration 17200/50000  Rate: 0.5810 bit   loss = -0.5810
# Iteration 17300/50000  Rate: 0.6775 bit   loss = -0.6775
# Iteration 17400/50000  Rate: 0.8005 bit   loss = -0.8005
# Iteration 17500/50000  Rate: 0.2734 bit   loss = -0.2734
# Iteration 17600/50000  Rate: 0.2140 bit   loss = -0.2140
# Iteration 17700/50000  Rate: 0.2306 bit   loss = -0.2306
# Iteration 17800/50000  Rate: 0.5616 bit   loss = -0.5616
# Iteration 17900/50000  Rate: 0.6472 bit   loss = -0.6472
# Iteration 18000/50000  Rate: 0.2174 bit   loss = -0.2174
# Iteration 18100/50000  Rate: 0.8561 bit   loss = -0.8561
# Iteration 18200/50000  Rate: 0.3547 bit   loss = -0.3547
# Iteration 18300/50000  Rate: 0.6094 bit   loss = -0.6094
# Iteration 18400/50000  Rate: 0.2354 bit   loss = -0.2354
# Iteration 18500/50000  Rate: 0.2522 bit   loss = -0.2522
# Iteration 18600/50000  Rate: 0.3261 bit   loss = -0.3261
# Iteration 18700/50000  Rate: 0.7319 bit   loss = -0.7319
# Iteration 18800/50000  Rate: 0.7557 bit   loss = -0.7557
# Iteration 18900/50000  Rate: 0.7548 bit   loss = -0.7548
# Iteration 19000/50000  Rate: 0.3817 bit   loss = -0.3817
# Iteration 19100/50000  Rate: 0.6125 bit   loss = -0.6125
# Iteration 19200/50000  Rate: 0.8332 bit   loss = -0.8332
# Iteration 19300/50000  Rate: 0.5531 bit   loss = -0.5531
# Iteration 19400/50000  Rate: 0.2274 bit   loss = -0.2274
# Iteration 19500/50000  Rate: 0.4071 bit   loss = -0.4071
# Iteration 19600/50000  Rate: 0.3704 bit   loss = -0.3704
# Iteration 19700/50000  Rate: 0.2333 bit   loss = -0.2333
# Iteration 19800/50000  Rate: 0.8379 bit   loss = -0.8379
# Iteration 19900/50000  Rate: 0.8399 bit   loss = -0.8399
# Iteration 20000/50000  Rate: 0.7838 bit   loss = -0.7838
# Iteration 20100/50000  Rate: 0.2768 bit   loss = -0.2768
# Iteration 20200/50000  Rate: 0.8238 bit   loss = -0.8238
# Iteration 20300/50000  Rate: 0.6610 bit   loss = -0.6610
# Iteration 20400/50000  Rate: 0.8055 bit   loss = -0.8055
# Iteration 20500/50000  Rate: 0.5334 bit   loss = -0.5334
# Iteration 20600/50000  Rate: 0.6336 bit   loss = -0.6336
# Iteration 20700/50000  Rate: 0.2362 bit   loss = -0.2362
# Iteration 20800/50000  Rate: 0.7050 bit   loss = -0.7050
# Iteration 20900/50000  Rate: 0.5857 bit   loss = -0.5857
# Iteration 21000/50000  Rate: 0.4938 bit   loss = -0.4938
# Iteration 21100/50000  Rate: 0.3596 bit   loss = -0.3596
# Iteration 21200/50000  Rate: 0.2995 bit   loss = -0.2995
# Iteration 21300/50000  Rate: 0.7348 bit   loss = -0.7348
# Iteration 21400/50000  Rate: 0.5863 bit   loss = -0.5863
# Iteration 21500/50000  Rate: 0.4443 bit   loss = -0.4443
# Iteration 21600/50000  Rate: 0.2755 bit   loss = -0.2755
# Iteration 21700/50000  Rate: 0.8209 bit   loss = -0.8209
# Iteration 21800/50000  Rate: 0.5571 bit   loss = -0.5571
# Iteration 21900/50000  Rate: 0.3680 bit   loss = -0.3680
# Iteration 22000/50000  Rate: 0.6330 bit   loss = -0.6330
# Iteration 22100/50000  Rate: 0.3527 bit   loss = -0.3527
# Iteration 22200/50000  Rate: 0.4577 bit   loss = -0.4577
# Iteration 22300/50000  Rate: 0.5539 bit   loss = -0.5539
# Iteration 22400/50000  Rate: 0.2464 bit   loss = -0.2464
# Iteration 22500/50000  Rate: 0.3069 bit   loss = -0.3069
# Iteration 22600/50000  Rate: 0.3837 bit   loss = -0.3837
# Iteration 22700/50000  Rate: 0.6618 bit   loss = -0.6618
# Iteration 22800/50000  Rate: 0.8208 bit   loss = -0.8208
# Iteration 22900/50000  Rate: 0.5461 bit   loss = -0.5461
# Iteration 23000/50000  Rate: 0.3770 bit   loss = -0.3770
# Iteration 23100/50000  Rate: 0.5511 bit   loss = -0.5511
# Iteration 23200/50000  Rate: 0.6644 bit   loss = -0.6644
# Iteration 23300/50000  Rate: 0.6379 bit   loss = -0.6379
# Iteration 23400/50000  Rate: 0.3400 bit   loss = -0.3400
# Iteration 23500/50000  Rate: 0.4158 bit   loss = -0.4158
# Iteration 23600/50000  Rate: 0.4243 bit   loss = -0.4243
# Iteration 23700/50000  Rate: 0.6294 bit   loss = -0.6294
# Iteration 23800/50000  Rate: 0.8038 bit   loss = -0.8038
# Iteration 23900/50000  Rate: 0.2484 bit   loss = -0.2484
# Iteration 24000/50000  Rate: 0.2820 bit   loss = -0.2820
# Iteration 24100/50000  Rate: 0.2675 bit   loss = -0.2675
# Iteration 24200/50000  Rate: 0.4700 bit   loss = -0.4700
# Iteration 24300/50000  Rate: 0.7071 bit   loss = -0.7071
# Iteration 24400/50000  Rate: 0.3497 bit   loss = -0.3497
# Iteration 24500/50000  Rate: 0.2387 bit   loss = -0.2387
# Iteration 24600/50000  Rate: 0.4022 bit   loss = -0.4022
# Iteration 24700/50000  Rate: 0.2802 bit   loss = -0.2802
# Iteration 24800/50000  Rate: 0.5258 bit   loss = -0.5258
# Iteration 24900/50000  Rate: 0.6940 bit   loss = -0.6940
# Iteration 25000/50000  Rate: 0.2615 bit   loss = -0.2615
# Iteration 25100/50000  Rate: 0.3465 bit   loss = -0.3465
# Iteration 25200/50000  Rate: 0.6431 bit   loss = -0.6431
# Iteration 25300/50000  Rate: 0.3311 bit   loss = -0.3311
# Iteration 25400/50000  Rate: 0.2195 bit   loss = -0.2195
# Iteration 25500/50000  Rate: 0.8394 bit   loss = -0.8394
# Iteration 25600/50000  Rate: 0.6276 bit   loss = -0.6276
# Iteration 25700/50000  Rate: 0.3924 bit   loss = -0.3924
# Iteration 25800/50000  Rate: 0.8073 bit   loss = -0.8073
# Iteration 25900/50000  Rate: 0.5166 bit   loss = -0.5166
# Iteration 26000/50000  Rate: 0.3914 bit   loss = -0.3914
# Iteration 26100/50000  Rate: 0.6546 bit   loss = -0.6546
# Iteration 26200/50000  Rate: 0.4428 bit   loss = -0.4428
# Iteration 26300/50000  Rate: 0.5506 bit   loss = -0.5506
# Iteration 26400/50000  Rate: 0.6418 bit   loss = -0.6418
# Iteration 26500/50000  Rate: 0.6055 bit   loss = -0.6055
# Iteration 26600/50000  Rate: 0.8541 bit   loss = -0.8541
# Iteration 26700/50000  Rate: 0.6292 bit   loss = -0.6292
# Iteration 26800/50000  Rate: 0.7599 bit   loss = -0.7599
# Iteration 26900/50000  Rate: 0.5375 bit   loss = -0.5375
# Iteration 27000/50000  Rate: 0.5228 bit   loss = -0.5228
# Iteration 27100/50000  Rate: 0.7835 bit   loss = -0.7835
# Iteration 27200/50000  Rate: 0.7271 bit   loss = -0.7271
# Iteration 27300/50000  Rate: 0.5381 bit   loss = -0.5381
# Iteration 27400/50000  Rate: 0.4966 bit   loss = -0.4966
# Iteration 27500/50000  Rate: 0.6873 bit   loss = -0.6873
# Iteration 27600/50000  Rate: 0.2736 bit   loss = -0.2736
# Iteration 27700/50000  Rate: 0.7109 bit   loss = -0.7109
# Iteration 27800/50000  Rate: 0.6955 bit   loss = -0.6955
# Iteration 27900/50000  Rate: 0.6322 bit   loss = -0.6322
# Iteration 28000/50000  Rate: 0.7991 bit   loss = -0.7991
# Iteration 28100/50000  Rate: 0.3686 bit   loss = -0.3686
# Iteration 28200/50000  Rate: 0.5608 bit   loss = -0.5608
# Iteration 28300/50000  Rate: 0.7505 bit   loss = -0.7505
# Iteration 28400/50000  Rate: 0.4193 bit   loss = -0.4193
# Iteration 28500/50000  Rate: 0.3684 bit   loss = -0.3684
# Iteration 28600/50000  Rate: 0.7910 bit   loss = -0.7910
# Iteration 28700/50000  Rate: 0.7406 bit   loss = -0.7406
# Iteration 28800/50000  Rate: 0.3989 bit   loss = -0.3989
# Iteration 28900/50000  Rate: 0.7565 bit   loss = -0.7565
# Iteration 29000/50000  Rate: 0.8433 bit   loss = -0.8433
# Iteration 29100/50000  Rate: 0.3293 bit   loss = -0.3293
# Iteration 29200/50000  Rate: 0.7497 bit   loss = -0.7497
# Iteration 29300/50000  Rate: 0.2383 bit   loss = -0.2383
# Iteration 29400/50000  Rate: 0.8258 bit   loss = -0.8258
# Iteration 29500/50000  Rate: 0.7842 bit   loss = -0.7842
# Iteration 29600/50000  Rate: 0.3518 bit   loss = -0.3518
# Iteration 29700/50000  Rate: 0.4086 bit   loss = -0.4086
# Iteration 29800/50000  Rate: 0.4012 bit   loss = -0.4012
# Iteration 29900/50000  Rate: 0.4480 bit   loss = -0.4480
# Iteration 30000/50000  Rate: 0.5566 bit   loss = -0.5566
# Iteration 30100/50000  Rate: 0.3710 bit   loss = -0.3710
# Iteration 30200/50000  Rate: 0.6674 bit   loss = -0.6674
# Iteration 30300/50000  Rate: 0.2616 bit   loss = -0.2616
# Iteration 30400/50000  Rate: 0.5700 bit   loss = -0.5700
# Iteration 30500/50000  Rate: 0.8119 bit   loss = -0.8119
# Iteration 30600/50000  Rate: 0.7765 bit   loss = -0.7765
# Iteration 30700/50000  Rate: 0.4304 bit   loss = -0.4304
# Iteration 30800/50000  Rate: 0.7250 bit   loss = -0.7250
# Iteration 30900/50000  Rate: 0.5573 bit   loss = -0.5573
# Iteration 31000/50000  Rate: 0.6997 bit   loss = -0.6997
# Iteration 31100/50000  Rate: 0.6015 bit   loss = -0.6015
# Iteration 31200/50000  Rate: 0.8149 bit   loss = -0.8149
# Iteration 31300/50000  Rate: 0.3428 bit   loss = -0.3428
# Iteration 31400/50000  Rate: 0.6779 bit   loss = -0.6779
# Iteration 31500/50000  Rate: 0.7212 bit   loss = -0.7212
# Iteration 31600/50000  Rate: 0.4944 bit   loss = -0.4944
# Iteration 31700/50000  Rate: 0.7387 bit   loss = -0.7387
# Iteration 31800/50000  Rate: 0.8210 bit   loss = -0.8210
# Iteration 31900/50000  Rate: 0.3793 bit   loss = -0.3793
# Iteration 32000/50000  Rate: 0.2186 bit   loss = -0.2186
# Iteration 32100/50000  Rate: 0.6182 bit   loss = -0.6182
# Iteration 32200/50000  Rate: 0.5752 bit   loss = -0.5752
# Iteration 32300/50000  Rate: 0.7662 bit   loss = -0.7662
# Iteration 32400/50000  Rate: 0.7974 bit   loss = -0.7974
# Iteration 32500/50000  Rate: 0.5750 bit   loss = -0.5750
# Iteration 32600/50000  Rate: 0.4076 bit   loss = -0.4076
# Iteration 32700/50000  Rate: 0.7457 bit   loss = -0.7457
# Iteration 32800/50000  Rate: 0.4830 bit   loss = -0.4830
# Iteration 32900/50000  Rate: 0.2408 bit   loss = -0.2408
# Iteration 33000/50000  Rate: 0.7897 bit   loss = -0.7897
# Iteration 33100/50000  Rate: 0.2343 bit   loss = -0.2343
# Iteration 33200/50000  Rate: 0.5925 bit   loss = -0.5925
# Iteration 33300/50000  Rate: 0.8452 bit   loss = -0.8452
# Iteration 33400/50000  Rate: 0.8247 bit   loss = -0.8247
# Iteration 33500/50000  Rate: 0.6815 bit   loss = -0.6815
# Iteration 33600/50000  Rate: 0.6837 bit   loss = -0.6837
# Iteration 33700/50000  Rate: 0.6166 bit   loss = -0.6166
# Iteration 33800/50000  Rate: 0.4033 bit   loss = -0.4033
# Iteration 33900/50000  Rate: 0.6223 bit   loss = -0.6223
# Iteration 34000/50000  Rate: 0.6118 bit   loss = -0.6118
# Iteration 34100/50000  Rate: 0.5590 bit   loss = -0.5590
# Iteration 34200/50000  Rate: 0.3696 bit   loss = -0.3696
# Iteration 34300/50000  Rate: 0.3115 bit   loss = -0.3115
# Iteration 34400/50000  Rate: 0.6664 bit   loss = -0.6664
# Iteration 34500/50000  Rate: 0.5596 bit   loss = -0.5596
# Iteration 34600/50000  Rate: 0.8030 bit   loss = -0.8030
# Iteration 34700/50000  Rate: 0.3812 bit   loss = -0.3812
# Iteration 34800/50000  Rate: 0.2356 bit   loss = -0.2356
# Iteration 34900/50000  Rate: 0.5523 bit   loss = -0.5523
# Iteration 35000/50000  Rate: 0.4692 bit   loss = -0.4692
# Iteration 35100/50000  Rate: 0.8474 bit   loss = -0.8474
# Iteration 35200/50000  Rate: 0.8340 bit   loss = -0.8340
# Iteration 35300/50000  Rate: 0.2677 bit   loss = -0.2677
# Iteration 35400/50000  Rate: 0.5347 bit   loss = -0.5347
# Iteration 35500/50000  Rate: 0.6183 bit   loss = -0.6183
# Iteration 35600/50000  Rate: 0.2494 bit   loss = -0.2494
# Iteration 35700/50000  Rate: 0.7145 bit   loss = -0.7145
# Iteration 35800/50000  Rate: 0.4277 bit   loss = -0.4277
# Iteration 35900/50000  Rate: 0.3865 bit   loss = -0.3865
# Iteration 36000/50000  Rate: 0.8415 bit   loss = -0.8415
# Iteration 36100/50000  Rate: 0.8253 bit   loss = -0.8253
# Iteration 36200/50000  Rate: 0.8703 bit   loss = -0.8703
# Iteration 36300/50000  Rate: 0.7973 bit   loss = -0.7973
# Iteration 36400/50000  Rate: 0.7504 bit   loss = -0.7504
# Iteration 36500/50000  Rate: 0.7414 bit   loss = -0.7414
# Iteration 36600/50000  Rate: 0.6693 bit   loss = -0.6693
# Iteration 36700/50000  Rate: 0.6923 bit   loss = -0.6923
# Iteration 36800/50000  Rate: 0.6232 bit   loss = -0.6232
# Iteration 36900/50000  Rate: 0.5912 bit   loss = -0.5912
# Iteration 37000/50000  Rate: 0.6343 bit   loss = -0.6343
# Iteration 37100/50000  Rate: 0.6415 bit   loss = -0.6415
# Iteration 37200/50000  Rate: 0.2843 bit   loss = -0.2843
# Iteration 37300/50000  Rate: 0.3780 bit   loss = -0.3780
# Iteration 37400/50000  Rate: 0.8073 bit   loss = -0.8073
# Iteration 37500/50000  Rate: 0.6588 bit   loss = -0.6588
# Iteration 37600/50000  Rate: 0.2270 bit   loss = -0.2270
# Iteration 37700/50000  Rate: 0.3896 bit   loss = -0.3896
# Iteration 37800/50000  Rate: 0.4595 bit   loss = -0.4595
# Iteration 37900/50000  Rate: 0.3404 bit   loss = -0.3404
# Iteration 38000/50000  Rate: 0.8456 bit   loss = -0.8456
# Iteration 38100/50000  Rate: 0.8371 bit   loss = -0.8371
# Iteration 38200/50000  Rate: 0.4514 bit   loss = -0.4514
# Iteration 38300/50000  Rate: 0.8311 bit   loss = -0.8311
# Iteration 38400/50000  Rate: 0.8521 bit   loss = -0.8521
# Iteration 38500/50000  Rate: 0.7466 bit   loss = -0.7466
# Iteration 38600/50000  Rate: 0.8400 bit   loss = -0.8400
# Iteration 38700/50000  Rate: 0.8506 bit   loss = -0.8506
# Iteration 38800/50000  Rate: 0.7827 bit   loss = -0.7827
# Iteration 38900/50000  Rate: 0.4999 bit   loss = -0.4999
# Iteration 39000/50000  Rate: 0.6408 bit   loss = -0.6408
# Iteration 39100/50000  Rate: 0.6675 bit   loss = -0.6675
# Iteration 39200/50000  Rate: 0.5907 bit   loss = -0.5907
# Iteration 39300/50000  Rate: 0.2907 bit   loss = -0.2907
# Iteration 39400/50000  Rate: 0.2873 bit   loss = -0.2873
# Iteration 39500/50000  Rate: 0.5747 bit   loss = -0.5747
# Iteration 39600/50000  Rate: 0.5988 bit   loss = -0.5988
# Iteration 39700/50000  Rate: 0.8554 bit   loss = -0.8554
# Iteration 39800/50000  Rate: 0.7221 bit   loss = -0.7221
# Iteration 39900/50000  Rate: 0.6009 bit   loss = -0.6009
# Iteration 40000/50000  Rate: 0.6480 bit   loss = -0.6480
# Iteration 40100/50000  Rate: 0.7249 bit   loss = -0.7249
# Iteration 40200/50000  Rate: 0.7582 bit   loss = -0.7582
# Iteration 40300/50000  Rate: 0.3470 bit   loss = -0.3470
# Iteration 40400/50000  Rate: 0.8570 bit   loss = -0.8570
# Iteration 40500/50000  Rate: 0.3478 bit   loss = -0.3478
# Iteration 40600/50000  Rate: 0.3578 bit   loss = -0.3578
# Iteration 40700/50000  Rate: 0.7134 bit   loss = -0.7134
# Iteration 40800/50000  Rate: 0.4185 bit   loss = -0.4185
# Iteration 40900/50000  Rate: 0.2213 bit   loss = -0.2213
# Iteration 41000/50000  Rate: 0.4877 bit   loss = -0.4877
# Iteration 41100/50000  Rate: 0.2166 bit   loss = -0.2166
# Iteration 41200/50000  Rate: 0.7309 bit   loss = -0.7309
# Iteration 41300/50000  Rate: 0.3340 bit   loss = -0.3340
# Iteration 41400/50000  Rate: 0.4452 bit   loss = -0.4452
# Iteration 41500/50000  Rate: 0.7593 bit   loss = -0.7593
# Iteration 41600/50000  Rate: 0.7754 bit   loss = -0.7754
# Iteration 41700/50000  Rate: 0.2195 bit   loss = -0.2195
# Iteration 41800/50000  Rate: 0.8267 bit   loss = -0.8267
# Iteration 41900/50000  Rate: 0.3463 bit   loss = -0.3463
# Iteration 42000/50000  Rate: 0.6501 bit   loss = -0.6501
# Iteration 42100/50000  Rate: 0.4560 bit   loss = -0.4560
# Iteration 42200/50000  Rate: 0.4462 bit   loss = -0.4462
# Iteration 42300/50000  Rate: 0.7194 bit   loss = -0.7194
# Iteration 42400/50000  Rate: 0.4889 bit   loss = -0.4889
# Iteration 42500/50000  Rate: 0.7968 bit   loss = -0.7968
# Iteration 42600/50000  Rate: 0.8712 bit   loss = -0.8712
# Iteration 42700/50000  Rate: 0.5210 bit   loss = -0.5210
# Iteration 42800/50000  Rate: 0.7361 bit   loss = -0.7361
# Iteration 42900/50000  Rate: 0.2618 bit   loss = -0.2618
# Iteration 43000/50000  Rate: 0.3998 bit   loss = -0.3998
# Iteration 43100/50000  Rate: 0.7871 bit   loss = -0.7871
# Iteration 43200/50000  Rate: 0.4610 bit   loss = -0.4610
# Iteration 43300/50000  Rate: 0.3319 bit   loss = -0.3319
# Iteration 43400/50000  Rate: 0.3603 bit   loss = -0.3603
# Iteration 43500/50000  Rate: 0.5498 bit   loss = -0.5498
# Iteration 43600/50000  Rate: 0.6824 bit   loss = -0.6824
# Iteration 43700/50000  Rate: 0.8317 bit   loss = -0.8317
# Iteration 43800/50000  Rate: 0.3632 bit   loss = -0.3632
# Iteration 43900/50000  Rate: 0.5939 bit   loss = -0.5939
# Iteration 44000/50000  Rate: 0.3729 bit   loss = -0.3729
# Iteration 44100/50000  Rate: 0.3930 bit   loss = -0.3930
# Iteration 44200/50000  Rate: 0.2135 bit   loss = -0.2135
# Iteration 44300/50000  Rate: 0.5397 bit   loss = -0.5397
# Iteration 44400/50000  Rate: 0.3488 bit   loss = -0.3488
# Iteration 44500/50000  Rate: 0.4621 bit   loss = -0.4621
# Iteration 44600/50000  Rate: 0.5881 bit   loss = -0.5881
# Iteration 44700/50000  Rate: 0.7908 bit   loss = -0.7908
# Iteration 44800/50000  Rate: 0.3031 bit   loss = -0.3031
# Iteration 44900/50000  Rate: 0.3433 bit   loss = -0.3433
# Iteration 45000/50000  Rate: 0.7812 bit   loss = -0.7812
# Iteration 45100/50000  Rate: 0.4299 bit   loss = -0.4299
# Iteration 45200/50000  Rate: 0.6320 bit   loss = -0.6320
# Iteration 45300/50000  Rate: 0.8474 bit   loss = -0.8474
# Iteration 45400/50000  Rate: 0.3116 bit   loss = -0.3116
# Iteration 45500/50000  Rate: 0.7504 bit   loss = -0.7504
# Iteration 45600/50000  Rate: 0.2409 bit   loss = -0.2409
# Iteration 45700/50000  Rate: 0.4024 bit   loss = -0.4024
# Iteration 45800/50000  Rate: 0.2727 bit   loss = -0.2727
# Iteration 45900/50000  Rate: 0.2813 bit   loss = -0.2813
# Iteration 46000/50000  Rate: 0.8514 bit   loss = -0.8514
# Iteration 46100/50000  Rate: 0.4086 bit   loss = -0.4086
# Iteration 46200/50000  Rate: 0.3810 bit   loss = -0.3810
# Iteration 46300/50000  Rate: 0.2391 bit   loss = -0.2391
# Iteration 46400/50000  Rate: 0.8581 bit   loss = -0.8581
# Iteration 46500/50000  Rate: 0.4603 bit   loss = -0.4603
# Iteration 46600/50000  Rate: 0.2284 bit   loss = -0.2284
# Iteration 46700/50000  Rate: 0.7338 bit   loss = -0.7338
# Iteration 46800/50000  Rate: 0.2825 bit   loss = -0.2825
# Iteration 46900/50000  Rate: 0.4199 bit   loss = -0.4199
# Iteration 47000/50000  Rate: 0.7927 bit   loss = -0.7927
# Iteration 47100/50000  Rate: 0.3107 bit   loss = -0.3107
# Iteration 47200/50000  Rate: 0.5072 bit   loss = -0.5072
# Iteration 47300/50000  Rate: 0.6374 bit   loss = -0.6374
# Iteration 47400/50000  Rate: 0.7143 bit   loss = -0.7143
# Iteration 47500/50000  Rate: 0.4127 bit   loss = -0.4127
# Iteration 47600/50000  Rate: 0.6441 bit   loss = -0.6441
# Iteration 47700/50000  Rate: 0.4221 bit   loss = -0.4221
# Iteration 47800/50000  Rate: 0.5926 bit   loss = -0.5926
# Iteration 47900/50000  Rate: 0.3784 bit   loss = -0.3784
# Iteration 48000/50000  Rate: 0.5950 bit   loss = -0.5950
# Iteration 48100/50000  Rate: 0.3566 bit   loss = -0.3566
# Iteration 48200/50000  Rate: 0.7253 bit   loss = -0.7253
# Iteration 48300/50000  Rate: 0.6289 bit   loss = -0.6289
# Iteration 48400/50000  Rate: 0.3470 bit   loss = -0.3470
# Iteration 48500/50000  Rate: 0.7237 bit   loss = -0.7237
# Iteration 48600/50000  Rate: 0.5141 bit   loss = -0.5141
# Iteration 48700/50000  Rate: 0.8173 bit   loss = -0.8173
# Iteration 48800/50000  Rate: 0.5957 bit   loss = -0.5957
# Iteration 48900/50000  Rate: 0.7566 bit   loss = -0.7566
# Iteration 49000/50000  Rate: 0.3521 bit   loss = -0.3521
# Iteration 49100/50000  Rate: 0.7112 bit   loss = -0.7112
# Iteration 49200/50000  Rate: 0.4651 bit   loss = -0.4651
# Iteration 49300/50000  Rate: 0.5544 bit   loss = -0.5544
# Iteration 49400/50000  Rate: 0.7393 bit   loss = -0.7393
# Iteration 49500/50000  Rate: 0.6216 bit   loss = -0.6216
# Iteration 49600/50000  Rate: 0.3570 bit   loss = -0.3570
# Iteration 49700/50000  Rate: 0.8326 bit   loss = -0.8326
# Iteration 49800/50000  Rate: 0.2302 bit   loss = -0.2302
# Iteration 49900/50000  Rate: 0.3381 bit   loss = -0.3381

# %%
import re

def extract_loss_values_from_file(file_path):
    loss_values = []

    with open(file_path, 'r') as file:
        file_content = file.read()

        matches = re.findall(r'loss = (-?\d+\.\d+)', file_content)
        
        # Convert matched strings to float and append to the list
        loss_values.extend(map(float, matches))

    return loss_values

def extract_bmd_values_from_file(file_path):
    loss_values = []

    with open(file_path, 'r') as file:
        file_content = file.read()

        matches = re.findall(r'Rate: (-?\d+\.\d+)', file_content)
        
        # Convert matched strings to float and append to the list
        loss_values.extend(map(lambda x: -float(x), matches))

    return loss_values

loss_values_standard = extract_bmd_values_from_file('loss_standard.txt')
loss_values_trained = extract_loss_values_from_file('loss_trained.txt')

# print(loss_values_standard)
# print(loss_values_trained)

num_iterations = len(loss_values_trained)
num_iterations = len(loss_values_standard)
epochs = np.arange(0, 50000, 100)

plt.figure(figsize=(15,6))
plt.scatter(epochs, loss_values_trained, color='blue', marker='')
plt.plot(epochs, loss_values_trained, color='blue', linestyle='-', linewidth=1)

plt.title('Training Loss (trained mapper)')
plt.xlabel('Iterations')
plt.ylabel('Training Loss')
plt.ylim((-1.0, 1.0))
plt.grid(True)

plt.figure(figsize=(15,6))
plt.scatter(epochs, loss_values_standard, color='red', marker='')
plt.plot(epochs, loss_values_standard, color='red', linestyle='-', linewidth=1)

plt.title('Training Loss (standard mapper)')
plt.xlabel('Iterations')
plt.ylabel('Training Loss')
plt.ylim((-1.0, 1.0))
plt.grid(True)

plt.show()

# %% [markdown]
# ## Evaluation of the Neural Receiver <a class="anchor" id="Evaluation-of-the-Neural-Receiver"></a>

# %% [markdown]
# The next cell evaluates the neural receiver.
#
# **Note:** Evaluation of the system can take a while and requires having the trained weights of the neural receiver. Therefore, we provide pre-computed results at the end of this notebook.

# %%
model = E2ESystem('neural-receiver-standard')

# Run one inference to build the layers and loading the weights
model(1, tf.constant(10.0, tf.float32))
with open(model_weights_path_standard, 'rb') as f:
    weights = pickle.load(f)
model.set_weights(weights)

# Evaluations
_,bler = sim_ber(model, ebno_dbs, batch_size=128, num_target_block_errors=50, max_mc_iter=1000)
BLER['neural-receiver-standard'] = bler.numpy()

with open(results_filename, 'wb') as f:
    pickle.dump((ebno_dbs, BLER), f)
# Out:
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#      -5.0 | 3.2781e-01 | 1.0000e+00 |      175222 |      534528 |          128 |         128 |         0.4 |reached target block errors
#      -4.5 | 3.1658e-01 | 1.0000e+00 |      169221 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -4.0 | 3.0944e-01 | 1.0000e+00 |      165402 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -3.5 | 2.9791e-01 | 1.0000e+00 |      159242 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -3.0 | 2.8682e-01 | 1.0000e+00 |      153311 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -2.5 | 2.7628e-01 | 1.0000e+00 |      147678 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -2.0 | 2.6581e-01 | 1.0000e+00 |      142081 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -1.5 | 2.5241e-01 | 1.0000e+00 |      134918 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -1.0 | 2.4139e-01 | 1.0000e+00 |      129029 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -0.5 | 2.2768e-01 | 1.0000e+00 |      121704 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       0.0 | 2.1512e-01 | 1.0000e+00 |      114990 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       0.5 | 2.0006e-01 | 1.0000e+00 |      106937 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.0 | 1.8663e-01 | 1.0000e+00 |       99757 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.5 | 1.6756e-01 | 1.0000e+00 |       89563 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.0 | 1.4690e-01 | 1.0000e+00 |       78522 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.5 | 1.0611e-01 | 1.0000e+00 |       56720 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       3.0 | 5.2708e-02 | 9.6094e-01 |       28174 |      534528 |          123 |         128 |         0.3 |reached target block errors
#       3.5 | 7.5768e-03 | 2.5391e-01 |        8100 |     1069056 |           65 |         256 |         0.7 |reached target block errors
#       4.0 | 6.7948e-04 | 2.6562e-02 |        5448 |     8017920 |           51 |        1920 |         5.0 |reached target block errors
#       4.5 | 2.9597e-04 | 5.3510e-03 |       11549 |    39020544 |           50 |        9344 |        24.4 |reached target block errors
#       5.0 | 9.2807e-05 | 1.3197e-03 |       14684 |   158220288 |           50 |       37888 |        99.0 |reached target block errors
#       5.5 | 3.6240e-05 | 5.6694e-04 |       13347 |   368289792 |           50 |       88192 |       230.5 |reached target block errors
#       6.0 | 2.3675e-05 | 2.8906e-04 |       12655 |   534528000 |           37 |      128000 |       334.5 |reached max iter
#       6.5 | 1.1831e-05 | 1.3281e-04 |        6324 |   534528000 |           17 |      128000 |       334.3 |reached max iter
#       7.0 | 7.6105e-06 | 7.8125e-05 |        4068 |   534528000 |           10 |      128000 |       334.4 |reached max iter
#       7.5 | 3.0157e-06 | 3.9063e-05 |        1612 |   534528000 |            5 |      128000 |       334.5 |reached max iter
#       8.0 | 5.3561e-06 | 4.6875e-05 |        2863 |   534528000 |            6 |      128000 |       334.4 |reached max iter
#       8.5 | 4.9202e-07 | 7.8125e-06 |         263 |   534528000 |            1 |      128000 |       334.4 |reached max iter
#       9.0 | 0.0000e+00 | 0.0000e+00 |           0 |   534528000 |            0 |      128000 |       334.4 |reached max iter
#
# Simulation stopped as no error occurred @ EbNo = 9.0 dB.

# %%
model = E2ESystem('neural-receiver-trained')

# Run one inference to build the layers and loading the weights
model(1, tf.constant(10.0, tf.float32))
with open(model_weights_path_trained, 'rb') as f:
    weights = pickle.load(f)
model.set_weights(weights)

# Evaluations
_,bler = sim_ber(model, ebno_dbs, batch_size=128, num_target_block_errors=50, max_mc_iter=1000)
BLER['neural-receiver-trained'] = bler.numpy()

with open(results_filename, 'wb') as f:
    pickle.dump((ebno_dbs, BLER), f)
# Out:
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#      -5.0 | 3.2222e-01 | 1.0000e+00 |      172233 |      534528 |          128 |         128 |         0.4 |reached target block errors
#      -4.5 | 3.1099e-01 | 1.0000e+00 |      166233 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -4.0 | 3.0293e-01 | 1.0000e+00 |      161922 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -3.5 | 2.9003e-01 | 1.0000e+00 |      155029 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -3.0 | 2.7940e-01 | 1.0000e+00 |      149349 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -2.5 | 2.6704e-01 | 1.0000e+00 |      142743 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -2.0 | 2.5594e-01 | 1.0000e+00 |      136807 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -1.5 | 2.4359e-01 | 1.0000e+00 |      130206 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -1.0 | 2.3126e-01 | 1.0000e+00 |      123613 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -0.5 | 2.1720e-01 | 1.0000e+00 |      116097 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       0.0 | 2.0275e-01 | 1.0000e+00 |      108375 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       0.5 | 1.8804e-01 | 1.0000e+00 |      100513 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.0 | 1.6690e-01 | 1.0000e+00 |       89213 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.5 | 1.3745e-01 | 1.0000e+00 |       73472 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.0 | 8.8532e-02 | 9.9219e-01 |       47323 |      534528 |          127 |         128 |         0.3 |reached target block errors
#       2.5 | 1.7470e-02 | 7.4219e-01 |        9338 |      534528 |           95 |         128 |         0.3 |reached target block errors
#       3.0 | 7.6783e-04 | 5.9152e-02 |        2873 |     3741696 |           53 |         896 |         2.3 |reached target block errors
#       3.5 | 2.0412e-04 | 4.2459e-03 |       10038 |    49176576 |           50 |       11776 |        30.8 |reached target block errors
#       4.0 | 1.3143e-04 | 2.1463e-03 |       12786 |    97284096 |           50 |       23296 |        61.0 |reached target block errors
#       4.5 | 5.2234e-05 | 7.5850e-04 |       14379 |   275281920 |           50 |       65920 |       172.6 |reached target block errors
#       5.0 | 3.5689e-05 | 3.6719e-04 |       19077 |   534528000 |           47 |      128000 |       335.2 |reached max iter
#       5.5 | 1.6214e-05 | 2.1875e-04 |        8667 |   534528000 |           28 |      128000 |       335.1 |reached max iter
#       6.0 | 6.3926e-06 | 1.0156e-04 |        3417 |   534528000 |           13 |      128000 |       335.1 |reached max iter
#       6.5 | 2.2749e-06 | 6.2500e-05 |        1216 |   534528000 |            8 |      128000 |       335.1 |reached max iter
#       7.0 | 1.4293e-06 | 1.5625e-05 |         764 |   534528000 |            2 |      128000 |       335.1 |reached max iter
#       7.5 | 3.8034e-06 | 3.1250e-05 |        2033 |   534528000 |            4 |      128000 |       334.9 |reached max iter
#       8.0 | 1.7043e-06 | 1.5625e-05 |         911 |   534528000 |            2 |      128000 |       334.7 |reached max iter
#       8.5 | 1.4686e-06 | 7.8125e-06 |         785 |   534528000 |            1 |      128000 |       334.7 |reached max iter
#       9.0 | 1.4162e-06 | 7.8125e-06 |         757 |   534528000 |            1 |      128000 |       334.7 |reached max iter
#       9.5 | 0.0000e+00 | 0.0000e+00 |           0 |   534528000 |            0 |      128000 |       334.6 |reached max iter
#
# Simulation stopped as no error occurred @ EbNo = 9.5 dB.

# %% [markdown]
# Finally, we plots the BLERs

# %%
with open(results_filename, 'rb') as file:
        ebno_dbs, BLER = pickle.load(file)
    
plt.figure(figsize=(10,6))
# Baseline - Perfect CSI
plt.semilogy(ebno_dbs, BLER['baseline-perfect-csi'], 'o-', c=f'C0', label=f'Baseline - Perfect CSI')
# Baseline - LS Estimation
plt.semilogy(ebno_dbs, BLER['baseline-ls-estimation'], 'x--', c=f'C1', label=f'Baseline - LS Estimation')
# Neural receiver - standard mapper
plt.semilogy(ebno_dbs, BLER['neural-receiver-standard'], 's-.', c=f'C2', label=f'Standard mapper + Neural receiver')
# Neural receiver - trained mapper
plt.semilogy(ebno_dbs, BLER['neural-receiver-trained'], 's-.', c=f'C3', label=f'Trained mapper + Neural receiver')
#
plt.xlabel(r"$E_b/N_0$ (dB)")
plt.ylabel("BLER")
plt.grid(which="both")
plt.ylim((1e-5, 1.0))
plt.legend()
plt.tight_layout()

# %% [markdown]
# ## Learned Constellation <a class="anchor" id="Constellation"></a>

# %%
# Utility function to load and set weights of a mode
def load_weights(model, model_weights_path):
    model(1, tf.constant(10.0, tf.float32))
    with open(model_weights_path, 'rb') as f:
        weights = pickle.load(f)
    model.set_weights(weights)

# %%
model = E2ESystem('neural-receiver-trained', training=True)
load_weights(model, model_weights_path_trained)

# fig = model.constellation.show()
constellation = model.constellation
figsize=(10,10)
maxval = np.max(np.abs(constellation.points))*1.05
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(111)
plt.xlim(-maxval, maxval)
plt.ylim(-maxval, maxval)
plt.scatter(np.real(constellation.points), np.imag(constellation.points))
ax.set_aspect("equal", adjustable="box")
plt.grid(True, which="both", axis="both")
plt.title("Trained mapper")
plt.xlabel("Real Part")
plt.ylabel("Imaginary Part")
for j, p in enumerate(constellation.points):
    plt.annotate(
        np.binary_repr(j, num_bits_per_symbol),
        (np.real(p), np.imag(p))
    )

# %% [markdown]
# ## References <a class="anchor" id="References"></a>

# %% [markdown]
# [1] M. Honkala, D. Korpi and J. M. J. Huttunen, "DeepRx: Fully Convolutional Deep Learning Receiver," in IEEE Transactions on Wireless Communications, vol. 20, no. 6, pp. 3925-3940, June 2021, doi: 10.1109/TWC.2021.3054520.
#
# [2] F. Ait Aoudia and J. Hoydis, "End-to-end Learning for OFDM: From Neural Receivers to Pilotless Communication," in IEEE Transactions on Wireless Communications, doi: 10.1109/TWC.2021.3101364.
#
# [3] Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun, "Deep Residual Learning for Image Recognition", Proceedings of the IEEE Conference on Computer Vision and Pattern Recognition (CVPR), 2016, pp. 770-778
#
# [4] G. Böcherer, "Achievable Rates for Probabilistic Shaping", arXiv:1707.01134, 2017.
