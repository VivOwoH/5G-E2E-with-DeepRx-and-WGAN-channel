# %% [markdown]
# # Neural Receiver for OFDM SIMO Systems

# %% [markdown]
# ## GPU Configuration and Imports <a class="anchor" id="GPU-Configuration-and-Imports"></a>

# %%
import os
import tensorflow as tf
import sys
import gc
print(sys.version)
print(sys.executable)
print(sys.version_info)

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0" # 0,1,2,3
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"

# Configure the notebook to use only a single GPU and allocate only as much memory as needed
# For more details, see https://www.tensorflow.org/guide/gpu
gpus = tf.config.list_physical_devices('GPU')

print(gpus)

if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print("Error loading GPU:", e)
# Avoid warnings from TensorFlow
tf.get_logger().setLevel('ERROR')
# Out:
# 3.10.12 (main, Jan 26 2026, 14:55:28) [GCC 11.4.0]
# /usr/bin/python3
# sys.version_info(major=3, minor=10, micro=12, releaselevel='final', serial=0)
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Import Sionna
try:
    import sionna
except ImportError as e:
    # Install Sionna if package is not already installed
    import os
    os.system("pip install sionna")
    import sionna

sionna.phy.config.seed = 42 # Set seed for reproducible random number generation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pickle

from tensorflow.keras import Model
from tensorflow.keras.layers import Layer, Conv2D, LayerNormalization, Dense, ReLU, Reshape, Conv2DTranspose, LeakyReLU, Flatten, Embedding
from tensorflow.nn import relu
from tensorflow.keras.models import Sequential

from sionna.phy.channel.tr38901 import Antenna, AntennaArray, CDL
from sionna.phy.channel import OFDMChannel, RayleighBlockFading, GenerateOFDMChannel
from sionna.phy.mimo import StreamManagement
from sionna.phy.ofdm import ResourceGrid, ResourceGridMapper, LSChannelEstimator, LMMSEEqualizer, LinearInterpolator, RemoveNulledSubcarriers, ResourceGridDemapper, LMMSEInterpolator, BaseChannelEstimator, BaseChannelInterpolator
from sionna.phy.utils import ebnodb2no, insert_dims, flatten_last_dims, log10, expand_to_rank, split_dim
from sionna.phy.fec.ldpc.encoding import LDPC5GEncoder
from sionna.phy.fec.ldpc.decoding import LDPC5GDecoder
from sionna.phy.mapping import BinarySource, Mapper, Demapper, Constellation
from sionna.phy.utils.metrics import compute_ber
from sionna.phy.utils import sim_ber, hard_decisions

from tqdm.auto import tqdm

# %% [markdown]
# ## Simulation Parameters <a class="anchor" id="Simulation-Parameters"></a>

# %%
# ## Channel configuration
carrier_frequency = 3.5e9 # Hz
cdl_model = "C" # CDL model to use
delay_spread = 100e-9 # s, Bc=1.59 MHz
speed = 10.0 # Speed for evaluation and training [m/s], Tc=4.3ms

# Ultra-high coherence channel
# delay_spread = 10e-9  # 10 ns → Bc ≈ 16 MHz
# speed = 0.1  # 0.1 m/s → Tc ≈ 428 ms

# SNR range for evaluation and training [dB]
ebno_db_min = 0.0
ebno_db_max = 15.0

############################################
## OFDM waveform configuration
subcarrier_spacing = 30e3 # Hz
fft_size = 128 # Number of subcarriers forming the resource grid, including the null-subcarrier and the guard bands
num_ofdm_symbols = 14 # Number of OFDM symbols forming the resource grid
dc_null = True # Null the DC subcarrier
num_guard_carriers = [5, 6] # Number of guard carriers on each side
pilot_pattern = "kronecker" # Pilot pattern
pilot_ofdm_symbol_indices = [2, 11] # Index of OFDM symbols carrying pilots
cyclic_prefix_length = 0 # Simulation in frequency domain. This is useless

############################################
## Modulation and coding configuration
num_bits_per_symbol = 6 # 64-QAM
coderate = 0.5 # 0.5 # Coderate for LDPC code
noise_dim = 100

############################################
## Neural receiver configuration
num_conv_channels = 128 # Number of convolutional channels for the convolutional layers forming the neural receiver
GAN_DIM=64

############################################
## Training configuration
num_training_iterations = 30000 # Number of training iterations
batch_size = 128 # Training batch size
training_batch_size = 32

# %% [markdown]
# The `StreamManagement` class is used to configure the receiver-transmitter association and the number of streams per transmitter.
# A SIMO system is considered, with a single transmitter equipped with a single non-polarized antenna.
# Therefore, there is only a single stream, and the receiver-transmitter association matrix is $[1]$.
# The receiver is equipped with an antenna array.

# %%
stream_manager = StreamManagement(np.array([[1]]), # Receiver-transmitter association matrix
                                  1)               # One stream per transmitter

# %% [markdown]
# The `ResourceGrid` class is used to configure the OFDM resource grid. It is initialized with the parameters defined above.

# %%
resource_grid = ResourceGrid(num_ofdm_symbols = num_ofdm_symbols,
                             fft_size = fft_size,
                             subcarrier_spacing = subcarrier_spacing,
                             num_tx = 1,
                             num_streams_per_tx = 1,
                             cyclic_prefix_length = cyclic_prefix_length,
                             dc_null = dc_null,
                             pilot_pattern = pilot_pattern,
                             pilot_ofdm_symbol_indices = pilot_ofdm_symbol_indices,
                             num_guard_carriers = num_guard_carriers)

# %% [markdown]
# Outer coding is performed such that all the databits carried by the resource grid with size `fft_size`x`num_ofdm_symbols` form a single codeword.

# %%
MOD_ORDERS      = [2, 4, 6]          # QPSK, 16QAM, 64QAM → bits per symbol
MOD_IDX_MAP     = {2: 0, 4: 1, 6: 2} # for FiLM embedding lookup
max_bits_per_symbol = 6
# Pre-compute (k, n) per modulation
def compute_kn(nbps):
    n_ = int(resource_grid.num_data_symbols * nbps)
    k_ = int(n_ * coderate)
    return k_, n_
KN_TABLE = {nbps: compute_kn(nbps) for nbps in MOD_ORDERS}
print(KN_TABLE)
# Out:
# {2: (1392, 2784), 4: (2784, 5568), 6: (4176, 8352)}

# %%
# Codeword length. It is calculated from the total number of databits carried by the resource grid, and the number of bits transmitted per resource element
n = int(resource_grid.num_data_symbols*num_bits_per_symbol)
# Number of information bits per codeword
k = int(n*coderate)

print(n, k)
# Out:
# 8352 4176

# %% [markdown]
# The SIMO link is setup by considering an uplink transmission with one user terminal (UT) equipped with a single non-polarized antenna, and a base station (BS) equipped with an antenna array.
# One can try other configurations for the BS antenna array.

# %%
ut_antenna = Antenna(polarization="single",
                     polarization_type="V",
                     antenna_pattern="38.901",
                     carrier_frequency=carrier_frequency)

# bs_array = AntennaArray(num_rows=1,
#                         num_cols=1,
#                         polarization="dual",
#                         polarization_type="VH",
#                         antenna_pattern="38.901",
#                         carrier_frequency=carrier_frequency)

bs_array = AntennaArray(num_rows=1,
                        num_cols=1,
                        polarization="single", # dual
                        polarization_type="V", # VH
                        antenna_pattern="38.901",
                        carrier_frequency=carrier_frequency)

# %% [markdown]
# ## New Neural Receiver

# %%
class ResidualBlock(Layer):
    r"""
    Input
    ------
    : [batch size, num time samples, num subcarriers, num_conv_channel], tf.float
        Input of the layer
    Output
    -------
    : [batch size, num time samples, num subcarriers, num_conv_channel], tf.float
        Output of the layer
    """

    def __init__(self, kernel_size=[3,3], **kwargs):
        super().__init__(**kwargs)
        self._kernel_size = kernel_size
        # Layer normalization is done over the last three dimensions: time, frequency, conv 'channels'
        self._layer_norm_1 = LayerNormalization(axis=(-1, -2, -3))
        self._conv_1 = Conv2D(filters=num_conv_channels,
                              kernel_size=self._kernel_size,
                              padding='same',
                              activation=None)
        # Layer normalization is done over the last three dimensions: time, frequency, conv 'channels'
        self._layer_norm_2 = LayerNormalization(axis=(-1, -2, -3))
        self._conv_2 = Conv2D(filters=num_conv_channels,
                              kernel_size=self._kernel_size,
                              padding='same',
                              activation=None)

    def call(self, inputs):
        z = self._layer_norm_1(inputs)
        z = relu(z)
        z = self._conv_1(z)
        z = self._layer_norm_2(z)
        z = relu(z)
        z = self._conv_2(z) # [batch size, num time samples, num subcarriers, num_channels]
        # Skip connection
        z = z + inputs

        return z

# %%
class NR_NN1(Model):
    """
        y_pilot, x_pilot, no                      [batch, 2, fft_size], [batch]
            ↓  stack real/imag + tile no          [batch, 2, fft_size, 5]
            ↓  input Conv2D [1,3]  (freq only)
            ↓  ResBlock [1,3]*2                 ← denoise along frequency
                                                  [batch, 2, fft_size, C]
            ↓  Dense(2 → 14) along time axis      ← learned interpolation
                                                  [batch, 14, fft_size, C]
        Output: H_feature

    Input
    -----
    y_pilot : [batch, 2, fft_size], tf.complex64
    x_pilot : [batch, 2, fft_size], tf.complex64
    no      : [batch], tf.float32

    Output
    ------
    H_feature : [batch, 14, fft_size, num_conv_channels], tf.float32
    """

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        # Input convolution (frequency only, 1x3)
        self._input_conv = Conv2D(filters=num_conv_channels,
                                kernel_size=[1,3],
                                padding='same',
                                activation=None)
        
        # Residual blocks for frequency denoising
        self._res_block_freq_1 = ResidualBlock(kernel_size=[1,3])
        self._res_block_freq_2 = ResidualBlock(kernel_size=[1,3])

        # interpolation from 2 pilot symbols to 14 OFDM symbols
        self._interp_dense = Dense(14, activation=None)

    def call(self, y_pilot, x_pilot, no):
        # Feeding the noise power in log10 scale helps with the performance
        no = log10(no)
        no = insert_dims(no, 3, 1)  # [batch, 1, 1, 1]
        no = tf.tile(no, [1, 2, y_pilot.shape[-1], 1])  # [batch, 2, fft_size, 1]

        # Stack real and imaginary parts of y_pilot and x_pilot
        z = tf.stack([tf.math.real(y_pilot),
                      tf.math.imag(y_pilot),
                      tf.math.real(x_pilot),
                      tf.math.imag(x_pilot)], axis=-1)  # [batch, 2, fft_size, 4]
        
        # Concatenate noise channel
        z = tf.concat([z, no], axis=-1)  # [batch, 2, fft_size, 5]

        # Input conv (frequency only)
        z = self._input_conv(z)
        # frequency denoising
        z = self._res_block_freq_1(z)
        z = self._res_block_freq_2(z) # z : [batch, 2, 128, channel]

        # interpolation along time axis
        z = tf.transpose(z, [0, 2, 3, 1]) # [batch, 128, channel, 2]
        z = self._interp_dense(z)
        z = tf.transpose(z, [0, 3, 1, 2]) # [batch, 14, 128, channel]

        return z


class NR_NN2(Model):
    """
    Input
    -----
    H_feature : [batch, 14, fft_size, C],          tf.float32
    no        : [batch, 1],                        tf.float32
    y         : [batch, num_rx_ant, 14, fft_size], tf.complex64
    constellation_points : [M, 2],                 tf.float32

    Output
    ------
    llrs : [batch, 14, fft_size, num_bits_per_symbol], tf.float32
        LLRs at non-data positions discarded.
    """

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        # Input convolution
        self._input_conv = Conv2D(filters=num_conv_channels,
                                  kernel_size=[3,3],
                                  padding='same',
                                  activation=None)
        # Residual blocks
        self._res_block_1 = ResidualBlock()
        self._res_block_2 = ResidualBlock()
        self._res_block_3 = ResidualBlock()
        self._res_block_4 = ResidualBlock()
        # Output conv
        self._output_conv = Conv2D(filters=num_bits_per_symbol,
                                   kernel_size=[3,3],
                                   padding='same',
                                   activation=None)

    def call(self, H_feature, y, no, constellation_points):
        # Feeding the noise power in log10 scale helps with the performance
        no = log10(no)

        # Stacking the real and imaginary components along the 'channel' dimension
        y = tf.transpose(y, [0, 2, 3, 1]) # Putting antenna dimension last
        no = insert_dims(no, 3, 1)
        no = tf.tile(no, [1, y.shape[1], y.shape[2], 1])
        
        z = tf.concat([tf.math.real(y),
                       tf.math.imag(y),
                       no,
                       H_feature], axis=-1) # z : [batch size, 14, 128, 2*rx_ant + 1 + conv]
        
        # constellation_points [M, 2] flatten to [2*M]
        const_flat = tf.reshape(constellation_points, [-1])
        batch_size = tf.shape(z)[0] # [batch, 14, 128, 2*M]
        const_tiled = tf.tile(tf.reshape(const_flat, [1, 1, 1, -1]),
                                [batch_size, z.shape[1], z.shape[2], 1])
        z = tf.concat([z, const_tiled], axis=-1)  # [batch, 14, 128, 2*rx_ant + 1 + conv + 2*M]

        # Input conv
        z = self._input_conv(z)
        # Residual blocks
        z = self._res_block_1(z)
        z = self._res_block_2(z)
        z = self._res_block_3(z)
        z = self._res_block_4(z)
        # Output conv
        z = self._output_conv(z)

        return z


class NeuralReceiver(Model):
    """
    Keras layer implementing a residual convolutional neural receiver.

    This neural receiver is fed with the post-DFT received samples, forming a resource grid of size num_of_symbols x fft_size, and computes LLRs on the transmitted coded bits.
    These LLRs can then be fed to an outer decoder to reconstruct the information bits.

    As the neural receiver is fed with the entire resource grid, including the guard bands and pilots, it also computes LLRs for these resource elements.
    They must be discarded to only keep the LLRs corresponding to the data-carrying resource elements.

    Input
    ------
    y : [batch size, num rx antenna, num ofdm symbols, num subcarriers], tf.complex
        Received post-DFT samples.
    no : [batch size], tf.float32
        Noise variance. At training, a different noise variance value is sampled for each batch example.
    constellation_points : [M, 2], tf.float32
        Constellation from mapper (optional)

    Output
    -------
    : [batch size, num ofdm symbols, num subcarriers, num_bits_per_symbol]
        LLRs on the transmitted bits.
        LLRs computed for resource elements not carrying data (pilots, guard bands...) must be discarded.
    """

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self._channel_estimation = NR_NN1()
        self._equalization = NR_NN2()

    def call(self, y, no, y_pilot, x_pilot, constellation_points):
        # NN1: Channel estimation and interpolation
        H_feature = self._channel_estimation(y_pilot, x_pilot, no)
        # NN2: Equalization and demapping
        llrs = self._equalization(H_feature, y, no, constellation_points)
        return llrs

# %%
NR = NeuralReceiver()
y_pilot = tf.zeros([1, 2, 128], dtype=tf.complex64)
x_pilot = tf.zeros([1, 2, 128], dtype=tf.complex64)
y = tf.zeros([1, 1, 14, 128], dtype=tf.complex64)
no = tf.zeros([1], dtype=tf.float32)
constellation_points = tf.zeros([64, 2], dtype=tf.float32)

_ = NR(y, no, y_pilot, x_pilot, constellation_points=constellation_points)
NR._channel_estimation.summary()
NR._equalization.summary()
# Out:
# 2026-02-27 11:57:20.881924: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2026-02-27 11:57:21.170470: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Model: "nr_nn1_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          multiple                  2048
#
#  residual_block_6 (Residual  multiple                  229632
#  Block)
#
#  residual_block_7 (Residual  multiple                  229632
#  Block)
#
#  dense_1 (Dense)             multiple                  42
#
# =================================================================
# Total params: 461354 (1.76 MB)
# Trainable params: 461354 (1.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "nr_nn2_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          multiple                  298496
#
#  residual_block_8 (Residual  multiple                  1212672
#  Block)
#
#  residual_block_9 (Residual  multiple                  1212672
#  Block)
#
#  residual_block_10 (Residua  multiple                  1212672
#  lBlock)
#
#  residual_block_11 (Residua  multiple                  1212672
#  lBlock)
#
#  conv2d_29 (Conv2D)          multiple                  6918
#
# =================================================================
# Total params: 5156102 (19.67 MB)
# Trainable params: 5156102 (19.67 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Modulation-agnostic NR (FiLM)

# %%
class ResidualBlock(Layer):
    def __init__(self, kernel_size=[3,3], **kwargs):
        super().__init__(**kwargs)
        self._layer_norm_1 = LayerNormalization(axis=(-1, -2, -3))
        self._conv_1 = Conv2D(filters=num_conv_channels, kernel_size=kernel_size, padding='same', activation=None)
        self._layer_norm_2 = LayerNormalization(axis=(-1, -2, -3))
        self._conv_2 = Conv2D(filters=num_conv_channels, kernel_size=kernel_size, padding='same', activation=None)
        self._film = Dense(2 * num_conv_channels, activation=None)

    def call(self, inputs, cond):
        gamma, beta = tf.split(self._film(cond), 2, axis=-1)
        gamma = insert_dims(gamma, 2, 1)  # [batch, 1, 1, C]
        beta  = insert_dims(beta,  2, 1)

        z = self._layer_norm_1(inputs)
        z = gamma * z + beta
        z = relu(z)
        z = self._conv_1(z)

        z = self._layer_norm_2(z)
        z = gamma * z + beta
        z = relu(z)
        z = self._conv_2(z)

        return z + inputs

class FiLMConditioner(Layer):
    def __init__(self, num_mod_orders=3, **kwargs):
        super().__init__(**kwargs)
        self._mod_embedding = Embedding(num_mod_orders, 16)  # 0=QPSK, 1=16QAM, 2=64QAM

    def call(self, mcs_idx, no_log):
        mod_emb = self._mod_embedding(mcs_idx) # [batch, 16]
        return tf.concat([mod_emb, no_log[:, None]], axis=-1) # [batch, 17]

# %%
class NR_NN1(Model):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self._input_conv = Conv2D(filters=num_conv_channels, kernel_size=[1,3], padding='same', activation=None)
        self._res_block_freq_1 = ResidualBlock(kernel_size=[1,3])
        self._res_block_freq_2 = ResidualBlock(kernel_size=[1,3])
        self._interp_dense = Dense(14, activation=None)

    def call(self, y_pilot, x_pilot, no_log, cond):
        # no_log already log10-scaled
        no = insert_dims(no_log, 3, 1)
        no = tf.tile(no, [1, 2, y_pilot.shape[-1], 1]) # [batch, 2, fft_size, 1]

        z = tf.stack([tf.math.real(y_pilot),
                      tf.math.imag(y_pilot),
                      tf.math.real(x_pilot),
                      tf.math.imag(x_pilot)], axis=-1) # [batch, 2, fft_size, 4]
        z = tf.concat([z, no], axis=-1) # [batch, 2, fft_size, 5]

        z = self._input_conv(z)
        z = self._res_block_freq_1(z, cond)
        z = self._res_block_freq_2(z, cond) # [batch, 2, fft_size, C]

        z = tf.transpose(z, [0, 2, 3, 1]) # [batch, fft_size, C, 2]
        z = self._interp_dense(z)
        z = tf.transpose(z, [0, 3, 1, 2]) # [batch, 14, fft_size, C]
        return z


class NR_NN2(Model):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self._input_conv = Conv2D(filters=num_conv_channels, kernel_size=[3,3], padding='same', activation=None)
        self._res_block_1 = ResidualBlock()
        self._res_block_2 = ResidualBlock()
        self._res_block_3 = ResidualBlock()
        self._res_block_4 = ResidualBlock()
        self._output_conv = Conv2D(filters=num_bits_per_symbol, kernel_size=[3,3], padding='same', activation=None)

    def call(self, H_feature, y, no_log, cond):
        y = tf.transpose(y, [0, 2, 3, 1]) # [batch, 14, fft_size, rx_ant]

        no = insert_dims(no_log, 3, 1)
        no = tf.tile(no, [1, y.shape[1], y.shape[2], 1]) # [batch, 14, fft_size, 1]

        z = tf.concat([tf.math.real(y), tf.math.imag(y), no, H_feature], axis=-1)

        z = self._input_conv(z)
        z = self._res_block_1(z, cond)
        z = self._res_block_2(z, cond)
        z = self._res_block_3(z, cond)
        z = self._res_block_4(z, cond)
        z = self._output_conv(z)
        return z


class NeuralReceiver(Model):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self._conditioner = FiLMConditioner()
        self._channel_estimation = NR_NN1()
        self._equalization = NR_NN2()

    def call(self, y, no, y_pilot, x_pilot, mcs_idx):
        no_log = log10(no) # log10 here for easier computation
        cond = self._conditioner(mcs_idx, no_log) # [batch, 17]

        H_feature = self._channel_estimation(y_pilot, x_pilot, no_log, cond)
        llrs = self._equalization(H_feature, y, no_log, cond)
        return llrs

# %%
NR = NeuralReceiver()

y_pilot = tf.zeros([1, 2, 128], dtype=tf.complex64)
x_pilot = tf.zeros([1, 2, 128], dtype=tf.complex64)
y = tf.zeros([1, 1, 14, 128], dtype=tf.complex64)
no = tf.ones([1], dtype=tf.float32)
mcs_idx = tf.zeros([1], dtype=tf.int32)

_ = NR(y, no, y_pilot, x_pilot, mcs_idx)

NR._channel_estimation.summary()
NR._equalization.summary()
# Out:
# Model: "nr_nn1_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_210 (Conv2D)         multiple                  2048
#
#  residual_block_84 (Residua  multiple                  234240
#  lBlock)
#
#  residual_block_85 (Residua  multiple                  234240
#  lBlock)
#
#  dense_34 (Dense)            multiple                  42
#
# =================================================================
# Total params: 470570 (1.80 MB)
# Trainable params: 470570 (1.80 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "nr_nn2_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_215 (Conv2D)         multiple                  151040
#
#  residual_block_86 (Residua  multiple                  1217280
#  lBlock)
#
#  residual_block_87 (Residua  multiple                  1217280
#  lBlock)
#
#  residual_block_88 (Residua  multiple                  1217280
#  lBlock)
#
#  residual_block_89 (Residua  multiple                  1217280
#  lBlock)
#
#  conv2d_224 (Conv2D)         multiple                  6918
#
# =================================================================
# Total params: 5027078 (19.18 MB)
# Trainable params: 5027078 (19.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## End-to-end System <a class="anchor" id="End-to-end-System"></a>

# %% [markdown]
# ### MLP-mapper

# %%
class SNRNFMapper(Layer):
    def __init__(self,
                 num_bits_per_symbol,
                 **kwargs):
        super().__init__(**kwargs)
        self.num_bits_per_symbol = num_bits_per_symbol
        self.num_constellation_points = 2 ** num_bits_per_symbol
        
        # Base QAM constellation
        qam_points = Constellation("qam", num_bits_per_symbol).points
        
        # Trainable base constellation using tf.Variable
        self.base_points_r = tf.Variable(
            initial_value=tf.math.real(qam_points),
            trainable=True,
            dtype=tf.float32,
            name='base_points_r'
        )
        self.base_points_i = tf.Variable(
            initial_value=tf.math.imag(qam_points),
            trainable=True,
            dtype=tf.float32,
            name='base_points_i'
        )
        
        # SNR embedding network (generates constellation adjustments)
        self.snr_dense1 = Dense(256, activation='relu', name='snr_embed1')
        self.constellation_I_dense = Dense(self.num_constellation_points, name='constellation_I')
        self.constellation_Q_dense = Dense(self.num_constellation_points, name='constellation_Q')
        
        # Bit positions for mapping
        n = num_bits_per_symbol
        self._bit_positions = tf.cast(tf.range(n-1, -1, -1), dtype=tf.int32)
    
    def call(self, bits, ebno_db, training=False):
        """
        Args:
            bits: [..., num_bits] binary tensor
            ebno_db: scalar or [...] - SNR in dB
        Returns:
            x_real: [..., num_symbols, 2] where last dim is [I, Q]
            constellation_points: [M] complex - for visualization
        """
        batch_size = tf.shape(bits)[0]
        
        # Process SNR through embedding network
        ebno_db_expanded = tf.reshape(ebno_db, [batch_size, 1])
        ebno_db_expanded = tf.cast(ebno_db_expanded, tf.float32)
        
        x = self.snr_dense1(ebno_db_expanded, training=training)
        
        points_r = self.constellation_I_dense(x, training=training)  # [batch, M]
        points_i = self.constellation_Q_dense(x, training=training)  # [batch, M]
        
        # Aggregate to single constellation (non-batched)
        points_r = tf.reduce_mean(points_r, axis=0)  # [M]
        points_i = tf.reduce_mean(points_i, axis=0)  # [M]
        
        # Normalize to unit average energy
        point_energy = points_r**2 + points_i**2
        avg_energy = tf.reduce_mean(point_energy)
        norm_factor = tf.sqrt(avg_energy)
        points_r = points_r / norm_factor
        points_i = points_i / norm_factor
        
        # Convert bits to indices
        bits = tf.cast(bits, dtype=tf.int32)
        n1 = int(bits.shape[-1] / self.num_bits_per_symbol)
        new_shape = [n1, self.num_bits_per_symbol]
        bits = split_dim(bits, new_shape, axis=tf.rank(bits)-1)
        
        shifted_bits = tf.bitwise.left_shift(bits, self._bit_positions)
        int_rep = tf.reduce_sum(shifted_bits, axis=-1)
        
        # Map bits to constellation (non-batched, so axis=0)
        x_I = tf.gather(points_r, int_rep, axis=0)
        x_Q = tf.gather(points_i, int_rep, axis=0)
        
        constellation_points = tf.complex(points_r, points_i)  # for checking
        
        x_real = tf.stack([x_I, x_Q], axis=-1)
        
        return x_real, constellation_points

# %% [markdown]
# ### Res-mapper

# %%
class ResidualBlock1D(Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self._layer_norm_1 = LayerNormalization(axis=-1)
        self._dense_1 = Dense(256, activation=None)
        self._layer_norm_2 = LayerNormalization(axis=-1)
        self._dense_2 = Dense(256, activation=None)

    def call(self, inputs):
        z = self._layer_norm_1(inputs)
        z = relu(z)
        z = self._dense_1(z)
        z = self._layer_norm_2(z)
        z = relu(z)
        z = self._dense_2(z)
        # Skip connection
        z = z + inputs
        return z

class SNRNFMapper(Layer):
    def __init__(self, num_bits_per_symbol, **kwargs):
        super().__init__(**kwargs)
        self.num_bits_per_symbol = num_bits_per_symbol
        self.num_constellation_points = 2 ** num_bits_per_symbol
        
        # SNR embedding network with ResNet
        self._input_dense = Dense(256, activation=None, name='snr_input')
        self._res_blocks = [ResidualBlock1D(name=f'res_block_{i}') for i in range(3)]
        self._output_dense_I = Dense(self.num_constellation_points, name='constellation_I')
        self._output_dense_Q = Dense(self.num_constellation_points, name='constellation_Q')
        
        # mapping bit positions
        n = num_bits_per_symbol
        self._bit_positions = tf.cast(tf.range(n-1, -1, -1), dtype=tf.int32)
    
    def call(self, bits, ebno_db, training=False):
        """
        Args:
            bits: [..., num_bits] binary tensor
            ebno_db: scalar or [...] - SNR in dB
        Returns:
            x_real: [..., num_symbols, 2] where last dim is [I, Q]
            constellation_points: [M] complex - for visualization
        """
        batch_size = tf.shape(bits)[0]
        
        # Process SNR through ResNet
        ebno_db_expanded = tf.reshape(ebno_db, [batch_size, 1])
        ebno_db_expanded = tf.cast(ebno_db_expanded, tf.float32)
        
        z = self._input_dense(ebno_db_expanded, training=training)
        for res_block in self._res_blocks:
            z = res_block(z)
        
        points_r = self._output_dense_I(z, training=training)  # [batch, M]
        points_i = self._output_dense_Q(z, training=training)  # [batch, M]
        
        # Aggregate to single constellation (non-batched)
        points_r = tf.reduce_mean(points_r, axis=0)  # [M]
        points_i = tf.reduce_mean(points_i, axis=0)  # [M]
        
        # Normalize to unit average energy
        point_energy = points_r**2 + points_i**2
        avg_energy = tf.reduce_mean(point_energy)
        norm_factor = tf.sqrt(avg_energy)
        points_r = points_r / norm_factor
        points_i = points_i / norm_factor
        
        # Convert bits to indices
        bits = tf.cast(bits, dtype=tf.int32)
        n1 = int(bits.shape[-1] / self.num_bits_per_symbol)
        new_shape = [n1, self.num_bits_per_symbol]
        bits = split_dim(bits, new_shape, axis=tf.rank(bits)-1)
        
        shifted_bits = tf.bitwise.left_shift(bits, self._bit_positions)
        int_rep = tf.reduce_sum(shifted_bits, axis=-1)
        
        # Map bits to constellation (non-batched, so axis=0)
        x_I = tf.gather(points_r, int_rep, axis=0)
        x_Q = tf.gather(points_i, int_rep, axis=0)
        
        constellation_points = tf.complex(points_r, points_i)
        
        x_real = tf.stack([x_I, x_Q], axis=-1)
        
        return x_real, constellation_points

# %% [markdown]
# ### FiLM-mapper

# %%
class ResidualBlock1D(Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self._layer_norm_1 = LayerNormalization(axis=-1)
        self._dense_1 = Dense(256, activation=None)
        self._layer_norm_2 = LayerNormalization(axis=-1)
        self._dense_2 = Dense(256, activation=None)
        self._film = Dense(2 * 256, activation=None)

    def call(self, inputs, cond):
        gamma, beta = tf.split(self._film(cond), 2, axis=-1)  # [batch, 256] each

        z = self._layer_norm_1(inputs)
        z = gamma * z + beta
        z = relu(z)
        z = self._dense_1(z)

        z = self._layer_norm_2(z)
        z = gamma * z + beta
        z = relu(z)
        z = self._dense_2(z)

        return z + inputs


class ResSNRFiLMMapper(Layer):
    def __init__(self, max_bits_per_symbol=6, num_mod_orders=3, **kwargs):
        """
        max_bits_per_symbol: largest M used (e.g. 6 for 64QAM)
        num_mod_orders:      number of modulation orders (e.g. 3 for QPSK/16QAM/64QAM)
        """
        super().__init__(**kwargs)
        self.max_bits_per_symbol = max_bits_per_symbol
        self.max_constellation_points = 2 ** max_bits_per_symbol # 6=64

        # conditioning: mod order embedding + SNR
        self._mod_embedding = Embedding(num_mod_orders, 16)  # 0=QPSK, 1=16QAM, 2=64QAM
        self._cond_dense = Dense(256, activation=None, name='cond_input')

        # ResNet trunk
        self._input_dense = Dense(256, activation=None, name='snr_input')
        self._res_blocks = [ResidualBlock1D(name=f'res_block_{i}') for i in range(3)]

        self._output_dense_I = Dense(self.max_constellation_points, name='constellation_I')
        self._output_dense_Q = Dense(self.max_constellation_points, name='constellation_Q')

    def call(self, bits, ebno_db, mcs_idx, num_bits_per_symbol, training=False):
        """
        Args:
            bits:                [..., num_bits] binary tensor
            ebno_db:             [batch] or scalar
            mcs_idx:             [batch] int - 0=QPSK, 1=16QAM, 2=64QAM
            num_bits_per_symbol: scalar int - actual M for this batch
        Returns:
            x_real:              [..., num_symbols, 2] where last dim is [I, Q]
            constellation_points:[M] complex - for visualization
        """
        batch_size = tf.shape(bits)[0]
        num_constellation_points = 2 ** num_bits_per_symbol

        # prepare conditioning
        ebno = tf.reshape(tf.cast(ebno_db, tf.float32), [batch_size, 1])
        mod_emb = self._mod_embedding(mcs_idx) # [batch, 16]
        cond_raw = tf.concat([ebno, mod_emb], axis=-1) # [batch, 17]
        cond = self._cond_dense(cond_raw) # [batch, 256]

        z = self._input_dense(ebno, training=training) # input SNR
        for res_block in self._res_blocks:
            z = res_block(z, cond) # FiLM conditioning

        points_r = self._output_dense_I(z, training=training) # [batch, 64]
        points_i = self._output_dense_Q(z, training=training) # [batch, 64]

        # slice to actual constellation size
        points_r = points_r[:, :num_constellation_points] # [batch, M]
        points_i = points_i[:, :num_constellation_points] # [batch, M]

        # normalize
        points_r = tf.reduce_mean(points_r, axis=0) # [M]
        points_i = tf.reduce_mean(points_i, axis=0) # [M]
        avg_energy = tf.reduce_mean(points_r**2 + points_i**2)
        norm_factor = tf.sqrt(avg_energy)
        points_r = points_r / norm_factor
        points_i = points_i / norm_factor

        bit_positions = tf.cast(tf.range(num_bits_per_symbol - 1, -1, -1), dtype=tf.int32)
        bits = tf.cast(bits, dtype=tf.int32)
        n1 = int(bits.shape[-1] / num_bits_per_symbol)
        bits = split_dim(bits, [n1, num_bits_per_symbol], axis=tf.rank(bits) - 1)
        int_rep = tf.reduce_sum(tf.bitwise.left_shift(bits, bit_positions), axis=-1)

        x_I = tf.gather(points_r, int_rep, axis=0)
        x_Q = tf.gather(points_i, int_rep, axis=0)

        constellation_points = tf.complex(points_r, points_i)
        x_real = tf.stack([x_I, x_Q], axis=-1)

        return x_real, constellation_points

# %%
## Transmitter
binary_source = BinarySource()
qam_mapper = Mapper("qam", num_bits_per_symbol)
mapper = SNRNFMapper(num_bits_per_symbol=num_bits_per_symbol)
rg_mapper = ResourceGridMapper(resource_grid)

## Channel
cdl = CDL(cdl_model, delay_spread, carrier_frequency,
          ut_antenna, bs_array, "uplink", min_speed=speed)
channel = OFDMChannel(cdl, resource_grid, normalize_channel=True, return_channel=True)

## Receiver
neural_receiver = NeuralReceiver()
rg_demapper = ResourceGridDemapper(resource_grid, stream_manager) # Used to extract data-carrying resource elements

# %% [markdown]
# The following cell performs one forward step through the end-to-end system:

# %%
batch_size = 128
ebno_db = tf.fill([batch_size], 5.0)
no = ebnodb2no(ebno_db, num_bits_per_symbol, coderate)

## Transmitter
# Generate codewords
c = binary_source([batch_size, 1, 1, n])
print("c shape: ", c.shape)

## First stage
x_init = qam_mapper(c)
x_rg_init = rg_mapper(x_init)

# Map bits to QAM symbols
x, constellation_points = mapper(c, ebno_db, training=True)
print("x shape: ", x.shape, x.dtype)
print("constellation shape: ", constellation_points.shape, constellation_points.dtype)
# Map the QAM symbols to a resource grid
x = tf.complex(x[...,0], x[...,1])
x_rg = rg_mapper(x)
print("x_rg shape: ", x_rg.shape, x_rg.dtype)

######################################
## Channel
# A batch of new channel realizations is sampled and applied at every inference
no_ = expand_to_rank(no, tf.rank(x_rg))
y,_ = channel(x_rg, no_)
print("y shape: ", y.shape)

######################################
## Receiver
# The neural receiver computes LLRs from the frequency domain received symbols and N0
y = tf.squeeze(y, axis=1)
llr = neural_receiver(y, no)
print("llr shape: ", llr.shape)
# Reshape the input to fit what the resource grid demapper is expected
llr = insert_dims(llr, 2, 1)
# Extract data-carrying resource elements. The other LLRs are discarded
llr = rg_demapper(llr)
llr = tf.reshape(llr, [batch_size, 1, 1, n])
print("Post RG-demapper LLRs: ", llr.shape)

# %% [markdown]
# The BMD rate is computed from the LLRs and transmitted bits as follows:

# %%
bce = tf.nn.sigmoid_cross_entropy_with_logits(c, llr)
bce = tf.reduce_mean(bce)
rate = tf.constant(1.0, tf.float32) - bce/tf.math.log(2.)
print(f"Rate: {rate:.2E} bit")
# Out:
# Rate: -6.97E-01 bit

# %% [markdown]
# The rate is very poor (negative values means 0 bit) as the neural receiver is not trained.

# %% [markdown]
# ## End-to-end System as a Sionna Block

# %%
class E2ESystem(Model):
    def __init__(self, system, training=False, use_fec=True):
        super().__init__()
        self._system = system
        self._training = training
        self._use_fec = use_fec

        ######################################
        ## Transmitter
        self._binary_source = BinarySource()
        
        if not training and use_fec:
            self._encoder = LDPC5GEncoder(k, n)
            self._decoder = LDPC5GDecoder(self._encoder, cn_update='offset-minsum', hard_out=True)
        
        # qam
        # self._mapper = Mapper("qam", num_bits_per_symbol)
        
        # non-frame
        self._mapper = SNRNFMapper(num_bits_per_symbol=num_bits_per_symbol)

        self._rg_mapper = ResourceGridMapper(resource_grid)

        ######################################
        ## Channel
        # A 3GPP CDL channel model is used
        cdl = CDL(cdl_model, delay_spread, carrier_frequency,
                  ut_antenna, bs_array, "uplink", min_speed=speed, max_speed=speed)
        self._channel = OFDMChannel(cdl, resource_grid, normalize_channel=True, return_channel=True)

        ######################################
        ## Receiver
        # Three options for the receiver depending on the value of `system`
        if "baseline" in system:
            self._removed_null_subc = RemoveNulledSubcarriers(resource_grid)
            self.interpolator = LinearInterpolator(resource_grid.pilot_pattern)
            self._ls_est = LSChannelEstimator(resource_grid, interpolator=self.interpolator)
            # Components required by both baselines
            self._lmmse_equ = LMMSEEqualizer(resource_grid, stream_manager, )
            self._demapper = Demapper("app", "qam", num_bits_per_symbol)
            
        elif system == "neural-receiver": # Neural receiver
            self._neural_receiver = NeuralReceiver()
            self._rg_demapper = ResourceGridDemapper(resource_grid, stream_manager) # Used to extract data-carrying resource elements      


    @tf.function
    def call(self, batch_size, ebno_db):

        # If `ebno_db` is a scalar, a tensor with shape [batch size] is created as it is what is expected by some layers
        if len(ebno_db.shape) == 0:
            ebno_db = tf.fill([batch_size], ebno_db)

        ######################################
        ## Transmitter
        if self._use_fec:
            no = ebnodb2no(ebno_db, num_bits_per_symbol, coderate)
        else:
            no = ebnodb2no(ebno_db, num_bits_per_symbol, 1.0)
        # Outer coding is only performed if not training and FEC is enabled
        if self._training or not self._use_fec:
            c = self._binary_source([batch_size, 1, 1, n])
            b = c
        else:
            b = self._binary_source([batch_size, 1, 1, k])
            c = self._encoder(b)
        
        # x = self._mapper(c)
        
        # Frame or NF
        x, constellation_points = self._mapper(c, ebno_db, training=self._training)
        self.constellation_points = constellation_points
        constellation_points = tf.stack([tf.math.real(constellation_points),
                                    tf.math.imag(constellation_points)], axis=-1)

        x = tf.complex(x[...,0], x[...,1])
        
        x_rg = self._rg_mapper(x)

        ######################################
        ## Channel
        # A batch of new channel realizations is sampled and applied at every inference
        no_ = expand_to_rank(no, tf.rank(x_rg))
        y,h = self._channel(x_rg, no_)

        # Manual AWGN: h = 1 everywhere
        # h = tf.ones_like(h, dtype=h.dtype)
        # y = x_rg  # No channel distortion
        # Add AWGN noise
        # noise_real = tf.random.normal(tf.shape(y), 
        #                                 stddev=tf.sqrt(no_/2),
        #                                 dtype=y.dtype.real_dtype)
        # noise_imag = tf.random.normal(tf.shape(y), 
        #                                 stddev=tf.sqrt(no_/2),
        #                                 dtype=y.dtype.real_dtype)
        # noise = tf.complex(noise_real, noise_imag)
        # y = y + noise
        
        ######################################
        ## Receiver
        # Three options for the receiver depending on the value of ``system``
        if "baseline" in self._system:
            # debugging
            h_perfect = self._removed_null_subc(h)
            h_ls, err_var = self._ls_est(y, no)

            if self._system == 'baseline-perfect-csi':
                h_hat = self._removed_null_subc(h) # Extract non-null subcarriers
                err_var = 0.0 # No channel estimation error when perfect CSI knowledge is assumed
            elif self._system == 'baseline-ls-estimation':
                h_hat, err_var = self._ls_est(y, no) # LS channel estimation with nearest-neighbor
                err_var = 0.0
                
            x_hat, no_eff = self._lmmse_equ(y, h_hat, err_var, no) # LMMSE equalization
            no_eff_= expand_to_rank(no_eff, tf.rank(x_hat))
            llr = self._demapper(x_hat, no_eff_) # Demapping

        elif self._system == "neural-receiver":
            # Extract pilot symbols from received signal and transmitted pilots
            y_pilot = tf.gather(y[:, 0, 0, :, :], pilot_ofdm_symbol_indices, axis=1)  # [batch, 2, fft_size]
            x_pilot = tf.gather(x_rg[:, 0, 0, :, :], pilot_ofdm_symbol_indices, axis=1)  # [batch, 2, fft_size]

            # The neural receiver computes LLRs from the frequency domain received symbols and N0
            y = tf.squeeze(y, axis=2)  # [batch, 1, 14, fft_size] - keep num_rx_ant dim
            llr = self._neural_receiver(y, no, y_pilot, x_pilot, constellation_points)

            llr = insert_dims(llr, 2, 1) # Reshape the input to fit what the resource grid demapper is expected
            llr = self._rg_demapper(llr) # Extract data-carrying resource elements. The other LLrs are discarded
            llr = tf.reshape(llr, [batch_size, 1, 1, n]) # Reshape the LLRs to fit what the outer decoder is expected

        
        # Outer coding is not needed if the information rate is returned or FEC is disabled
        if self._training:
            # Use the transmitted bits (c) for comparison
            bce = tf.nn.sigmoid_cross_entropy_with_logits(c, llr)
            bce = tf.reduce_mean(bce)
            rate = tf.constant(1.0, tf.float32) - bce/tf.math.log(2.)
            return rate
        else:
            if self._use_fec:
                b_hat = self._decoder(llr)
            else:
                # Hard decision on LLRs without FEC
                b_hat = tf.cast(tf.greater(llr, 0.0), dtype=b.dtype)
            return b, b_hat # Ground truth and reconstructed information bits returned for BER/BLER computation

# %% [markdown]
# ### FiLM

# %%
class E2ESystem(Model):
    def __init__(self, system, training=False, use_fec=True):
        super().__init__()
        self._system = system
        self._training = training
        self._use_fec = use_fec

        ######################################
        ## Transmitter
        self._binary_source = BinarySource()
        
        if not training and use_fec:
            # self._encoder = LDPC5GEncoder(k, n)
            self._encoders  = {nbps: LDPC5GEncoder(KN_TABLE[nbps][0], KN_TABLE[nbps][1])
                                for nbps in MOD_ORDERS}
            self._decoders  = {nbps: LDPC5GDecoder(self._encoders[nbps], cn_update='offset-minsum', hard_out=True)
                                for nbps in MOD_ORDERS}
            # self._decoder = LDPC5GDecoder(self._encoder, cn_update='offset-minsum', hard_out=True)
        
        # qam
        # self._mapper = Mapper("qam", num_bits_per_symbol)
        self._mappers = {nbps: Mapper("qam", nbps) for nbps in MOD_ORDERS}
        
        # non-frame
        # self._mapper = SNRNFMapper(num_bits_per_symbol=num_bits_per_symbol)

        self._rg_mapper = ResourceGridMapper(resource_grid)

        ######################################
        ## Channel
        # A 3GPP CDL channel model is used
        cdl = CDL(cdl_model, delay_spread, carrier_frequency,
                  ut_antenna, bs_array, "uplink", min_speed=speed, max_speed=speed)
        self._channel = OFDMChannel(cdl, resource_grid, normalize_channel=True, return_channel=True)

        ######################################
        ## Receiver
        # Three options for the receiver depending on the value of `system`
        if "baseline" in system:
            self._removed_null_subc = RemoveNulledSubcarriers(resource_grid)
            self.interpolator = LinearInterpolator(resource_grid.pilot_pattern)
            self._ls_est = LSChannelEstimator(resource_grid, interpolator=self.interpolator)
            # Components required by both baselines
            self._lmmse_equ = LMMSEEqualizer(resource_grid, stream_manager, )
            # self._demapper = Demapper("app", "qam", num_bits_per_symbol)
            self._demappers = {nbps: Demapper("app", "qam", nbps) for nbps in MOD_ORDERS}
            
        elif system == "neural-receiver": # Neural receiver
            self._neural_receiver = NeuralReceiver()
            self._rg_demapper = ResourceGridDemapper(resource_grid, stream_manager) # Used to extract data-carrying resource elements      


    @tf.function
    def call(self, batch_size, ebno_db, nbps):

        # If `ebno_db` is a scalar, a tensor with shape [batch size] is created as it is what is expected by some layers
        if len(ebno_db.shape) == 0:
            ebno_db = tf.fill([batch_size], ebno_db)
        
        k, n = KN_TABLE[nbps]
        mod_idx = tf.fill([batch_size],
                          tf.constant(MOD_IDX_MAP[nbps], dtype=tf.int32))

        ######################################
        ## Transmitter
        if self._use_fec:
            no = ebnodb2no(ebno_db, num_bits_per_symbol, coderate)
        else:
            no = ebnodb2no(ebno_db, num_bits_per_symbol, 1.0)
        # Outer coding is only performed if not training and FEC is enabled
        if self._training or not self._use_fec:
            c = self._binary_source([batch_size, 1, 1, n]).
            b = c
        else:
            b = self._binary_source([batch_size, 1, 1, k])
            c = self._encoders[nbps](b)
        
        # x = self._mapper(c)
        x = self._mappers[nbps](c)

        # Frame or NF
        # x, constellation_points = self._mapper(c, ebno_db, training=self._training)
        # x, constellation_points = self._mappers[nbps](c, ebno_db, training=self._training)
        # self.constellation_points = constellation_points

        # x = tf.complex(x[...,0], x[...,1])
        
        x_rg = self._rg_mapper(x)

        ######################################
        ## Channel
        # A batch of new channel realizations is sampled and applied at every inference
        no_ = expand_to_rank(no, tf.rank(x_rg))
        y,h = self._channel(x_rg, no_)

        # Manual AWGN: h = 1 everywhere
        # h = tf.ones_like(h, dtype=h.dtype)
        # y = x_rg  # No channel distortion
        # Add AWGN noise
        # noise_real = tf.random.normal(tf.shape(y), 
        #                                 stddev=tf.sqrt(no_/2),
        #                                 dtype=y.dtype.real_dtype)
        # noise_imag = tf.random.normal(tf.shape(y), 
        #                                 stddev=tf.sqrt(no_/2),
        #                                 dtype=y.dtype.real_dtype)
        # noise = tf.complex(noise_real, noise_imag)
        # y = y + noise
        
        ######################################
        ## Receiver
        # Three options for the receiver depending on the value of ``system``
        if "baseline" in self._system:
            # debugging
            h_perfect = self._removed_null_subc(h)
            h_ls, err_var = self._ls_est(y, no)

            if self._system == 'baseline-perfect-csi':
                h_hat = self._removed_null_subc(h) # Extract non-null subcarriers
                err_var = 0.0 # No channel estimation error when perfect CSI knowledge is assumed
            elif self._system == 'baseline-ls-estimation':
                h_hat, err_var = self._ls_est(y, no) # LS channel estimation with nearest-neighbor
                err_var = 0.0
                
            x_hat, no_eff = self._lmmse_equ(y, h_hat, err_var, no) # LMMSE equalization
            no_eff_= expand_to_rank(no_eff, tf.rank(x_hat))
            llr = self._demappers[nbps](x_hat, no_eff_)
            # llr = self._demapper(x_hat, no_eff_) # Demapping

        elif self._system == "neural-receiver":
            # Extract pilot symbols from received signal and transmitted pilots
            y_pilot = tf.gather(y[:, 0, 0, :, :], pilot_ofdm_symbol_indices, axis=1)  # [batch, 2, fft_size]
            x_pilot = tf.gather(x_rg[:, 0, 0, :, :], pilot_ofdm_symbol_indices, axis=1)  # [batch, 2, fft_size]

            # The neural receiver computes LLRs from the frequency domain received symbols and N0
            y = tf.squeeze(y, axis=2)  # [batch, 1, 14, fft_size] - keep num_rx_ant dim
            llr = self._neural_receiver(y, no, y_pilot, x_pilot, mod_idx)
            # llr is [batch, 14, fft_size, 6] mask to active bits
            llr = llr[..., :nbps]  # [batch, 14, 128, active_bits]

            llr = insert_dims(llr, 2, 1) # Reshape the input to fit what the resource grid demapper is expected
            llr = self._rg_demapper(llr) # Extract data-carrying resource elements. The other LLrs are discarded
            llr = tf.reshape(llr, [batch_size, 1, 1, n]) # Reshape the LLRs to fit what the outer decoder is expected

        
        # Outer coding is not needed if the information rate is returned or FEC is disabled
        if self._training:
            # Use the transmitted bits (c) for comparison
            bce = tf.nn.sigmoid_cross_entropy_with_logits(c, llr)
            bce = tf.reduce_mean(bce)
            rate = tf.constant(1.0, tf.float32) - bce/tf.math.log(2.)
            return rate
        else:
            if self._use_fec:
                b_hat = self._decoders[nbps](llr)
            else:
                # Hard decision on LLRs without FEC
                b_hat = tf.cast(tf.greater(llr, 0.0), dtype=b.dtype)
            return b, b_hat # Ground truth and reconstructed information bits returned for BER/BLER computation

# %% [markdown]
# ## Evaluation of the Baselines <a class="anchor" id="Evaluation-of-the-Baselines"></a>

# %% [markdown]
# We evaluate the BERs achieved by the baselines in the next cell.
#
# **Note:** Evaluation of the two systems can take a while. Therefore, we provide pre-computed results at the end of this notebook.

# %%
# Range of SNRs over which the systems are evaluated
ebno_dbs = np.arange(ebno_db_min, # Min SNR for evaluation
                     ebno_db_max, # Max SNR for evaluation
                     0.5) # Step

# Dictionary storing the evaluation results
BLER = {}
BER = {}

# %%
# conventional system
conv_model = E2ESystem('baseline-perfect-csi', False, True)

ber,bler  = sim_ber(conv_model, ebno_dbs, batch_size=128, num_target_block_errors=50, max_mc_iter=300)
BER['baseline-perfect-csi'] = ber.numpy()
BLER['baseline-perfect-csi'] = bler.numpy()

conv_model = E2ESystem('baseline-ls-estimation', False, True)

ber,bler = sim_ber(conv_model, ebno_dbs, batch_size=128, num_target_block_errors=50, max_mc_iter=300)
BER['baseline-ls-estimation'] = ber.numpy()
BLER['baseline-ls-estimation'] = bler.numpy()

with open('E2E_baseline_result', 'wb') as f:
    pickle.dump((ebno_dbs, BLER, BER), f)

# %%
# uncoded
BLER_uc = {}
BER_uc = {}

model = E2ESystem('baseline-perfect-csi', False, False)
ber,bler = sim_ber(model, ebno_dbs, batch_size=128, num_target_block_errors=100, max_mc_iter=100)
BLER_uc['baseline-perfect-csi'] = bler.numpy()
BER_uc['baseline-perfect-csi'] = ber.numpy()

model = E2ESystem('baseline-ls-estimation', False, False)
ber,bler = sim_ber(model, ebno_dbs, batch_size=128, num_target_block_errors=100, max_mc_iter=100)
BLER_uc['baseline-ls-estimation'] = bler.numpy()
BER_uc['baseline-ls-estimation'] = ber.numpy()
# Out:
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       0.0 | 2.0008e-01 | 1.0000e+00 |      213901 |     1069056 |          128 |         128 |         2.3 |reached target block errors
#       0.5 | 1.8795e-01 | 1.0000e+00 |      200925 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       1.0 | 1.7723e-01 | 1.0000e+00 |      189468 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       1.5 | 1.6727e-01 | 1.0000e+00 |      178816 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       2.0 | 1.5668e-01 | 1.0000e+00 |      167502 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       2.5 | 1.4677e-01 | 1.0000e+00 |      156910 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       3.0 | 1.3712e-01 | 1.0000e+00 |      146586 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       3.5 | 1.2770e-01 | 1.0000e+00 |      136522 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       4.0 | 1.1907e-01 | 1.0000e+00 |      127297 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       4.5 | 1.0929e-01 | 1.0000e+00 |      116836 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       5.0 | 1.0113e-01 | 1.0000e+00 |      108115 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       5.5 | 9.2452e-02 | 1.0000e+00 |       98836 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       6.0 | 8.3664e-02 | 1.0000e+00 |       89442 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       6.5 | 7.6057e-02 | 1.0000e+00 |       81309 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       7.0 | 6.7815e-02 | 1.0000e+00 |       72498 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       7.5 | 5.9841e-02 | 1.0000e+00 |       63973 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       8.0 | 5.2742e-02 | 1.0000e+00 |       56384 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       8.5 | 4.5288e-02 | 1.0000e+00 |       48415 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       9.0 | 3.8570e-02 | 1.0000e+00 |       41234 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       9.5 | 3.2148e-02 | 1.0000e+00 |       34368 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      10.0 | 2.6771e-02 | 1.0000e+00 |       28620 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      10.5 | 2.1500e-02 | 1.0000e+00 |       22985 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      11.0 | 1.6948e-02 | 1.0000e+00 |       18118 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      11.5 | 1.2954e-02 | 1.0000e+00 |       13849 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      12.0 | 9.8330e-03 | 1.0000e+00 |       10512 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      12.5 | 7.0941e-03 | 1.0000e+00 |        7584 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      13.0 | 4.9923e-03 | 1.0000e+00 |        5337 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      13.5 | 3.3665e-03 | 1.0000e+00 |        3599 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      14.0 | 2.1439e-03 | 1.0000e+00 |        2292 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      14.5 | 1.3283e-03 | 1.0000e+00 |        1420 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      15.0 | 7.4365e-04 | 9.9219e-01 |         795 |     1069056 |          127 |         128 |         0.1 |reached target block errors
#      15.5 | 5.2663e-04 | 9.8438e-01 |         563 |     1069056 |          126 |         128 |         0.1 |reached target block errors
#      16.0 | 2.2637e-04 | 8.5938e-01 |         242 |     1069056 |          110 |         128 |         0.1 |reached target block errors
#      16.5 | 1.0196e-04 | 5.9375e-01 |         218 |     2138112 |          152 |         256 |         0.2 |reached target block errors
#      17.0 | 5.0512e-05 | 3.3594e-01 |         162 |     3207168 |          129 |         384 |         0.3 |reached target block errors
#      17.5 | 2.2294e-05 | 1.4062e-01 |         143 |     6414336 |          108 |         768 |         0.7 |reached target block errors
#      18.0 | 7.5501e-06 | 5.7478e-02 |         113 |    14966784 |          103 |        1792 |         1.6 |reached target block errors
#      18.5 | 6.3046e-06 | 1.5781e-02 |         337 |    53452800 |          101 |        6400 |         5.8 |reached target block errors
#      19.0 | 1.8895e-06 | 4.2969e-03 |         202 |   106905600 |           55 |       12800 |        11.6 |reached max iterations
#      19.5 | 4.9576e-07 | 1.4844e-03 |          53 |   106905600 |           19 |       12800 |        11.6 |reached max iterations
#      20.0 | 3.5826e-06 | 1.2500e-03 |         383 |   106905600 |           16 |       12800 |        11.6 |reached max iterations
#      20.5 | 1.7399e-06 | 7.8125e-04 |         186 |   106905600 |           10 |       12800 |        11.6 |reached max iterations
#      21.0 | 6.5478e-08 | 3.1250e-04 |           7 |   106905600 |            4 |       12800 |        11.6 |reached max iterations
#      21.5 | 3.8352e-07 | 1.5625e-04 |          41 |   106905600 |            2 |       12800 |        11.5 |reached max iterations
#      22.0 | 2.1140e-06 | 2.3437e-04 |         226 |   106905600 |            3 |       12800 |        11.5 |reached max iterations
#      22.5 | 3.2739e-07 | 2.3437e-04 |          35 |   106905600 |            3 |       12800 |        11.6 |reached max iterations
#      23.0 | 6.1737e-07 | 1.5625e-04 |          66 |   106905600 |            2 |       12800 |        11.6 |reached max iterations
#      23.5 | 0.0000e+00 | 0.0000e+00 |           0 |   106905600 |            0 |       12800 |        11.6 |reached max iterations
#
# Simulation stopped as no error occurred @ EbNo = 23.5 dB.
#
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       0.0 | 2.5728e-01 | 1.0000e+00 |      275042 |     1069056 |          128 |         128 |         2.1 |reached target block errors
#       0.5 | 2.4587e-01 | 1.0000e+00 |      262854 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       1.0 | 2.3419e-01 | 1.0000e+00 |      250364 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       1.5 | 2.2235e-01 | 1.0000e+00 |      237702 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       2.0 | 2.1140e-01 | 1.0000e+00 |      226003 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       2.5 | 2.0052e-01 | 1.0000e+00 |      214372 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       3.0 | 1.8908e-01 | 1.0000e+00 |      202135 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       3.5 | 1.7834e-01 | 1.0000e+00 |      190659 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       4.0 | 1.6829e-01 | 1.0000e+00 |      179912 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       4.5 | 1.5785e-01 | 1.0000e+00 |      168747 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       5.0 | 1.4831e-01 | 1.0000e+00 |      158556 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       5.5 | 1.3967e-01 | 1.0000e+00 |      149310 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       6.0 | 1.2954e-01 | 1.0000e+00 |      138482 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       6.5 | 1.2005e-01 | 1.0000e+00 |      128337 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       7.0 | 1.1154e-01 | 1.0000e+00 |      119242 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       7.5 | 1.0235e-01 | 1.0000e+00 |      109414 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       8.0 | 9.4618e-02 | 1.0000e+00 |      101152 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       8.5 | 8.6082e-02 | 1.0000e+00 |       92026 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       9.0 | 7.7644e-02 | 1.0000e+00 |       83006 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#       9.5 | 7.0138e-02 | 1.0000e+00 |       74981 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      10.0 | 6.2310e-02 | 1.0000e+00 |       66613 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      10.5 | 5.5508e-02 | 1.0000e+00 |       59341 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      11.0 | 4.8077e-02 | 1.0000e+00 |       51397 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      11.5 | 4.1669e-02 | 1.0000e+00 |       44547 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      12.0 | 3.4952e-02 | 1.0000e+00 |       37366 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      12.5 | 2.9400e-02 | 1.0000e+00 |       31430 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      13.0 | 2.4170e-02 | 1.0000e+00 |       25839 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      13.5 | 1.9739e-02 | 1.0000e+00 |       21102 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      14.0 | 1.5627e-02 | 1.0000e+00 |       16706 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      14.5 | 1.2183e-02 | 1.0000e+00 |       13024 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      15.0 | 9.3821e-03 | 1.0000e+00 |       10030 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      15.5 | 6.8631e-03 | 1.0000e+00 |        7337 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      16.0 | 4.9764e-03 | 1.0000e+00 |        5320 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      16.5 | 3.6135e-03 | 1.0000e+00 |        3863 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      17.0 | 2.3189e-03 | 1.0000e+00 |        2479 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      17.5 | 1.5378e-03 | 1.0000e+00 |        1644 |     1069056 |          128 |         128 |         0.1 |reached target block errors
#      18.0 | 9.6347e-04 | 9.9219e-01 |        1030 |     1069056 |          127 |         128 |         0.1 |reached target block errors
#      18.5 | 6.5385e-04 | 9.8438e-01 |         699 |     1069056 |          126 |         128 |         0.1 |reached target block errors
#      19.0 | 3.4610e-04 | 9.2188e-01 |         370 |     1069056 |          118 |         128 |         0.1 |reached target block errors
#      19.5 | 2.0111e-04 | 7.9688e-01 |         215 |     1069056 |          102 |         128 |         0.1 |reached target block errors
#      20.0 | 1.0289e-04 | 5.6250e-01 |         220 |     2138112 |          144 |         256 |         0.2 |reached target block errors
#      20.5 | 4.6458e-05 | 2.9688e-01 |         149 |     3207168 |          114 |         384 |         0.3 |reached target block errors
#      21.0 | 4.7893e-05 | 1.8125e-01 |         256 |     5345280 |          116 |         640 |         0.6 |reached target block errors
#      21.5 | 9.0989e-06 | 7.3153e-02 |         107 |    11759616 |          103 |        1408 |         1.3 |reached target block errors
#      22.0 | 3.4075e-06 | 2.8460e-02 |         102 |    29933568 |          102 |        3584 |         3.2 |reached target block errors
#      22.5 | 1.9533e-06 | 1.1719e-02 |         142 |    72695808 |          102 |        8704 |         7.8 |reached target block errors
#      23.0 | 6.7349e-07 | 3.6719e-03 |          72 |   106905600 |           47 |       12800 |        11.8 |reached max iterations
#      23.5 | 5.6124e-07 | 1.8750e-03 |          60 |   106905600 |           24 |       12800 |        11.5 |reached max iterations
#      24.0 | 6.5478e-08 | 5.4688e-04 |           7 |   106905600 |            7 |       12800 |        11.6 |reached max iterations
#      24.5 | 1.3563e-06 | 3.9063e-04 |         145 |   106905600 |            5 |       12800 |        11.6 |reached max iterations
#      25.0 | 4.1251e-06 | 4.6875e-04 |         441 |   106905600 |            6 |       12800 |        11.6 |reached max iterations
#      25.5 | 5.0512e-07 | 2.3437e-04 |          54 |   106905600 |            3 |       12800 |        11.6 |reached max iterations
#      26.0 | 3.7229e-06 | 5.4688e-04 |         398 |   106905600 |            7 |       12800 |        11.5 |reached max iterations
#      26.5 | 1.4966e-06 | 7.8125e-05 |         160 |   106905600 |            1 |       12800 |        11.6 |reached max iterations
#      27.0 | 1.0289e-07 | 1.5625e-04 |          11 |   106905600 |            2 |       12800 |        11.6 |reached max iterations
#      27.5 | 0.0000e+00 | 0.0000e+00 |           0 |   106905600 |            0 |       12800 |        11.6 |reached max iterations
#
# Simulation stopped as no error occurred @ EbNo = 27.5 dB.

# %% [markdown]
# ## Training the Neural Receiver <a class="anchor" id="Training-the-Neural-Receiver"></a>

# %% [markdown]
# ### Baseline

# %%
model = E2ESystem('neural-receiver', training=True, use_fec=True)
optimizer = tf.keras.optimizers.Adam()

for i in tqdm(range(num_training_iterations+1)):
    ebno_db = tf.random.uniform(shape=[], minval=ebno_db_min, maxval=ebno_db_max)

    with tf.GradientTape() as tape:
        rate = model(training_batch_size, ebno_db)
        loss = -rate

    grads = tape.gradient(loss, model.trainable_weights)
    optimizer.apply_gradients(zip(grads, model.trainable_weights))

    if i % 100 == 0:
        log_str = f"Iteration {i}/{num_training_iterations}, Eb/No: {ebno_db.numpy():.4f}, Loss: {loss.numpy():.4f}"
        print(log_str)

# Save the weights in a file
weights = model.get_weights()
with open('qam_neural_receiver_model_weights.pkl', 'wb') as f:
    pickle.dump(weights, f)
# Out:
#   0%|          | 0/10001 [00:00<?, ?it/s]
# 2026-01-24 00:08:59.575681: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2026-01-24 00:08:59.678156: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-01-24 00:09:06.547912: I external/local_xla/xla/service/service.cc:168] XLA service 0x5f7a8b2ab1c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-01-24 00:09:06.547959: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A2000 12GB, Compute Capability 8.6
# 2026-01-24 00:09:06.564504: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1769173746.669862    9162 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Iteration 0/10000, Eb/No: 9.0728, Loss: 0.2557
# Iteration 100/10000, Eb/No: 5.8537, Loss: -0.0039
# Iteration 200/10000, Eb/No: 9.7684, Loss: -0.0627
# Iteration 300/10000, Eb/No: 10.3945, Loss: -0.0921
# Iteration 400/10000, Eb/No: 8.3308, Loss: -0.0992
# Iteration 500/10000, Eb/No: 7.2142, Loss: -0.1039
# Iteration 600/10000, Eb/No: 4.2565, Loss: -0.0776
# Iteration 700/10000, Eb/No: 7.6501, Loss: -0.1121
# Iteration 800/10000, Eb/No: 2.1088, Loss: -0.0548
# Iteration 900/10000, Eb/No: 5.9098, Loss: -0.0963
# Iteration 1000/10000, Eb/No: 10.0689, Loss: -0.1376
# Iteration 1100/10000, Eb/No: 4.5764, Loss: -0.1389
# Iteration 1200/10000, Eb/No: 13.3448, Loss: -0.2384
# Iteration 1300/10000, Eb/No: 9.9958, Loss: -0.3778
# Iteration 1400/10000, Eb/No: 4.5599, Loss: -0.2714
# Iteration 1500/10000, Eb/No: 10.6133, Loss: -0.5282
# Iteration 1600/10000, Eb/No: 14.9602, Loss: -0.6347
# Iteration 1700/10000, Eb/No: 13.9245, Loss: -0.5147
# Iteration 1800/10000, Eb/No: 4.1676, Loss: -0.3670
# Iteration 1900/10000, Eb/No: 3.1216, Loss: -0.3744
# Iteration 2000/10000, Eb/No: 4.1125, Loss: -0.4194
# Iteration 2100/10000, Eb/No: 3.3752, Loss: -0.3442
# Iteration 2200/10000, Eb/No: 5.0834, Loss: -0.4704
# Iteration 2300/10000, Eb/No: 4.0729, Loss: -0.4278
# Iteration 2400/10000, Eb/No: 6.0642, Loss: -0.5030
# Iteration 2500/10000, Eb/No: 13.4308, Loss: -0.7655
# Iteration 2600/10000, Eb/No: 7.3059, Loss: -0.5150
# Iteration 2700/10000, Eb/No: 11.1884, Loss: -0.7256
# Iteration 2800/10000, Eb/No: 12.8489, Loss: -0.8067
# Iteration 2900/10000, Eb/No: 10.3635, Loss: -0.6220
# Iteration 3000/10000, Eb/No: 9.9882, Loss: -0.7068
# Iteration 3100/10000, Eb/No: 11.4454, Loss: -0.7549
# Iteration 3200/10000, Eb/No: 2.6713, Loss: -0.3625
# Iteration 3300/10000, Eb/No: 14.6962, Loss: -0.8539
# Iteration 3400/10000, Eb/No: 0.6300, Loss: -0.2842
# Iteration 3500/10000, Eb/No: 9.9612, Loss: -0.4561
# Iteration 3600/10000, Eb/No: 12.4258, Loss: -0.8017
# Iteration 3700/10000, Eb/No: 0.6060, Loss: -0.2834
# Iteration 3800/10000, Eb/No: 10.8837, Loss: -0.7222
# Iteration 3900/10000, Eb/No: 12.5880, Loss: -0.8271
# Iteration 4000/10000, Eb/No: 3.3837, Loss: -0.3990
# Iteration 4100/10000, Eb/No: 9.1803, Loss: -0.6006
# Iteration 4200/10000, Eb/No: 0.6772, Loss: -0.2932
# Iteration 4300/10000, Eb/No: 9.9178, Loss: -0.7181
# Iteration 4400/10000, Eb/No: 3.2942, Loss: -0.4048
# Iteration 4500/10000, Eb/No: 5.8243, Loss: -0.5255
# Iteration 4600/10000, Eb/No: 5.0208, Loss: -0.4864
# Iteration 4700/10000, Eb/No: 14.4260, Loss: -0.8605
# Iteration 4800/10000, Eb/No: 8.1147, Loss: -0.6331
# Iteration 4900/10000, Eb/No: 5.4776, Loss: -0.4887
# Iteration 5000/10000, Eb/No: 5.4998, Loss: -0.4945
# Iteration 5100/10000, Eb/No: 6.1657, Loss: -0.5346
# Iteration 5200/10000, Eb/No: 11.9838, Loss: -0.8000
# Iteration 5300/10000, Eb/No: 7.5935, Loss: -0.6021
# Iteration 5400/10000, Eb/No: 0.0707, Loss: -0.2270
# Iteration 5500/10000, Eb/No: 14.3643, Loss: -0.8862
# Iteration 5600/10000, Eb/No: 12.1477, Loss: -0.5579
# Iteration 5700/10000, Eb/No: 6.8336, Loss: -0.5719
# Iteration 5800/10000, Eb/No: 12.4338, Loss: -0.7734
# Iteration 5900/10000, Eb/No: 5.8515, Loss: -0.5263
# Iteration 6000/10000, Eb/No: 11.3051, Loss: -0.7463
# Iteration 6100/10000, Eb/No: 1.5199, Loss: -0.3216
# Iteration 6200/10000, Eb/No: 0.6002, Loss: -0.2802
# Iteration 6300/10000, Eb/No: 0.0882, Loss: -0.2696
# Iteration 6400/10000, Eb/No: 13.0482, Loss: -0.8477
# Iteration 6500/10000, Eb/No: 7.1675, Loss: -0.5947
# Iteration 6600/10000, Eb/No: 13.9894, Loss: -0.8892
# Iteration 6700/10000, Eb/No: 4.3893, Loss: -0.4465
# Iteration 6800/10000, Eb/No: 6.8253, Loss: -0.5624
# Iteration 6900/10000, Eb/No: 4.5579, Loss: -0.4642
# Iteration 7000/10000, Eb/No: 1.5243, Loss: -0.3280
# Iteration 7100/10000, Eb/No: 8.0547, Loss: -0.6332
# Iteration 7200/10000, Eb/No: 10.3337, Loss: -0.7392
# Iteration 7300/10000, Eb/No: 3.4519, Loss: -0.4149
# Iteration 7400/10000, Eb/No: 5.7917, Loss: -0.5215
# Iteration 7500/10000, Eb/No: 14.0041, Loss: -0.8881
# Iteration 7600/10000, Eb/No: 6.0155, Loss: -0.5393
# Iteration 7700/10000, Eb/No: 6.3709, Loss: -0.5061
# Iteration 7800/10000, Eb/No: 11.5167, Loss: -0.7936
# Iteration 7900/10000, Eb/No: 8.8296, Loss: -0.6557
# Iteration 8000/10000, Eb/No: 4.3012, Loss: -0.4475
# Iteration 8100/10000, Eb/No: 10.1502, Loss: -0.7306
# Iteration 8200/10000, Eb/No: 4.7920, Loss: -0.4705
# Iteration 8300/10000, Eb/No: 14.8608, Loss: -0.8657
# Iteration 8400/10000, Eb/No: 3.0688, Loss: -0.3979
# Iteration 8500/10000, Eb/No: 7.5287, Loss: -0.5989
# Iteration 8600/10000, Eb/No: 0.4022, Loss: -0.2862
# Iteration 8700/10000, Eb/No: 1.3984, Loss: -0.3268
# Iteration 8800/10000, Eb/No: 0.6302, Loss: -0.2976
# Iteration 8900/10000, Eb/No: 3.4003, Loss: -0.3821
# Iteration 9000/10000, Eb/No: 2.8854, Loss: -0.3893
# Iteration 9100/10000, Eb/No: 14.8106, Loss: -0.7750
# Iteration 9200/10000, Eb/No: 13.6214, Loss: -0.8688
# Iteration 9300/10000, Eb/No: 9.2569, Loss: -0.6886
# Iteration 9400/10000, Eb/No: 14.4673, Loss: -0.8680
# Iteration 9500/10000, Eb/No: 10.8793, Loss: -0.7487
# Iteration 9600/10000, Eb/No: 12.2785, Loss: -0.7817
# Iteration 9700/10000, Eb/No: 13.9151, Loss: -0.8770
# Iteration 9800/10000, Eb/No: 2.4262, Loss: -0.3751
# Iteration 9900/10000, Eb/No: 11.9183, Loss: -0.7976
# Iteration 10000/10000, Eb/No: 0.4064, Loss: -0.2902

# %% [markdown]
# ### NN

# %%
model = E2ESystem('neural-receiver', training=True, use_fec=True)
optimizer = tf.keras.optimizers.Adam()

for i in tqdm(range(num_training_iterations+1)):
    ebno_db = tf.random.uniform(shape=[], minval=ebno_db_min, maxval=ebno_db_max)

    with tf.GradientTape() as tape:
        rate = model(training_batch_size, ebno_db, training=True)
        loss = -rate

    grads = tape.gradient(loss, model.trainable_weights)
    optimizer.apply_gradients(zip(grads, model.trainable_weights))

    if i % 100 == 0:
        log_str = f"Iteration {i}/{num_training_iterations}, Eb/No: {ebno_db.numpy():.4f}, Loss: {loss.numpy():.4f}"
        print(log_str)
    
    if i % 10000 == 0:
        weights = model.get_weights()
        with open('10000_SNRNF_2stage_const_neural_receiver_model_weights.pkl', 'wb') as f:
            pickle.dump(weights, f)

# Save the weights in a file
weights = model.get_weights()
with open('30000_SNRNF_2stage_const_neural_receiver_model_weights.pkl', 'wb') as f:
    pickle.dump(weights, f)
# Out:
#   0%|          | 0/30001 [00:00<?, ?it/s]
# 2026-02-27 12:07:44.440501: I external/local_xla/xla/service/service.cc:168] XLA service 0x5dd9dc641130 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-02-27 12:07:44.440570: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A2000 12GB, Compute Capability 8.6
# 2026-02-27 12:07:44.482256: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772154464.682046    8496 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Iteration 0/30000, Eb/No: 6.4245, Loss: 0.4527
# Iteration 100/30000, Eb/No: 0.9629, Loss: 0.0044
# Iteration 200/30000, Eb/No: 5.9950, Loss: 0.0203
# Iteration 300/30000, Eb/No: 3.8690, Loss: 0.0009
# Iteration 400/30000, Eb/No: 11.5306, Loss: 0.0003
# Iteration 500/30000, Eb/No: 10.9713, Loss: -0.0459
# Iteration 600/30000, Eb/No: 8.3022, Loss: -0.1421
# Iteration 700/30000, Eb/No: 2.5314, Loss: -0.2197
# Iteration 800/30000, Eb/No: 5.9348, Loss: -0.3642
# Iteration 900/30000, Eb/No: 10.9931, Loss: -0.4789
# Iteration 1000/30000, Eb/No: 13.9768, Loss: -0.5557
# Iteration 1100/30000, Eb/No: 0.1270, Loss: -0.1825
# Iteration 1200/30000, Eb/No: 2.8656, Loss: -0.3416
# Iteration 1300/30000, Eb/No: 13.6627, Loss: -0.5919
# Iteration 1400/30000, Eb/No: 2.4009, Loss: -0.3165
# Iteration 1500/30000, Eb/No: 6.1339, Loss: -0.4021
# Iteration 1600/30000, Eb/No: 4.3670, Loss: -0.4468
# Iteration 1700/30000, Eb/No: 8.9860, Loss: -0.5912
# Iteration 1800/30000, Eb/No: 5.9522, Loss: -0.5152
# Iteration 1900/30000, Eb/No: 1.5075, Loss: -0.3435
# Iteration 2000/30000, Eb/No: 5.9668, Loss: -0.4549
# Iteration 2100/30000, Eb/No: 7.3789, Loss: -0.5598
# Iteration 2200/30000, Eb/No: 4.7523, Loss: -0.4809
# Iteration 2300/30000, Eb/No: 9.5545, Loss: -0.5419
# Iteration 2400/30000, Eb/No: 7.1662, Loss: -0.5583
# Iteration 2500/30000, Eb/No: 12.4239, Loss: -0.7184
# Iteration 2600/30000, Eb/No: 11.2458, Loss: -0.6903
# Iteration 2700/30000, Eb/No: 9.9671, Loss: -0.6664
# Iteration 2800/30000, Eb/No: 9.4094, Loss: -0.6803
# Iteration 2900/30000, Eb/No: 6.5479, Loss: -0.5005
# Iteration 3000/30000, Eb/No: 3.3801, Loss: -0.4190
# Iteration 3100/30000, Eb/No: 4.7035, Loss: -0.4792
# Iteration 3200/30000, Eb/No: 9.1673, Loss: -0.6860
# Iteration 3300/30000, Eb/No: 3.9281, Loss: -0.4464
# Iteration 3400/30000, Eb/No: 13.4171, Loss: -0.8208
# Iteration 3500/30000, Eb/No: 13.6681, Loss: -0.8069
# Iteration 3600/30000, Eb/No: 5.9178, Loss: -0.5496
# Iteration 3700/30000, Eb/No: 11.6940, Loss: -0.7457
# Iteration 3800/30000, Eb/No: 11.2546, Loss: -0.6678
# Iteration 3900/30000, Eb/No: 11.6285, Loss: -0.8020
# Iteration 4000/30000, Eb/No: 4.1115, Loss: -0.4559
# Iteration 4100/30000, Eb/No: 8.3189, Loss: -0.6747
# Iteration 4200/30000, Eb/No: 7.1469, Loss: -0.5973
# Iteration 4300/30000, Eb/No: 3.8096, Loss: -0.4386
# Iteration 4400/30000, Eb/No: 0.9332, Loss: -0.3365
# Iteration 4500/30000, Eb/No: 2.8924, Loss: -0.3440
# Iteration 4600/30000, Eb/No: 4.4585, Loss: -0.4810
# Iteration 4700/30000, Eb/No: 2.0445, Loss: -0.3785
# Iteration 4800/30000, Eb/No: 7.7282, Loss: -0.6409
# Iteration 4900/30000, Eb/No: 12.7326, Loss: -0.8245
# Iteration 5000/30000, Eb/No: 10.2058, Loss: -0.7280
# Iteration 5100/30000, Eb/No: 12.3735, Loss: -0.8291
# Iteration 5200/30000, Eb/No: 10.2582, Loss: -0.6995
# Iteration 5300/30000, Eb/No: 13.3094, Loss: -0.8077
# Iteration 5400/30000, Eb/No: 1.9063, Loss: -0.3698
# Iteration 5500/30000, Eb/No: 11.9090, Loss: -0.7996
# Iteration 5600/30000, Eb/No: 0.2771, Loss: -0.3015
# Iteration 5700/30000, Eb/No: 10.4890, Loss: -0.7733
# Iteration 5800/30000, Eb/No: 13.4615, Loss: -0.7997
# Iteration 5900/30000, Eb/No: 7.1707, Loss: -0.6201
# Iteration 6000/30000, Eb/No: 12.3939, Loss: -0.8449
# Iteration 6100/30000, Eb/No: 5.9730, Loss: -0.5606
# Iteration 6200/30000, Eb/No: 0.5307, Loss: -0.3105
# Iteration 6300/30000, Eb/No: 4.6994, Loss: -0.5002
# Iteration 6400/30000, Eb/No: 8.4762, Loss: -0.6746
# Iteration 6500/30000, Eb/No: 12.6505, Loss: -0.8501
# Iteration 6600/30000, Eb/No: 9.0272, Loss: -0.7097
# Iteration 6700/30000, Eb/No: 1.3194, Loss: -0.3442
# Iteration 6800/30000, Eb/No: 7.4857, Loss: -0.6412
# Iteration 6900/30000, Eb/No: 3.7520, Loss: -0.4474
# Iteration 7000/30000, Eb/No: 12.8311, Loss: -0.8446
# Iteration 7100/30000, Eb/No: 9.4176, Loss: -0.7245
# Iteration 7200/30000, Eb/No: 8.8739, Loss: -0.6741
# Iteration 7300/30000, Eb/No: 3.3894, Loss: -0.4439
# Iteration 7400/30000, Eb/No: 7.5088, Loss: -0.6329
# Iteration 7500/30000, Eb/No: 1.1334, Loss: -0.3413
# Iteration 7600/30000, Eb/No: 11.5380, Loss: -0.8049
# Iteration 7700/30000, Eb/No: 9.4928, Loss: -0.7057
# Iteration 7800/30000, Eb/No: 8.0995, Loss: -0.6666
# Iteration 7900/30000, Eb/No: 5.0969, Loss: -0.5015
# Iteration 8000/30000, Eb/No: 2.4794, Loss: -0.4003
# Iteration 8100/30000, Eb/No: 12.5995, Loss: -0.8511
# Iteration 8200/30000, Eb/No: 0.5997, Loss: -0.3215
# Iteration 8300/30000, Eb/No: 4.1517, Loss: -0.4476
# Iteration 8400/30000, Eb/No: 1.5328, Loss: -0.3530
# Iteration 8500/30000, Eb/No: 2.8276, Loss: -0.4012
# Iteration 8600/30000, Eb/No: 10.6643, Loss: -0.7724
# Iteration 8700/30000, Eb/No: 2.6889, Loss: -0.4081
# Iteration 8800/30000, Eb/No: 7.3734, Loss: -0.6281
# Iteration 8900/30000, Eb/No: 4.4575, Loss: -0.4883
# Iteration 9000/30000, Eb/No: 1.5054, Loss: -0.3600
# Iteration 9100/30000, Eb/No: 3.2141, Loss: -0.4199
# Iteration 9200/30000, Eb/No: 10.4413, Loss: -0.7794
# Iteration 9300/30000, Eb/No: 14.5274, Loss: -0.9071
# Iteration 9400/30000, Eb/No: 5.1865, Loss: -0.5171
# Iteration 9500/30000, Eb/No: 4.9797, Loss: -0.5233
# Iteration 9600/30000, Eb/No: 12.1911, Loss: -0.8422
# Iteration 9700/30000, Eb/No: 10.7220, Loss: -0.7862
# Iteration 9800/30000, Eb/No: 12.9108, Loss: -0.8348
# Iteration 9900/30000, Eb/No: 0.8135, Loss: -0.3316
# Iteration 10000/30000, Eb/No: 0.1793, Loss: -0.2737
# Iteration 10100/30000, Eb/No: 10.0833, Loss: -0.7580
# Iteration 10200/30000, Eb/No: 1.8545, Loss: -0.3617
# Iteration 10300/30000, Eb/No: 7.0869, Loss: -0.5438
# Iteration 10400/30000, Eb/No: 4.0621, Loss: -0.4706
# Iteration 10500/30000, Eb/No: 3.9677, Loss: -0.4718
# Iteration 10600/30000, Eb/No: 9.4016, Loss: -0.7353
# Iteration 10700/30000, Eb/No: 11.0693, Loss: -0.8054
# Iteration 10800/30000, Eb/No: 5.1196, Loss: -0.5308
# Iteration 10900/30000, Eb/No: 11.6149, Loss: -0.8299
# Iteration 11000/30000, Eb/No: 14.9420, Loss: -0.9292
# Iteration 11100/30000, Eb/No: 7.3220, Loss: -0.6258
# Iteration 11200/30000, Eb/No: 3.0753, Loss: -0.4294
# Iteration 11300/30000, Eb/No: 5.6589, Loss: -0.4610
# Iteration 11400/30000, Eb/No: 0.5215, Loss: -0.3103
# Iteration 11500/30000, Eb/No: 10.8822, Loss: -0.8025
# Iteration 11600/30000, Eb/No: 1.5273, Loss: -0.3611
# Iteration 11700/30000, Eb/No: 14.0265, Loss: -0.8945
# Iteration 11800/30000, Eb/No: 4.8105, Loss: -0.5165
# Iteration 11900/30000, Eb/No: 6.0225, Loss: -0.5460
# Iteration 12000/30000, Eb/No: 1.7870, Loss: -0.3551
# Iteration 12100/30000, Eb/No: 6.7173, Loss: -0.6062
# Iteration 12200/30000, Eb/No: 8.9461, Loss: -0.7173
# Iteration 12300/30000, Eb/No: 13.1743, Loss: -0.8394
# Iteration 12400/30000, Eb/No: 11.8560, Loss: -0.8237
# Iteration 12500/30000, Eb/No: 0.5726, Loss: -0.3219
# Iteration 12600/30000, Eb/No: 8.4537, Loss: -0.6969
# Iteration 12700/30000, Eb/No: 9.9361, Loss: -0.7386
# Iteration 12800/30000, Eb/No: 2.5886, Loss: -0.3719
# Iteration 12900/30000, Eb/No: 3.8984, Loss: -0.4517
# Iteration 13000/30000, Eb/No: 8.2963, Loss: -0.6760
# Iteration 13100/30000, Eb/No: 8.2244, Loss: -0.6781
# Iteration 13200/30000, Eb/No: 4.6198, Loss: -0.4979
# Iteration 13300/30000, Eb/No: 3.6280, Loss: -0.4585
# Iteration 13400/30000, Eb/No: 0.7277, Loss: -0.3331
# Iteration 13500/30000, Eb/No: 1.2507, Loss: -0.3531
# Iteration 13600/30000, Eb/No: 2.4032, Loss: -0.4034
# Iteration 13700/30000, Eb/No: 1.3072, Loss: -0.3536
# Iteration 13800/30000, Eb/No: 12.3846, Loss: -0.8453
# Iteration 13900/30000, Eb/No: 4.2939, Loss: -0.4846
# Iteration 14000/30000, Eb/No: 6.7257, Loss: -0.5997
# Iteration 14100/30000, Eb/No: 12.4850, Loss: -0.6453
# Iteration 14200/30000, Eb/No: 4.7235, Loss: -0.4448
# Iteration 14300/30000, Eb/No: 2.7573, Loss: -0.4024
# Iteration 14400/30000, Eb/No: 9.5224, Loss: -0.7412
# Iteration 14500/30000, Eb/No: 13.0946, Loss: -0.8694
# Iteration 14600/30000, Eb/No: 12.5653, Loss: -0.8620
# Iteration 14700/30000, Eb/No: 14.3649, Loss: -0.7841
# Iteration 14800/30000, Eb/No: 9.4645, Loss: -0.7347
# Iteration 14900/30000, Eb/No: 14.8879, Loss: -0.8357
# Iteration 15000/30000, Eb/No: 8.1875, Loss: -0.6735
# Iteration 15100/30000, Eb/No: 13.0600, Loss: -0.8808
# Iteration 15200/30000, Eb/No: 10.5010, Loss: -0.7635
# Iteration 15300/30000, Eb/No: 11.5736, Loss: -0.8279
# Iteration 15400/30000, Eb/No: 1.8866, Loss: -0.3827
# Iteration 15500/30000, Eb/No: 14.1400, Loss: -0.9074
# Iteration 15600/30000, Eb/No: 14.2427, Loss: -0.9168
# Iteration 15700/30000, Eb/No: 10.3214, Loss: -0.7782
# Iteration 15800/30000, Eb/No: 10.0421, Loss: -0.7570
# Iteration 15900/30000, Eb/No: 2.8082, Loss: -0.4247
# Iteration 16000/30000, Eb/No: 3.7321, Loss: -0.4620
# Iteration 16100/30000, Eb/No: 7.7237, Loss: -0.6528
# Iteration 16200/30000, Eb/No: 1.4660, Loss: -0.3644
# Iteration 16300/30000, Eb/No: 4.5389, Loss: -0.5009
# Iteration 16400/30000, Eb/No: 13.8116, Loss: -0.8886
# Iteration 16500/30000, Eb/No: 3.3509, Loss: -0.4400
# Iteration 16600/30000, Eb/No: 3.3729, Loss: -0.4406
# Iteration 16700/30000, Eb/No: 1.3970, Loss: -0.3552
# Iteration 16800/30000, Eb/No: 1.5848, Loss: -0.3680
# Iteration 16900/30000, Eb/No: 2.2067, Loss: -0.3932
# Iteration 17000/30000, Eb/No: 7.0990, Loss: -0.6275
# Iteration 17100/30000, Eb/No: 10.9744, Loss: -0.8091
# Iteration 17200/30000, Eb/No: 11.6466, Loss: -0.8305
# Iteration 17300/30000, Eb/No: 10.7793, Loss: -0.7803
# Iteration 17400/30000, Eb/No: 7.4465, Loss: -0.6436
# Iteration 17500/30000, Eb/No: 10.9168, Loss: -0.7932
# Iteration 17600/30000, Eb/No: 4.6883, Loss: -0.5070
# Iteration 17700/30000, Eb/No: 14.6585, Loss: -0.9210
# Iteration 17800/30000, Eb/No: 0.8127, Loss: 0.6621
# Iteration 17900/30000, Eb/No: 8.0471, Loss: -0.6465
# Iteration 18000/30000, Eb/No: 8.8569, Loss: -0.7069
# Iteration 18100/30000, Eb/No: 7.4854, Loss: -0.6475
# Iteration 18200/30000, Eb/No: 10.5153, Loss: -0.7826
# Iteration 18300/30000, Eb/No: 6.3146, Loss: -0.5816
# Iteration 18400/30000, Eb/No: 8.1385, Loss: -0.6775
# Iteration 18500/30000, Eb/No: 2.9866, Loss: -0.4237
# Iteration 18600/30000, Eb/No: 4.4154, Loss: -0.4898
# Iteration 18700/30000, Eb/No: 2.7499, Loss: -0.4198
# Iteration 18800/30000, Eb/No: 11.9346, Loss: -0.8416
# Iteration 18900/30000, Eb/No: 6.1773, Loss: -0.5840
# Iteration 19000/30000, Eb/No: 3.1977, Loss: -0.4357
# Iteration 19100/30000, Eb/No: 8.8649, Loss: -0.7080
# Iteration 19200/30000, Eb/No: 13.4268, Loss: -0.8865
# Iteration 19300/30000, Eb/No: 4.2167, Loss: -0.4893
# Iteration 19400/30000, Eb/No: 7.0170, Loss: -0.6227
# Iteration 19500/30000, Eb/No: 2.8890, Loss: -0.4072
# Iteration 19600/30000, Eb/No: 1.5311, Loss: -0.3670
# Iteration 19700/30000, Eb/No: 7.5010, Loss: -0.6358
# Iteration 19800/30000, Eb/No: 12.3151, Loss: -0.8607
# Iteration 19900/30000, Eb/No: 0.0826, Loss: -0.3113
# Iteration 20000/30000, Eb/No: 2.5457, Loss: -0.4086
# Iteration 20100/30000, Eb/No: 2.7383, Loss: -0.4168
# Iteration 20200/30000, Eb/No: 0.6791, Loss: -0.3214
# Iteration 20300/30000, Eb/No: 6.9125, Loss: -0.6222
# Iteration 20400/30000, Eb/No: 1.8850, Loss: -0.3780
# Iteration 20500/30000, Eb/No: 8.2620, Loss: -0.6772
# Iteration 20600/30000, Eb/No: 0.0913, Loss: -0.3022
# Iteration 20700/30000, Eb/No: 4.0417, Loss: -0.4816
# Iteration 20800/30000, Eb/No: 13.1974, Loss: -0.7711
# Iteration 20900/30000, Eb/No: 13.5752, Loss: -0.8616
# Iteration 21000/30000, Eb/No: 5.3297, Loss: -0.5389
# Iteration 21100/30000, Eb/No: 2.3915, Loss: -0.4006
# Iteration 21200/30000, Eb/No: 5.2359, Loss: -0.5350
# Iteration 21300/30000, Eb/No: 12.5088, Loss: -0.8688
# Iteration 21400/30000, Eb/No: 4.1795, Loss: -0.4843
# Iteration 21500/30000, Eb/No: 11.2363, Loss: -0.8172
# Iteration 21600/30000, Eb/No: 3.8605, Loss: -0.4672
# Iteration 21700/30000, Eb/No: 3.8570, Loss: -0.4705
# Iteration 21800/30000, Eb/No: 1.0915, Loss: -0.3502
# Iteration 21900/30000, Eb/No: 13.0104, Loss: -0.8748
# Iteration 22000/30000, Eb/No: 14.6314, Loss: -0.8902
# Iteration 22100/30000, Eb/No: 7.9850, Loss: -0.6567
# Iteration 22200/30000, Eb/No: 5.6053, Loss: -0.5124
# Iteration 22300/30000, Eb/No: 0.0502, Loss: -0.2935
# Iteration 22400/30000, Eb/No: 5.1682, Loss: -0.5282
# Iteration 22500/30000, Eb/No: 11.1937, Loss: -0.8038
# Iteration 22600/30000, Eb/No: 14.9373, Loss: -0.9297
# Iteration 22700/30000, Eb/No: 9.2115, Loss: -0.7249
# Iteration 22800/30000, Eb/No: 8.0109, Loss: -0.6760
# Iteration 22900/30000, Eb/No: 14.4688, Loss: -0.9213
# Iteration 23000/30000, Eb/No: 1.4158, Loss: -0.3577
# Iteration 23100/30000, Eb/No: 14.7892, Loss: -0.9099
# Iteration 23200/30000, Eb/No: 10.2381, Loss: -0.7768
# Iteration 23300/30000, Eb/No: 0.9339, Loss: -0.3419
# Iteration 23400/30000, Eb/No: 6.1371, Loss: -0.5831
# Iteration 23500/30000, Eb/No: 13.5607, Loss: -0.9020
# Iteration 23600/30000, Eb/No: 10.9074, Loss: -0.8055
# Iteration 23700/30000, Eb/No: 6.2098, Loss: -0.5849
# Iteration 23800/30000, Eb/No: 0.9040, Loss: -0.3384
# Iteration 23900/30000, Eb/No: 3.0327, Loss: -0.4298
# Iteration 24000/30000, Eb/No: 5.8421, Loss: -0.5688
# Iteration 24100/30000, Eb/No: 5.7660, Loss: -0.5677
# Iteration 24200/30000, Eb/No: 10.5616, Loss: -0.7918
# Iteration 24300/30000, Eb/No: 14.2729, Loss: -0.8965
# Iteration 24400/30000, Eb/No: 2.5874, Loss: -0.4074
# Iteration 24500/30000, Eb/No: 14.5136, Loss: -0.9241
# Iteration 24600/30000, Eb/No: 0.4972, Loss: -0.3241
# Iteration 24700/30000, Eb/No: 14.4210, Loss: -0.9235
# Iteration 24800/30000, Eb/No: 6.7056, Loss: -0.6149
# Iteration 24900/30000, Eb/No: 12.8361, Loss: -0.8661
# Iteration 25000/30000, Eb/No: 13.6631, Loss: -0.9054
# Iteration 25100/30000, Eb/No: 14.5266, Loss: -0.9261
# Iteration 25200/30000, Eb/No: 1.0380, Loss: -0.3478
# Iteration 25300/30000, Eb/No: 4.8623, Loss: -0.5166
# Iteration 25400/30000, Eb/No: 7.4044, Loss: -0.6398
# Iteration 25500/30000, Eb/No: 9.1972, Loss: -0.7316
# Iteration 25600/30000, Eb/No: 14.9780, Loss: -0.9371
# Iteration 25700/30000, Eb/No: 4.1588, Loss: -0.4749
# Iteration 25800/30000, Eb/No: 4.0315, Loss: -0.4747
# Iteration 25900/30000, Eb/No: 6.6011, Loss: -0.5567
# Iteration 26000/30000, Eb/No: 0.3398, Loss: -0.3186
# Iteration 26100/30000, Eb/No: 7.4038, Loss: -0.6429
# Iteration 26200/30000, Eb/No: 5.1674, Loss: -0.5370
# Iteration 26300/30000, Eb/No: 7.9061, Loss: -0.6662
# Iteration 26400/30000, Eb/No: 11.6298, Loss: -0.8118
# Iteration 26500/30000, Eb/No: 12.7367, Loss: -0.8797
# Iteration 26600/30000, Eb/No: 13.3713, Loss: -0.8822
# Iteration 26700/30000, Eb/No: 13.8608, Loss: -0.9071
# Iteration 26800/30000, Eb/No: 10.4445, Loss: -0.7728
# Iteration 26900/30000, Eb/No: 12.5311, Loss: -0.8581
# Iteration 27000/30000, Eb/No: 6.5299, Loss: -0.5976
# Iteration 27100/30000, Eb/No: 3.5890, Loss: -0.4615
# Iteration 27200/30000, Eb/No: 10.6479, Loss: -0.7783
# Iteration 27300/30000, Eb/No: 8.6317, Loss: -0.6929
# Iteration 27400/30000, Eb/No: 9.3625, Loss: -0.7373
# Iteration 27500/30000, Eb/No: 14.5233, Loss: -0.9228
# Iteration 27600/30000, Eb/No: 13.4474, Loss: -0.8759
# Iteration 27700/30000, Eb/No: 10.3327, Loss: -0.7024
# Iteration 27800/30000, Eb/No: 11.9264, Loss: -0.8362
# Iteration 27900/30000, Eb/No: 10.9233, Loss: -0.8036
# Iteration 28000/30000, Eb/No: 3.3100, Loss: -0.4464
# Iteration 28100/30000, Eb/No: 1.6906, Loss: -0.3669
# Iteration 28200/30000, Eb/No: 13.5900, Loss: -0.8800
# Iteration 28300/30000, Eb/No: 9.5368, Loss: -0.7431
# Iteration 28400/30000, Eb/No: 4.6471, Loss: -0.5010
# Iteration 28500/30000, Eb/No: 1.9578, Loss: -0.3890
# Iteration 28600/30000, Eb/No: 6.1076, Loss: -0.5822
# Iteration 28700/30000, Eb/No: 12.4973, Loss: -0.8645
# Iteration 28800/30000, Eb/No: 6.2587, Loss: -0.5918
# Iteration 28900/30000, Eb/No: 12.4050, Loss: -0.8712
# Iteration 29000/30000, Eb/No: 12.8463, Loss: -0.8875
# Iteration 29100/30000, Eb/No: 12.2208, Loss: -0.8616
# Iteration 29200/30000, Eb/No: 2.9384, Loss: -0.4248
# Iteration 29300/30000, Eb/No: 3.5274, Loss: -0.4540
# Iteration 29400/30000, Eb/No: 6.3867, Loss: -0.5953
# Iteration 29500/30000, Eb/No: 5.1586, Loss: -0.5387
# Iteration 29600/30000, Eb/No: 2.4544, Loss: -0.4048
# Iteration 29700/30000, Eb/No: 12.7959, Loss: -0.8748
# Iteration 29800/30000, Eb/No: 10.5540, Loss: -0.7889
# Iteration 29900/30000, Eb/No: 4.4799, Loss: -0.4973
# Iteration 30000/30000, Eb/No: 7.7441, Loss: -0.6552

# %%
# FiLM
model = E2ESystem('neural-receiver', training=True)
optimizer = tf.keras.optimizers.Adam()

# one compiled call per modulation order to avoid retracing issues
@tf.function
def train_step(batch_size, ebno_db, nbps):
    with tf.GradientTape() as tape:
        rate = model(batch_size, ebno_db, nbps)
        loss = -rate
    grads = tape.gradient(loss, model.trainable_weights)
    optimizer.apply_gradients(zip(grads, model.trainable_weights))
    return loss

for i in tqdm(range(num_training_iterations*3 + 1)):
    ebno_db = tf.random.uniform(shape=[], minval=ebno_db_min, maxval=ebno_db_max)
    # cycle through modulation orders — round-robin
    nbps = MOD_ORDERS[i % len(MOD_ORDERS)]   # 2, 4, 6, 2, 4, 6, ...

    loss = train_step(training_batch_size, ebno_db, nbps)

    if i % 100 == 0:
        print(f"Iter {i} | nbps={nbps} | "
              f"Eb/No={ebno_db.numpy():.2f}dB | Loss={loss.numpy():.4f}")
    # if i % 30000 == 0:
    #     weights = model.get_weights()
    #     with open('FiLM/30000_qam_multi_mod_neural_receiver_weights.pkl', 'wb') as f:
    #         pickle.dump(weights, f)

weights = model.get_weights()
with open('FiLM/90000_qam_multi_mod_neural_receiver_weights.pkl', 'wb') as f:
    pickle.dump(weights, f)
# Out:
#   0%|          | 0/90001 [00:00<?, ?it/s]
# Iter 0 | nbps=2 | Eb/No=11.06dB | Loss=0.0567
# Iter 100 | nbps=4 | Eb/No=1.49dB | Loss=-0.0017
# Iter 200 | nbps=6 | Eb/No=5.90dB | Loss=-0.1658
# Iter 300 | nbps=2 | Eb/No=11.83dB | Loss=-0.9926
# Iter 400 | nbps=4 | Eb/No=2.92dB | Loss=-0.5070
# Iter 500 | nbps=6 | Eb/No=11.15dB | Loss=-0.5030
# Iter 600 | nbps=2 | Eb/No=8.81dB | Loss=-0.9896
# Iter 700 | nbps=4 | Eb/No=8.13dB | Loss=-0.8370
# Iter 800 | nbps=6 | Eb/No=10.96dB | Loss=-0.5309
# Iter 900 | nbps=2 | Eb/No=6.87dB | Loss=-0.9947
# Iter 1000 | nbps=4 | Eb/No=7.09dB | Loss=-0.8010
# Iter 1100 | nbps=6 | Eb/No=5.54dB | Loss=-0.4130
# Iter 1200 | nbps=2 | Eb/No=5.44dB | Loss=-0.9888
# Iter 1300 | nbps=4 | Eb/No=10.12dB | Loss=-0.9204
# Iter 1400 | nbps=6 | Eb/No=5.36dB | Loss=-0.4327
# Iter 1500 | nbps=2 | Eb/No=11.88dB | Loss=-0.9978
# Iter 1600 | nbps=4 | Eb/No=4.02dB | Loss=-0.6667
# Iter 1700 | nbps=6 | Eb/No=2.63dB | Loss=-0.3435
# Iter 1800 | nbps=2 | Eb/No=7.62dB | Loss=-0.9907
# Iter 1900 | nbps=4 | Eb/No=12.24dB | Loss=-0.9628
# Iter 2000 | nbps=6 | Eb/No=2.50dB | Loss=-0.3454
# Iter 2100 | nbps=2 | Eb/No=14.58dB | Loss=-1.0000
# Iter 2200 | nbps=4 | Eb/No=0.80dB | Loss=-0.4792
# Iter 2300 | nbps=6 | Eb/No=12.03dB | Loss=-0.5988
# Iter 2400 | nbps=2 | Eb/No=13.56dB | Loss=-1.0000
# Iter 2500 | nbps=4 | Eb/No=6.57dB | Loss=-0.8003
# Iter 2600 | nbps=6 | Eb/No=5.97dB | Loss=-0.4643
# Iter 2700 | nbps=2 | Eb/No=14.50dB | Loss=-1.0000
# Iter 2800 | nbps=4 | Eb/No=2.42dB | Loss=-0.4529
# Iter 2900 | nbps=6 | Eb/No=1.94dB | Loss=-0.3331
# Iter 3000 | nbps=2 | Eb/No=7.09dB | Loss=-0.9970
# Iter 3100 | nbps=4 | Eb/No=9.43dB | Loss=-0.9190
# Iter 3200 | nbps=6 | Eb/No=5.10dB | Loss=-0.4186
# Iter 3300 | nbps=2 | Eb/No=9.27dB | Loss=-0.9999
# Iter 3400 | nbps=4 | Eb/No=14.61dB | Loss=-0.9731
# Iter 3500 | nbps=6 | Eb/No=12.35dB | Loss=-0.6291
# Iter 3600 | nbps=2 | Eb/No=4.29dB | Loss=-0.9762
# Iter 3700 | nbps=4 | Eb/No=3.55dB | Loss=-0.6440
# Iter 3800 | nbps=6 | Eb/No=13.80dB | Loss=-0.5580
# Iter 3900 | nbps=2 | Eb/No=4.68dB | Loss=-0.9834
# Iter 4000 | nbps=4 | Eb/No=12.33dB | Loss=-0.9756
# Iter 4100 | nbps=6 | Eb/No=11.63dB | Loss=-0.6162
# Iter 4200 | nbps=2 | Eb/No=14.51dB | Loss=-0.9996
# Iter 4300 | nbps=4 | Eb/No=11.28dB | Loss=-0.9712
# Iter 4400 | nbps=6 | Eb/No=14.31dB | Loss=-0.6441
# Iter 4500 | nbps=2 | Eb/No=3.63dB | Loss=-0.9648
# Iter 4600 | nbps=4 | Eb/No=3.76dB | Loss=-0.6650
# Iter 4700 | nbps=6 | Eb/No=11.70dB | Loss=-0.6209
# Iter 4800 | nbps=2 | Eb/No=10.43dB | Loss=-0.9998
# Iter 4900 | nbps=4 | Eb/No=11.00dB | Loss=-0.9684
# Iter 5000 | nbps=6 | Eb/No=4.71dB | Loss=-0.4326
# Iter 5100 | nbps=2 | Eb/No=14.86dB | Loss=-1.0000
# Iter 5200 | nbps=4 | Eb/No=8.98dB | Loss=-0.9206
# Iter 5300 | nbps=6 | Eb/No=13.60dB | Loss=-0.6590
# Iter 5400 | nbps=2 | Eb/No=0.54dB | Loss=-0.8610
# Iter 5500 | nbps=4 | Eb/No=0.79dB | Loss=-0.4891
# Iter 5600 | nbps=6 | Eb/No=11.84dB | Loss=-0.6220
# Iter 5700 | nbps=2 | Eb/No=11.12dB | Loss=-0.9999
# Iter 5800 | nbps=4 | Eb/No=14.60dB | Loss=-0.9895
# Iter 5900 | nbps=6 | Eb/No=2.83dB | Loss=-0.3670
# Iter 6000 | nbps=2 | Eb/No=6.14dB | Loss=-0.9953
# Iter 6100 | nbps=4 | Eb/No=4.26dB | Loss=-0.6922
# Iter 6200 | nbps=6 | Eb/No=7.32dB | Loss=-0.5244
# Iter 6300 | nbps=2 | Eb/No=14.61dB | Loss=-1.0000
# Iter 6400 | nbps=4 | Eb/No=6.46dB | Loss=-0.8206
# Iter 6500 | nbps=6 | Eb/No=3.04dB | Loss=-0.3720
# Iter 6600 | nbps=2 | Eb/No=4.39dB | Loss=-0.9868
# Iter 6700 | nbps=4 | Eb/No=12.53dB | Loss=-0.9872
# Iter 6800 | nbps=6 | Eb/No=13.79dB | Loss=-0.7153
# Iter 6900 | nbps=2 | Eb/No=10.45dB | Loss=-0.9999
# Iter 7000 | nbps=4 | Eb/No=14.61dB | Loss=-0.9948
# Iter 7100 | nbps=6 | Eb/No=14.61dB | Loss=-0.7368
# Iter 7200 | nbps=2 | Eb/No=9.31dB | Loss=-0.9998
# Iter 7300 | nbps=4 | Eb/No=13.98dB | Loss=-0.9858
# Iter 7400 | nbps=6 | Eb/No=4.45dB | Loss=-0.4343
# Iter 7500 | nbps=2 | Eb/No=11.59dB | Loss=-1.0000
# Iter 7600 | nbps=4 | Eb/No=5.81dB | Loss=-0.7878
# Iter 7700 | nbps=6 | Eb/No=11.71dB | Loss=-0.7147
# Iter 7800 | nbps=2 | Eb/No=13.28dB | Loss=-0.9957
# Iter 7900 | nbps=4 | Eb/No=9.90dB | Loss=-0.9565
# Iter 8000 | nbps=6 | Eb/No=6.14dB | Loss=-0.5205
# Iter 8100 | nbps=2 | Eb/No=13.39dB | Loss=-0.9991
# Iter 8200 | nbps=4 | Eb/No=3.60dB | Loss=-0.6553
# Iter 8300 | nbps=6 | Eb/No=8.35dB | Loss=-0.5776
# Iter 8400 | nbps=2 | Eb/No=10.98dB | Loss=-0.9998
# Iter 8500 | nbps=4 | Eb/No=14.77dB | Loss=-0.9958
# Iter 8600 | nbps=6 | Eb/No=1.75dB | Loss=-0.3219
# Iter 8700 | nbps=2 | Eb/No=14.28dB | Loss=-1.0000
# Iter 8800 | nbps=4 | Eb/No=9.51dB | Loss=-0.9402
# Iter 8900 | nbps=6 | Eb/No=14.70dB | Loss=-0.8276
# Iter 9000 | nbps=2 | Eb/No=12.66dB | Loss=-1.0000
# Iter 9100 | nbps=4 | Eb/No=4.77dB | Loss=-0.7292
# Iter 9200 | nbps=6 | Eb/No=3.10dB | Loss=-0.3875
# Iter 9300 | nbps=2 | Eb/No=9.30dB | Loss=-1.0000
# Iter 9400 | nbps=4 | Eb/No=5.35dB | Loss=-0.7638
# Iter 9500 | nbps=6 | Eb/No=7.03dB | Loss=-0.5661
# Iter 9600 | nbps=2 | Eb/No=12.15dB | Loss=-0.9999
# Iter 9700 | nbps=4 | Eb/No=8.81dB | Loss=-0.9240
# Iter 9800 | nbps=6 | Eb/No=13.75dB | Loss=-0.8152
# Iter 9900 | nbps=2 | Eb/No=13.43dB | Loss=-0.9995
# Iter 10000 | nbps=4 | Eb/No=6.42dB | Loss=-0.7984
# Iter 10100 | nbps=6 | Eb/No=1.17dB | Loss=-0.3150
# Iter 10200 | nbps=2 | Eb/No=1.19dB | Loss=-0.8918
# Iter 10300 | nbps=4 | Eb/No=14.37dB | Loss=-0.9947
# Iter 10400 | nbps=6 | Eb/No=4.84dB | Loss=-0.4685
# Iter 10500 | nbps=2 | Eb/No=13.68dB | Loss=-1.0000
# Iter 10600 | nbps=4 | Eb/No=2.03dB | Loss=-0.5740
# Iter 10700 | nbps=6 | Eb/No=7.93dB | Loss=-0.5485
# Iter 10800 | nbps=2 | Eb/No=12.21dB | Loss=-1.0000
# Iter 10900 | nbps=4 | Eb/No=7.86dB | Loss=-0.8901
# Iter 11000 | nbps=6 | Eb/No=9.29dB | Loss=-0.6727
# Iter 11100 | nbps=2 | Eb/No=6.58dB | Loss=-0.9928
# Iter 11200 | nbps=4 | Eb/No=9.78dB | Loss=-0.9540
# Iter 11300 | nbps=6 | Eb/No=14.63dB | Loss=-0.8605
# Iter 11400 | nbps=2 | Eb/No=8.20dB | Loss=-0.9964
# Iter 11500 | nbps=4 | Eb/No=3.86dB | Loss=-0.6878
# Iter 11600 | nbps=6 | Eb/No=0.10dB | Loss=-0.2710
# Iter 11700 | nbps=2 | Eb/No=13.05dB | Loss=-0.9999
# Iter 11800 | nbps=4 | Eb/No=8.74dB | Loss=-0.9232
# Iter 11900 | nbps=6 | Eb/No=5.41dB | Loss=-0.5005
# Iter 12000 | nbps=2 | Eb/No=2.92dB | Loss=-0.9436
# Iter 12100 | nbps=4 | Eb/No=10.87dB | Loss=-0.9771
# Iter 12200 | nbps=6 | Eb/No=10.82dB | Loss=-0.7275
# Iter 12300 | nbps=2 | Eb/No=12.44dB | Loss=-1.0000
# Iter 12400 | nbps=4 | Eb/No=14.53dB | Loss=-0.9984
# Iter 12500 | nbps=6 | Eb/No=11.92dB | Loss=-0.7738
# Iter 12600 | nbps=2 | Eb/No=8.47dB | Loss=-0.9942
# Iter 12700 | nbps=4 | Eb/No=4.90dB | Loss=-0.7290
# Iter 12800 | nbps=6 | Eb/No=8.56dB | Loss=-0.6210
# Iter 12900 | nbps=2 | Eb/No=4.17dB | Loss=-0.9789
# Iter 13000 | nbps=4 | Eb/No=8.93dB | Loss=-0.9395
# Iter 13100 | nbps=6 | Eb/No=1.19dB | Loss=-0.3203
# Iter 13200 | nbps=2 | Eb/No=8.61dB | Loss=-0.9913
# Iter 13300 | nbps=4 | Eb/No=7.84dB | Loss=-0.8786
# Iter 13400 | nbps=6 | Eb/No=10.90dB | Loss=-0.7528
# Iter 13500 | nbps=2 | Eb/No=9.78dB | Loss=-0.9985
# Iter 13600 | nbps=4 | Eb/No=0.99dB | Loss=-0.4978
# Iter 13700 | nbps=6 | Eb/No=5.78dB | Loss=-0.5236
# Iter 13800 | nbps=2 | Eb/No=11.35dB | Loss=-0.9998
# Iter 13900 | nbps=4 | Eb/No=0.77dB | Loss=-0.4854
# Iter 14000 | nbps=6 | Eb/No=8.28dB | Loss=-0.5815
# Iter 14100 | nbps=2 | Eb/No=0.78dB | Loss=-0.8535
# Iter 14200 | nbps=4 | Eb/No=14.27dB | Loss=-0.9956
# Iter 14300 | nbps=6 | Eb/No=3.87dB | Loss=-0.4285
# Iter 14400 | nbps=2 | Eb/No=14.35dB | Loss=-0.9975
# Iter 14500 | nbps=4 | Eb/No=2.19dB | Loss=-0.5761
# Iter 14600 | nbps=6 | Eb/No=4.63dB | Loss=-0.4771
# Iter 14700 | nbps=2 | Eb/No=0.47dB | Loss=-0.8581
# Iter 14800 | nbps=4 | Eb/No=0.54dB | Loss=-0.4791
# Iter 14900 | nbps=6 | Eb/No=6.11dB | Loss=-0.5415
# Iter 15000 | nbps=2 | Eb/No=7.65dB | Loss=-0.9980
# Iter 15100 | nbps=4 | Eb/No=8.30dB | Loss=-0.9117
# Iter 15200 | nbps=6 | Eb/No=2.98dB | Loss=-0.3939
# Iter 15300 | nbps=2 | Eb/No=12.88dB | Loss=-0.9995
# Iter 15400 | nbps=4 | Eb/No=8.79dB | Loss=-0.9218
# Iter 15500 | nbps=6 | Eb/No=12.37dB | Loss=-0.8174
# Iter 15600 | nbps=2 | Eb/No=5.85dB | Loss=-0.9974
# Iter 15700 | nbps=4 | Eb/No=2.79dB | Loss=-0.6192
# Iter 15800 | nbps=6 | Eb/No=7.22dB | Loss=-0.5858
# Iter 15900 | nbps=2 | Eb/No=10.60dB | Loss=-0.9952
# Iter 16000 | nbps=4 | Eb/No=4.05dB | Loss=-0.6937
# Iter 16100 | nbps=6 | Eb/No=1.74dB | Loss=-0.3303
# Iter 16200 | nbps=2 | Eb/No=2.97dB | Loss=-0.9603
# Iter 16300 | nbps=4 | Eb/No=9.36dB | Loss=-0.9442
# Iter 16400 | nbps=6 | Eb/No=2.23dB | Loss=-0.3582
# Iter 16500 | nbps=2 | Eb/No=7.03dB | Loss=-0.9832
# Iter 16600 | nbps=4 | Eb/No=9.21dB | Loss=-0.9226
# Iter 16700 | nbps=6 | Eb/No=10.83dB | Loss=-0.6074
# Iter 16800 | nbps=2 | Eb/No=1.14dB | Loss=-0.8867
# Iter 16900 | nbps=4 | Eb/No=10.99dB | Loss=-0.9725
# Iter 17000 | nbps=6 | Eb/No=10.36dB | Loss=-0.7353
# Iter 17100 | nbps=2 | Eb/No=5.58dB | Loss=-0.9923
# Iter 17200 | nbps=4 | Eb/No=4.80dB | Loss=-0.7371
# Iter 17300 | nbps=6 | Eb/No=12.48dB | Loss=-0.7715
# Iter 17400 | nbps=2 | Eb/No=6.82dB | Loss=-0.9978
# Iter 17500 | nbps=4 | Eb/No=0.76dB | Loss=-0.4945
# Iter 17600 | nbps=6 | Eb/No=12.48dB | Loss=-0.8235
# Iter 17700 | nbps=2 | Eb/No=12.10dB | Loss=-0.9980
# Iter 17800 | nbps=4 | Eb/No=9.33dB | Loss=-0.9456
# Iter 17900 | nbps=6 | Eb/No=14.01dB | Loss=-0.8792
# Iter 18000 | nbps=2 | Eb/No=11.31dB | Loss=-1.0000
# Iter 18100 | nbps=4 | Eb/No=14.11dB | Loss=-0.9971
# Iter 18200 | nbps=6 | Eb/No=10.77dB | Loss=-0.7504
# Iter 18300 | nbps=2 | Eb/No=7.42dB | Loss=-0.9984
# Iter 18400 | nbps=4 | Eb/No=2.97dB | Loss=-0.6240
# Iter 18500 | nbps=6 | Eb/No=7.68dB | Loss=-0.5609
# Iter 18600 | nbps=2 | Eb/No=5.42dB | Loss=-0.9884
# Iter 18700 | nbps=4 | Eb/No=5.79dB | Loss=-0.8022
# Iter 18800 | nbps=6 | Eb/No=8.31dB | Loss=-0.6448
# Iter 18900 | nbps=2 | Eb/No=1.16dB | Loss=-0.8759
# Iter 19000 | nbps=4 | Eb/No=1.60dB | Loss=-0.5490
# Iter 19100 | nbps=6 | Eb/No=0.59dB | Loss=-0.2985
# Iter 19200 | nbps=2 | Eb/No=13.90dB | Loss=-1.0000
# Iter 19300 | nbps=4 | Eb/No=13.31dB | Loss=-0.9870
# Iter 19400 | nbps=6 | Eb/No=1.24dB | Loss=-0.3210
# Iter 19500 | nbps=2 | Eb/No=6.58dB | Loss=-0.9971
# Iter 19600 | nbps=4 | Eb/No=4.19dB | Loss=-0.7079
# Iter 19700 | nbps=6 | Eb/No=1.59dB | Loss=-0.3359
# Iter 19800 | nbps=2 | Eb/No=0.38dB | Loss=-0.8493
# Iter 19900 | nbps=4 | Eb/No=2.53dB | Loss=-0.5894
# Iter 20000 | nbps=6 | Eb/No=4.41dB | Loss=-0.4631
# Iter 20100 | nbps=2 | Eb/No=13.05dB | Loss=-1.0000
# Iter 20200 | nbps=4 | Eb/No=0.86dB | Loss=-0.4919
# Iter 20300 | nbps=6 | Eb/No=13.15dB | Loss=-0.8357
# Iter 20400 | nbps=2 | Eb/No=14.66dB | Loss=-0.9992
# Iter 20500 | nbps=4 | Eb/No=3.91dB | Loss=-0.6778
# Iter 20600 | nbps=6 | Eb/No=7.55dB | Loss=-0.6115
# Iter 20700 | nbps=2 | Eb/No=8.30dB | Loss=-0.9999
# Iter 20800 | nbps=4 | Eb/No=9.42dB | Loss=-0.9448
# Iter 20900 | nbps=6 | Eb/No=7.65dB | Loss=-0.6193
# Iter 21000 | nbps=2 | Eb/No=11.91dB | Loss=-0.9961
# Iter 21100 | nbps=4 | Eb/No=2.44dB | Loss=-0.6019
# Iter 21200 | nbps=6 | Eb/No=2.44dB | Loss=-0.3788
# Iter 21300 | nbps=2 | Eb/No=2.78dB | Loss=-0.9411
# Iter 21400 | nbps=4 | Eb/No=9.27dB | Loss=-0.9401
# Iter 21500 | nbps=6 | Eb/No=5.57dB | Loss=-0.5191
# Iter 21600 | nbps=2 | Eb/No=2.62dB | Loss=-0.9538
# Iter 21700 | nbps=4 | Eb/No=5.46dB | Loss=-0.7742
# Iter 21800 | nbps=6 | Eb/No=6.02dB | Loss=-0.5279
# Iter 21900 | nbps=2 | Eb/No=13.01dB | Loss=-0.9996
# Iter 22000 | nbps=4 | Eb/No=0.78dB | Loss=-0.4990
# Iter 22100 | nbps=6 | Eb/No=5.44dB | Loss=-0.5074
# Iter 22200 | nbps=2 | Eb/No=9.54dB | Loss=-0.9999
# Iter 22300 | nbps=4 | Eb/No=6.49dB | Loss=-0.8368
# Iter 22400 | nbps=6 | Eb/No=2.83dB | Loss=-0.3893
# Iter 22500 | nbps=2 | Eb/No=10.28dB | Loss=-1.0000
# Iter 22600 | nbps=4 | Eb/No=8.87dB | Loss=-0.9366
# Iter 22700 | nbps=6 | Eb/No=5.09dB | Loss=-0.4948
# Iter 22800 | nbps=2 | Eb/No=14.22dB | Loss=-1.0000
# Iter 22900 | nbps=4 | Eb/No=13.33dB | Loss=-0.9917
# Iter 23000 | nbps=6 | Eb/No=5.89dB | Loss=-0.5227
# Iter 23100 | nbps=2 | Eb/No=10.25dB | Loss=-0.9929
# Iter 23200 | nbps=4 | Eb/No=11.37dB | Loss=-0.9753
# Iter 23300 | nbps=6 | Eb/No=3.76dB | Loss=-0.4238
# Iter 23400 | nbps=2 | Eb/No=9.31dB | Loss=-1.0000
# Iter 23500 | nbps=4 | Eb/No=9.66dB | Loss=-0.9542
# Iter 23600 | nbps=6 | Eb/No=6.74dB | Loss=-0.5771
# Iter 23700 | nbps=2 | Eb/No=5.87dB | Loss=-0.9943
# Iter 23800 | nbps=4 | Eb/No=14.49dB | Loss=-0.9970
# Iter 23900 | nbps=6 | Eb/No=12.61dB | Loss=-0.8330
# Iter 24000 | nbps=2 | Eb/No=4.83dB | Loss=-0.9915
# Iter 24100 | nbps=4 | Eb/No=1.80dB | Loss=-0.5619
# Iter 24200 | nbps=6 | Eb/No=0.64dB | Loss=-0.2999
# Iter 24300 | nbps=2 | Eb/No=12.95dB | Loss=-1.0000
# Iter 24400 | nbps=4 | Eb/No=2.62dB | Loss=-0.6141
# Iter 24500 | nbps=6 | Eb/No=14.99dB | Loss=-0.9101
# Iter 24600 | nbps=2 | Eb/No=0.97dB | Loss=-0.8873
# Iter 24700 | nbps=4 | Eb/No=7.92dB | Loss=-0.9018
# Iter 24800 | nbps=6 | Eb/No=12.45dB | Loss=-0.7017
# Iter 24900 | nbps=2 | Eb/No=8.42dB | Loss=-0.9940
# Iter 25000 | nbps=4 | Eb/No=6.31dB | Loss=-0.8230
# Iter 25100 | nbps=6 | Eb/No=2.32dB | Loss=-0.3665
# Iter 25200 | nbps=2 | Eb/No=12.47dB | Loss=-1.0000
# Iter 25300 | nbps=4 | Eb/No=1.42dB | Loss=-0.5402
# Iter 25400 | nbps=6 | Eb/No=12.75dB | Loss=-0.8428
# Iter 25500 | nbps=2 | Eb/No=14.92dB | Loss=-1.0000
# Iter 25600 | nbps=4 | Eb/No=3.24dB | Loss=-0.6490
# Iter 25700 | nbps=6 | Eb/No=6.54dB | Loss=-0.5629
# Iter 25800 | nbps=2 | Eb/No=14.81dB | Loss=-1.0000
# Iter 25900 | nbps=4 | Eb/No=10.76dB | Loss=-0.9432
# Iter 26000 | nbps=6 | Eb/No=13.31dB | Loss=-0.7934
# Iter 26100 | nbps=2 | Eb/No=9.35dB | Loss=-0.9998
# Iter 26200 | nbps=4 | Eb/No=7.70dB | Loss=-0.8898
# Iter 26300 | nbps=6 | Eb/No=1.65dB | Loss=-0.3323
# Iter 26400 | nbps=2 | Eb/No=13.39dB | Loss=-1.0000
# Iter 26500 | nbps=4 | Eb/No=5.37dB | Loss=-0.7744
# Iter 26600 | nbps=6 | Eb/No=8.40dB | Loss=-0.6443
# Iter 26700 | nbps=2 | Eb/No=10.54dB | Loss=-0.9976
# Iter 26800 | nbps=4 | Eb/No=9.08dB | Loss=-0.9392
# Iter 26900 | nbps=6 | Eb/No=13.54dB | Loss=-0.8714
# Iter 27000 | nbps=2 | Eb/No=8.29dB | Loss=-0.9997
# Iter 27100 | nbps=4 | Eb/No=1.68dB | Loss=-0.5529
# Iter 27200 | nbps=6 | Eb/No=4.52dB | Loss=-0.4658
# Iter 27300 | nbps=2 | Eb/No=1.05dB | Loss=-0.8750
# Iter 27400 | nbps=4 | Eb/No=2.10dB | Loss=-0.5793
# Iter 27500 | nbps=6 | Eb/No=5.65dB | Loss=-0.5275
# Iter 27600 | nbps=2 | Eb/No=7.00dB | Loss=-0.9954
# Iter 27700 | nbps=4 | Eb/No=0.01dB | Loss=-0.4421
# Iter 27800 | nbps=6 | Eb/No=13.48dB | Loss=-0.8435
# Iter 27900 | nbps=2 | Eb/No=6.23dB | Loss=-0.9946
# Iter 28000 | nbps=4 | Eb/No=4.74dB | Loss=-0.7378
# Iter 28100 | nbps=6 | Eb/No=2.31dB | Loss=-0.3673
# Iter 28200 | nbps=2 | Eb/No=9.30dB | Loss=-0.9986
# Iter 28300 | nbps=4 | Eb/No=9.73dB | Loss=-0.9587
# Iter 28400 | nbps=6 | Eb/No=9.57dB | Loss=-0.7141
# Iter 28500 | nbps=2 | Eb/No=0.27dB | Loss=-0.8352
# Iter 28600 | nbps=4 | Eb/No=9.31dB | Loss=-0.9396
# Iter 28700 | nbps=6 | Eb/No=13.90dB | Loss=-0.8877
# Iter 28800 | nbps=2 | Eb/No=2.46dB | Loss=-0.9463
# Iter 28900 | nbps=4 | Eb/No=14.77dB | Loss=-0.9963
# Iter 29000 | nbps=6 | Eb/No=2.02dB | Loss=-0.3559
# Iter 29100 | nbps=2 | Eb/No=12.13dB | Loss=-1.0000
# Iter 29200 | nbps=4 | Eb/No=3.84dB | Loss=-0.6765
# Iter 29300 | nbps=6 | Eb/No=7.45dB | Loss=-0.6065
# Iter 29400 | nbps=2 | Eb/No=14.74dB | Loss=-1.0000
# Iter 29500 | nbps=4 | Eb/No=10.01dB | Loss=-0.9564
# Iter 29600 | nbps=6 | Eb/No=4.97dB | Loss=-0.4942
# Iter 29700 | nbps=2 | Eb/No=3.87dB | Loss=-0.9783
# Iter 29800 | nbps=4 | Eb/No=1.78dB | Loss=-0.5555
# Iter 29900 | nbps=6 | Eb/No=9.96dB | Loss=-0.7241
# Iter 30000 | nbps=2 | Eb/No=11.69dB | Loss=-0.9997
# Iter 30100 | nbps=4 | Eb/No=12.32dB | Loss=-0.9868
# Iter 30200 | nbps=6 | Eb/No=1.92dB | Loss=-0.3515
# Iter 30300 | nbps=2 | Eb/No=9.71dB | Loss=-1.0000
# Iter 30400 | nbps=4 | Eb/No=11.33dB | Loss=-0.9818
# Iter 30500 | nbps=6 | Eb/No=0.73dB | Loss=-0.3079
# Iter 30600 | nbps=2 | Eb/No=8.73dB | Loss=-0.9936
# Iter 30700 | nbps=4 | Eb/No=7.55dB | Loss=-0.8837
# Iter 30800 | nbps=6 | Eb/No=8.33dB | Loss=-0.6569
# Iter 30900 | nbps=2 | Eb/No=11.65dB | Loss=-1.0000
# Iter 31000 | nbps=4 | Eb/No=2.84dB | Loss=-0.6171
# Iter 31100 | nbps=6 | Eb/No=3.28dB | Loss=-0.4139
# Iter 31200 | nbps=2 | Eb/No=8.63dB | Loss=-0.9998
# Iter 31300 | nbps=4 | Eb/No=7.66dB | Loss=-0.8977
# Iter 31400 | nbps=6 | Eb/No=14.04dB | Loss=-0.9014
# Iter 31500 | nbps=2 | Eb/No=12.40dB | Loss=-1.0000
# Iter 31600 | nbps=4 | Eb/No=13.87dB | Loss=-0.9972
# Iter 31700 | nbps=6 | Eb/No=12.74dB | Loss=-0.8499
# Iter 31800 | nbps=2 | Eb/No=5.06dB | Loss=-0.9927
# Iter 31900 | nbps=4 | Eb/No=4.59dB | Loss=-0.7268
# Iter 32000 | nbps=6 | Eb/No=14.58dB | Loss=-0.8888
# Iter 32100 | nbps=2 | Eb/No=2.24dB | Loss=-0.9257
# Iter 32200 | nbps=4 | Eb/No=6.82dB | Loss=-0.8489
# Iter 32300 | nbps=6 | Eb/No=9.39dB | Loss=-0.7075
# Iter 32400 | nbps=2 | Eb/No=8.96dB | Loss=-0.9984
# Iter 32500 | nbps=4 | Eb/No=1.20dB | Loss=-0.5248
# Iter 32600 | nbps=6 | Eb/No=14.58dB | Loss=-0.9055
# Iter 32700 | nbps=2 | Eb/No=12.10dB | Loss=-0.9997
# Iter 32800 | nbps=4 | Eb/No=1.81dB | Loss=-0.5628
# Iter 32900 | nbps=6 | Eb/No=9.76dB | Loss=-0.7095
# Iter 33000 | nbps=2 | Eb/No=6.70dB | Loss=-0.9948
# Iter 33100 | nbps=4 | Eb/No=1.84dB | Loss=-0.5612
# Iter 33200 | nbps=6 | Eb/No=2.95dB | Loss=-0.3988
# Iter 33300 | nbps=2 | Eb/No=10.85dB | Loss=-1.0000
# Iter 33400 | nbps=4 | Eb/No=0.76dB | Loss=-0.4954
# Iter 33500 | nbps=6 | Eb/No=6.97dB | Loss=-0.5921
# Iter 33600 | nbps=2 | Eb/No=12.77dB | Loss=-1.0000
# Iter 33700 | nbps=4 | Eb/No=11.40dB | Loss=-0.9803
# Iter 33800 | nbps=6 | Eb/No=7.81dB | Loss=-0.6310
# Iter 33900 | nbps=2 | Eb/No=10.51dB | Loss=-0.9999
# Iter 34000 | nbps=4 | Eb/No=11.25dB | Loss=-0.9819
# Iter 34100 | nbps=6 | Eb/No=3.97dB | Loss=-0.4458
# Iter 34200 | nbps=2 | Eb/No=5.41dB | Loss=-0.9953
# Iter 34300 | nbps=4 | Eb/No=11.20dB | Loss=-0.9838
# Iter 34400 | nbps=6 | Eb/No=1.02dB | Loss=-0.3161
# Iter 34500 | nbps=2 | Eb/No=0.16dB | Loss=-0.8345
# Iter 34600 | nbps=4 | Eb/No=14.89dB | Loss=-0.9965
# Iter 34700 | nbps=6 | Eb/No=14.69dB | Loss=-0.9043
# Iter 34800 | nbps=2 | Eb/No=7.40dB | Loss=-0.9994
# Iter 34900 | nbps=4 | Eb/No=0.01dB | Loss=-0.4471
# Iter 35000 | nbps=6 | Eb/No=9.96dB | Loss=-0.7185
# Iter 35100 | nbps=2 | Eb/No=6.19dB | Loss=-0.9920
# Iter 35200 | nbps=4 | Eb/No=7.56dB | Loss=-0.8866
# Iter 35300 | nbps=6 | Eb/No=8.29dB | Loss=-0.6566
# Iter 35400 | nbps=2 | Eb/No=9.92dB | Loss=-1.0000
# Iter 35500 | nbps=4 | Eb/No=12.76dB | Loss=-0.9908
# Iter 35600 | nbps=6 | Eb/No=0.01dB | Loss=-0.2737
# Iter 35700 | nbps=2 | Eb/No=8.37dB | Loss=-0.9895
# Iter 35800 | nbps=4 | Eb/No=11.83dB | Loss=-0.9818
# Iter 35900 | nbps=6 | Eb/No=10.44dB | Loss=-0.7548
# Iter 36000 | nbps=2 | Eb/No=11.87dB | Loss=-0.9998
# Iter 36100 | nbps=4 | Eb/No=14.47dB | Loss=-0.9985
# Iter 36200 | nbps=6 | Eb/No=12.88dB | Loss=-0.8622
# Iter 36300 | nbps=2 | Eb/No=1.38dB | Loss=-0.9038
# Iter 36400 | nbps=4 | Eb/No=2.95dB | Loss=-0.6253
# Iter 36500 | nbps=6 | Eb/No=11.62dB | Loss=-0.8008
# Iter 36600 | nbps=2 | Eb/No=9.62dB | Loss=-1.0000
# Iter 36700 | nbps=4 | Eb/No=8.75dB | Loss=-0.9361
# Iter 36800 | nbps=6 | Eb/No=3.44dB | Loss=-0.4273
# Iter 36900 | nbps=2 | Eb/No=5.88dB | Loss=-0.9942
# Iter 37000 | nbps=4 | Eb/No=0.60dB | Loss=-0.4937
# Iter 37100 | nbps=6 | Eb/No=6.71dB | Loss=-0.5838
# Iter 37200 | nbps=2 | Eb/No=7.04dB | Loss=-0.9965
# Iter 37300 | nbps=4 | Eb/No=8.70dB | Loss=-0.9323
# Iter 37400 | nbps=6 | Eb/No=13.36dB | Loss=-0.8464
# Iter 37500 | nbps=2 | Eb/No=2.96dB | Loss=-0.9558
# Iter 37600 | nbps=4 | Eb/No=1.95dB | Loss=-0.5718
# Iter 37700 | nbps=6 | Eb/No=1.94dB | Loss=-0.3546
# Iter 37800 | nbps=2 | Eb/No=14.50dB | Loss=-1.0000
# Iter 37900 | nbps=4 | Eb/No=8.42dB | Loss=-0.9070
# Iter 38000 | nbps=6 | Eb/No=12.00dB | Loss=-0.8218
# Iter 38100 | nbps=2 | Eb/No=5.27dB | Loss=-0.9918
# Iter 38200 | nbps=4 | Eb/No=10.56dB | Loss=-0.9726
# Iter 38300 | nbps=6 | Eb/No=12.70dB | Loss=-0.8534
# Iter 38400 | nbps=2 | Eb/No=13.71dB | Loss=-1.0000
# Iter 38500 | nbps=4 | Eb/No=10.37dB | Loss=-0.9686
# Iter 38600 | nbps=6 | Eb/No=4.69dB | Loss=-0.4810
# Iter 38700 | nbps=2 | Eb/No=2.70dB | Loss=-0.9445
# Iter 38800 | nbps=4 | Eb/No=7.42dB | Loss=-0.8726
# Iter 38900 | nbps=6 | Eb/No=9.17dB | Loss=-0.6972
# Iter 39000 | nbps=2 | Eb/No=3.67dB | Loss=-0.9654
# Iter 39100 | nbps=4 | Eb/No=7.86dB | Loss=-0.8925
# Iter 39200 | nbps=6 | Eb/No=6.14dB | Loss=-0.5490
# Iter 39300 | nbps=2 | Eb/No=0.46dB | Loss=-0.8587
# Iter 39400 | nbps=4 | Eb/No=12.02dB | Loss=-0.9871
# Iter 39500 | nbps=6 | Eb/No=3.72dB | Loss=-0.4336
# Iter 39600 | nbps=2 | Eb/No=9.47dB | Loss=-1.0000
# Iter 39700 | nbps=4 | Eb/No=7.58dB | Loss=-0.8822
# Iter 39800 | nbps=6 | Eb/No=8.20dB | Loss=-0.6548
# Iter 39900 | nbps=2 | Eb/No=8.80dB | Loss=-0.9966
# Iter 40000 | nbps=4 | Eb/No=12.06dB | Loss=-0.9875
# Iter 40100 | nbps=6 | Eb/No=7.80dB | Loss=-0.6358
# Iter 40200 | nbps=2 | Eb/No=6.05dB | Loss=-0.9888
# Iter 40300 | nbps=4 | Eb/No=12.37dB | Loss=-0.9796
# Iter 40400 | nbps=6 | Eb/No=8.86dB | Loss=-0.6736
# Iter 40500 | nbps=2 | Eb/No=13.72dB | Loss=-1.0000
# Iter 40600 | nbps=4 | Eb/No=2.74dB | Loss=-0.6200
# Iter 40700 | nbps=6 | Eb/No=5.10dB | Loss=-0.4991
# Iter 40800 | nbps=2 | Eb/No=0.16dB | Loss=-0.8435
# Iter 40900 | nbps=4 | Eb/No=6.86dB | Loss=-0.8519
# Iter 41000 | nbps=6 | Eb/No=5.57dB | Loss=-0.5154
# Iter 41100 | nbps=2 | Eb/No=3.51dB | Loss=-0.9700
# Iter 41200 | nbps=4 | Eb/No=12.34dB | Loss=-0.9878
# Iter 41300 | nbps=6 | Eb/No=8.72dB | Loss=-0.6830
# Iter 41400 | nbps=2 | Eb/No=13.22dB | Loss=-1.0000
# Iter 41500 | nbps=4 | Eb/No=12.23dB | Loss=-0.9936
# Iter 41600 | nbps=6 | Eb/No=5.78dB | Loss=-0.5309
# Iter 41700 | nbps=2 | Eb/No=7.82dB | Loss=-0.9989
# Iter 41800 | nbps=4 | Eb/No=13.93dB | Loss=-0.9982
# Iter 41900 | nbps=6 | Eb/No=8.57dB | Loss=-0.6747
# Iter 42000 | nbps=2 | Eb/No=5.07dB | Loss=-0.9847
# Iter 42100 | nbps=4 | Eb/No=1.32dB | Loss=-0.5247
# Iter 42200 | nbps=6 | Eb/No=3.86dB | Loss=-0.4387
# Iter 42300 | nbps=2 | Eb/No=11.03dB | Loss=-0.9979
# Iter 42400 | nbps=4 | Eb/No=7.17dB | Loss=-0.8751
# Iter 42500 | nbps=6 | Eb/No=4.10dB | Loss=-0.4566
# Iter 42600 | nbps=2 | Eb/No=3.07dB | Loss=-0.9655
# Iter 42700 | nbps=4 | Eb/No=2.87dB | Loss=-0.6216
# Iter 42800 | nbps=6 | Eb/No=4.14dB | Loss=-0.4480
# Iter 42900 | nbps=2 | Eb/No=2.45dB | Loss=-0.9342
# Iter 43000 | nbps=4 | Eb/No=13.91dB | Loss=-0.9946
# Iter 43100 | nbps=6 | Eb/No=5.37dB | Loss=-0.5195
# Iter 43200 | nbps=2 | Eb/No=9.44dB | Loss=-1.0000
# Iter 43300 | nbps=4 | Eb/No=6.55dB | Loss=-0.8361
# Iter 43400 | nbps=6 | Eb/No=10.41dB | Loss=-0.7509
# Iter 43500 | nbps=2 | Eb/No=9.91dB | Loss=-0.9966
# Iter 43600 | nbps=4 | Eb/No=7.14dB | Loss=-0.8719
# Iter 43700 | nbps=6 | Eb/No=3.32dB | Loss=-0.4136
# Iter 43800 | nbps=2 | Eb/No=13.94dB | Loss=-1.0000
# Iter 43900 | nbps=4 | Eb/No=14.84dB | Loss=-0.9982
# Iter 44000 | nbps=6 | Eb/No=13.18dB | Loss=-0.8476
# Iter 44100 | nbps=2 | Eb/No=7.69dB | Loss=-0.9990
# Iter 44200 | nbps=4 | Eb/No=13.79dB | Loss=-0.9980
# Iter 44300 | nbps=6 | Eb/No=13.66dB | Loss=-0.8970
# Iter 44400 | nbps=2 | Eb/No=2.77dB | Loss=-0.9489
# Iter 44500 | nbps=4 | Eb/No=0.72dB | Loss=-0.4974
# Iter 44600 | nbps=6 | Eb/No=8.94dB | Loss=-0.6870
# Iter 44700 | nbps=2 | Eb/No=9.31dB | Loss=-0.9996
# Iter 44800 | nbps=4 | Eb/No=12.99dB | Loss=-0.9925
# Iter 44900 | nbps=6 | Eb/No=3.19dB | Loss=-0.4118
# Iter 45000 | nbps=2 | Eb/No=10.76dB | Loss=-1.0000
# Iter 45100 | nbps=4 | Eb/No=6.27dB | Loss=-0.8232
# Iter 45200 | nbps=6 | Eb/No=2.99dB | Loss=-0.3936
# Iter 45300 | nbps=2 | Eb/No=12.51dB | Loss=-0.9999
# Iter 45400 | nbps=4 | Eb/No=11.89dB | Loss=-0.9888
# Iter 45500 | nbps=6 | Eb/No=10.15dB | Loss=-0.7501
# Iter 45600 | nbps=2 | Eb/No=9.39dB | Loss=-0.9998
# Iter 45700 | nbps=4 | Eb/No=4.49dB | Loss=-0.7143
# Iter 45800 | nbps=6 | Eb/No=0.46dB | Loss=-0.2948
# Iter 45900 | nbps=2 | Eb/No=3.16dB | Loss=-0.9652
# Iter 46000 | nbps=4 | Eb/No=14.21dB | Loss=-0.9988
# Iter 46100 | nbps=6 | Eb/No=11.61dB | Loss=-0.7511
# Iter 46200 | nbps=2 | Eb/No=5.36dB | Loss=-0.9942
# Iter 46300 | nbps=4 | Eb/No=6.46dB | Loss=-0.8309
# Iter 46400 | nbps=6 | Eb/No=13.62dB | Loss=-0.8837
# Iter 46500 | nbps=2 | Eb/No=4.90dB | Loss=-0.9791
# Iter 46600 | nbps=4 | Eb/No=9.03dB | Loss=-0.9426
# Iter 46700 | nbps=6 | Eb/No=13.02dB | Loss=-0.8199
# Iter 46800 | nbps=2 | Eb/No=12.56dB | Loss=-1.0000
# Iter 46900 | nbps=4 | Eb/No=2.98dB | Loss=-0.6250
# Iter 47000 | nbps=6 | Eb/No=5.21dB | Loss=-0.4920
# Iter 47100 | nbps=2 | Eb/No=13.89dB | Loss=-1.0000
# Iter 47200 | nbps=4 | Eb/No=11.57dB | Loss=-0.9864
# Iter 47300 | nbps=6 | Eb/No=3.49dB | Loss=-0.4274
# Iter 47400 | nbps=2 | Eb/No=5.00dB | Loss=-0.9906
# Iter 47500 | nbps=4 | Eb/No=5.27dB | Loss=-0.7698
# Iter 47600 | nbps=6 | Eb/No=12.42dB | Loss=-0.8365
# Iter 47700 | nbps=2 | Eb/No=13.52dB | Loss=-0.9996
# Iter 47800 | nbps=4 | Eb/No=3.32dB | Loss=-0.6565
# Iter 47900 | nbps=6 | Eb/No=3.47dB | Loss=-0.4283
# Iter 48000 | nbps=2 | Eb/No=10.63dB | Loss=-1.0000
# Iter 48100 | nbps=4 | Eb/No=3.94dB | Loss=-0.6824
# Iter 48200 | nbps=6 | Eb/No=9.52dB | Loss=-0.7197
# Iter 48300 | nbps=2 | Eb/No=9.63dB | Loss=-0.9978
# Iter 48400 | nbps=4 | Eb/No=4.69dB | Loss=-0.7426
# Iter 48500 | nbps=6 | Eb/No=8.95dB | Loss=-0.6884
# Iter 48600 | nbps=2 | Eb/No=7.14dB | Loss=-0.9983
# Iter 48700 | nbps=4 | Eb/No=10.96dB | Loss=-0.9802
# Iter 48800 | nbps=6 | Eb/No=10.49dB | Loss=-0.7635
# Iter 48900 | nbps=2 | Eb/No=10.91dB | Loss=-1.0000
# Iter 49000 | nbps=4 | Eb/No=13.36dB | Loss=-0.9896
# Iter 49100 | nbps=6 | Eb/No=9.05dB | Loss=-0.6922
# Iter 49200 | nbps=2 | Eb/No=3.91dB | Loss=-0.9784
# Iter 49300 | nbps=4 | Eb/No=1.09dB | Loss=-0.5140
# Iter 49400 | nbps=6 | Eb/No=12.12dB | Loss=-0.8407
# Iter 49500 | nbps=2 | Eb/No=10.73dB | Loss=-1.0000
# Iter 49600 | nbps=4 | Eb/No=6.22dB | Loss=-0.8225
# Iter 49700 | nbps=6 | Eb/No=2.52dB | Loss=-0.3701
# Iter 49800 | nbps=2 | Eb/No=11.15dB | Loss=-1.0000
# Iter 49900 | nbps=4 | Eb/No=4.34dB | Loss=-0.7214
# Iter 50000 | nbps=6 | Eb/No=5.37dB | Loss=-0.5189
# Iter 50100 | nbps=2 | Eb/No=14.24dB | Loss=-0.9998
# Iter 50200 | nbps=4 | Eb/No=6.43dB | Loss=-0.8322
# Iter 50300 | nbps=6 | Eb/No=10.36dB | Loss=-0.7465
# Iter 50400 | nbps=2 | Eb/No=12.13dB | Loss=-0.9999
# Iter 50500 | nbps=4 | Eb/No=5.29dB | Loss=-0.7761
# Iter 50600 | nbps=6 | Eb/No=9.94dB | Loss=-0.7363
# Iter 50700 | nbps=2 | Eb/No=13.10dB | Loss=-1.0000
# Iter 50800 | nbps=4 | Eb/No=4.37dB | Loss=-0.7207
# Iter 50900 | nbps=6 | Eb/No=0.24dB | Loss=-0.2814
# Iter 51000 | nbps=2 | Eb/No=3.97dB | Loss=-0.9672
# Iter 51100 | nbps=4 | Eb/No=9.44dB | Loss=-0.9278
# Iter 51200 | nbps=6 | Eb/No=13.95dB | Loss=-0.8937
# Iter 51300 | nbps=2 | Eb/No=3.04dB | Loss=-0.9645
# Iter 51400 | nbps=4 | Eb/No=1.82dB | Loss=-0.5626
# Iter 51500 | nbps=6 | Eb/No=7.41dB | Loss=-0.6178
# Iter 51600 | nbps=2 | Eb/No=10.38dB | Loss=-0.9995
# Iter 51700 | nbps=4 | Eb/No=14.00dB | Loss=-0.9976
# Iter 51800 | nbps=6 | Eb/No=4.00dB | Loss=-0.4548
# Iter 51900 | nbps=2 | Eb/No=5.30dB | Loss=-0.9942
# Iter 52000 | nbps=4 | Eb/No=0.87dB | Loss=-0.4976
# Iter 52100 | nbps=6 | Eb/No=9.85dB | Loss=-0.7229
# Iter 52200 | nbps=2 | Eb/No=2.72dB | Loss=-0.9463
# Iter 52300 | nbps=4 | Eb/No=5.40dB | Loss=-0.7809
# Iter 52400 | nbps=6 | Eb/No=6.24dB | Loss=-0.5535
# Iter 52500 | nbps=2 | Eb/No=4.05dB | Loss=-0.9761
# Iter 52600 | nbps=4 | Eb/No=11.58dB | Loss=-0.9911
# Iter 52700 | nbps=6 | Eb/No=9.06dB | Loss=-0.6925
# Iter 52800 | nbps=2 | Eb/No=2.43dB | Loss=-0.9437
# Iter 52900 | nbps=4 | Eb/No=13.63dB | Loss=-0.9863
# Iter 53000 | nbps=6 | Eb/No=6.70dB | Loss=-0.5718
# Iter 53100 | nbps=2 | Eb/No=4.96dB | Loss=-0.9918
# Iter 53200 | nbps=4 | Eb/No=4.83dB | Loss=-0.7494
# Iter 53300 | nbps=6 | Eb/No=4.48dB | Loss=-0.4715
# Iter 53400 | nbps=2 | Eb/No=2.43dB | Loss=-0.9370
# Iter 53500 | nbps=4 | Eb/No=7.97dB | Loss=-0.9095
# Iter 53600 | nbps=6 | Eb/No=10.27dB | Loss=-0.7465
# Iter 53700 | nbps=2 | Eb/No=13.82dB | Loss=-0.9998
# Iter 53800 | nbps=4 | Eb/No=14.35dB | Loss=-0.9990
# Iter 53900 | nbps=6 | Eb/No=7.98dB | Loss=-0.6471
# Iter 54000 | nbps=2 | Eb/No=11.52dB | Loss=-1.0000
# Iter 54100 | nbps=4 | Eb/No=0.89dB | Loss=-0.5078
# Iter 54200 | nbps=6 | Eb/No=4.02dB | Loss=-0.4521
# Iter 54300 | nbps=2 | Eb/No=1.81dB | Loss=-0.9234
# Iter 54400 | nbps=4 | Eb/No=14.93dB | Loss=-0.9996
# Iter 54500 | nbps=6 | Eb/No=4.99dB | Loss=-0.5000
# Iter 54600 | nbps=2 | Eb/No=7.70dB | Loss=-0.9995
# Iter 54700 | nbps=4 | Eb/No=8.24dB | Loss=-0.9190
# Iter 54800 | nbps=6 | Eb/No=3.22dB | Loss=-0.4060
# Iter 54900 | nbps=2 | Eb/No=0.11dB | Loss=-0.8436
# Iter 55000 | nbps=4 | Eb/No=6.52dB | Loss=-0.8494
# Iter 55100 | nbps=6 | Eb/No=2.35dB | Loss=-0.3735
# Iter 55200 | nbps=2 | Eb/No=11.17dB | Loss=-1.0000
# Iter 55300 | nbps=4 | Eb/No=13.24dB | Loss=-0.9904
# Iter 55400 | nbps=6 | Eb/No=7.39dB | Loss=-0.6175
# Iter 55500 | nbps=2 | Eb/No=12.26dB | Loss=-1.0000
# Iter 55600 | nbps=4 | Eb/No=1.25dB | Loss=-0.5225
# Iter 55700 | nbps=6 | Eb/No=11.54dB | Loss=-0.7421
# Iter 55800 | nbps=2 | Eb/No=4.89dB | Loss=-0.9902
# Iter 55900 | nbps=4 | Eb/No=14.57dB | Loss=-0.9975
# Iter 56000 | nbps=6 | Eb/No=13.99dB | Loss=-0.9037
# Iter 56100 | nbps=2 | Eb/No=9.35dB | Loss=-0.9996
# Iter 56200 | nbps=4 | Eb/No=2.53dB | Loss=-0.6117
# Iter 56300 | nbps=6 | Eb/No=12.72dB | Loss=-0.8666
# Iter 56400 | nbps=2 | Eb/No=1.12dB | Loss=-0.8935
# Iter 56500 | nbps=4 | Eb/No=4.91dB | Loss=-0.7433
# Iter 56600 | nbps=6 | Eb/No=14.88dB | Loss=-0.9296
# Iter 56700 | nbps=2 | Eb/No=4.71dB | Loss=-0.9829
# Iter 56800 | nbps=4 | Eb/No=13.47dB | Loss=-0.9980
# Iter 56900 | nbps=6 | Eb/No=13.84dB | Loss=-0.8987
# Iter 57000 | nbps=2 | Eb/No=12.43dB | Loss=-1.0000
# Iter 57100 | nbps=4 | Eb/No=0.35dB | Loss=-0.4719
# Iter 57200 | nbps=6 | Eb/No=7.85dB | Loss=-0.6360
# Iter 57300 | nbps=2 | Eb/No=1.10dB | Loss=-0.8797
# Iter 57400 | nbps=4 | Eb/No=8.37dB | Loss=-0.9193
# Iter 57500 | nbps=6 | Eb/No=4.51dB | Loss=-0.4732
# Iter 57600 | nbps=2 | Eb/No=5.92dB | Loss=-0.9912
# Iter 57700 | nbps=4 | Eb/No=5.86dB | Loss=-0.8085
# Iter 57800 | nbps=6 | Eb/No=2.16dB | Loss=-0.3664
# Iter 57900 | nbps=2 | Eb/No=14.37dB | Loss=-1.0000
# Iter 58000 | nbps=4 | Eb/No=0.84dB | Loss=-0.5057
# Iter 58100 | nbps=6 | Eb/No=3.01dB | Loss=-0.4030
# Iter 58200 | nbps=2 | Eb/No=1.61dB | Loss=-0.9023
# Iter 58300 | nbps=4 | Eb/No=4.57dB | Loss=-0.7327
# Iter 58400 | nbps=6 | Eb/No=13.97dB | Loss=-0.9103
# Iter 58500 | nbps=2 | Eb/No=12.57dB | Loss=-1.0000
# Iter 58600 | nbps=4 | Eb/No=13.98dB | Loss=-0.9956
# Iter 58700 | nbps=6 | Eb/No=9.96dB | Loss=-0.7250
# Iter 58800 | nbps=2 | Eb/No=7.42dB | Loss=-0.9989
# Iter 58900 | nbps=4 | Eb/No=5.83dB | Loss=-0.8052
# Iter 59000 | nbps=6 | Eb/No=9.15dB | Loss=-0.7064
# Iter 59100 | nbps=2 | Eb/No=6.35dB | Loss=-0.9988
# Iter 59200 | nbps=4 | Eb/No=10.05dB | Loss=-0.9690
# Iter 59300 | nbps=6 | Eb/No=10.08dB | Loss=-0.7477
# Iter 59400 | nbps=2 | Eb/No=5.90dB | Loss=-0.9970
# Iter 59500 | nbps=4 | Eb/No=0.23dB | Loss=-0.4678
# Iter 59600 | nbps=6 | Eb/No=11.31dB | Loss=-0.8027
# Iter 59700 | nbps=2 | Eb/No=5.92dB | Loss=-0.9974
# Iter 59800 | nbps=4 | Eb/No=14.77dB | Loss=-0.9958
# Iter 59900 | nbps=6 | Eb/No=2.61dB | Loss=-0.3874
# Iter 60000 | nbps=2 | Eb/No=13.02dB | Loss=-0.9999
# Iter 60100 | nbps=4 | Eb/No=9.09dB | Loss=-0.9377
# Iter 60200 | nbps=6 | Eb/No=1.05dB | Loss=-0.3189
# Iter 60300 | nbps=2 | Eb/No=0.72dB | Loss=-0.8754
# Iter 60400 | nbps=4 | Eb/No=11.32dB | Loss=-0.9833
# Iter 60500 | nbps=6 | Eb/No=9.16dB | Loss=-0.7047
# Iter 60600 | nbps=2 | Eb/No=5.28dB | Loss=-0.9949
# Iter 60700 | nbps=4 | Eb/No=4.83dB | Loss=-0.7586
# Iter 60800 | nbps=6 | Eb/No=1.46dB | Loss=-0.3358
# Iter 60900 | nbps=2 | Eb/No=4.57dB | Loss=-0.9896
# Iter 61000 | nbps=4 | Eb/No=12.65dB | Loss=-0.9922
# Iter 61100 | nbps=6 | Eb/No=12.82dB | Loss=-0.8626
# Iter 61200 | nbps=2 | Eb/No=4.96dB | Loss=-0.9922
# Iter 61300 | nbps=4 | Eb/No=9.39dB | Loss=-0.9551
# Iter 61400 | nbps=6 | Eb/No=11.72dB | Loss=-0.8059
# Iter 61500 | nbps=2 | Eb/No=14.96dB | Loss=-1.0000
# Iter 61600 | nbps=4 | Eb/No=4.50dB | Loss=-0.7291
# Iter 61700 | nbps=6 | Eb/No=7.84dB | Loss=-0.6399
# Iter 61800 | nbps=2 | Eb/No=5.71dB | Loss=-0.9800
# Iter 61900 | nbps=4 | Eb/No=5.06dB | Loss=-0.7622
# Iter 62000 | nbps=6 | Eb/No=7.06dB | Loss=-0.5997
# Iter 62100 | nbps=2 | Eb/No=5.86dB | Loss=-0.9976
# Iter 62200 | nbps=4 | Eb/No=1.08dB | Loss=-0.5137
# Iter 62300 | nbps=6 | Eb/No=2.97dB | Loss=-0.3963
# Iter 62400 | nbps=2 | Eb/No=2.14dB | Loss=-0.9379
# Iter 62500 | nbps=4 | Eb/No=12.50dB | Loss=-0.9899
# Iter 62600 | nbps=6 | Eb/No=9.92dB | Loss=-0.7448
# Iter 62700 | nbps=2 | Eb/No=8.52dB | Loss=-0.9997
# Iter 62800 | nbps=4 | Eb/No=9.05dB | Loss=-0.9370
# Iter 62900 | nbps=6 | Eb/No=1.13dB | Loss=-0.3230
# Iter 63000 | nbps=2 | Eb/No=14.71dB | Loss=-1.0000
# Iter 63100 | nbps=4 | Eb/No=12.46dB | Loss=-0.9927
# Iter 63200 | nbps=6 | Eb/No=7.37dB | Loss=-0.6186
# Iter 63300 | nbps=2 | Eb/No=13.78dB | Loss=-0.9998
# Iter 63400 | nbps=4 | Eb/No=6.39dB | Loss=-0.8357
# Iter 63500 | nbps=6 | Eb/No=14.54dB | Loss=-0.9276
# Iter 63600 | nbps=2 | Eb/No=12.07dB | Loss=-1.0000
# Iter 63700 | nbps=4 | Eb/No=8.08dB | Loss=-0.9059
# Iter 63800 | nbps=6 | Eb/No=2.53dB | Loss=-0.3851
# Iter 63900 | nbps=2 | Eb/No=14.37dB | Loss=-1.0000
# Iter 64000 | nbps=4 | Eb/No=12.98dB | Loss=-0.9957
# Iter 64100 | nbps=6 | Eb/No=8.65dB | Loss=-0.6672
# Iter 64200 | nbps=2 | Eb/No=10.42dB | Loss=-1.0000
# Iter 64300 | nbps=4 | Eb/No=4.60dB | Loss=-0.7346
# Iter 64400 | nbps=6 | Eb/No=4.66dB | Loss=-0.4658
# Iter 64500 | nbps=2 | Eb/No=7.89dB | Loss=-0.9946
# Iter 64600 | nbps=4 | Eb/No=10.09dB | Loss=-0.9647
# Iter 64700 | nbps=6 | Eb/No=5.95dB | Loss=-0.5432
# Iter 64800 | nbps=2 | Eb/No=12.83dB | Loss=-1.0000
# Iter 64900 | nbps=4 | Eb/No=0.94dB | Loss=-0.5107
# Iter 65000 | nbps=6 | Eb/No=5.47dB | Loss=-0.5210
# Iter 65100 | nbps=2 | Eb/No=11.91dB | Loss=-0.9957
# Iter 65200 | nbps=4 | Eb/No=0.46dB | Loss=-0.4764
# Iter 65300 | nbps=6 | Eb/No=0.28dB | Loss=-0.2927
# Iter 65400 | nbps=2 | Eb/No=0.76dB | Loss=-0.8762
# Iter 65500 | nbps=4 | Eb/No=6.85dB | Loss=-0.8625
# Iter 65600 | nbps=6 | Eb/No=10.81dB | Loss=-0.7790
# Iter 65700 | nbps=2 | Eb/No=14.06dB | Loss=-0.9987
# Iter 65800 | nbps=4 | Eb/No=9.57dB | Loss=-0.9515
# Iter 65900 | nbps=6 | Eb/No=0.94dB | Loss=-0.3167
# Iter 66000 | nbps=2 | Eb/No=8.84dB | Loss=-0.9975
# Iter 66100 | nbps=4 | Eb/No=5.50dB | Loss=-0.7902
# Iter 66200 | nbps=6 | Eb/No=7.01dB | Loss=-0.5992
# Iter 66300 | nbps=2 | Eb/No=2.00dB | Loss=-0.9319
# Iter 66400 | nbps=4 | Eb/No=14.71dB | Loss=-0.9944
# Iter 66500 | nbps=6 | Eb/No=11.98dB | Loss=-0.8368
# Iter 66600 | nbps=2 | Eb/No=2.26dB | Loss=-0.9377
# Iter 66700 | nbps=4 | Eb/No=10.68dB | Loss=-0.9801
# Iter 66800 | nbps=6 | Eb/No=2.03dB | Loss=-0.3579
# Iter 66900 | nbps=2 | Eb/No=9.37dB | Loss=-0.9997
# Iter 67000 | nbps=4 | Eb/No=4.57dB | Loss=-0.7334
# Iter 67100 | nbps=6 | Eb/No=7.50dB | Loss=-0.6162
# Iter 67200 | nbps=2 | Eb/No=6.85dB | Loss=-0.9937
# Iter 67300 | nbps=4 | Eb/No=8.89dB | Loss=-0.9369
# Iter 67400 | nbps=6 | Eb/No=5.84dB | Loss=-0.5307
# Iter 67500 | nbps=2 | Eb/No=5.04dB | Loss=-0.9826
# Iter 67600 | nbps=4 | Eb/No=1.19dB | Loss=-0.5233
# Iter 67700 | nbps=6 | Eb/No=3.57dB | Loss=-0.4308
# Iter 67800 | nbps=2 | Eb/No=1.78dB | Loss=-0.9015
# Iter 67900 | nbps=4 | Eb/No=13.27dB | Loss=-0.9962
# Iter 68000 | nbps=6 | Eb/No=6.28dB | Loss=-0.5639
# Iter 68100 | nbps=2 | Eb/No=14.21dB | Loss=-0.9994
# Iter 68200 | nbps=4 | Eb/No=3.57dB | Loss=-0.6700
# Iter 68300 | nbps=6 | Eb/No=11.28dB | Loss=-0.8027
# Iter 68400 | nbps=2 | Eb/No=14.80dB | Loss=-1.0000
# Iter 68500 | nbps=4 | Eb/No=0.31dB | Loss=-0.4699
# Iter 68600 | nbps=6 | Eb/No=12.92dB | Loss=-0.8700
# Iter 68700 | nbps=2 | Eb/No=1.38dB | Loss=-0.8930
# Iter 68800 | nbps=4 | Eb/No=2.14dB | Loss=-0.5923
# Iter 68900 | nbps=6 | Eb/No=8.09dB | Loss=-0.6532
# Iter 69000 | nbps=2 | Eb/No=1.13dB | Loss=-0.8925
# Iter 69100 | nbps=4 | Eb/No=9.72dB | Loss=-0.9553
# Iter 69200 | nbps=6 | Eb/No=10.58dB | Loss=-0.7768
# Iter 69300 | nbps=2 | Eb/No=10.26dB | Loss=-1.0000
# Iter 69400 | nbps=4 | Eb/No=6.40dB | Loss=-0.8299
# Iter 69500 | nbps=6 | Eb/No=11.90dB | Loss=-0.8345
# Iter 69600 | nbps=2 | Eb/No=14.84dB | Loss=-0.9977
# Iter 69700 | nbps=4 | Eb/No=10.81dB | Loss=-0.9808
# Iter 69800 | nbps=6 | Eb/No=12.21dB | Loss=-0.8331
# Iter 69900 | nbps=2 | Eb/No=11.27dB | Loss=-0.9970
# Iter 70000 | nbps=4 | Eb/No=3.07dB | Loss=-0.6427
# Iter 70100 | nbps=6 | Eb/No=4.20dB | Loss=-0.4569
# Iter 70200 | nbps=2 | Eb/No=9.39dB | Loss=-1.0000
# Iter 70300 | nbps=4 | Eb/No=2.14dB | Loss=-0.5794
# Iter 70400 | nbps=6 | Eb/No=13.64dB | Loss=-0.8879
# Iter 70500 | nbps=2 | Eb/No=11.86dB | Loss=-0.9971
# Iter 70600 | nbps=4 | Eb/No=12.35dB | Loss=-0.9820
# Iter 70700 | nbps=6 | Eb/No=8.45dB | Loss=-0.6493
# Iter 70800 | nbps=2 | Eb/No=11.49dB | Loss=-1.0000
# Iter 70900 | nbps=4 | Eb/No=10.99dB | Loss=-0.9809
# Iter 71000 | nbps=6 | Eb/No=5.10dB | Loss=-0.5063
# Iter 71100 | nbps=2 | Eb/No=7.02dB | Loss=-0.9960
# Iter 71200 | nbps=4 | Eb/No=11.35dB | Loss=-0.9878
# Iter 71300 | nbps=6 | Eb/No=9.71dB | Loss=-0.7238
# Iter 71400 | nbps=2 | Eb/No=5.78dB | Loss=-0.9945
# Iter 71500 | nbps=4 | Eb/No=1.59dB | Loss=-0.5472
# Iter 71600 | nbps=6 | Eb/No=8.46dB | Loss=-0.6362
# Iter 71700 | nbps=2 | Eb/No=13.90dB | Loss=-0.9999
# Iter 71800 | nbps=4 | Eb/No=9.88dB | Loss=-0.9612
# Iter 71900 | nbps=6 | Eb/No=9.74dB | Loss=-0.7306
# Iter 72000 | nbps=2 | Eb/No=11.76dB | Loss=-1.0000
# Iter 72100 | nbps=4 | Eb/No=7.87dB | Loss=-0.9039
# Iter 72200 | nbps=6 | Eb/No=10.69dB | Loss=-0.7647
# Iter 72300 | nbps=2 | Eb/No=6.63dB | Loss=-0.9985
# Iter 72400 | nbps=4 | Eb/No=10.36dB | Loss=-0.9674
# Iter 72500 | nbps=6 | Eb/No=1.96dB | Loss=-0.3600
# Iter 72600 | nbps=2 | Eb/No=1.04dB | Loss=-0.8853
# Iter 72700 | nbps=4 | Eb/No=0.64dB | Loss=-0.4950
# Iter 72800 | nbps=6 | Eb/No=14.47dB | Loss=-0.9229
# Iter 72900 | nbps=2 | Eb/No=6.45dB | Loss=-0.9978
# Iter 73000 | nbps=4 | Eb/No=1.20dB | Loss=-0.5255
# Iter 73100 | nbps=6 | Eb/No=14.46dB | Loss=-0.9166
# Iter 73200 | nbps=2 | Eb/No=2.25dB | Loss=-0.9459
# Iter 73300 | nbps=4 | Eb/No=6.09dB | Loss=-0.8201
# Iter 73400 | nbps=6 | Eb/No=14.20dB | Loss=-0.8976
# Iter 73500 | nbps=2 | Eb/No=13.27dB | Loss=-0.9998
# Iter 73600 | nbps=4 | Eb/No=12.34dB | Loss=-0.9948
# Iter 73700 | nbps=6 | Eb/No=8.28dB | Loss=-0.6612
# Iter 73800 | nbps=2 | Eb/No=9.38dB | Loss=-0.9950
# Iter 73900 | nbps=4 | Eb/No=4.91dB | Loss=-0.7523
# Iter 74000 | nbps=6 | Eb/No=10.40dB | Loss=-0.7573
# Iter 74100 | nbps=2 | Eb/No=6.34dB | Loss=-0.9981
# Iter 74200 | nbps=4 | Eb/No=12.58dB | Loss=-0.9861
# Iter 74300 | nbps=6 | Eb/No=9.97dB | Loss=-0.7300
# Iter 74400 | nbps=2 | Eb/No=1.02dB | Loss=-0.8703
# Iter 74500 | nbps=4 | Eb/No=10.23dB | Loss=-0.9731
# Iter 74600 | nbps=6 | Eb/No=3.98dB | Loss=-0.4501
# Iter 74700 | nbps=2 | Eb/No=12.23dB | Loss=-1.0000
# Iter 74800 | nbps=4 | Eb/No=3.21dB | Loss=-0.6509
# Iter 74900 | nbps=6 | Eb/No=3.21dB | Loss=-0.4179
# Iter 75000 | nbps=2 | Eb/No=6.60dB | Loss=-0.9988
# Iter 75100 | nbps=4 | Eb/No=7.54dB | Loss=-0.8973
# Iter 75200 | nbps=6 | Eb/No=11.83dB | Loss=-0.8267
# Iter 75300 | nbps=2 | Eb/No=2.51dB | Loss=-0.9522
# Iter 75400 | nbps=4 | Eb/No=0.97dB | Loss=-0.5088
# Iter 75500 | nbps=6 | Eb/No=10.32dB | Loss=-0.7625
# Iter 75600 | nbps=2 | Eb/No=13.56dB | Loss=-1.0000
# Iter 75700 | nbps=4 | Eb/No=7.53dB | Loss=-0.8865
# Iter 75800 | nbps=6 | Eb/No=9.49dB | Loss=-0.7257
# Iter 75900 | nbps=2 | Eb/No=12.02dB | Loss=-1.0000
# Iter 76000 | nbps=4 | Eb/No=6.65dB | Loss=-0.8593
# Iter 76100 | nbps=6 | Eb/No=3.07dB | Loss=-0.4062
# Iter 76200 | nbps=2 | Eb/No=2.25dB | Loss=-0.9350
# Iter 76300 | nbps=4 | Eb/No=12.39dB | Loss=-0.9926
# Iter 76400 | nbps=6 | Eb/No=3.24dB | Loss=-0.4110
# Iter 76500 | nbps=2 | Eb/No=4.26dB | Loss=-0.9856
# Iter 76600 | nbps=4 | Eb/No=12.71dB | Loss=-0.9956
# Iter 76700 | nbps=6 | Eb/No=3.06dB | Loss=-0.4041
# Iter 76800 | nbps=2 | Eb/No=4.11dB | Loss=-0.9781
# Iter 76900 | nbps=4 | Eb/No=15.00dB | Loss=-0.9994
# Iter 77000 | nbps=6 | Eb/No=14.63dB | Loss=-0.9261
# Iter 77100 | nbps=2 | Eb/No=4.36dB | Loss=-0.9887
# Iter 77200 | nbps=4 | Eb/No=13.52dB | Loss=-0.9890
# Iter 77300 | nbps=6 | Eb/No=11.76dB | Loss=-0.8219
# Iter 77400 | nbps=2 | Eb/No=1.97dB | Loss=-0.9160
# Iter 77500 | nbps=4 | Eb/No=11.18dB | Loss=-0.9594
# Iter 77600 | nbps=6 | Eb/No=10.22dB | Loss=-0.7578
# Iter 77700 | nbps=2 | Eb/No=0.61dB | Loss=-0.8590
# Iter 77800 | nbps=4 | Eb/No=0.30dB | Loss=-0.4711
# Iter 77900 | nbps=6 | Eb/No=3.85dB | Loss=-0.4395
# Iter 78000 | nbps=2 | Eb/No=13.80dB | Loss=-1.0000
# Iter 78100 | nbps=4 | Eb/No=13.30dB | Loss=-0.9967
# Iter 78200 | nbps=6 | Eb/No=1.18dB | Loss=-0.3296
# Iter 78300 | nbps=2 | Eb/No=6.82dB | Loss=-0.9978
# Iter 78400 | nbps=4 | Eb/No=2.34dB | Loss=-0.5994
# Iter 78500 | nbps=6 | Eb/No=14.69dB | Loss=-0.9245
# Iter 78600 | nbps=2 | Eb/No=12.09dB | Loss=-0.9998
# Iter 78700 | nbps=4 | Eb/No=5.57dB | Loss=-0.7906
# Iter 78800 | nbps=6 | Eb/No=2.68dB | Loss=-0.3950
# Iter 78900 | nbps=2 | Eb/No=10.47dB | Loss=-1.0000
# Iter 79000 | nbps=4 | Eb/No=0.10dB | Loss=-0.4573
# Iter 79100 | nbps=6 | Eb/No=12.81dB | Loss=-0.8624
# Iter 79200 | nbps=2 | Eb/No=0.82dB | Loss=-0.8690
# Iter 79300 | nbps=4 | Eb/No=10.90dB | Loss=-0.9634
# Iter 79400 | nbps=6 | Eb/No=6.07dB | Loss=-0.5468
# Iter 79500 | nbps=2 | Eb/No=9.07dB | Loss=-1.0000
# Iter 79600 | nbps=4 | Eb/No=9.13dB | Loss=-0.9530
# Iter 79700 | nbps=6 | Eb/No=6.35dB | Loss=-0.5647
# Iter 79800 | nbps=2 | Eb/No=13.24dB | Loss=-1.0000
# Iter 79900 | nbps=4 | Eb/No=10.63dB | Loss=-0.9804
# Iter 80000 | nbps=6 | Eb/No=7.60dB | Loss=-0.6331
# Iter 80100 | nbps=2 | Eb/No=7.91dB | Loss=-0.9991
# Iter 80200 | nbps=4 | Eb/No=12.79dB | Loss=-0.9964
# Iter 80300 | nbps=6 | Eb/No=7.28dB | Loss=-0.6098
# Iter 80400 | nbps=2 | Eb/No=2.57dB | Loss=-0.9558
# Iter 80500 | nbps=4 | Eb/No=9.30dB | Loss=-0.9529
# Iter 80600 | nbps=6 | Eb/No=4.72dB | Loss=-0.4890
# Iter 80700 | nbps=2 | Eb/No=12.97dB | Loss=-1.0000
# Iter 80800 | nbps=4 | Eb/No=8.13dB | Loss=-0.9190
# Iter 80900 | nbps=6 | Eb/No=1.42dB | Loss=-0.3328
# Iter 81000 | nbps=2 | Eb/No=7.95dB | Loss=-0.9998
# Iter 81100 | nbps=4 | Eb/No=13.57dB | Loss=-0.9985
# Iter 81200 | nbps=6 | Eb/No=5.09dB | Loss=-0.5085
# Iter 81300 | nbps=2 | Eb/No=8.22dB | Loss=-0.9974
# Iter 81400 | nbps=4 | Eb/No=13.43dB | Loss=-0.9985
# Iter 81500 | nbps=6 | Eb/No=9.34dB | Loss=-0.7127
# Iter 81600 | nbps=2 | Eb/No=11.18dB | Loss=-0.9927
# Iter 81700 | nbps=4 | Eb/No=8.34dB | Loss=-0.9214
# Iter 81800 | nbps=6 | Eb/No=0.94dB | Loss=-0.3173
# Iter 81900 | nbps=2 | Eb/No=4.32dB | Loss=-0.9702
# Iter 82000 | nbps=4 | Eb/No=1.86dB | Loss=-0.5717
# Iter 82100 | nbps=6 | Eb/No=7.60dB | Loss=-0.6286
# Iter 82200 | nbps=2 | Eb/No=13.90dB | Loss=-1.0000
# Iter 82300 | nbps=4 | Eb/No=0.22dB | Loss=-0.4585
# Iter 82400 | nbps=6 | Eb/No=2.75dB | Loss=-0.3845
# Iter 82500 | nbps=2 | Eb/No=0.67dB | Loss=-0.8767
# Iter 82600 | nbps=4 | Eb/No=5.31dB | Loss=-0.7577
# Iter 82700 | nbps=6 | Eb/No=13.01dB | Loss=-0.8740
# Iter 82800 | nbps=2 | Eb/No=5.16dB | Loss=-0.9922
# Iter 82900 | nbps=4 | Eb/No=1.38dB | Loss=-0.5303
# Iter 83000 | nbps=6 | Eb/No=13.63dB | Loss=-0.8921
# Iter 83100 | nbps=2 | Eb/No=6.67dB | Loss=-0.9985
# Iter 83200 | nbps=4 | Eb/No=1.06dB | Loss=-0.5135
# Iter 83300 | nbps=6 | Eb/No=3.00dB | Loss=-0.4075
# Iter 83400 | nbps=2 | Eb/No=6.69dB | Loss=-0.9955
# Iter 83500 | nbps=4 | Eb/No=6.52dB | Loss=-0.8453
# Iter 83600 | nbps=6 | Eb/No=12.61dB | Loss=-0.8602
# Iter 83700 | nbps=2 | Eb/No=7.39dB | Loss=-0.9973
# Iter 83800 | nbps=4 | Eb/No=6.26dB | Loss=-0.8212
# Iter 83900 | nbps=6 | Eb/No=9.31dB | Loss=-0.7145
# Iter 84000 | nbps=2 | Eb/No=9.24dB | Loss=-0.9934
# Iter 84100 | nbps=4 | Eb/No=3.59dB | Loss=-0.6809
# Iter 84200 | nbps=6 | Eb/No=3.79dB | Loss=-0.4440
# Iter 84300 | nbps=2 | Eb/No=12.35dB | Loss=-1.0000
# Iter 84400 | nbps=4 | Eb/No=1.58dB | Loss=-0.5486
# Iter 84500 | nbps=6 | Eb/No=11.65dB | Loss=-0.8172
# Iter 84600 | nbps=2 | Eb/No=2.03dB | Loss=-0.9282
# Iter 84700 | nbps=4 | Eb/No=12.12dB | Loss=-0.9849
# Iter 84800 | nbps=6 | Eb/No=2.49dB | Loss=-0.3846
# Iter 84900 | nbps=2 | Eb/No=3.57dB | Loss=-0.9749
# Iter 85000 | nbps=4 | Eb/No=6.04dB | Loss=-0.8226
# Iter 85100 | nbps=6 | Eb/No=6.23dB | Loss=-0.5589
# Iter 85200 | nbps=2 | Eb/No=4.92dB | Loss=-0.9918
# Iter 85300 | nbps=4 | Eb/No=6.01dB | Loss=-0.8209
# Iter 85400 | nbps=6 | Eb/No=2.13dB | Loss=-0.3661
# Iter 85500 | nbps=2 | Eb/No=8.19dB | Loss=-0.9986
# Iter 85600 | nbps=4 | Eb/No=10.58dB | Loss=-0.9730
# Iter 85700 | nbps=6 | Eb/No=12.66dB | Loss=-0.8457
# Iter 85800 | nbps=2 | Eb/No=0.85dB | Loss=-0.8670
# Iter 85900 | nbps=4 | Eb/No=3.92dB | Loss=-0.6990
# Iter 86000 | nbps=6 | Eb/No=1.39dB | Loss=-0.3368
# Iter 86100 | nbps=2 | Eb/No=10.56dB | Loss=-0.9999
# Iter 86200 | nbps=4 | Eb/No=3.92dB | Loss=-0.6993
# Iter 86300 | nbps=6 | Eb/No=0.00dB | Loss=-0.2774
# Iter 86400 | nbps=2 | Eb/No=9.42dB | Loss=-0.9988
# Iter 86500 | nbps=4 | Eb/No=5.27dB | Loss=-0.7777
# Iter 86600 | nbps=6 | Eb/No=7.42dB | Loss=-0.6190
# Iter 86700 | nbps=2 | Eb/No=3.11dB | Loss=-0.9589
# Iter 86800 | nbps=4 | Eb/No=13.97dB | Loss=-0.9970
# Iter 86900 | nbps=6 | Eb/No=11.24dB | Loss=-0.7961
# Iter 87000 | nbps=2 | Eb/No=6.37dB | Loss=-0.9908
# Iter 87100 | nbps=4 | Eb/No=11.14dB | Loss=-0.9826
# Iter 87200 | nbps=6 | Eb/No=6.31dB | Loss=-0.5641
# Iter 87300 | nbps=2 | Eb/No=7.93dB | Loss=-0.9998
# Iter 87400 | nbps=4 | Eb/No=8.70dB | Loss=-0.9343
# Iter 87500 | nbps=6 | Eb/No=14.43dB | Loss=-0.8841
# Iter 87600 | nbps=2 | Eb/No=7.91dB | Loss=-0.9940
# Iter 87700 | nbps=4 | Eb/No=5.48dB | Loss=-0.7893
# Iter 87800 | nbps=6 | Eb/No=1.17dB | Loss=-0.3271
# Iter 87900 | nbps=2 | Eb/No=8.30dB | Loss=-0.9974
# Iter 88000 | nbps=4 | Eb/No=8.75dB | Loss=-0.9304
# Iter 88100 | nbps=6 | Eb/No=13.34dB | Loss=-0.8770
# Iter 88200 | nbps=2 | Eb/No=1.75dB | Loss=-0.9207
# Iter 88300 | nbps=4 | Eb/No=6.91dB | Loss=-0.8649
# Iter 88400 | nbps=6 | Eb/No=11.78dB | Loss=-0.8328
# Iter 88500 | nbps=2 | Eb/No=13.64dB | Loss=-1.0000
# Iter 88600 | nbps=4 | Eb/No=3.81dB | Loss=-0.6871
# Iter 88700 | nbps=6 | Eb/No=5.42dB | Loss=-0.5190
# Iter 88800 | nbps=2 | Eb/No=11.64dB | Loss=-1.0000
# Iter 88900 | nbps=4 | Eb/No=7.23dB | Loss=-0.8811
# Iter 89000 | nbps=6 | Eb/No=10.37dB | Loss=-0.7603
# Iter 89100 | nbps=2 | Eb/No=9.18dB | Loss=-0.9998
# Iter 89200 | nbps=4 | Eb/No=0.98dB | Loss=-0.5081
# Iter 89300 | nbps=6 | Eb/No=2.52dB | Loss=-0.3822
# Iter 89400 | nbps=2 | Eb/No=11.42dB | Loss=-1.0000
# Iter 89500 | nbps=4 | Eb/No=9.79dB | Loss=-0.9678
# Iter 89600 | nbps=6 | Eb/No=5.34dB | Loss=-0.5094
# Iter 89700 | nbps=2 | Eb/No=0.29dB | Loss=-0.8524
# Iter 89800 | nbps=4 | Eb/No=11.39dB | Loss=-0.9911
# Iter 89900 | nbps=6 | Eb/No=8.77dB | Loss=-0.6798
# Iter 90000 | nbps=2 | Eb/No=10.83dB | Loss=-1.0000

# %%
# iterative
model = E2ESystem('neural-receiver', training=True, use_fec=True)
eval_model = E2ESystem('neural-receiver', training=False, use_fec=True)

mapper_optimizer = tf.keras.optimizers.Adam()
receiver_optimizer = tf.keras.optimizers.Adam()

model(1, tf.constant(10.0, tf.float32))

mapper_vars = model._mapper.trainable_variables
receiver_vars = model._neural_receiver.trainable_variables

# warmup
def get_receiver_updates(iteration, total_iterations, batch_size):
    warmup_fraction = 0.1
    warmup_iters = int(total_iterations * warmup_fraction)
    
    if iteration < warmup_iters:
        return 1  # Warmup stay at 1
    else:
        # Linear growth from 1 to batch_size
        progress = (iteration - warmup_iters) / (total_iterations - warmup_iters)
        updates = int(1 + (batch_size - 1) * progress)
        return max(1, min(updates, batch_size))  # Clamp to [1, batch_size]

for i in tqdm(range(10000)):
    ebno_db = tf.random.uniform(shape=[], minval=ebno_db_min, maxval=ebno_db_max)
    
    # Mapper update
    with tf.GradientTape() as tape_tx:
        rate = model(training_batch_size, ebno_db, training=True)
        mapper_loss = -rate
    
    mapper_grads = tape_tx.gradient(mapper_loss, mapper_vars)
    mapper_optimizer.apply_gradients(zip(mapper_grads, mapper_vars))
    
    # Receiver updates (gradually increasing)
    receiver_updates = get_receiver_updates(i, 10000, batch_size//2)
    
    for j in range(receiver_updates):
        with tf.GradientTape() as tape_rx:
            rate = model(training_batch_size, ebno_db, training=True)
            receiver_loss = -rate
        
        receiver_grads = tape_rx.gradient(receiver_loss, receiver_vars)
        receiver_optimizer.apply_gradients(zip(receiver_grads, receiver_vars))
    
    if i % 100 == 0:
        log_str = f"Iter {i}/{10000}, Eb/No: {ebno_db.numpy():.2f}dB, " \
                  f"Loss: {receiver_loss.numpy():.4f}, RxUpdates: {receiver_updates}"
        print(log_str)

# Save weights
weights = model.get_weights()
with open('iter_resNF_2stage_neural_receiver_model_weights.pkl', 'wb') as f:
    pickle.dump(weights, f)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Iter 0/10000, Eb/No: 10.80dB, Loss: 0.7403, RxUpdates: 1
# Iter 100/10000, Eb/No: 12.34dB, Loss: 0.0073, RxUpdates: 1
# Iter 200/10000, Eb/No: 4.93dB, Loss: 0.0027, RxUpdates: 1
# Iter 300/10000, Eb/No: 8.99dB, Loss: -0.0012, RxUpdates: 1
# Iter 400/10000, Eb/No: 11.09dB, Loss: -0.1176, RxUpdates: 1
# Iter 500/10000, Eb/No: 8.05dB, Loss: -0.2613, RxUpdates: 1
# Iter 600/10000, Eb/No: 4.67dB, Loss: -0.2905, RxUpdates: 1
# Iter 700/10000, Eb/No: 9.83dB, Loss: -0.3301, RxUpdates: 1
# Iter 800/10000, Eb/No: 11.85dB, Loss: -0.4006, RxUpdates: 1
# Iter 900/10000, Eb/No: 7.81dB, Loss: -0.4322, RxUpdates: 1
# Iter 1000/10000, Eb/No: 14.00dB, Loss: -0.5358, RxUpdates: 1
# Iter 1100/10000, Eb/No: 3.20dB, Loss: -0.3539, RxUpdates: 1
# Iter 1200/10000, Eb/No: 1.81dB, Loss: -0.3180, RxUpdates: 2
# Iter 1300/10000, Eb/No: 9.72dB, Loss: -0.6066, RxUpdates: 3
# Iter 1400/10000, Eb/No: 10.57dB, Loss: -0.6310, RxUpdates: 3
# Iter 1500/10000, Eb/No: 2.16dB, Loss: -0.3099, RxUpdates: 4
# Iter 1600/10000, Eb/No: 4.64dB, Loss: -0.4659, RxUpdates: 5
# Iter 1700/10000, Eb/No: 5.84dB, Loss: -0.5154, RxUpdates: 5
# Iter 1800/10000, Eb/No: 14.04dB, Loss: -0.7822, RxUpdates: 6
# Iter 1900/10000, Eb/No: 12.63dB, Loss: -0.7998, RxUpdates: 7
# Iter 2000/10000, Eb/No: 0.51dB, Loss: -0.3128, RxUpdates: 8
# Iter 2100/10000, Eb/No: 8.48dB, Loss: -0.6691, RxUpdates: 8
# Iter 2200/10000, Eb/No: 5.20dB, Loss: -0.5178, RxUpdates: 9
# Iter 2300/10000, Eb/No: 7.54dB, Loss: -0.6363, RxUpdates: 10
# Iter 2400/10000, Eb/No: 2.70dB, Loss: -0.3998, RxUpdates: 10
# Iter 2500/10000, Eb/No: 2.82dB, Loss: -0.4142, RxUpdates: 11
# Iter 2600/10000, Eb/No: 13.24dB, Loss: -0.8732, RxUpdates: 12
# Iter 2700/10000, Eb/No: 11.53dB, Loss: -0.8161, RxUpdates: 12
# Iter 2800/10000, Eb/No: 4.69dB, Loss: -0.5017, RxUpdates: 13
# Iter 2900/10000, Eb/No: 2.69dB, Loss: -0.4122, RxUpdates: 14
# Iter 3000/10000, Eb/No: 11.58dB, Loss: -0.8238, RxUpdates: 15
# Iter 3100/10000, Eb/No: 11.44dB, Loss: -0.8014, RxUpdates: 15
# Iter 3200/10000, Eb/No: 8.38dB, Loss: -0.6804, RxUpdates: 16
# Iter 3300/10000, Eb/No: 9.51dB, Loss: -0.7200, RxUpdates: 17
# Iter 3400/10000, Eb/No: 0.84dB, Loss: -0.3370, RxUpdates: 17
# Iter 3500/10000, Eb/No: 12.04dB, Loss: -0.8355, RxUpdates: 18
# Iter 3600/10000, Eb/No: 13.53dB, Loss: -0.8881, RxUpdates: 19
# Iter 3700/10000, Eb/No: 1.72dB, Loss: -0.3674, RxUpdates: 19
# Iter 3800/10000, Eb/No: 14.59dB, Loss: -0.9272, RxUpdates: 20
# Iter 3900/10000, Eb/No: 5.94dB, Loss: -0.5655, RxUpdates: 21
# Iter 4000/10000, Eb/No: 0.44dB, Loss: -0.3192, RxUpdates: 22
# Iter 4100/10000, Eb/No: 14.21dB, Loss: -0.9168, RxUpdates: 22
# Iter 4200/10000, Eb/No: 4.23dB, Loss: -0.4827, RxUpdates: 23
# Iter 4300/10000, Eb/No: 11.56dB, Loss: -0.8307, RxUpdates: 24
# Iter 4400/10000, Eb/No: 13.05dB, Loss: -0.8808, RxUpdates: 24
# Iter 4500/10000, Eb/No: 11.00dB, Loss: -0.8080, RxUpdates: 25
# Iter 4600/10000, Eb/No: 2.31dB, Loss: -0.4050, RxUpdates: 26
# Iter 4700/10000, Eb/No: 2.22dB, Loss: -0.3996, RxUpdates: 26
# Iter 4800/10000, Eb/No: 6.74dB, Loss: -0.6104, RxUpdates: 27
# Iter 4900/10000, Eb/No: 5.88dB, Loss: -0.5641, RxUpdates: 28
# Iter 5000/10000, Eb/No: 7.84dB, Loss: -0.6621, RxUpdates: 29
# Iter 5100/10000, Eb/No: 9.20dB, Loss: -0.7336, RxUpdates: 29
# Iter 5200/10000, Eb/No: 6.65dB, Loss: -0.6111, RxUpdates: 30
# Iter 5300/10000, Eb/No: 7.13dB, Loss: -0.6283, RxUpdates: 31
# Iter 5400/10000, Eb/No: 10.16dB, Loss: -0.7586, RxUpdates: 31
# Iter 5500/10000, Eb/No: 8.36dB, Loss: -0.6936, RxUpdates: 32
# Iter 5600/10000, Eb/No: 10.00dB, Loss: -0.7645, RxUpdates: 33
# Iter 5700/10000, Eb/No: 14.25dB, Loss: -0.9241, RxUpdates: 33
# Iter 5800/10000, Eb/No: 9.85dB, Loss: -0.7612, RxUpdates: 34
# Iter 5900/10000, Eb/No: 14.88dB, Loss: -0.9384, RxUpdates: 35
# Iter 6000/10000, Eb/No: 6.12dB, Loss: -0.5860, RxUpdates: 36
# Iter 6100/10000, Eb/No: 14.90dB, Loss: -0.9463, RxUpdates: 36
# Iter 6200/10000, Eb/No: 5.48dB, Loss: -0.5516, RxUpdates: 37
# Iter 6300/10000, Eb/No: 8.70dB, Loss: -0.7096, RxUpdates: 38
# Iter 6400/10000, Eb/No: 2.18dB, Loss: -0.3991, RxUpdates: 38
# Iter 6500/10000, Eb/No: 10.51dB, Loss: -0.7935, RxUpdates: 39
# Iter 6600/10000, Eb/No: 6.45dB, Loss: -0.6012, RxUpdates: 40
# Iter 6700/10000, Eb/No: 11.37dB, Loss: -0.8250, RxUpdates: 40
# Iter 6800/10000, Eb/No: 14.29dB, Loss: -0.9284, RxUpdates: 41
# Iter 6900/10000, Eb/No: 14.52dB, Loss: -0.9366, RxUpdates: 42
# Iter 7000/10000, Eb/No: 9.55dB, Loss: -0.7499, RxUpdates: 43
# Iter 7100/10000, Eb/No: 2.94dB, Loss: -0.4372, RxUpdates: 43
# Iter 7200/10000, Eb/No: 13.19dB, Loss: -0.8944, RxUpdates: 44
# Iter 7300/10000, Eb/No: 4.89dB, Loss: -0.5262, RxUpdates: 45
# Iter 7400/10000, Eb/No: 13.17dB, Loss: -0.8984, RxUpdates: 45
# Iter 7500/10000, Eb/No: 8.33dB, Loss: -0.6861, RxUpdates: 46
# Iter 7600/10000, Eb/No: 14.50dB, Loss: -0.9373, RxUpdates: 47
# Iter 7700/10000, Eb/No: 14.13dB, Loss: -0.9228, RxUpdates: 47
# Iter 7800/10000, Eb/No: 13.09dB, Loss: -0.8923, RxUpdates: 48
# Iter 7900/10000, Eb/No: 2.56dB, Loss: -0.4173, RxUpdates: 49
# Iter 8000/10000, Eb/No: 3.33dB, Loss: -0.4528, RxUpdates: 50
# Iter 8100/10000, Eb/No: 0.69dB, Loss: -0.3356, RxUpdates: 50
# Iter 8200/10000, Eb/No: 13.41dB, Loss: -0.9044, RxUpdates: 51
# Iter 8300/10000, Eb/No: 4.14dB, Loss: -0.4887, RxUpdates: 52
# Iter 8400/10000, Eb/No: 12.90dB, Loss: -0.8928, RxUpdates: 52
# Iter 8500/10000, Eb/No: 12.13dB, Loss: -0.8647, RxUpdates: 53
# Iter 8600/10000, Eb/No: 5.79dB, Loss: -0.5671, RxUpdates: 54
# Iter 8700/10000, Eb/No: 2.17dB, Loss: -0.4044, RxUpdates: 54
# Iter 8800/10000, Eb/No: 9.40dB, Loss: -0.7460, RxUpdates: 55
# Iter 8900/10000, Eb/No: 1.79dB, Loss: -0.3835, RxUpdates: 56
# Iter 9000/10000, Eb/No: 7.72dB, Loss: -0.6658, RxUpdates: 57
# Iter 9100/10000, Eb/No: 5.97dB, Loss: -0.5759, RxUpdates: 57
# Iter 9200/10000, Eb/No: 2.15dB, Loss: -0.4015, RxUpdates: 58
# Iter 9300/10000, Eb/No: 2.34dB, Loss: -0.4083, RxUpdates: 59
# Iter 9400/10000, Eb/No: 9.03dB, Loss: -0.7299, RxUpdates: 59
# Iter 9500/10000, Eb/No: 4.11dB, Loss: -0.4897, RxUpdates: 60
# Iter 9600/10000, Eb/No: 6.01dB, Loss: -0.5826, RxUpdates: 61
# Iter 9700/10000, Eb/No: 11.41dB, Loss: -0.8294, RxUpdates: 61
# Iter 9800/10000, Eb/No: 1.85dB, Loss: -0.3908, RxUpdates: 62
# Iter 9900/10000, Eb/No: 9.05dB, Loss: -0.7276, RxUpdates: 63

# %% [markdown]
# ## Evaluation of the Neural Receiver <a class="anchor" id="Evaluation-of-the-Neural-Receiver"></a>

# %%
# Range of SNRs over which the systems are evaluated
ebno_dbs = np.arange(ebno_db_min, # Min SNR for evaluation
                     ebno_db_max, # Max SNR for evaluation
                     0.5) # Step

# Dictionary storing the evaluation results
BLER = {}
BER = {}

# %%
eval_model = E2ESystem('neural-receiver', training=False, use_fec=True)

with open('10000_SNRNF_2stage_const_neural_receiver_model_weights.pkl', 'rb') as f:
    weights = pickle.load(f)
eval_model(1, tf.constant(10.0, tf.float32))
eval_model.set_weights(weights)

# Evaluations
ber,bler = sim_ber(eval_model, ebno_dbs, batch_size=128, num_target_block_errors=100, max_mc_iter=300)
BLER['neural-receiver-standard'] = bler.numpy()
BER['neural-receiver-standard'] = ber.numpy()

with open('10000_SNRNF_2stage_const_neural_receiver_model_result', 'wb') as f:
    pickle.dump((ebno_dbs, BLER, BER), f)
# Out:
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       0.0 | 2.9527e-01 | 1.0000e+00 |      157832 |      534528 |          128 |         128 |         0.6 |reached target block errors
#       0.5 | 2.8331e-01 | 1.0000e+00 |      151437 |      534528 |          128 |         128 |         0.4 |reached target block errors
#       1.0 | 2.7280e-01 | 1.0000e+00 |      145819 |      534528 |          128 |         128 |         0.4 |reached target block errors
#       1.5 | 2.5922e-01 | 1.0000e+00 |      138558 |      534528 |          128 |         128 |         0.4 |reached target block errors
#       2.0 | 2.4619e-01 | 1.0000e+00 |      131595 |      534528 |          128 |         128 |         0.4 |reached target block errors
#       2.5 | 2.3003e-01 | 1.0000e+00 |      122960 |      534528 |          128 |         128 |         0.4 |reached target block errors
#       3.0 | 2.1565e-01 | 1.0000e+00 |      115271 |      534528 |          128 |         128 |         0.4 |reached target block errors
#       3.5 | 1.9829e-01 | 1.0000e+00 |      105989 |      534528 |          128 |         128 |         0.4 |reached target block errors
#       4.0 | 1.8095e-01 | 1.0000e+00 |       96722 |      534528 |          128 |         128 |         0.4 |reached target block errors
#       4.5 | 1.6204e-01 | 1.0000e+00 |       86615 |      534528 |          128 |         128 |         0.4 |reached target block errors
#       5.0 | 1.2717e-01 | 1.0000e+00 |       67974 |      534528 |          128 |         128 |         0.4 |reached target block errors
#       5.5 | 6.2605e-02 | 9.7656e-01 |       33464 |      534528 |          125 |         128 |         0.4 |reached target block errors
#       6.0 | 9.4308e-03 | 2.7604e-01 |       15123 |     1603584 |          106 |         384 |         1.3 |reached target block errors
#       6.5 | 3.8761e-03 | 4.6875e-02 |       37294 |     9621504 |          108 |        2304 |         7.6 |reached target block errors
#       7.0 | 3.0137e-03 | 2.6042e-02 |       48327 |    16035840 |          100 |        3840 |        12.7 |reached target block errors
#       7.5 | 2.1084e-03 | 1.7708e-02 |       50716 |    24053760 |          102 |        5760 |        18.8 |reached target block errors
#       8.0 | 1.4065e-03 | 1.1777e-02 |       50370 |    35813376 |          101 |        8576 |        28.1 |reached target block errors
#       8.5 | 1.1550e-03 | 9.7656e-03 |       49389 |    42762240 |          100 |       10240 |        32.9 |reached target block errors
#       9.0 | 6.8614e-04 | 6.2500e-03 |       45845 |    66816000 |          100 |       16000 |        52.5 |reached target block errors
#       9.5 | 4.3590e-04 | 4.9010e-03 |       37513 |    86059008 |          101 |       20608 |        68.8 |reached target block errors
#      10.0 | 2.1334e-04 | 2.9705e-03 |       29992 |   140580864 |          100 |       33664 |       111.8 |reached target block errors
#      10.5 | 3.0575e-05 | 8.0729e-04 |        4903 |   160358400 |           31 |       38400 |       128.2 |reached max iterations
#      11.0 | 8.6868e-06 | 4.4271e-04 |        1393 |   160358400 |           17 |       38400 |       127.6 |reached max iterations
#      11.5 | 0.0000e+00 | 0.0000e+00 |           0 |   160358400 |            0 |       38400 |       127.5 |reached max iterations
#
# Simulation stopped as no error occurred @ EbNo = 11.5 dB.

# %% [markdown]
# ### FiLM

# %%
def make_eval_fn(model, nbps):
    def eval_fn(batch_size, ebno_db):
        return model(batch_size, ebno_db, nbps)
    return eval_fn

# %%
eval_film = E2ESystem('neural-receiver', training=False, use_fec=True)
eval_film(1, tf.constant(10.0), 6)  # build with max nbps first
with open('FiLM/90000_qam_multi_mod_neural_receiver_weights.pkl', 'rb') as f:
    weights = pickle.load(f)
eval_film.set_weights(weights)

for nbps in MOD_ORDERS:
    eval_fn = make_eval_fn(eval_film, nbps)
    ber, bler = sim_ber(eval_fn, ebno_dbs, batch_size=128, num_target_block_errors=100, max_mc_iter=300)
    BLER[f'neural-film-{nbps}bps'] = bler.numpy()
    BER[f'neural-film-{nbps}bps'] = ber.numpy()

with open('FiLM/90000_qam_multi_mod_eval_results.pkl', 'wb') as f:
    pickle.dump((ebno_dbs, BLER, BER), f)
# Out:
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       0.0 | 5.1180e-04 | 3.9453e-03 |       18238 |    35635200 |          101 |       25600 |        72.9 |reached target block errors
#       0.5 | 1.9030e-04 | 2.1094e-03 |       10172 |    53452800 |           81 |       38400 |       104.9 |reached max iterations
#       1.0 | 6.4169e-05 | 9.8958e-04 |        3430 |    53452800 |           38 |       38400 |       109.1 |reached max iterations
#       1.5 | 9.3540e-06 | 3.3854e-04 |         500 |    53452800 |           13 |       38400 |       104.0 |reached max iterations
#       2.0 | 0.0000e+00 | 0.0000e+00 |           0 |    53452800 |            0 |       38400 |       105.0 |reached max iterations
#
# Simulation stopped as no error occurred @ EbNo = 2.0 dB.
#
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       0.0 | 2.0057e-01 | 1.0000e+00 |       71475 |      356352 |          128 |         128 |         3.6 |reached target block errors
#       0.5 | 1.7848e-01 | 1.0000e+00 |       63603 |      356352 |          128 |         128 |         0.4 |reached target block errors
#       1.0 | 1.4445e-01 | 1.0000e+00 |       51475 |      356352 |          128 |         128 |         0.4 |reached target block errors
#       1.5 | 7.0486e-02 | 9.9219e-01 |       25118 |      356352 |          127 |         128 |         0.4 |reached target block errors
#       2.0 | 1.6019e-02 | 4.8438e-01 |       11417 |      712704 |          124 |         256 |         0.8 |reached target block errors
#       2.5 | 4.1599e-03 | 5.5208e-02 |       22236 |     5345280 |          106 |        1920 |         5.7 |reached target block errors
#       3.0 | 3.6760e-03 | 2.7902e-02 |       36679 |     9977856 |          100 |        3584 |        10.7 |reached target block errors
#       3.5 | 2.3526e-03 | 1.7933e-02 |       36888 |    15679488 |          101 |        5632 |        16.9 |reached target block errors
#       4.0 | 1.5460e-03 | 1.1393e-02 |       39667 |    25657344 |          105 |        9216 |        27.2 |reached target block errors
#       4.5 | 1.0601e-03 | 7.8906e-03 |       37778 |    35635200 |          101 |       12800 |        38.0 |reached target block errors
#       5.0 | 8.0176e-04 | 6.1516e-03 |       36285 |    45256704 |          100 |       16256 |        48.8 |reached target block errors
#       5.5 | 4.2373e-04 | 3.6337e-03 |       32464 |    76615680 |          100 |       27520 |        80.9 |reached target block errors
#       6.0 | 2.0748e-04 | 2.2135e-03 |       22181 |   106905600 |           85 |       38400 |       116.7 |reached max iterations
#       6.5 | 4.8875e-05 | 8.3333e-04 |        5225 |   106905600 |           32 |       38400 |       117.6 |reached max iterations
#       7.0 | 3.4488e-05 | 5.7292e-04 |        3687 |   106905600 |           22 |       38400 |       118.5 |reached max iterations
#       7.5 | 3.0307e-06 | 5.2083e-05 |         324 |   106905600 |            2 |       38400 |       118.2 |reached max iterations
#       8.0 | 1.1225e-07 | 2.6042e-05 |          12 |   106905600 |            1 |       38400 |       117.0 |reached max iterations
#       8.5 | 0.0000e+00 | 0.0000e+00 |           0 |   106905600 |            0 |       38400 |       118.5 |reached max iterations
#
# Simulation stopped as no error occurred @ EbNo = 8.5 dB.
#
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       0.0 | 2.8928e-01 | 1.0000e+00 |      154629 |      534528 |          128 |         128 |         0.5 |reached target block errors
#       0.5 | 2.7652e-01 | 1.0000e+00 |      147806 |      534528 |          128 |         128 |         0.5 |reached target block errors
#       1.0 | 2.6694e-01 | 1.0000e+00 |      142689 |      534528 |          128 |         128 |         0.5 |reached target block errors
#       1.5 | 2.5679e-01 | 1.0000e+00 |      137263 |      534528 |          128 |         128 |         0.5 |reached target block errors
#       2.0 | 2.4368e-01 | 1.0000e+00 |      130252 |      534528 |          128 |         128 |         0.5 |reached target block errors
#       2.5 | 2.3194e-01 | 1.0000e+00 |      123976 |      534528 |          128 |         128 |         0.5 |reached target block errors
#       3.0 | 2.1963e-01 | 1.0000e+00 |      117396 |      534528 |          128 |         128 |         0.5 |reached target block errors
#       3.5 | 2.0574e-01 | 1.0000e+00 |      109973 |      534528 |          128 |         128 |         0.5 |reached target block errors
#       4.0 | 1.9004e-01 | 1.0000e+00 |      101583 |      534528 |          128 |         128 |         0.5 |reached target block errors
#       4.5 | 1.7853e-01 | 1.0000e+00 |       95428 |      534528 |          128 |         128 |         0.5 |reached target block errors
#       5.0 | 1.6100e-01 | 1.0000e+00 |       86057 |      534528 |          128 |         128 |         0.5 |reached target block errors
#       5.5 | 1.3002e-01 | 1.0000e+00 |       69499 |      534528 |          128 |         128 |         0.5 |reached target block errors
#       6.0 | 7.7414e-02 | 9.9219e-01 |       41380 |      534528 |          127 |         128 |         0.5 |reached target block errors
#       6.5 | 1.3880e-02 | 5.1562e-01 |       14839 |     1069056 |          132 |         256 |         0.9 |reached target block errors
#       7.0 | 4.9286e-03 | 5.6362e-02 |       36883 |     7483392 |          101 |        1792 |         6.6 |reached target block errors
#       7.5 | 3.5148e-03 | 2.7478e-02 |       54484 |    15501312 |          102 |        3712 |        13.6 |reached target block errors
#       8.0 | 1.9537e-03 | 1.8787e-02 |       43861 |    22450176 |          101 |        5376 |        19.5 |reached target block errors
#       8.5 | 1.6719e-03 | 1.5035e-02 |       47364 |    28329984 |          102 |        6784 |        24.5 |reached target block errors
#       9.0 | 1.0134e-03 | 8.6806e-03 |       48754 |    48107520 |          100 |       11520 |        41.6 |reached target block errors
#       9.5 | 5.8306e-04 | 5.7026e-03 |       42698 |    73230336 |          100 |       17536 |        63.4 |reached target block errors
#      10.0 | 3.7508e-04 | 4.0064e-03 |       39096 |   104232960 |          100 |       24960 |        89.9 |reached target block errors
#      10.5 | 1.2350e-04 | 2.2656e-03 |       19804 |   160358400 |           87 |       38400 |       137.8 |reached max iterations
#      11.0 | 2.8492e-05 | 1.0938e-03 |        4569 |   160358400 |           42 |       38400 |       137.7 |reached max iterations
#      11.5 | 9.3790e-06 | 2.0833e-04 |        1504 |   160358400 |            8 |       38400 |       137.5 |reached max iterations
#      12.0 | 0.0000e+00 | 0.0000e+00 |           0 |   160358400 |            0 |       38400 |       137.0 |reached max iterations
#
# Simulation stopped as no error occurred @ EbNo = 12.0 dB.

# %%
for nbps in MOD_ORDERS:
    for system in ['baseline-perfect-csi', 'baseline-ls-estimation']:
        baseline = E2ESystem(system, training=False, use_fec=True)
        baseline(1, tf.constant(10.0), nbps)
        ber, bler = sim_ber(make_eval_fn(baseline, nbps), ebno_dbs,
                            batch_size=128, num_target_block_errors=100, max_mc_iter=300)
        BLER[f'{system}-{nbps}bps'] = bler.numpy()
        BER[f'{system}-{nbps}bps'] = ber.numpy()

with open('baseline_multi_mod_eval_results.pkl', 'wb') as f:
    pickle.dump((ebno_dbs, BLER, BER), f)
# Out:
# 2026-02-25 20:39:25.270805: I tensorflow/core/util/cuda_solvers.cc:179] Creating GpuSolver handles for stream 0x59ea8850a990
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       0.0 | 2.2008e-04 | 2.5000e-03 |       11764 |    53452800 |           96 |       38400 |        57.3 |reached max iterations
#       0.5 | 6.6208e-05 | 1.2760e-03 |        3539 |    53452800 |           49 |       38400 |        56.6 |reached max iterations
#       1.0 | 1.8427e-05 | 4.9479e-04 |         985 |    53452800 |           19 |       38400 |        57.2 |reached max iterations
#       1.5 | 5.9492e-06 | 1.0417e-04 |         318 |    53452800 |            4 |       38400 |        57.3 |reached max iterations
#       2.0 | 0.0000e+00 | 0.0000e+00 |           0 |    53452800 |            0 |       38400 |        57.2 |reached max iterations
#
# Simulation stopped as no error occurred @ EbNo = 2.0 dB.
#
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       0.0 | 6.2446e-03 | 5.8036e-02 |       15577 |     2494464 |          104 |        1792 |         2.9 |reached target block errors
#       0.5 | 3.7365e-03 | 2.4658e-02 |       21304 |     5701632 |          101 |        4096 |         6.2 |reached target block errors
#       1.0 | 3.1777e-03 | 1.8532e-02 |       24346 |     7661568 |          102 |        5504 |         8.3 |reached target block errors
#       1.5 | 1.9223e-03 | 1.0809e-02 |       25003 |    13006848 |          101 |        9344 |        14.1 |reached target block errors
#       2.0 | 1.2170e-03 | 7.5149e-03 |       22768 |    18708480 |          101 |       13440 |        20.3 |reached target block errors
#       2.5 | 9.1858e-04 | 5.6205e-03 |       22750 |    24766464 |          100 |       17792 |        26.8 |reached target block errors
#       3.0 | 5.8703e-04 | 3.7202e-03 |       21965 |    37416960 |          100 |       26880 |        40.3 |reached target block errors
#       3.5 | 3.8693e-04 | 2.6573e-03 |       20269 |    52383744 |          100 |       37632 |        56.5 |reached target block errors
#       4.0 | 1.9750e-04 | 1.5104e-03 |       10557 |    53452800 |           58 |       38400 |        57.8 |reached max iterations
#       4.5 | 5.7677e-05 | 5.9896e-04 |        3083 |    53452800 |           23 |       38400 |        57.7 |reached max iterations
#       5.0 | 2.6640e-05 | 1.5625e-04 |        1424 |    53452800 |            6 |       38400 |        57.7 |reached max iterations
#       5.5 | 3.6855e-06 | 2.6042e-05 |         197 |    53452800 |            1 |       38400 |        57.8 |reached max iterations
#       6.0 | 0.0000e+00 | 0.0000e+00 |           0 |    53452800 |            0 |       38400 |        57.4 |reached max iterations
#
# Simulation stopped as no error occurred @ EbNo = 6.0 dB.
#
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       0.0 | 1.9779e-01 | 1.0000e+00 |       70483 |      356352 |          128 |         128 |         0.5 |reached target block errors
#       0.5 | 1.6978e-01 | 1.0000e+00 |       60502 |      356352 |          128 |         128 |         0.2 |reached target block errors
#       1.0 | 1.3481e-01 | 1.0000e+00 |       48039 |      356352 |          128 |         128 |         0.2 |reached target block errors
#       1.5 | 5.3450e-02 | 9.5312e-01 |       19047 |      356352 |          122 |         128 |         0.2 |reached target block errors
#       2.0 | 8.8220e-03 | 2.0703e-01 |       12575 |     1425408 |          106 |         512 |         0.9 |reached target block errors
#       2.5 | 4.6777e-03 | 4.1941e-02 |       31671 |     6770688 |          102 |        2432 |         4.3 |reached target block errors
#       3.0 | 2.5742e-03 | 1.9922e-02 |       36693 |    14254080 |          102 |        5120 |         9.0 |reached target block errors
#       3.5 | 2.0146e-03 | 1.6789e-02 |       33741 |    16748544 |          101 |        6016 |        10.5 |reached target block errors
#       4.0 | 1.3504e-03 | 9.5274e-03 |       39459 |    29220864 |          100 |       10496 |        18.3 |reached target block errors
#       4.5 | 8.3517e-04 | 6.7441e-03 |       34821 |    41693184 |          101 |       14976 |        26.0 |reached target block errors
#       5.0 | 4.9109e-04 | 4.1097e-03 |       33600 |    68419584 |          101 |       24576 |        42.6 |reached target block errors
#       5.5 | 2.9777e-04 | 3.0466e-03 |       27483 |    92295168 |          101 |       33152 |        57.8 |reached target block errors
#       6.0 | 1.1229e-04 | 1.3021e-03 |       12004 |   106905600 |           50 |       38400 |        66.7 |reached max iterations
#       6.5 | 4.2299e-05 | 5.7292e-04 |        4522 |   106905600 |           22 |       38400 |        67.1 |reached max iterations
#       7.0 | 2.9185e-06 | 2.3437e-04 |         312 |   106905600 |            9 |       38400 |        67.1 |reached max iterations
#       7.5 | 4.0971e-06 | 5.2083e-05 |         438 |   106905600 |            2 |       38400 |        67.0 |reached max iterations
#       8.0 | 4.1438e-06 | 2.6042e-05 |         443 |   106905600 |            1 |       38400 |        67.0 |reached max iterations
#       8.5 | 0.0000e+00 | 0.0000e+00 |           0 |   106905600 |            0 |       38400 |        67.0 |reached max iterations
#
# Simulation stopped as no error occurred @ EbNo = 8.5 dB.
#
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       0.0 | 2.7882e-01 | 1.0000e+00 |       99359 |      356352 |          128 |         128 |         0.5 |reached target block errors
#       0.5 | 2.6593e-01 | 1.0000e+00 |       94763 |      356352 |          128 |         128 |         0.2 |reached target block errors
#       1.0 | 2.5057e-01 | 1.0000e+00 |       89291 |      356352 |          128 |         128 |         0.2 |reached target block errors
#       1.5 | 2.4167e-01 | 1.0000e+00 |       86118 |      356352 |          128 |         128 |         0.2 |reached target block errors
#       2.0 | 2.2517e-01 | 1.0000e+00 |       80240 |      356352 |          128 |         128 |         0.2 |reached target block errors
#       2.5 | 2.0663e-01 | 1.0000e+00 |       73632 |      356352 |          128 |         128 |         0.2 |reached target block errors
#       3.0 | 1.8368e-01 | 1.0000e+00 |       65453 |      356352 |          128 |         128 |         0.2 |reached target block errors
#       3.5 | 1.4917e-01 | 1.0000e+00 |       53157 |      356352 |          128 |         128 |         0.2 |reached target block errors
#       4.0 | 7.6579e-02 | 9.7656e-01 |       27289 |      356352 |          125 |         128 |         0.2 |reached target block errors
#       4.5 | 2.1486e-02 | 4.8047e-01 |       15313 |      712704 |          123 |         256 |         0.4 |reached target block errors
#       5.0 | 5.3590e-03 | 6.7308e-02 |       24826 |     4632576 |          112 |        1664 |         3.0 |reached target block errors
#       5.5 | 3.6958e-03 | 2.8181e-02 |       36876 |     9977856 |          101 |        3584 |         6.4 |reached target block errors
#       6.0 | 2.8311e-03 | 1.8601e-02 |       42372 |    14966784 |          100 |        5376 |         9.6 |reached target block errors
#       6.5 | 1.4536e-03 | 9.1595e-03 |       45064 |    31002624 |          102 |       11136 |        19.7 |reached target block errors
#       7.0 | 1.2816e-03 | 8.6806e-03 |       41104 |    32071680 |          100 |       11520 |        20.3 |reached target block errors
#       7.5 | 7.6739e-04 | 5.2787e-03 |       40472 |    52740096 |          100 |       18944 |        33.4 |reached target block errors
#       8.0 | 4.2921e-04 | 3.4722e-03 |       34414 |    80179200 |          100 |       28800 |        50.6 |reached target block errors
#       8.5 | 2.5969e-04 | 2.1354e-03 |       27762 |   106905600 |           82 |       38400 |        67.6 |reached max iterations
#       9.0 | 7.5917e-05 | 8.3333e-04 |        8116 |   106905600 |           32 |       38400 |        67.5 |reached max iterations
#       9.5 | 3.8389e-05 | 4.1667e-04 |        4104 |   106905600 |           16 |       38400 |        67.4 |reached max iterations
#      10.0 | 3.6294e-06 | 2.6042e-05 |         388 |   106905600 |            1 |       38400 |        67.3 |reached max iterations
#      10.5 | 9.3540e-09 | 2.6042e-05 |           1 |   106905600 |            1 |       38400 |        67.5 |reached max iterations
#      11.0 | 0.0000e+00 | 0.0000e+00 |           0 |   106905600 |            0 |       38400 |        67.2 |reached max iterations
#
# Simulation stopped as no error occurred @ EbNo = 11.0 dB.
#
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       0.0 | 2.8564e-01 | 1.0000e+00 |      152682 |      534528 |          128 |         128 |         0.4 |reached target block errors
#       0.5 | 2.7473e-01 | 1.0000e+00 |      146851 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.0 | 2.6272e-01 | 1.0000e+00 |      140433 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.5 | 2.5047e-01 | 1.0000e+00 |      133882 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.0 | 2.3764e-01 | 1.0000e+00 |      127025 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.5 | 2.2545e-01 | 1.0000e+00 |      120510 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       3.0 | 2.1437e-01 | 1.0000e+00 |      114586 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       3.5 | 1.9916e-01 | 1.0000e+00 |      106457 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       4.0 | 1.8748e-01 | 1.0000e+00 |      100213 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       4.5 | 1.6846e-01 | 1.0000e+00 |       90049 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       5.0 | 1.4948e-01 | 1.0000e+00 |       79903 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       5.5 | 1.1163e-01 | 1.0000e+00 |       59671 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       6.0 | 3.3504e-02 | 8.5938e-01 |       17909 |      534528 |          110 |         128 |         0.3 |reached target block errors
#       6.5 | 6.9265e-03 | 1.2835e-01 |       25917 |     3741696 |          115 |         896 |         2.1 |reached target block errors
#       7.0 | 2.2981e-03 | 3.0048e-02 |       31939 |    13897728 |          100 |        3328 |         7.8 |reached target block errors
#       7.5 | 2.3022e-03 | 2.1537e-02 |       45532 |    19777536 |          102 |        4736 |        11.1 |reached target block errors
#       8.0 | 1.4051e-03 | 1.2207e-02 |       48068 |    34209792 |          100 |        8192 |        18.9 |reached target block errors
#       8.5 | 7.7189e-04 | 6.6308e-03 |       49099 |    63608832 |          101 |       15232 |        35.1 |reached target block errors
#       9.0 | 5.0856e-04 | 5.2957e-03 |       40504 |    79644672 |          101 |       19072 |        44.0 |reached target block errors
#       9.5 | 2.6763e-04 | 3.2150e-03 |       34762 |   129890304 |          100 |       31104 |        71.6 |reached target block errors
#      10.0 | 1.0859e-04 | 2.1094e-03 |       17414 |   160358400 |           81 |       38400 |        88.0 |reached max iterations
#      10.5 | 1.8153e-05 | 4.9479e-04 |        2911 |   160358400 |           19 |       38400 |        88.9 |reached max iterations
#      11.0 | 4.9888e-08 | 2.6042e-05 |           8 |   160358400 |            1 |       38400 |        90.1 |reached max iterations
#      11.5 | 0.0000e+00 | 0.0000e+00 |           0 |   160358400 |            0 |       38400 |        89.5 |reached max iterations
#
# Simulation stopped as no error occurred @ EbNo = 11.5 dB.
#
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       0.0 | 3.3418e-01 | 1.0000e+00 |      178630 |      534528 |          128 |         128 |         0.5 |reached target block errors
#       0.5 | 3.2304e-01 | 1.0000e+00 |      172672 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.0 | 3.1561e-01 | 1.0000e+00 |      168702 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.5 | 3.0279e-01 | 1.0000e+00 |      161851 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.0 | 2.9349e-01 | 1.0000e+00 |      156876 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.5 | 2.8307e-01 | 1.0000e+00 |      151307 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       3.0 | 2.7223e-01 | 1.0000e+00 |      145514 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       3.5 | 2.6135e-01 | 1.0000e+00 |      139701 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       4.0 | 2.5263e-01 | 1.0000e+00 |      135038 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       4.5 | 2.4097e-01 | 1.0000e+00 |      128804 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       5.0 | 2.3270e-01 | 1.0000e+00 |      124384 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       5.5 | 2.2060e-01 | 1.0000e+00 |      117918 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       6.0 | 2.0896e-01 | 1.0000e+00 |      111697 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       6.5 | 1.9595e-01 | 1.0000e+00 |      104743 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       7.0 | 1.8390e-01 | 1.0000e+00 |       98298 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       7.5 | 1.6669e-01 | 1.0000e+00 |       89099 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       8.0 | 1.3861e-01 | 1.0000e+00 |       74089 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       8.5 | 7.1023e-02 | 9.2188e-01 |       37964 |      534528 |          118 |         128 |         0.3 |reached target block errors
#       9.0 | 1.2451e-02 | 3.5938e-01 |       19966 |     1603584 |          138 |         384 |         0.9 |reached target block errors
#       9.5 | 4.4607e-03 | 4.8713e-02 |       40534 |     9086976 |          106 |        2176 |         5.1 |reached target block errors
#      10.0 | 2.5590e-03 | 2.2545e-02 |       47875 |    18708480 |          101 |        4480 |        10.5 |reached target block errors
#      10.5 | 1.5811e-03 | 1.4489e-02 |       46482 |    29399040 |          102 |        7040 |        16.3 |reached target block errors
#      11.0 | 1.1914e-03 | 9.5068e-03 |       52859 |    44365824 |          101 |       10624 |        24.5 |reached target block errors
#      11.5 | 8.9903e-04 | 7.3703e-03 |       50939 |    56659968 |          100 |       13568 |        31.2 |reached target block errors
#      12.0 | 5.9261e-04 | 4.9316e-03 |       50683 |    85524480 |          101 |       20480 |        46.8 |reached target block errors
#      12.5 | 2.4231e-04 | 2.7221e-03 |       37172 |   153409536 |          100 |       36736 |        83.6 |reached target block errors
#      13.0 | 7.6323e-05 | 1.3021e-03 |       12239 |   160358400 |           50 |       38400 |        87.7 |reached max iterations
#      13.5 | 4.8454e-06 | 3.1250e-04 |         777 |   160358400 |           12 |       38400 |        87.3 |reached max iterations
#      14.0 | 1.8708e-07 | 2.6042e-05 |          30 |   160358400 |            1 |       38400 |        87.3 |reached max iterations
#      14.5 | 0.0000e+00 | 0.0000e+00 |           0 |   160358400 |            0 |       38400 |        87.3 |reached max iterations
#
# Simulation stopped as no error occurred @ EbNo = 14.5 dB.

# %% [markdown]
# ## Plot

# %%
ebno_db = tf.random.uniform(shape=[], minval=ebno_db_min, maxval=ebno_db_max)
ebno_db = tf.fill([batch_size], ebno_db)
print(tf.reduce_mean(ebno_db))
# Out:
# tf.Tensor(5.731632, shape=(), dtype=float32)

# %%
def load_weights(model, model_weights_path):
    model(1, tf.constant(10.0, tf.float32))
    with open(model_weights_path, 'rb') as f:
        weights = pickle.load(f)
    model.set_weights(weights)
    
# Load the model and weights
model = E2ESystem('neural-receiver', training=True, use_fec=True)
load_weights(model, "30000_SNRNF_alt_2stage_neural_receiver_model_weights.pkl")

# Get constellation points from mapper
c = binary_source([batch_size, 1, 1, n])
_, constellation_points = model._mapper(c, ebno_db, training=False)
constellation_points = constellation_points.numpy()  # Take first batch sample

# Plot
figsize = (7, 7)
maxval = np.max(np.abs(constellation_points)) * 1.05
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(111)
plt.xlim(-maxval, maxval)
plt.ylim(-maxval, maxval)
plt.scatter(np.real(constellation_points), np.imag(constellation_points))
ax.set_aspect("equal", adjustable="box")
plt.grid(True, which="both", axis="both")
plt.title("Trained Conditional Mapper Constellation")
plt.xlabel("Real Part")
plt.ylabel("Imaginary Part")
for j, p in enumerate(constellation_points):
    plt.annotate(
        np.binary_repr(j, num_bits_per_symbol),
        (np.real(p), np.imag(p))
    )
plt.show()

# %%
def load_weights(model, model_weights_path):
    model(1, tf.constant(10.0, tf.float32))
    with open(model_weights_path, 'rb') as f:
        weights = pickle.load(f)
    model.set_weights(weights)
    
# Load the model and weights
model = E2ESystem('neural-receiver', training=True, use_fec=True)
load_weights(model, "nf_neural_receiver_model_weights.pkl")

constellation_points = tf.complex(model.points_r, model.points_i).numpy()

figsize = (7, 7)
maxval = np.max(np.abs(constellation_points)) * 1.05

fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(111)
plt.xlim(-maxval, maxval)
plt.ylim(-maxval, maxval)
plt.scatter(np.real(constellation_points), np.imag(constellation_points))
ax.set_aspect("equal", adjustable="box")
plt.grid(True, which="both", axis="both")
plt.title("Trained mapper")
plt.xlabel("Real Part")
plt.ylabel("Imaginary Part")

for j, p in enumerate(constellation_points):
    plt.annotate(
        np.binary_repr(j, num_bits_per_symbol),
        (np.real(p), np.imag(p))
    )

plt.show()

# %%
def plot_multi_batch_constellations(model, c, num_batches_to_plot=4, num_bits_per_symbol=6):
    # Get constellation points for all batches
    _, constellation_points = model._mapper(c, ebno_db, training=False)
    constellation_points = constellation_points.numpy()  # [batch, 16]
    
    # Limit to num_batches_to_plot
    num_batches = min(num_batches_to_plot, constellation_points.shape[0])
    
    # Setup plot
    figsize = (8, 8)
    maxval = np.max(np.abs(constellation_points[num_batches:])) * 1.1
    fig, ax = plt.subplots(figsize=figsize)
    ax.set_xlim(-maxval, maxval)
    ax.set_ylim(-maxval, maxval)
    ax.set_aspect("equal", adjustable="box")
    ax.grid(True, which="both", axis="both")
    ax.axhline(y=0, color='k', linewidth=0.5)
    ax.axvline(x=0, color='k', linewidth=0.5)
    
    # Color map for different batches
    colors = plt.cm.tab10(np.linspace(0, 1, num_batches))
    
    # Plot each batch's constellation
    for batch_idx in range(num_batches):
        points = constellation_points[batch_idx]
        real_parts = np.real(points)
        imag_parts = np.imag(points)
        
        # Scatter plot for this batch
        ax.scatter(real_parts, imag_parts, 
                  c=[colors[batch_idx]], 
                  s=100,
                  alpha=0.7,
                  label=f'Batch {batch_idx}',
                  edgecolors='black',
                  linewidths=1)
        
        # Annotate with binary labels (only for first batch to avoid clutter)
        if batch_idx == 0:
            for j, p in enumerate(points):
                ax.annotate(
                    np.binary_repr(j, num_bits_per_symbol),
                    (np.real(p), np.imag(p)),
                    fontsize=8,
                    ha='right',
                    va='bottom'
                )
    
    ax.legend(loc='upper right')
    ax.set_xlabel("Real Part (I)")
    ax.set_ylabel("Imaginary Part (Q)")
    plt.tight_layout()
    plt.show()
    
    # for point_idx in range(2**num_bits_per_symbol):
    #     points_across_batches = constellation_points[:num_batches, point_idx]
    #     real_std = np.std(np.real(points_across_batches))
    #     imag_std = np.std(np.imag(points_across_batches))
        
    #     print(f"Point {np.binary_repr(point_idx, num_bits_per_symbol)}: "
    #           f"I_std={real_std:.4f}, Q_std={imag_std:.4f}")
    
    # # Overall variation metric
    # all_points = constellation_points[:num_batches].reshape(-1)
    # overall_std = np.std(all_points)
    # print(f"\nOverall constellation std: {overall_std:.4f}")
    # print(f"Max position difference: {np.max(np.abs(constellation_points[:num_batches] - constellation_points[0])):.4f}")

# Usage
load_weights(model, "neural_receiver_model_weights.pkl")
plot_multi_batch_constellations(model, c, num_batches_to_plot=11, num_bits_per_symbol=6)

# %%
with open('E2E_baseline_result', 'rb') as file: 
        ebno_dbs, BLER_base, BER_base = pickle.load(file)
with open('10000_qam_neural_receiver_model_result', 'rb') as file: 
        ebno_dbs, BLER_qam, BER_qam = pickle.load(file)
with open('10000_qam_2stage_neural_receiver_model_result', 'rb') as file: 
        ebno_dbs, BLER_2stqam, BER_2stqam = pickle.load(file)
with open('10000_SNRNF_neural_receiver_model_result', 'rb') as file: 
        ebno_dbs, BLER_snrnf, BER_snrnf = pickle.load(file)
with open('10000_SNRNF_2stage_neural_receiver_model_result', 'rb') as file: 
        ebno_dbs, BLER_2stsnrnf, BER_2stsnrnf = pickle.load(file)
with open('10000_SNRNF_2stage_const_neural_receiver_model_result', 'rb') as file: 
        ebno_dbs, BLER_const, BER_const = pickle.load(file)

with open('FiLM/30000_qam_multi_mod_eval_results.pkl', 'rb') as file:
    ebno_dbs, BLER_film, BER_film = pickle.load(file)

plt.figure(figsize=(10,6))
# Baseline - Perfect CSI
plt.semilogy(ebno_dbs, BLER_base['baseline-perfect-csi'], 'o-', c=f'C0', label=f'64QAM + Perfect CSI + stdDemapper')
# Baseline - LS Estimation
plt.semilogy(ebno_dbs, BLER_base['baseline-ls-estimation'], 'x--', c=f'C1', label=f'64QAM + LS Hest + stdDemapper')
# Neural receiver
plt.semilogy(ebno_dbs, BLER_qam['neural-receiver-standard'], 's-.', c=f'C2', label=f'64QAM + NR')
plt.semilogy(ebno_dbs, BLER_2stqam['neural-receiver-standard'], 's-.', c=f'C4', label=f'64QAM + v2-NR')
plt.semilogy(ebno_dbs, BLER_snrnf['neural-receiver-standard'], 's-.', c=f'C5', label=f'SNR-NF + NR')
plt.semilogy(ebno_dbs, BLER_2stsnrnf['neural-receiver-standard'], 's-.', c=f'C3', label=f'SNR-NF + v2-NR')
plt.semilogy(ebno_dbs, BLER_const['neural-receiver-standard'], 's-.', c=f'C6', label=f'SNR-NF + v2-const-NR')

plt.semilogy(ebno_dbs, BLER_film['neural-film-6bps'], 'D-', c='C9', label='64QAM + FiLM v2-NR')

plt.title('10000_iterations')
plt.xlabel(r"$E_b/N_0$ (dB)")
plt.ylabel("BLER")
plt.grid(which="both")
plt.ylim((1e-4, 1.0))
plt.xlim((5, 15))
plt.legend()
plt.tight_layout()

# %%
with open('E2E_baseline_result', 'rb') as file: 
        ebno_dbs, BLER_base, BER_base = pickle.load(file)
with open('30000_qam_neural_receiver_model_result', 'rb') as file: 
        ebno_dbs, BLER_qam, BER_qam = pickle.load(file)
with open('30000_qam_2stage_neural_receiver_model_result', 'rb') as file: 
        ebno_dbs, BLER_2stqam, BER_2stqam = pickle.load(file)
with open('30000_SNRNF_neural_receiver_model_result', 'rb') as file: 
        ebno_dbs, BLER_snrnf, BER_snrnf = pickle.load(file)
with open('30000_SNRNF_2stage_neural_receiver_model_result', 'rb') as file: 
        ebno_dbs, BLER_2stsnrnf, BER_2stsnrnf = pickle.load(file)
with open('30000_SNRNF_2stage_const_neural_receiver_model_result', 'rb') as file: 
        ebno_dbs, BLER_const, BER_const = pickle.load(file)
with open('30000_resNF_2stage_neural_receiver_model_result', 'rb') as file: 
        ebno_dbs, BLER_res, BER_res = pickle.load(file)

with open('iter_SNRNF_2stage_neural_receiver_model_result', 'rb') as file: 
        ebno_dbs, BLER_iter, BER_iter = pickle.load(file)
with open('iter_resNF_2stage_neural_receiver_model_result', 'rb') as file: 
        ebno_dbs, BLER_iterRES, BER_iterRES = pickle.load(file)

with open('FiLM/90000_qam_multi_mod_eval_results.pkl', 'rb') as file:
    ebno_dbs, BLER_film, BER_film = pickle.load(file)

plt.figure(figsize=(10,6))
# Baseline - Perfect CSI
plt.semilogy(ebno_dbs, BLER_base['baseline-perfect-csi'], 'o-', c=f'C0', label=f'QAM + Perfect CSI + stdDemapper')
# Baseline - LS Estimation
plt.semilogy(ebno_dbs, BLER_base['baseline-ls-estimation'], 'x--', c=f'C1', label=f'QAM + LS Hest + stdDemapper')
# Neural receiver
plt.semilogy(ebno_dbs, BLER_qam['neural-receiver-standard'], 's-.', c=f'C2', label=f'QAM + NR')
plt.semilogy(ebno_dbs, BLER_2stqam['neural-receiver-standard'], 's-.', c=f'C4', label=f'QAM + v2-NR')
# plt.semilogy(ebno_dbs, BLER_snrnf['neural-receiver-standard'], 's-.', c=f'C5', label=f'SNR-NF + NR')
# plt.semilogy(ebno_dbs, BLER_2stsnrnf['neural-receiver-standard'], 's-.', c=f'C3', label=f'SNR-NF + v2-NR')
# plt.semilogy(ebno_dbs, BLER_const['neural-receiver-standard'], 's-.', c=f'C9', label=f'SNR-NF + v2-const-NR')
# plt.semilogy(ebno_dbs, BLER_res['neural-receiver-standard'], 's-.', c=f'C6', label=f'Res-SNR-NF + v2-NR')
# plt.semilogy(ebno_dbs, BLER_iter['neural-receiver-standard'], 's-.', c=f'C7', label=f'Iter-SNR-NF + v2-NR')
# plt.semilogy(ebno_dbs, BLER_iterRES['neural-receiver-standard'], 's-.', c=f'C8', label=f'Iter-Res-SNR-NF + v2-NR')

plt.semilogy(ebno_dbs, BLER_film['neural-film-6bps'], 'D-', c='C8', label='64QAM + FiLM v2-NR')

plt.title('30000_iterations')
plt.xlabel(r"$E_b/N_0$ (dB)")
plt.ylabel("BLER")
plt.grid(which="both")
plt.ylim((1e-4, 1.0))
plt.xlim((5, 15))
plt.legend()
plt.tight_layout()

# %%
with open('baseline_multi_mod_eval_results.pkl', 'rb') as file: 
    ebno_dbs, BLER_base, BER_base = pickle.load(file)
with open('30000_qam_multi_mod_eval_results.pkl', 'rb') as file:
    ebno_dbs, BLER_film, BER_film = pickle.load(file)

MOD_LABELS = {2: 'QPSK', 4: '16QAM', 6: '64QAM'}
MOD_COLORS = {2: 'C2', 4: 'C3', 6: 'C4'}
MOD_MARKERS = {2: 's', 4: '^', 6: 'o'}

fig, axes = plt.subplots(3, 1, figsize=(12, 16), sharey=True)

for ax, nbps in zip(axes, MOD_ORDERS):
    label = MOD_LABELS[nbps]
    
    # Classical baselines
    ax.semilogy(ebno_dbs, BLER_base[f'baseline-perfect-csi-{nbps}bps'],   'o-',  c='C0', label='Perfect CSI')
    ax.semilogy(ebno_dbs, BLER_base[f'baseline-ls-estimation-{nbps}bps'], 'x--', c='C1', label='LS Estimation')
    
    # FiLM multi-mod receiver
    ax.semilogy(ebno_dbs, BLER_film[f'neural-film-{nbps}bps'],
                f'{MOD_MARKERS[nbps]}-.', c=MOD_COLORS[nbps], label=f'FiLM NR ({label})')

    ax.set_title(f'{label}')
    ax.set_xlabel(r"$E_b/N_0$ (dB)")
    ax.set_ylabel("BLER")
    ax.grid(which="both")
    ax.set_ylim((1e-4, 1.0))
    ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Finally, we plots the BLERs

# %%
with open('SISO_highco_coderate78', 'wb') as f:
    pickle.dump((ebno_dbs, BLER, BER), f)
with open('SISO_highco_uncoded', 'wb') as f:
    pickle.dump((ebno_dbs, BLER_uc, BER_uc), f)

# %%
with open('SISO_coderate78', 'rb') as file: 
        ebno_dbs, BLER_s, BER_s = pickle.load(file)
with open('SISO_uncoded', 'rb') as file: 
        ebno_dbs, BLER_uc_s, BER_uc_s = pickle.load(file)
# with open('SIMO_coderate78', 'rb') as file: 
#         ebno_dbs, BLER_m, BER_m = pickle.load(file)
# with open('SIMO_uncoded', 'rb') as file: 
#         ebno_dbs, BLER_uc_m, BER_uc_m = pickle.load(file)
with open('SISO_highco_coderate78', 'rb') as file: 
        ebno_dbs, BLER_c, BER_c = pickle.load(file)
with open('SISO_highco_uncoded', 'rb') as file: 
        ebno_dbs, BLER_uc_c, BER_uc_c = pickle.load(file)

# %%
plt.figure(figsize=(10,6))
# Baseline - Perfect CSI
# plt.semilogy(ebno_dbs, BER_s['baseline-perfect-csi'], 'o-', c=f'C0', label=f'coderate78 - Perfect CSI')
# # Baseline - LS Estimation
# plt.semilogy(ebno_dbs, BER_s['baseline-ls-estimation'], 'x--', c=f'C1', label=f'coderate78 - LS Estimation')

# plt.semilogy(ebno_dbs, BER_uc_s['baseline-perfect-csi'], 'o-', c=f'C4', label=f'uncoded - Perfect CSI')
# plt.semilogy(ebno_dbs, BER_uc_s['baseline-ls-estimation'], 'x--', c=f'C5', label=f'uncoded - LS Estimation')

plt.semilogy(ebno_dbs, BER_c['baseline-perfect-csi'], 'o-', c=f'C2', label=f'highco - Perfect CSI')
plt.semilogy(ebno_dbs, BER_c['baseline-ls-estimation'], 'x--', c=f'C3', label=f'highco - LS Estimation')
# plt.semilogy(ebno_dbs, BER_uc_c['baseline-perfect-csi'], 'o-', c=f'C6', label=f'uncoded-highco - Perfect CSI')
# plt.semilogy(ebno_dbs, BER_uc_c['baseline-ls-estimation'], 'x--', c=f'C7', label=f'uncoded-highco - LS Estimation')

# Neural receiver
# plt.semilogy(ebno_dbs, BLER['neural-receiver'], 's-.', c=f'C2', label=f'Neural receiver')
#
plt.xlabel(r"$E_b/N_0$ (dB)")
plt.ylabel("BER")
plt.grid(which="both")
# plt.ylim((1e-5, 1.0))
plt.xlim((0, 10))
plt.legend()
plt.tight_layout()

# %% [markdown]
# ## References <a class="anchor" id="References"></a>

# %% [markdown]
# [1] M. Honkala, D. Korpi and J. M. J. Huttunen, "DeepRx: Fully Convolutional Deep Learning Receiver," in IEEE Transactions on Wireless Communications, vol. 20, no. 6, pp. 3925-3940, June 2021, doi: 10.1109/TWC.2021.3054520.
#
# [2] F. Ait Aoudia and J. Hoydis, "End-to-end Learning for OFDM: From Neural Receivers to Pilotless Communication," in IEEE Transactions on Wireless Communications, doi: 10.1109/TWC.2021.3101364.
#
# [3] Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun, "Deep Residual Learning for Image Recognition", Proceedings of the IEEE Conference on Computer Vision and Pattern Recognition (CVPR), 2016, pp. 770-778
#
# [4] G. Böcherer, "Achievable Rates for Probabilistic Shaping", arXiv:1707.01134, 2017.
