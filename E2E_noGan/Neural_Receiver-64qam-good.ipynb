# %% [markdown]
# # Neural Receiver for OFDM SIMO Systems

# %% [markdown]
# In this notebook, you will learn how to train a neural receiver that implements OFDM detection.
# The considered setup is shown in the figure below.
# As one can see, the neural receiver substitutes channel estimation, equalization, and demapping.
# It takes as input the post-DFT (discrete Fourier transform) received samples, which form the received resource grid, and computes log-likelihood ratios (LLRs) on the transmitted coded bits.
# These LLRs are then fed to the outer decoder to reconstruct the transmitted information bits.

# %% [markdown]
# ![System Model](data:image/png;base64,...)

# %% [markdown]
# Two baselines are considered for benchmarking, which are shown in the figure above.
# Both baselines use linear minimum mean square error (LMMSE) equalization and demapping assuming additive white Gaussian noise (AWGN).
# They differ by how channel estimation is performed:
#
# - **Pefect CSI**: Perfect channel state information (CSI) knowledge is assumed.
# - **LS estimation**: Uses the transmitted pilots to perform least squares (LS) estimation of the channel with nearest-neighbor interpolation.
#
# All the considered end-to-end systems use an LDPC outer code from the 5G NR specification, QPSK modulation, and a 3GPP CDL channel model simulated in the frequency domain.

# %% [markdown]
# * [GPU Configuration and Imports](#GPU-Configuration-and-Imports)
# * [Simulation Parameters](#Simulation-Parameters)
# * [Neural Receiver](#Neural-Receiver)
# * [End-to-end System](#End-to-end-System)
# * [End-to-end System as a Keras Model](#End-to-end-System-as-a-Keras-Model)
# * [Evaluation of the Baselines](#Evaluation-of-the-Baselines)
# * [Training the Neural Receiver](#Training-the-Neural-Receiver)
# * [Evaluation of the Neural Receiver](#Evaluation-of-the-Neural-Receiver)
# * [Pre-computed Results](#Pre-computed-Results)
# * [References](#References)

# %% [markdown]
# ## GPU Configuration and Imports <a class="anchor" id="GPU-Configuration-and-Imports"></a>

# %%
import os
import tensorflow as tf
import sys
print(sys.version)
print(sys.executable)
print(sys.version_info)

gpu_num = 0 # Use "" to use the CPU
os.environ["CUDA_VISIBLE_DEVICES"] = f"{gpu_num}"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# Configure the notebook to use only a single GPU and allocate only as much memory as needed
# For more details, see https://www.tensorflow.org/guide/gpu
gpus = tf.config.list_physical_devices('GPU')
print(gpus)

if gpus:
    try:
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e:
        print("Error loading GPU:", e)
# Avoid warnings from TensorFlow
tf.get_logger().setLevel('ERROR')
# Out:
# 2024-12-09 23:44:58.076523: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-09 23:44:59.157714: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-09 23:44:59.157786: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-09 23:44:59.404911: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-09 23:44:59.855785: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-09 23:45:01.940187: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 3.11.4 (main, Jul  5 2023, 13:45:01) [GCC 11.2.0]
# /home/ubuntu/miniconda3/bin/python
# sys.version_info(major=3, minor=11, micro=4, releaselevel='final', serial=0)
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-12-09 23:45:06.560963: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-09 23:45:07.193609: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-09 23:45:07.195761: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
# Import Sionna
try:
    import sionna
except ImportError as e:
    # Install Sionna if package is not already installed
    import os
    os.system("pip install sionna")
    import sionna

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pickle

from tensorflow.keras import Model
from tensorflow.keras.layers import Layer, Conv2D, LayerNormalization, Dense, ReLU
from tensorflow.nn import relu

from sionna.channel.tr38901 import Antenna, AntennaArray, CDL
from sionna.channel import OFDMChannel
from sionna.mimo import StreamManagement
from sionna.ofdm import ResourceGrid, ResourceGridMapper, LSChannelEstimator, LMMSEEqualizer, RemoveNulledSubcarriers, ResourceGridDemapper
from sionna.utils import BinarySource, ebnodb2no, insert_dims, flatten_last_dims, log10, expand_to_rank
from sionna.fec.ldpc.encoding import LDPC5GEncoder
from sionna.fec.ldpc.decoding import LDPC5GDecoder
from sionna.mapping import Mapper, Demapper, Constellation
from sionna.utils.metrics import compute_ber
from sionna.utils import sim_ber, hard_decisions

# %% [markdown]
# ## Simulation Parameters <a class="anchor" id="Simulation-Parameters"></a>

# %%
############################################
## Channel configuration
carrier_frequency = 3.5e9 # Hz
delay_spread = 100e-9 # s
cdl_model = "C" # CDL model to use
speed = 10.0 # Speed for evaluation and training [m/s]
# SNR range for evaluation and training [dB]
ebno_db_min = 0.0
ebno_db_max = 10.0

############################################
## OFDM waveform configuration
subcarrier_spacing = 30e3 # Hz
fft_size = 128 # Number of subcarriers forming the resource grid, including the null-subcarrier and the guard bands
num_ofdm_symbols = 14 # Number of OFDM symbols forming the resource grid
dc_null = True # Null the DC subcarrier
num_guard_carriers = [5, 6] # Number of guard carriers on each side
pilot_pattern = "kronecker" # Pilot pattern
pilot_ofdm_symbol_indices = [2, 11] # Index of OFDM symbols carrying pilots
cyclic_prefix_length = 0 # Simulation in frequency domain. This is useless

############################################
## Modulation and coding configuration
num_bits_per_symbol = 6 # 64-QAM
coderate = 0.5 # Coderate for LDPC code

############################################
## Neural receiver configuration
num_conv_channels = 128 # Number of convolutional channels for the convolutional layers forming the neural receiver

############################################
## Training configuration
num_training_iterations = 50000 # Number of training iterations
training_batch_size = 128 # Training batch size
model_weights_path_standard = "neural_receiver_weights_standard" # Location to save the neural receiver weights once training is done
model_weights_path_trained = "neural_receiver_weights_trained"

############################################
## Evaluation configuration
results_filename = "neural_receiver_results" # Location to save the results

# %% [markdown]
# The `StreamManagement` class is used to configure the receiver-transmitter association and the number of streams per transmitter.
# A SIMO system is considered, with a single transmitter equipped with a single non-polarized antenna.
# Therefore, there is only a single stream, and the receiver-transmitter association matrix is $[1]$.
# The receiver is equipped with an antenna array.

# %%
stream_manager = StreamManagement(np.array([[1]]), # Receiver-transmitter association matrix
                                  1)               # One stream per transmitter

# %% [markdown]
# The `ResourceGrid` class is used to configure the OFDM resource grid. It is initialized with the parameters defined above.

# %%
resource_grid = ResourceGrid(num_ofdm_symbols = num_ofdm_symbols,
                             fft_size = fft_size,
                             subcarrier_spacing = subcarrier_spacing,
                             num_tx = 1,
                             num_streams_per_tx = 1,
                             cyclic_prefix_length = cyclic_prefix_length,
                             dc_null = dc_null,
                             pilot_pattern = pilot_pattern,
                             pilot_ofdm_symbol_indices = pilot_ofdm_symbol_indices,
                             num_guard_carriers = num_guard_carriers)
# Out:
# 2024-12-09 23:45:09.233445: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-09 23:45:09.235274: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-09 23:45:09.236814: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-09 23:45:09.248379: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-09 23:45:09.249930: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-09 23:45:09.251458: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-12-09 23:45:09.252956: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13743 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5
# 2024-12-09 23:45:09.824406: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory

# %% [markdown]
# Outer coding is performed such that all the databits carried by the resource grid with size `fft_size`x`num_ofdm_symbols` form a single codeword.

# %%
# Codeword length. It is calculated from the total number of databits carried by the resource grid, and the number of bits transmitted per resource element
# data symbols = 1392
n = int(resource_grid.num_data_symbols*num_bits_per_symbol)
# Number of information bits per codeword
k = int(n*coderate)
print(n)
print(k)
# Out:
# 8352
# 4176

# %% [markdown]
# The SIMO link is setup by considering an uplink transmission with one user terminal (UT) equipped with a single non-polarized antenna, and a base station (BS) equipped with an antenna array.
# One can try other configurations for the BS antenna array.

# %%
ut_antenna = Antenna(polarization="single",
                     polarization_type="V",
                     antenna_pattern="38.901",
                     carrier_frequency=carrier_frequency)

bs_array = AntennaArray(num_rows=1,
                        num_cols=1,
                        polarization="dual",
                        polarization_type="VH",
                        antenna_pattern="38.901",
                        carrier_frequency=carrier_frequency)

# %% [markdown]
# ## Neural Receiver <a class="anchor" id="Neural-Receiver"></a>

# %% [markdown]
# The next cell defines the Keras layers that implement the neural receiver.
# As in [1] and [2], a neural receiver using residual convolutional layers is implemented. Convolutional layers are leveraged to efficienly process the 2D resource grid, that is fed as an input to the neural receiver.
# Residual (skip) connections are used to avoid gradient vanishing [3].
#
# For convinience, a Keras layer that implements a *residual block* is first defined. The Keras layer that implements the neural receiver is built by stacking such blocks. The following figure shows the architecture of the neural receiver.

# %% [markdown]
# ![Neural RX](data:image/png;base64,...)

# %%
class ResidualBlock(Layer):
    r"""
    This Keras layer implements a convolutional residual block made of two convolutional layers with ReLU activation, layer normalization, and a skip connection.
    The number of convolutional channels of the input must match the number of kernel of the convolutional layers ``num_conv_channel`` for the skip connection to work.

    Input
    ------
    : [batch size, num time samples, num subcarriers, num_conv_channel], tf.float
        Input of the layer

    Output
    -------
    : [batch size, num time samples, num subcarriers, num_conv_channel], tf.float
        Output of the layer
    """

    def build(self, input_shape):

        # Layer normalization is done over the last three dimensions: time, frequency, conv 'channels'
        self._layer_norm_1 = LayerNormalization(axis=(-1, -2, -3))
        self._conv_1 = Conv2D(filters=num_conv_channels,
                              kernel_size=[3,3],
                              padding='same',
                              activation=None)
        # Layer normalization is done over the last three dimensions: time, frequency, conv 'channels'
        self._layer_norm_2 = LayerNormalization(axis=(-1, -2, -3))
        self._conv_2 = Conv2D(filters=num_conv_channels,
                              kernel_size=[3,3],
                              padding='same',
                              activation=None)

    def call(self, inputs):
        z = self._layer_norm_1(inputs)
        z = relu(z)
        z = self._conv_1(z)
        z = self._layer_norm_2(z)
        z = relu(z)
        z = self._conv_2(z) # [batch size, num time samples, num subcarriers, num_channels]
        # Skip connection
        z = z + inputs

        return z

class NeuralReceiver(Layer):
    r"""
    Keras layer implementing a residual convolutional neural receiver.

    This neural receiver is fed with the post-DFT received samples, forming a resource grid of size num_of_symbols x fft_size, and computes LLRs on the transmitted coded bits.
    These LLRs can then be fed to an outer decoder to reconstruct the information bits.

    As the neural receiver is fed with the entire resource grid, including the guard bands and pilots, it also computes LLRs for these resource elements.
    They must be discarded to only keep the LLRs corresponding to the data-carrying resource elements.

    Input
    ------
    y : [batch size, num rx antenna, num ofdm symbols, num subcarriers], tf.complex
        Received post-DFT samples.

    no : [batch size], tf.float32
        Noise variance. At training, a different noise variance value is sampled for each batch example.

    Output
    -------
    : [batch size, num ofdm symbols, num subcarriers, num_bits_per_symbol]
        LLRs on the transmitted bits.
        LLRs computed for resource elements not carrying data (pilots, guard bands...) must be discarded.
    """

    def build(self, input_shape):

        # Input convolution
        self._input_conv = Conv2D(filters=num_conv_channels,
                                  kernel_size=[3,3],
                                  padding='same',
                                  activation=None)
        # Residual blocks
        self._res_block_1 = ResidualBlock()
        self._res_block_2 = ResidualBlock()
        self._res_block_3 = ResidualBlock()
        self._res_block_4 = ResidualBlock()
        # Output conv
        self._output_conv = Conv2D(filters=num_bits_per_symbol,
                                   kernel_size=[3,3],
                                   padding='same',
                                   activation=None)

    def call(self, inputs):
        y, no = inputs

        # Feeding the noise power in log10 scale helps with the performance
        no = log10(no)

        # Stacking the real and imaginary components of the different antennas along the 'channel' dimension
        y = tf.transpose(y, [0, 2, 3, 1]) # Putting antenna dimension last
        no = insert_dims(no, 3, 1)
        no = tf.tile(no, [1, y.shape[1], y.shape[2], 1])
        # z : [batch size, num ofdm symbols, num subcarriers, 2*num rx antenna + 1]
        z = tf.concat([tf.math.real(y),
                       tf.math.imag(y),
                       no], axis=-1)
        # Input conv
        z = self._input_conv(z)
        # Residual blocks
        z = self._res_block_1(z)
        z = self._res_block_2(z)
        z = self._res_block_3(z)
        z = self._res_block_4(z)
        # Output conv
        z = self._output_conv(z)

        return z

# %% [markdown]
# ## End-to-end System <a class="anchor" id="End-to-end-System"></a>

# %% [markdown]
# The following cell defines the end-to-end system.
#
# Training is done on the bit-metric decoding (BMD) rate which is computed from the transmitted bits and LLRs:
#
# \begin{equation}
# R = 1 - \frac{1}{SNMK} \sum_{s = 0}^{S-1} \sum_{n = 0}^{N-1} \sum_{m = 0}^{M-1} \sum_{k = 0}^{K-1} \texttt{BCE} \left( B_{s,n,m,k}, \texttt{LLR}_{s,n,m,k} \right)
# \end{equation}
#
# where
#
# * $S$ is the batch size
# * $N$ the number of subcarriers
# * $M$ the number of OFDM symbols
# * $K$ the number of bits per symbol
# * $B_{s,n,m,k}$ the $k^{th}$ coded bit transmitted on the resource element $(n,m)$ and for the $s^{th}$ batch example
# * $\texttt{LLR}_{s,n,m,k}$ the LLR (logit) computed by the neural receiver corresponding to the $k^{th}$ coded bit transmitted on the resource element $(n,m)$ and for the $s^{th}$ batch example
# * $\texttt{BCE} \left( \cdot, \cdot \right)$ the binary cross-entropy in log base 2
#
# Because no outer code is required at training, the outer encoder and decoder are not used at training to reduce computational complexity.
#
# The BMD rate is known to be an achievable information rate for BICM systems, which motivates its used as objective function [4].

# %%
## Transmitter
binary_source = BinarySource(seed=1)
# mapper = Mapper("qam", num_bits_per_symbol)
# rg_mapper = ResourceGridMapper(resource_grid)

constellation = Constellation("qam", num_bits_per_symbol, trainable=True)
mapper = Mapper(constellation=constellation)
rg_mapper = ResourceGridMapper(resource_grid)

## Channel
cdl = CDL(cdl_model, delay_spread, carrier_frequency,
          ut_antenna, bs_array, "uplink", min_speed=speed)
channel = OFDMChannel(cdl, resource_grid, normalize_channel=True, return_channel=True)

## Receiver
neural_receiver = NeuralReceiver()
rg_demapper = ResourceGridDemapper(resource_grid, stream_manager) # Used to extract data-carrying resource elements

# %% [markdown]
# The following cell performs one forward step through the end-to-end system:

# %%
batch_size = 128
ebno_db = tf.fill([batch_size], 5.0)
no = ebnodb2no(ebno_db, num_bits_per_symbol, coderate)

## Transmitter
# Generate codewords
c = binary_source([batch_size, 1, 1, n])
# print(c.numpy())
print("c shape: ", c.shape)

# Map bits to QAM symbols
x = mapper(c)
# print(x.numpy())
print("x shape: ", x.shape)

# Map the QAM symbols to a resource grid
x_rg = rg_mapper(x)
# print(x_rg.numpy())
print("x_rg shape: ", x_rg.shape)

######################################
## Channel
# A batch of new channel realizations is sampled and applied at every inference
no_ = expand_to_rank(no, tf.rank(x_rg))
y,_ = channel([x_rg, no_])
print("y shape: ", y.shape)

######################################
## Receiver
# The neural receover computes LLRs from the frequency domain received symbols and N0
y = tf.squeeze(y, axis=1)
llr = neural_receiver([y, no])
print("llr shape: ", llr.shape)
# Reshape the input to fit what the resource grid demapper is expected
llr = insert_dims(llr, 2, 1)
# Extract data-carrying resource elements. The other LLRs are discarded
llr = rg_demapper(llr)
llr = tf.reshape(llr, [batch_size, 1, 1, n])
print("Post RG-demapper LLRs: ", llr.shape)
# Out:
# c shape:  (128, 1, 1, 8352)
# x shape:  (128, 1, 1, 1392)
# x_rg shape:  (128, 1, 1, 14, 128)
# y shape:  (128, 1, 2, 14, 128)
# 2024-12-09 23:45:13.297851: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-12-09 23:45:13.877098: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# llr shape:  (128, 14, 128, 6)
# Post RG-demapper LLRs:  (128, 1, 1, 8352)

# %% [markdown]
# The BMD rate is computed from the LLRs and transmitted bits as follows:

# %%
bce = tf.nn.sigmoid_cross_entropy_with_logits(c, llr)
bce = tf.reduce_mean(bce)
rate = tf.constant(1.0, tf.float32) - bce/tf.math.log(2.)
print(f"Rate: {rate:.2E} bit")
# Out:
# Rate: -4.11E-01 bit

# %% [markdown]
# The rate is very poor (negative values means 0 bit) as the neural receiver is not trained.

# %% [markdown]
# ## End-to-end System as a Keras Model <a class="anchor" id="End-to-end-System-as-a-Keras-Model"></a>

# %% [markdown]
# The following Keras *Model* implements the three considered end-to-end systems (perfect CSI baseline, LS estimation baseline, and neural receiver).
#
# When instantiating the Keras model, the parameter ``system`` is used to specify the system to setup, and the parameter ``training`` is used to specified if the system is instantiated to be trained or to be evaluated. The ``training`` parameter is only relevant when the neural receiver is used.
#
# At each call of this model:
#
# * A batch of codewords is randomly sampled, modulated, and mapped to resource grids to form the channel inputs
# * A batch of channel realizations is randomly sampled and applied to the channel inputs
# * The receiver is executed on the post-DFT received samples to compute LLRs on the coded bits.
#   Which receiver is executed (baseline with perfect CSI knowledge, baseline with LS estimation, or neural receiver) depends on the specified ``system`` parameter.
# * If not training, the outer decoder is applied to reconstruct the information bits
# * If training, the BMD rate is estimated over the batch from the LLRs and the transmitted bits

# %%
class E2ESystem(Model):
    r"""
    Keras model that implements the end-to-end systems.

    As the three considered end-to-end systems (perfect CSI baseline, LS estimation baseline, and neural receiver) share most of
    the link components (transmitter, channel model, outer code...), they are implemented using the same Keras model.

    When instantiating the Keras model, the parameter ``system`` is used to specify the system to setup,
    and the parameter ``training`` is used to specified if the system is instantiated to be trained or to be evaluated.
    The ``training`` parameter is only relevant when the neural

    At each call of this model:
    * A batch of codewords is randomly sampled, modulated, and mapped to resource grids to form the channel inputs
    * A batch of channel realizations is randomly sampled and applied to the channel inputs
    * The receiver is executed on the post-DFT received samples to compute LLRs on the coded bits.
      Which receiver is executed (baseline with perfect CSI knowledge, baseline with LS estimation, or neural receiver) depends
      on the specified ``system`` parameter.
    * If not training, the outer decoder is applied to reconstruct the information bits
    * If training, the BMD rate is estimated over the batch from the LLRs and the transmitted bits

    Parameters
    -----------
    system : str
        Specify the receiver to use. Should be one of 'baseline-perfect-csi', 'baseline-ls-estimation' or 'neural-receiverstandard' or 'neural-receiver-trained'

    training : bool
        Set to `True` if the system is instantiated to be trained. Set to `False` otherwise. Defaults to `False`.
        If the system is instantiated to be trained, the outer encoder and decoder are not instantiated as they are not required for training.
        This significantly reduces the computational complexity of training.
        If training, the bit-metric decoding (BMD) rate is computed from the transmitted bits and the LLRs. The BMD rate is known to be
        an achievable information rate for BICM systems, and therefore training of the neural receiver aims at maximizing this rate.

    Input
    ------
    batch_size : int
        Batch size

    no : scalar or [batch_size], tf.float
        Noise variance.
        At training, a different noise variance should be sampled for each batch example.

    Output
    -------
    If ``training`` is set to `True`, then the output is a single scalar, which is an estimation of the BMD rate computed over the batch. It
    should be used as objective for training.
    If ``training`` is set to `False`, the transmitted information bits and their reconstruction on the receiver side are returned to
    compute the block/bit error rate.
    """

    def __init__(self, system, training=False):
        super().__init__()
        self._system = system
        self._training = training

        ######################################
        ## Transmitter
        self._binary_source = BinarySource(seed=4)
        # To reduce the computational complexity of training, the outer code is not used when training,
        # as it is not required
        if not training:
            self._encoder = LDPC5GEncoder(k, n)

        if system == 'neural-receiver-trained':
            # Trainable constellation
            constellation = Constellation("qam", num_bits_per_symbol, trainable=True)
            self.constellation = constellation
            self._mapper = Mapper(constellation=constellation)
            self._rg_mapper = ResourceGridMapper(resource_grid)
            
        else:
            self._mapper = Mapper("qam", num_bits_per_symbol)
            self._rg_mapper = ResourceGridMapper(resource_grid)

        ######################################
        ## Channel
        # A 3GPP CDL channel model is used
        cdl = CDL(cdl_model, delay_spread, carrier_frequency,
                  ut_antenna, bs_array, "uplink", min_speed=speed)
        self._channel = OFDMChannel(cdl, resource_grid, normalize_channel=True, return_channel=True)

        ######################################
        ## Receiver
        # Three options for the receiver depending on the value of `system`
        if "baseline" in system:
            
            if system == 'baseline-perfect-csi': # Perfect CSI
                self._removed_null_subc = RemoveNulledSubcarriers(resource_grid)
                
            elif system == 'baseline-ls-estimation': # LS estimation
                self._ls_est = LSChannelEstimator(resource_grid, interpolation_type="nn")
            # Components required by both baselines
            self._lmmse_equ = LMMSEEqualizer(resource_grid, stream_manager, )
            self._demapper = Demapper("app", "qam", num_bits_per_symbol)
            
        elif "neural-receiver" in system: # Neural receiver
            self._neural_receiver = NeuralReceiver()
            self._rg_demapper = ResourceGridDemapper(resource_grid, stream_manager) # Used to extract data-carrying resource elements
            
        # To reduce the computational complexity of training, the outer code is not used when training,
        # as it is not required
        if not training:
            self._decoder = LDPC5GDecoder(self._encoder, hard_out=True)

    @tf.function
    def call(self, batch_size, ebno_db):

        # If `ebno_db` is a scalar, a tensor with shape [batch size] is created as it is what is expected by some layers
        if len(ebno_db.shape) == 0:
            ebno_db = tf.fill([batch_size], ebno_db)

        ######################################
        ## Transmitter
        no = ebnodb2no(ebno_db, num_bits_per_symbol, coderate)
        
        # Outer coding is only performed if not training
        if self._training:
            c = self._binary_source([batch_size, 1, 1, n])
        else:
            b = self._binary_source([batch_size, 1, 1, k])
            c = self._encoder(b)
        
        # c = self._binary_source([batch_size, 1, 1, n]) # for uncoded simulation
        
        # Modulation
        x = self._mapper(c)
        x_rg = self._rg_mapper(x)

        ######################################
        ## Channel
        # A batch of new channel realizations is sampled and applied at every inference
        no_ = expand_to_rank(no, tf.rank(x_rg))
        y,h = self._channel([x_rg, no_])

        ######################################
        ## Receiver
        # Three options for the receiver depending on the value of ``system``
        if "baseline" in self._system:
            
            if self._system == 'baseline-perfect-csi':
                h_hat = self._removed_null_subc(h) # Extract non-null subcarriers
                err_var = 0.0 # No channel estimation error when perfect CSI knowledge is assumed
                
            elif self._system == 'baseline-ls-estimation':
                h_hat, err_var = self._ls_est([y, no]) # LS channel estimation with nearest-neighbor
                
            x_hat, no_eff = self._lmmse_equ([y, h_hat, err_var, no]) # LMMSE equalization
            no_eff_= expand_to_rank(no_eff, tf.rank(x_hat))
            llr = self._demapper([x_hat, no_eff_]) # Demapping
            
        elif "neural-receiver" in self._system:
            # The neural receover computes LLRs from the frequency domain received symbols and N0
            y = tf.squeeze(y, axis=1)
            llr = self._neural_receiver([y, no])
            llr = insert_dims(llr, 2, 1) # Reshape the input to fit what the resource grid demapper is expected
            llr = self._rg_demapper(llr) # Extract data-carrying resource elements. The other LLrs are discarded
            llr = tf.reshape(llr, [batch_size, 1, 1, n]) # Reshape the LLRs to fit what the outer decoder is expected

        # Outer coding is not needed if the information rate is returned
        if self._training:
            # Compute and return BMD rate (in bit), which is known to be an achievable
            # information rate for BICM systems.
            # Training aims at maximizing the BMD rate
            bce = tf.nn.sigmoid_cross_entropy_with_logits(c, llr)
            bce = tf.reduce_mean(bce)
            rate = tf.constant(1.0, tf.float32) - bce/tf.math.log(2.)
            return rate
        else:
            # Outer decoding
            b_hat = self._decoder(llr)
            return b,b_hat
            
            # probabilities = tf.math.sigmoid(llr)
            # b_hat = tf.cast(probabilities > 0.5, dtype=tf.float32) # 0.5-1 is False=bit 0; 0-0.5 is True=bit 1 
            # return c,b_hat # Ground truth and reconstructed information bits returned for BER/BLER computation

# %% [markdown]
# ## Evaluation of the Baselines <a class="anchor" id="Evaluation-of-the-Baselines"></a>

# %% [markdown]
# We evaluate the BERs achieved by the baselines in the next cell.
#
# **Note:** Evaluation of the two systems can take a while. Therefore, we provide pre-computed results at the end of this notebook.

# %%
# Range of SNRs over which the systems are evaluated
ebno_dbs = np.arange(ebno_db_min, # Min SNR for evaluation
                     ebno_db_max, # Max SNR for evaluation
                     0.5) # Step

# Dictionnary storing the evaluation results
BLER = {}
BER = {}

# %%
model = E2ESystem('baseline-perfect-csi')
ber,bler = sim_ber(model, ebno_dbs, batch_size=128, num_target_block_errors=100, max_mc_iter=3000)
BLER['baseline-perfect-csi'] = bler.numpy()
BER['baseline-perfect-csi'] = ber.numpy()

model = E2ESystem('baseline-ls-estimation')
ber,bler = sim_ber(model, ebno_dbs, batch_size=128, num_target_block_errors=100, max_mc_iter=3000)
BLER['baseline-ls-estimation'] = bler.numpy()
BER['baseline-ls-estimation'] = ber.numpy()

with open("baseline_results_3000", 'wb') as f:
    pickle.dump((ebno_dbs, BLER, BER), f)
# Out:
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       0.0 | 2.0684e-01 | 1.0000e+00 |      110562 |      534528 |          128 |         128 |         5.2 |reached target block errors
#       0.5 | 1.9112e-01 | 1.0000e+00 |      102160 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.0 | 1.7470e-01 | 1.0000e+00 |       93384 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.5 | 1.5496e-01 | 1.0000e+00 |       82828 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.0 | 1.1986e-01 | 1.0000e+00 |       64071 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.5 | 5.3485e-02 | 1.0000e+00 |       28589 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       3.0 | 2.9203e-03 | 2.7344e-01 |        4683 |     1603584 |          105 |         384 |         0.8 |reached target block errors
#       3.5 | 2.3733e-04 | 8.0492e-03 |       12559 |    52918272 |          102 |       12672 |        25.3 |reached target block errors
#       4.0 | 7.9830e-05 | 1.4335e-03 |       23256 |   291317760 |          100 |       69760 |       139.3 |reached target block errors
#       4.5 | 2.1688e-05 | 4.1358e-04 |       21899 |  1009723392 |          100 |      241792 |       485.1 |reached target block errors
#       5.0 | 6.8628e-06 | 1.3802e-04 |       11005 |  1603584000 |           53 |      384000 |       766.9 |reached max iter
#       5.5 | 4.2654e-06 | 8.3333e-05 |        6840 |  1603584000 |           32 |      384000 |       767.3 |reached max iter
#       6.0 | 6.7599e-07 | 7.8125e-06 |        1084 |  1603584000 |            3 |      384000 |       767.4 |reached max iter
#       6.5 | 4.0659e-07 | 7.8125e-06 |         652 |  1603584000 |            3 |      384000 |       769.8 |reached max iter
#       7.0 | 0.0000e+00 | 0.0000e+00 |           0 |  1603584000 |            0 |      384000 |       777.5 |reached max iter
#
# Simulation stopped as no error occurred @ EbNo = 7.0 dB.
#
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       0.0 | 2.9022e-01 | 1.0000e+00 |      155131 |      534528 |          128 |         128 |         5.6 |reached target block errors
#       0.5 | 2.7855e-01 | 1.0000e+00 |      148891 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.0 | 2.6358e-01 | 1.0000e+00 |      140890 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.5 | 2.5118e-01 | 1.0000e+00 |      134265 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.0 | 2.3769e-01 | 1.0000e+00 |      127054 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.5 | 2.2264e-01 | 1.0000e+00 |      119007 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       3.0 | 2.0811e-01 | 1.0000e+00 |      111242 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       3.5 | 1.9397e-01 | 1.0000e+00 |      103682 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       4.0 | 1.7592e-01 | 1.0000e+00 |       94036 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       4.5 | 1.5499e-01 | 1.0000e+00 |       82844 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       5.0 | 1.2630e-01 | 1.0000e+00 |       67513 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       5.5 | 6.3254e-02 | 9.8438e-01 |       33811 |      534528 |          126 |         128 |         0.3 |reached target block errors
#       6.0 | 1.1326e-02 | 4.4531e-01 |       12108 |     1069056 |          114 |         256 |         0.5 |reached target block errors
#       6.5 | 5.2501e-04 | 1.9055e-02 |       11506 |    21915648 |          100 |        5248 |        10.6 |reached target block errors
#       7.0 | 1.4018e-04 | 2.5955e-03 |       22554 |   160892928 |          100 |       38528 |        77.5 |reached target block errors
#       7.5 | 6.0818e-05 | 7.8755e-04 |       32249 |   530251776 |          100 |      126976 |       255.2 |reached target block errors
#       8.0 | 2.2781e-05 | 3.0328e-04 |       31368 |  1376944128 |          100 |      329728 |       662.8 |reached target block errors
#       8.5 | 1.0940e-05 | 1.4583e-04 |       17543 |  1603584000 |           56 |      384000 |       768.0 |reached max iter
#       9.0 | 4.7550e-06 | 5.9896e-05 |        7625 |  1603584000 |           23 |      384000 |       766.1 |reached max iter
#       9.5 | 1.5247e-06 | 3.3854e-05 |        2445 |  1603584000 |           13 |      384000 |       766.7 |reached max iter

# %%
folders = ['baseline_results_3000', 'baseline_results_6000', 'baseline_results_9000', 'baseline_results_12000']
colors = ['C0', 'C1', 'C2', 'C3']
linestyles = [':', ':', '-.', '-.', '-.']  

plt.figure(figsize=(10, 6))

for i, folder in enumerate(folders):
    with open(folder, 'rb') as file:
        ebno_dbs, BLER, BER = pickle.load(file)
    plt.semilogy(ebno_dbs, BER['baseline-perfect-csi'], marker="x", linestyle="-", c=colors[i], 
                 label=f'Perfect CSI - {folder}')
    plt.semilogy(ebno_dbs, BER['baseline-ls-estimation'], marker="x", linestyle="-", c=colors[i], 
                 label=f'LS-estimation - {folder}')
    
plt.xlabel(r"$E_b/N_0$ (dB)")
plt.ylabel("BER")
plt.grid(which="both")
plt.ylim((1e-8, 1.0))
plt.legend()
plt.tight_layout()

plt.figure(figsize=(10, 6))

for i, folder in enumerate(folders):
    with open(folder, 'rb') as file:
        ebno_dbs, BLER, BER = pickle.load(file)
    plt.semilogy(ebno_dbs, BLER['baseline-perfect-csi'], marker="x", linestyle="-", c=colors[i], 
                 label=f'Perfect CSI - {folder}')
    plt.semilogy(ebno_dbs, BLER['baseline-ls-estimation'], marker="x", linestyle="-", c=colors[i], 
                 label=f'LS-estimation - {folder}')
    
plt.xlabel(r"$E_b/N_0$ (dB)")
plt.ylabel("BLER")
plt.grid(which="both")
plt.ylim((1e-6, 1.0))
plt.legend()
plt.tight_layout()

# %% [markdown]
# ## Training the Neural Receiver <a class="anchor" id="Training-the-Neural-Receiver"></a>

# %% [markdown]
# **Note:** For an introduction to the implementation of differentiable communication systems and their optimization through SGD and backpropagation with Sionna, please refer to [the Part 2 of the Sionna tutorial for Beginners](https://nvlabs.github.io/sionna/examples/Sionna_tutorial_part2.html).

# %% [markdown]
# Training consists in looping over SGD steps. The next cell implements a training loop.
#
# At each iteration:
# - A batch of SNRs $E_b/N_0$ is sampled
# - A forward pass through the end-to-end system is performed within a gradient tape
# - The gradients are computed using the gradient tape, and applied using the Adam optimizer
# - The achieved BMD rate is periodically shown
#
# After training, the weights of the models are saved in a file
#
# **Note:** Training can take a while. Therefore, [we have made pre-trained weights available](https://drive.google.com/drive/folders/1h2m_AD-t3qtWYifowChmWEY0DBbIj84Q?usp=sharing). Do not execute the next cell if you don't want to train the model from scratch.

# %% [markdown]
# ### Training standard mapper + deepRx

# %%
# The end-to-end system equipped with the neural receiver is instantiated for training.
# When called, it therefore returns the estimated BMD rate
model = E2ESystem('neural-receiver-standard', training=True)
eval_model = E2ESystem('neural-receiver-standard')

optimizer = tf.keras.optimizers.Adam()

# training_log = open('training_log_standard.txt', 'w')
# validation_log = open('validation_log_standard.txt', 'w')

for i in range(num_training_iterations):
    # Sampling a batch of SNRs
    ebno_db = tf.random.uniform(shape=[], minval=ebno_db_min, maxval=ebno_db_max)
    
    # Forward pass
    with tf.GradientTape() as tape:
        rate = model(training_batch_size, ebno_db)
        # Tensorflow optimizers only know how to minimize loss function.
        # Therefore, a loss function is defined as the additive inverse of the BMD rate
        loss = -rate

    # Perform one step of stochastic gradient descent (SGD)
    # Computing and applying gradients
    weights = model.trainable_weights
    grads = tape.gradient(loss, weights)
    optimizer.apply_gradients(zip(grads, weights))
    
    log_str = f"Iteration {i}/{num_training_iterations}, Eb/No: {ebno_db.numpy():.4f}, Loss: {loss.numpy():.4f}\n"
    
    # training_log.write(log_str)  # Save to log file
    
    # Periodically printing the progress
    if i % 1000 == 0:
        print(log_str, end='\r')
        # print('Iteration {}/{}  Rate: {:.4f} bit'.format(i, num_training_iterations, rate.numpy()), end='\r')
        
        weights = model.get_weights()
        # with open(f'weights_standard/model_weights_{i}.pkl', 'wb') as f:
            # pickle.dump(weights, f)

        eval_model(1, tf.constant(10.0, tf.float32))
        for layer in eval_model.trainable_weights:
            print(f"{layer.name}, Shape: {layer.shape}")
        eval_model.set_weights(weights)
        
        # validation at 3.5dB
        ber, bler = sim_ber(eval_model, [3.5], batch_size=128, num_target_block_errors=50, max_mc_iter=3000)
        validation_log_str = f"Iteration {i}/{num_training_iterations}: BER = {ber.numpy()}, BLER = {bler.numpy()}\n"
        
        # validation_log.write(validation_log_str)  # Save to log file
        print(validation_log_str, end='\r')

# Save the weights in a file
weights = model.get_weights()
# with open(model_weights_path_standard, 'wb') as f:
    # pickle.dump(weights, f)
# Out:
# Iteration 0/50000, Eb/No: 4.0849, Loss: 0.5863
# neural_receiver_6/conv2d/kernel:0, Shape: (3, 3, 5, 128)
# neural_receiver_6/conv2d/bias:0, Shape: (128,)
# neural_receiver_6/residual_block/layer_normalization/gamma:0, Shape: (128, 128, 14)
# neural_receiver_6/residual_block/layer_normalization/beta:0, Shape: (128, 128, 14)
# neural_receiver_6/residual_block/conv2d_2/kernel:0, Shape: (3, 3, 128, 128)
# neural_receiver_6/residual_block/conv2d_2/bias:0, Shape: (128,)
# neural_receiver_6/residual_block/layer_normalization_1/gamma:0, Shape: (128, 128, 14)
# neural_receiver_6/residual_block/layer_normalization_1/beta:0, Shape: (128, 128, 14)
# neural_receiver_6/residual_block/conv2d_3/kernel:0, Shape: (3, 3, 128, 128)
# neural_receiver_6/residual_block/conv2d_3/bias:0, Shape: (128,)
# neural_receiver_6/residual_block_1/layer_normalization_2/gamma:0, Shape: (128, 128, 14)
# neural_receiver_6/residual_block_1/layer_normalization_2/beta:0, Shape: (128, 128, 14)
# neural_receiver_6/residual_block_1/conv2d_4/kernel:0, Shape: (3, 3, 128, 128)
# neural_receiver_6/residual_block_1/conv2d_4/bias:0, Shape: (128,)
# neural_receiver_6/residual_block_1/layer_normalization_3/gamma:0, Shape: (128, 128, 14)
# neural_receiver_6/residual_block_1/layer_normalization_3/beta:0, Shape: (128, 128, 14)
# neural_receiver_6/residual_block_1/conv2d_5/kernel:0, Shape: (3, 3, 128, 128)
# neural_receiver_6/residual_block_1/conv2d_5/bias:0, Shape: (128,)
# neural_receiver_6/residual_block_2/layer_normalization_4/gamma:0, Shape: (128, 128, 14)
# neural_receiver_6/residual_block_2/layer_normalization_4/beta:0, Shape: (128, 128, 14)
# neural_receiver_6/residual_block_2/conv2d_6/kernel:0, Shape: (3, 3, 128, 128)
# neural_receiver_6/residual_block_2/conv2d_6/bias:0, Shape: (128,)
# neural_receiver_6/residual_block_2/layer_normalization_5/gamma:0, Shape: (128, 128, 14)
# neural_receiver_6/residual_block_2/layer_normalization_5/beta:0, Shape: (128, 128, 14)
# neural_receiver_6/residual_block_2/conv2d_7/kernel:0, Shape: (3, 3, 128, 128)
# neural_receiver_6/residual_block_2/conv2d_7/bias:0, Shape: (128,)
# neural_receiver_6/residual_block_3/layer_normalization_6/gamma:0, Shape: (128, 128, 14)
# neural_receiver_6/residual_block_3/layer_normalization_6/beta:0, Shape: (128, 128, 14)
# neural_receiver_6/residual_block_3/conv2d_8/kernel:0, Shape: (3, 3, 128, 128)
# neural_receiver_6/residual_block_3/conv2d_8/bias:0, Shape: (128,)
# neural_receiver_6/residual_block_3/layer_normalization_7/gamma:0, Shape: (128, 128, 14)
# neural_receiver_6/residual_block_3/layer_normalization_7/beta:0, Shape: (128, 128, 14)
# neural_receiver_6/residual_block_3/conv2d_9/kernel:0, Shape: (3, 3, 128, 128)
# neural_receiver_6/residual_block_3/conv2d_9/bias:0, Shape: (128,)
# neural_receiver_6/conv2d_1/kernel:0, Shape: (3, 3, 128, 6)
# neural_receiver_6/conv2d_1/bias:0, Shape: (6,)
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 5.0022e-01 | 1.0000e+00 |      267379 |      534528 |          128 |         128 |         0.4 |reached target block errors
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 50
#      47         ber, bler = sim_ber(eval_model, [3.5], batch_size=128, num_target_block_errors=50, max_mc_iter=3000)
#      48         validation_log_str = f"Iteration {i}/{num_training_iterations}: BER = {ber.numpy()}, BLER = {bler.numpy()}\n"
# ---> 50         validation_log.write(validation_log_str)  # Save to log file
#      51         print(validation_log_str, end='\r')
#      53 # Save the weights in a file
#
# NameError: name 'validation_log' is not defined

# %%
model = E2ESystem('neural-receiver-standard', training=True)
eval_model = E2ESystem('neural-receiver-standard')

model(1, tf.constant(10.0, tf.float32))
with open('weights_standard/model_weights_49000.pkl', 'rb') as f:
    weights = pickle.load(f)
model.set_weights(weights)

optimizer = tf.keras.optimizers.Adam()

training_log = open('training_log2_standard.txt', 'w')
validation_log = open('validation_log2_standard.txt', 'w')

for i in range(num_training_iterations):
    ebno_db = tf.random.uniform(shape=[], minval=ebno_db_min, maxval=ebno_db_max)
    with tf.GradientTape() as tape:
        rate = model(training_batch_size, ebno_db)
        loss = -rate
    weights = model.trainable_weights
    grads = tape.gradient(loss, weights)
    optimizer.apply_gradients(zip(grads, weights))
    
    log_str = f"Iteration {i+50000}/{100000}, Eb/No: {ebno_db.numpy():.4f}, Loss: {loss.numpy():.4f}\n"
    training_log.write(log_str)  # Save to log file
    
    if i % 1000 == 0:
        print(log_str, end='\r')
        weights = model.get_weights()
        with open(f'weights_standard/model_weights_{i+50000}.pkl', 'wb') as f:
            pickle.dump(weights, f)

        eval_model(1, tf.constant(10.0, tf.float32))
        eval_model.set_weights(weights)
        # validation at 3.5dB
        ber, bler = sim_ber(eval_model, [3.5], batch_size=128, num_target_block_errors=50, max_mc_iter=3000)
        validation_log_str = f"Iteration {i}/{num_training_iterations}: BER = {ber.numpy()}, BLER = {bler.numpy()}\n"
        validation_log.write(validation_log_str)  # Save to log file
        print(validation_log_str, end='\r')

weights = model.get_weights()
with open(model_weights_path_standard, 'wb') as f:
    pickle.dump(weights, f)

# %%
model = E2ESystem('neural-receiver-standard', training=True)
eval_model = E2ESystem('neural-receiver-standard')

model(1, tf.constant(10.0, tf.float32))
with open('weights_standard/model_weights_299000.pkl', 'rb') as f:
    weights = pickle.load(f)
model.set_weights(weights)

optimizer = tf.keras.optimizers.Adam()

training_log = open('training_log7_standard.txt', 'w')
validation_log = open('validation_log7_standard.txt', 'w')

for i in range(num_training_iterations):
    ebno_db = tf.random.uniform(shape=[], minval=ebno_db_min, maxval=ebno_db_max)
    with tf.GradientTape() as tape:
        rate = model(training_batch_size, ebno_db)
        loss = -rate
    weights = model.trainable_weights
    grads = tape.gradient(loss, weights)
    optimizer.apply_gradients(zip(grads, weights))
    
    log_str = f"Iteration {i+300000}/{350000}, Eb/No: {ebno_db.numpy():.4f}, Loss: {loss.numpy():.4f}\n"
    training_log.write(log_str)  # Save to log file
    
    if i % 1000 == 0:
        print(log_str, end='\r')
        weights = model.get_weights()
        with open(f'weights_standard/model_weights_{i+300000}.pkl', 'wb') as f:
            pickle.dump(weights, f)

        eval_model(1, tf.constant(10.0, tf.float32))
        eval_model.set_weights(weights)
        # validation at 3.5dB
        ber, bler = sim_ber(eval_model, [3.5], batch_size=128, num_target_block_errors=50, max_mc_iter=3000)
        validation_log_str = f"Iteration {i+300000}/{350000}: BER = {ber.numpy()}, BLER = {bler.numpy()}\n"
        validation_log.write(validation_log_str)  # Save to log file
        print(validation_log_str, end='\r')

weights = model.get_weights()
with open(model_weights_path_standard, 'wb') as f:
    pickle.dump(weights, f)
# Out:
# 2024-10-06 15:31:34.005192: I external/local_xla/xla/service/service.cc:168] XLA service 0x342feab0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# Iteration 300000/350000, Eb/No: 0.4707, Loss: -0.4347
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 6.5806e-04 | 3.5156e-02 |        4221 |     6414336 |           54 |        1536 |         4.1 |reached target block errors
# Iteration 300000/350000: BER = [0.00065806], BLER = [0.03515625]
# Iteration 301000/350000, Eb/No: 3.1304, Loss: -0.5667
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 5.9336e-04 | 2.1701e-02 |        5709 |     9621504 |           50 |        2304 |         6.0 |reached target block errors
# Iteration 301000/350000: BER = [0.00059336], BLER = [0.02170139]
# Iteration 302000/350000, Eb/No: 5.1169, Loss: -0.6672
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 3.3363e-04 | 2.2569e-02 |        3210 |     9621504 |           52 |        2304 |         6.0 |reached target block errors
# Iteration 302000/350000: BER = [0.00033363], BLER = [0.02256944]
# Iteration 303000/350000, Eb/No: 6.4284, Loss: -0.7314
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 7.9000e-04 | 2.2135e-02 |        7601 |     9621504 |           51 |        2304 |         6.0 |reached target block errors
# Iteration 303000/350000: BER = [0.00079], BLER = [0.02213542]
# Iteration 304000/350000, Eb/No: 3.8146, Loss: -0.6024
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 5.9836e-04 | 2.2204e-02 |        6077 |    10156032 |           54 |        2432 |         6.4 |reached target block errors
# Iteration 304000/350000: BER = [0.00059836], BLER = [0.02220395]
# Iteration 305000/350000, Eb/No: 4.6363, Loss: -0.6422
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 6.9379e-04 | 2.0703e-02 |        7417 |    10690560 |           53 |        2560 |         6.7 |reached target block errors
# Iteration 305000/350000: BER = [0.00069379], BLER = [0.02070312]
# Iteration 306000/350000, Eb/No: 9.1355, Loss: -0.8572
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 6.2176e-04 | 1.7323e-02 |        7644 |    12294144 |           51 |        2944 |         7.7 |reached target block errors
# Iteration 306000/350000: BER = [0.00062176], BLER = [0.01732337]
# Iteration 307000/350000, Eb/No: 4.3180, Loss: -0.6256
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 6.7536e-04 | 2.4816e-02 |        6137 |     9086976 |           54 |        2176 |         5.7 |reached target block errors
# Iteration 307000/350000: BER = [0.00067536], BLER = [0.02481618]
# Iteration 308000/350000, Eb/No: 8.1009, Loss: -0.8119
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 5.8699e-04 | 1.6563e-02 |        7844 |    13363200 |           53 |        3200 |         8.3 |reached target block errors
# Iteration 308000/350000: BER = [0.00058699], BLER = [0.0165625]
# Iteration 309000/350000, Eb/No: 4.1132, Loss: -0.6140
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 2.5994e-04 | 2.2569e-02 |        2501 |     9621504 |           52 |        2304 |         6.0 |reached target block errors
# Iteration 309000/350000: BER = [0.00025994], BLER = [0.02256944]
# Iteration 310000/350000, Eb/No: 0.2323, Loss: -0.4235
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 2.8221e-04 | 1.9531e-02 |        3017 |    10690560 |           50 |        2560 |         6.7 |reached target block errors
# Iteration 310000/350000: BER = [0.00028221], BLER = [0.01953125]
# Iteration 311000/350000, Eb/No: 2.1141, Loss: -0.5096
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 5.9201e-04 | 4.5139e-02 |        2848 |     4810752 |           52 |        1152 |         3.0 |reached target block errors
# Iteration 311000/350000: BER = [0.00059201], BLER = [0.04513889]
# Iteration 312000/350000, Eb/No: 6.7373, Loss: -0.7430
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 6.4498e-04 | 2.1949e-02 |        7240 |    11225088 |           59 |        2688 |         7.0 |reached target block errors
# Iteration 312000/350000: BER = [0.00064498], BLER = [0.0219494]
# Iteration 313000/350000, Eb/No: 1.3052, Loss: -0.4751
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 4.7511e-04 | 1.5024e-02 |        6603 |    13897728 |           50 |        3328 |         8.7 |reached target block errors
# Iteration 313000/350000: BER = [0.00047511], BLER = [0.01502404]
# Iteration 314000/350000, Eb/No: 6.0529, Loss: -0.7135
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 3.5822e-04 | 1.6250e-02 |        4787 |    13363200 |           52 |        3200 |         8.3 |reached target block errors
# Iteration 314000/350000: BER = [0.00035822], BLER = [0.01625]
# Iteration 315000/350000, Eb/No: 1.0856, Loss: -0.4597
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 5.0886e-04 | 3.9062e-02 |        2992 |     5879808 |           55 |        1408 |         3.7 |reached target block errors
# Iteration 315000/350000: BER = [0.00050886], BLER = [0.0390625]
# Iteration 316000/350000, Eb/No: 5.8439, Loss: -0.7027
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 3.1390e-04 | 1.4788e-02 |        4698 |    14966784 |           53 |        3584 |         9.3 |reached target block errors
# Iteration 316000/350000: BER = [0.0003139], BLER = [0.01478795]
# Iteration 317000/350000, Eb/No: 7.3780, Loss: -0.7734
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 7.5191e-04 | 3.3203e-02 |        4823 |     6414336 |           51 |        1536 |         4.0 |reached target block errors
# Iteration 317000/350000: BER = [0.00075191], BLER = [0.03320312]
# Iteration 318000/350000, Eb/No: 9.9178, Loss: -0.8858
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 6.4623e-04 | 2.9018e-02 |        4836 |     7483392 |           52 |        1792 |         4.7 |reached target block errors
# Iteration 318000/350000: BER = [0.00064623], BLER = [0.02901786]
# Iteration 319000/350000, Eb/No: 4.5598, Loss: -0.6372
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 5.5264e-04 | 2.0313e-02 |        5908 |    10690560 |           52 |        2560 |         6.7 |reached target block errors
# Iteration 319000/350000: BER = [0.00055264], BLER = [0.0203125]
# Iteration 320000/350000, Eb/No: 4.1130, Loss: -0.6155
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 6.5933e-04 | 1.9345e-02 |        7401 |    11225088 |           52 |        2688 |         7.0 |reached target block errors
# Iteration 320000/350000: BER = [0.00065933], BLER = [0.01934524]
# Iteration 321000/350000, Eb/No: 1.2577, Loss: -0.4745
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 6.0786e-04 | 1.5938e-02 |        8123 |    13363200 |           51 |        3200 |         8.3 |reached target block errors
# Iteration 321000/350000: BER = [0.00060786], BLER = [0.0159375]
# Iteration 322000/350000, Eb/No: 8.5203, Loss: -0.8266
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 4.2765e-04 | 1.8466e-02 |        5029 |    11759616 |           52 |        2816 |         7.3 |reached target block errors
# Iteration 322000/350000: BER = [0.00042765], BLER = [0.01846591]
# Iteration 323000/350000, Eb/No: 7.9428, Loss: -0.7959
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 2.3301e-04 | 2.0703e-02 |        2491 |    10690560 |           53 |        2560 |         6.7 |reached target block errors
# Iteration 323000/350000: BER = [0.00023301], BLER = [0.02070312]
# Iteration 324000/350000, Eb/No: 8.8712, Loss: -0.8405
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 6.5207e-04 | 1.9531e-02 |        6971 |    10690560 |           50 |        2560 |         6.7 |reached target block errors
# Iteration 324000/350000: BER = [0.00065207], BLER = [0.01953125]
# Iteration 325000/350000, Eb/No: 0.3995, Loss: -0.4308
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 7.4391e-04 | 2.7902e-02 |        5567 |     7483392 |           50 |        1792 |         4.7 |reached target block errors
# Iteration 325000/350000: BER = [0.00074391], BLER = [0.02790179]
# Iteration 326000/350000, Eb/No: 6.2539, Loss: -0.7213
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 3.3609e-04 | 1.8003e-02 |        4132 |    12294144 |           53 |        2944 |         7.7 |reached target block errors
# Iteration 326000/350000: BER = [0.00033609], BLER = [0.01800272]
# Iteration 327000/350000, Eb/No: 4.9848, Loss: -0.6604
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 5.0269e-04 | 1.9531e-02 |        5374 |    10690560 |           50 |        2560 |         6.7 |reached target block errors
# Iteration 327000/350000: BER = [0.00050269], BLER = [0.01953125]
# Iteration 328000/350000, Eb/No: 4.7485, Loss: -0.6481
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 4.6136e-04 | 2.2135e-02 |        4439 |     9621504 |           51 |        2304 |         6.0 |reached target block errors
# Iteration 328000/350000: BER = [0.00046136], BLER = [0.02213542]
# Iteration 329000/350000, Eb/No: 7.7032, Loss: -0.7926
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 4.5427e-04 | 1.8466e-02 |        5342 |    11759616 |           52 |        2816 |         7.3 |reached target block errors
# Iteration 329000/350000: BER = [0.00045427], BLER = [0.01846591]
# Iteration 330000/350000, Eb/No: 1.4455, Loss: -0.4819
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 3.3438e-04 | 2.0970e-02 |        3396 |    10156032 |           51 |        2432 |         6.3 |reached target block errors
# Iteration 330000/350000: BER = [0.00033438], BLER = [0.02097039]
# Iteration 331000/350000, Eb/No: 4.0565, Loss: -0.6133
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 3.1944e-04 | 2.0313e-02 |        3415 |    10690560 |           52 |        2560 |         6.7 |reached target block errors
# Iteration 331000/350000: BER = [0.00031944], BLER = [0.0203125]
# Iteration 332000/350000, Eb/No: 8.8173, Loss: -0.8375
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 5.6686e-04 | 2.1793e-02 |        5757 |    10156032 |           53 |        2432 |         6.3 |reached target block errors
# Iteration 332000/350000: BER = [0.00056686], BLER = [0.02179276]
# Iteration 333000/350000, Eb/No: 6.1748, Loss: -0.7197
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 3.3523e-04 | 1.8601e-02 |        3763 |    11225088 |           50 |        2688 |         7.0 |reached target block errors
# Iteration 333000/350000: BER = [0.00033523], BLER = [0.01860119]
# Iteration 334000/350000, Eb/No: 9.4215, Loss: -0.8667
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 5.8993e-04 | 2.2569e-02 |        5676 |     9621504 |           52 |        2304 |         6.0 |reached target block errors
# Iteration 334000/350000: BER = [0.00058993], BLER = [0.02256944]
# Iteration 335000/350000, Eb/No: 7.5938, Loss: -0.7873
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 3.1690e-04 | 1.4509e-02 |        4743 |    14966784 |           52 |        3584 |         9.3 |reached target block errors
# Iteration 335000/350000: BER = [0.0003169], BLER = [0.01450893]
# Iteration 336000/350000, Eb/No: 8.4682, Loss: -0.8272
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 4.7485e-04 | 1.8111e-02 |        5584 |    11759616 |           51 |        2816 |         7.3 |reached target block errors
# Iteration 336000/350000: BER = [0.00047485], BLER = [0.0181108]
# Iteration 337000/350000, Eb/No: 5.0428, Loss: -0.6598
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 6.0751e-04 | 2.6042e-02 |        4871 |     8017920 |           50 |        1920 |         5.0 |reached target block errors
# Iteration 337000/350000: BER = [0.00060751], BLER = [0.02604167]
# Iteration 338000/350000, Eb/No: 5.6507, Loss: -0.6937
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 7.2482e-04 | 2.4902e-02 |        6199 |     8552448 |           51 |        2048 |         5.3 |reached target block errors
# Iteration 338000/350000: BER = [0.00072482], BLER = [0.02490234]
# Iteration 339000/350000, Eb/No: 2.6109, Loss: -0.5395
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 7.1964e-04 | 2.1701e-02 |        6924 |     9621504 |           50 |        2304 |         6.0 |reached target block errors
# Iteration 339000/350000: BER = [0.00071964], BLER = [0.02170139]
# Iteration 340000/350000, Eb/No: 2.7321, Loss: -0.5455
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 6.0240e-04 | 3.0048e-02 |        4186 |     6948864 |           50 |        1664 |         4.4 |reached target block errors
# Iteration 340000/350000: BER = [0.0006024], BLER = [0.03004808]
# Iteration 341000/350000, Eb/No: 9.1381, Loss: -0.8552
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 6.5630e-04 | 2.4902e-02 |        5613 |     8552448 |           51 |        2048 |         5.4 |reached target block errors
# Iteration 341000/350000: BER = [0.0006563], BLER = [0.02490234]
# Iteration 342000/350000, Eb/No: 7.8426, Loss: -0.7985
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 5.9959e-04 | 2.9576e-02 |        4487 |     7483392 |           53 |        1792 |         4.7 |reached target block errors
# Iteration 342000/350000: BER = [0.00059959], BLER = [0.02957589]
# Iteration 343000/350000, Eb/No: 8.7660, Loss: -0.8408
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 5.2465e-04 | 2.5391e-02 |        4487 |     8552448 |           52 |        2048 |         5.4 |reached target block errors
# Iteration 343000/350000: BER = [0.00052465], BLER = [0.02539062]
# Iteration 344000/350000, Eb/No: 6.3736, Loss: -0.7289
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 4.0750e-04 | 1.8821e-02 |        4792 |    11759616 |           53 |        2816 |         7.4 |reached target block errors
# Iteration 344000/350000: BER = [0.0004075], BLER = [0.01882102]
# Iteration 345000/350000, Eb/No: 5.6270, Loss: -0.6904
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 5.2622e-04 | 2.1701e-02 |        5063 |     9621504 |           50 |        2304 |         6.0 |reached target block errors
# Iteration 345000/350000: BER = [0.00052622], BLER = [0.02170139]
# Iteration 346000/350000, Eb/No: 7.9179, Loss: -0.8034
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 6.6898e-04 | 2.3438e-02 |        6079 |     9086976 |           51 |        2176 |         5.7 |reached target block errors
# Iteration 346000/350000: BER = [0.00066898], BLER = [0.0234375]
# Iteration 347000/350000, Eb/No: 7.2153, Loss: -0.7683
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 6.2051e-04 | 1.8111e-02 |        7297 |    11759616 |           51 |        2816 |         7.4 |reached target block errors
# Iteration 347000/350000: BER = [0.00062051], BLER = [0.0181108]
# Iteration 348000/350000, Eb/No: 3.7927, Loss: -0.5982
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 6.7812e-04 | 2.0559e-02 |        6887 |    10156032 |           50 |        2432 |         6.4 |reached target block errors
# Iteration 348000/350000: BER = [0.00067812], BLER = [0.02055921]
# Iteration 349000/350000, Eb/No: 4.0353, Loss: -0.6115
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 6.6414e-04 | 2.3897e-02 |        6035 |     9086976 |           52 |        2176 |         5.7 |reached target block errors
# Iteration 349000/350000: BER = [0.00066414], BLER = [0.02389706]

# %% [markdown]
# ### Training Neural mapper + deepRx

# %%
# The end-to-end system equipped with the neural receiver is instantiated for training.
# When called, it therefore returns the estimated BMD rate
model = E2ESystem('neural-receiver-trained', training=True)
eval_model = E2ESystem('neural-receiver-trained')

training_log = open('training_log_trained.txt', 'w')
validation_log = open('validation_log_trained.txt', 'w')

# learning_rate_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
#     initial_learning_rate=0.0005,
#     decay_steps=10000,
#     decay_rate=0.9
# )

# Create an optimizer with the learning rate schedule
optimizer = tf.keras.optimizers.Adam()
# optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate_schedule)

for i in range(num_training_iterations):
    # Sampling a batch of SNRs
    ebno_db = tf.random.uniform(shape=[], minval=ebno_db_min, maxval=ebno_db_max)
    
    # Forward pass
    with tf.GradientTape() as tape:
        rate, block_error = model(training_batch_size, ebno_db)
        # Tensorflow optimizers only know how to minimize loss function.
        # Therefore, a loss function is defined as the additive inverse of the BMD rate
        loss = -rate

    # Perform one step of stochastic gradient descent (SGD)
    # Computing and applying gradients
    weights = model.trainable_weights
    grads = tape.gradient(loss, weights)
    optimizer.apply_gradients(zip(grads, weights))

    block_error_int = int(block_error.numpy())  # block_error to 1/0
    log_str = f"Iteration {i}/{num_training_iterations}, Eb/No: {ebno_db.numpy():.4f}, Loss: {loss.numpy():.4f}, Block Error: {block_error_int}\n"
    
    training_log.write(log_str)  # Save to log file
    
    # Periodically printing the progress
    if i % 1000 == 0:
        print(log_str, end='\r')
        # print('Iteration {}/{}  Rate: {:.4f} bit'.format(i, num_training_iterations, rate.numpy()), end='\r')
        
        weights = model.get_weights()
        with open(f'weights_trained/model_weights_{i}.pkl', 'wb') as f:
            pickle.dump(weights, f)

        eval_model(1, tf.constant(10.0, tf.float32))
        for layer in eval_model.trainable_weights:
            print(f"{layer.name}, Shape: {layer.shape}")
        eval_model.set_weights(weights)
        
        # validation at 3.5dB
        ber, bler = sim_ber(eval_model, [3.5], batch_size=128, num_target_block_errors=50, max_mc_iter=3000)
        validation_log_str = f"Iteration {i}/{num_training_iterations}: BER = {ber.numpy()}, BLER = {bler.numpy()}\n"
        
        validation_log.write(validation_log_str)  # Save to log file
        print(validation_log_str, end='\r')

# Save the weights in a file
weights = model.get_weights()
with open(model_weights_path_trained, 'wb') as f:
    pickle.dump(weights, f)

# %%
model = E2ESystem('neural-receiver-trained', training=True)
eval_model = E2ESystem('neural-receiver-trained')

model(1, tf.constant(10.0, tf.float32))
with open('weights_trained/model_weights_49000.pkl', 'rb') as f:
    weights = pickle.load(f)
model.set_weights(weights)

optimizer = tf.keras.optimizers.Adam()

training_log = open('training_log2_trained.txt', 'w')
validation_log = open('validation_log2_trained.txt', 'w')

for i in range(num_training_iterations):
    ebno_db = tf.random.uniform(shape=[], minval=ebno_db_min, maxval=ebno_db_max)
    with tf.GradientTape() as tape:
        rate = model(training_batch_size, ebno_db)
        loss = -rate
    weights = model.trainable_weights
    grads = tape.gradient(loss, weights)
    optimizer.apply_gradients(zip(grads, weights))
    
    log_str = f"Iteration {i+50000}/{100000}, Eb/No: {ebno_db.numpy():.4f}, Loss: {loss.numpy():.4f}\n"
    training_log.write(log_str)  # Save to log file
    
    if i % 1000 == 0:
        print(log_str, end='\r')
        weights = model.get_weights()
        with open(f'weights_trained/model_weights_{i+50000}.pkl', 'wb') as f:
            pickle.dump(weights, f)

        eval_model(1, tf.constant(10.0, tf.float32))
        eval_model.set_weights(weights)
        # validation at 3.5dB
        ber, bler = sim_ber(eval_model, [3.5], batch_size=128, num_target_block_errors=50, max_mc_iter=3000)
        validation_log_str = f"Iteration {i}/{num_training_iterations}: BER = {ber.numpy()}, BLER = {bler.numpy()}\n"
        validation_log.write(validation_log_str)  # Save to log file
        print(validation_log_str, end='\r')

weights = model.get_weights()
with open(model_weights_path_trained, 'wb') as f:
    pickle.dump(weights, f)

# %%
model = E2ESystem('neural-receiver-trained', training=True)
eval_model = E2ESystem('neural-receiver-trained')

model(1, tf.constant(10.0, tf.float32))
with open('weights_trained/model_weights_299000.pkl', 'rb') as f:
    weights = pickle.load(f)
model.set_weights(weights)

optimizer = tf.keras.optimizers.Adam()

training_log = open('training_log7_trained.txt', 'w')
validation_log = open('validation_log7_trained.txt', 'w')

for i in range(num_training_iterations):
    ebno_db = tf.random.uniform(shape=[], minval=ebno_db_min, maxval=ebno_db_max)
    with tf.GradientTape() as tape:
        rate = model(training_batch_size, ebno_db)
        loss = -rate
    weights = model.trainable_weights
    grads = tape.gradient(loss, weights)
    optimizer.apply_gradients(zip(grads, weights))
    
    log_str = f"Iteration {i+300000}/{350000}, Eb/No: {ebno_db.numpy():.4f}, Loss: {loss.numpy():.4f}\n"
    training_log.write(log_str)  # Save to log file
    
    if i % 1000 == 0:
        print(log_str, end='\r')
        weights = model.get_weights()
        with open(f'weights_trained/model_weights_{i+300000}.pkl', 'wb') as f:
            pickle.dump(weights, f)

        eval_model(1, tf.constant(10.0, tf.float32))
        eval_model.set_weights(weights)
        # validation at 3.5dB
        ber, bler = sim_ber(eval_model, [3.5], batch_size=128, num_target_block_errors=50, max_mc_iter=3000)
        validation_log_str = f"Iteration {i+300000}/{350000}: BER = {ber.numpy()}, BLER = {bler.numpy()}\n"
        validation_log.write(validation_log_str)  # Save to log file
        print(validation_log_str, end='\r')

weights = model.get_weights()
with open(model_weights_path_trained, 'wb') as f:
    pickle.dump(weights, f)
# Out:
# Iteration 300000/350000, Eb/No: 1.2986, Loss: -0.4966
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 3.8345e-04 | 7.1023e-03 |       11273 |    29399040 |           50 |        7040 |        18.4 |reached target block errors
# Iteration 300000/350000: BER = [0.00038345], BLER = [0.00710227]
# Iteration 301000/350000, Eb/No: 7.0069, Loss: -0.7795
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.9999e-04 | 3.5895e-03 |       11866 |    59332608 |           51 |       14208 |        37.0 |reached target block errors
# Iteration 301000/350000: BER = [0.00019999], BLER = [0.00358953]
# Iteration 302000/350000, Eb/No: 4.2430, Loss: -0.6468
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.4337e-04 | 3.0518e-03 |        9809 |    68419584 |           50 |       16384 |        42.7 |reached target block errors
# Iteration 302000/350000: BER = [0.00014337], BLER = [0.00305176]
# Iteration 303000/350000, Eb/No: 1.6719, Loss: -0.5164
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.5088e-04 | 2.8935e-03 |       10888 |    72161280 |           50 |       17280 |        45.2 |reached target block errors
# Iteration 303000/350000: BER = [0.00015088], BLER = [0.00289352]
# Iteration 304000/350000, Eb/No: 8.5004, Loss: -0.8395
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.5488e-04 | 2.6573e-03 |       12170 |    78575616 |           50 |       18816 |        49.6 |reached target block errors
# Iteration 304000/350000: BER = [0.00015488], BLER = [0.00265731]
# Iteration 305000/350000, Eb/No: 9.8935, Loss: -0.8875
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.3148e-04 | 2.7105e-03 |       10331 |    78575616 |           51 |       18816 |        49.6 |reached target block errors
# Iteration 305000/350000: BER = [0.00013148], BLER = [0.00271046]
# Iteration 306000/350000, Eb/No: 2.8175, Loss: -0.5750
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.8844e-04 | 3.0887e-03 |       12994 |    68954112 |           51 |       16512 |        43.2 |reached target block errors
# Iteration 306000/350000: BER = [0.00018844], BLER = [0.00308866]
# Iteration 307000/350000, Eb/No: 5.7504, Loss: -0.7222
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.1037e-04 | 2.1115e-03 |       10914 |    98887680 |           50 |       23680 |        62.4 |reached target block errors
# Iteration 307000/350000: BER = [0.00011037], BLER = [0.00211149]
# Iteration 308000/350000, Eb/No: 2.0910, Loss: -0.5398
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 2.1457e-04 | 3.3766e-03 |       13534 |    63074304 |           51 |       15104 |        39.8 |reached target block errors
# Iteration 308000/350000: BER = [0.00021457], BLER = [0.00337659]
# Iteration 309000/350000, Eb/No: 8.5771, Loss: -0.8420
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.6711e-04 | 3.8676e-03 |        9022 |    53987328 |           50 |       12928 |        33.8 |reached target block errors
# Iteration 309000/350000: BER = [0.00016711], BLER = [0.00386757]
# Iteration 310000/350000, Eb/No: 8.9777, Loss: -0.8592
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 2.0932e-04 | 3.0758e-03 |       14210 |    67885056 |           50 |       16256 |        42.5 |reached target block errors
# Iteration 310000/350000: BER = [0.00020932], BLER = [0.00307579]
# Iteration 311000/350000, Eb/No: 1.4800, Loss: -0.5067
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.8443e-04 | 2.7704e-03 |       13900 |    75368448 |           50 |       18048 |        47.2 |reached target block errors
# Iteration 311000/350000: BER = [0.00018443], BLER = [0.00277039]
# Iteration 312000/350000, Eb/No: 4.1824, Loss: -0.6469
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.7534e-04 | 3.8297e-03 |        9560 |    54521856 |           50 |       13056 |        34.2 |reached target block errors
# Iteration 312000/350000: BER = [0.00017534], BLER = [0.00382966]
# Iteration 313000/350000, Eb/No: 8.9597, Loss: -0.8553
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.7170e-04 | 3.3387e-03 |       10738 |    62539776 |           50 |       14976 |        39.2 |reached target block errors
# Iteration 313000/350000: BER = [0.0001717], BLER = [0.00333868]
# Iteration 314000/350000, Eb/No: 8.5367, Loss: -0.8388
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.8757e-04 | 2.8103e-03 |       13936 |    74299392 |           50 |       17792 |        46.6 |reached target block errors
# Iteration 314000/350000: BER = [0.00018757], BLER = [0.00281025]
# Iteration 315000/350000, Eb/No: 2.9715, Loss: -0.5834
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 2.2146e-04 | 4.0200e-03 |       12193 |    55056384 |           53 |       13184 |        34.5 |reached target block errors
# Iteration 315000/350000: BER = [0.00022146], BLER = [0.00402002]
# Iteration 316000/350000, Eb/No: 4.7098, Loss: -0.6720
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.5699e-04 | 3.3104e-03 |        9902 |    63074304 |           50 |       15104 |        39.5 |reached target block errors
# Iteration 316000/350000: BER = [0.00015699], BLER = [0.00331038]
# Iteration 317000/350000, Eb/No: 8.1173, Loss: -0.8265
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.5896e-04 | 2.9819e-03 |       11131 |    70023168 |           50 |       16768 |        43.9 |reached target block errors
# Iteration 317000/350000: BER = [0.00015896], BLER = [0.00298187]
# Iteration 318000/350000, Eb/No: 1.2642, Loss: -0.4967
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.3893e-04 | 2.6921e-03 |       10991 |    79110144 |           51 |       18944 |        49.5 |reached target block errors
# Iteration 318000/350000: BER = [0.00013893], BLER = [0.00269215]
# Iteration 319000/350000, Eb/No: 5.9383, Loss: -0.7312
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.9592e-04 | 3.5511e-03 |       11520 |    58798080 |           50 |       14080 |        36.9 |reached target block errors
# Iteration 319000/350000: BER = [0.00019592], BLER = [0.00355114]
# Iteration 320000/350000, Eb/No: 8.1530, Loss: -0.8253
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 2.1211e-04 | 3.3675e-03 |       13152 |    62005248 |           50 |       14848 |        38.8 |reached target block errors
# Iteration 320000/350000: BER = [0.00021211], BLER = [0.00336746]
# Iteration 321000/350000, Eb/No: 5.1559, Loss: -0.6945
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.6627e-04 | 2.8306e-03 |       12265 |    73764864 |           50 |       17664 |        46.1 |reached target block errors
# Iteration 321000/350000: BER = [0.00016627], BLER = [0.00283062]
# Iteration 322000/350000, Eb/No: 7.4257, Loss: -0.7988
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 2.2198e-04 | 4.1118e-03 |       11272 |    50780160 |           50 |       12160 |        31.7 |reached target block errors
# Iteration 322000/350000: BER = [0.00022198], BLER = [0.00411184]
# Iteration 323000/350000, Eb/No: 5.1334, Loss: -0.6911
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 2.0964e-04 | 3.3967e-03 |       12887 |    61470720 |           50 |       14720 |        38.6 |reached target block errors
# Iteration 323000/350000: BER = [0.00020964], BLER = [0.00339674]
# Iteration 324000/350000, Eb/No: 7.7843, Loss: -0.8133
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.4653e-04 | 2.8103e-03 |       10887 |    74299392 |           50 |       17792 |        46.6 |reached target block errors
# Iteration 324000/350000: BER = [0.00014653], BLER = [0.00281025]
# Iteration 325000/350000, Eb/No: 5.7531, Loss: -0.7246
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.3643e-04 | 2.8513e-03 |        9991 |    73230336 |           50 |       17536 |        45.8 |reached target block errors
# Iteration 325000/350000: BER = [0.00013643], BLER = [0.00285128]
# Iteration 326000/350000, Eb/No: 8.8068, Loss: -0.8499
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.7549e-04 | 3.2018e-03 |       11444 |    65212416 |           50 |       15616 |        40.8 |reached target block errors
# Iteration 326000/350000: BER = [0.00017549], BLER = [0.00320184]
# Iteration 327000/350000, Eb/No: 0.7787, Loss: -0.4705
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.7039e-04 | 2.8513e-03 |       12478 |    73230336 |           50 |       17536 |        45.9 |reached target block errors
# Iteration 327000/350000: BER = [0.00017039], BLER = [0.00285128]
# Iteration 328000/350000, Eb/No: 1.4349, Loss: -0.5057
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.7995e-04 | 3.0281e-03 |       12408 |    68954112 |           50 |       16512 |        43.2 |reached target block errors
# Iteration 328000/350000: BER = [0.00017995], BLER = [0.0030281]
# Iteration 329000/350000, Eb/No: 4.6687, Loss: -0.6663
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 2.0701e-04 | 4.1118e-03 |       10512 |    50780160 |           50 |       12160 |        31.9 |reached target block errors
# Iteration 329000/350000: BER = [0.00020701], BLER = [0.00411184]
# Iteration 330000/350000, Eb/No: 2.4660, Loss: -0.5587
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 9.6538e-05 | 2.4262e-03 |        8308 |    86059008 |           50 |       20608 |        54.1 |reached target block errors
# Iteration 330000/350000: BER = [9.65384123e-05], BLER = [0.00242624]
# Iteration 331000/350000, Eb/No: 0.7865, Loss: -0.4703
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.8237e-04 | 3.6169e-03 |       10528 |    57729024 |           50 |       13824 |        36.2 |reached target block errors
# Iteration 331000/350000: BER = [0.00018237], BLER = [0.0036169]
# Iteration 332000/350000, Eb/No: 1.0939, Loss: -0.4879
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 2.2006e-04 | 4.0271e-03 |       11410 |    51849216 |           50 |       12416 |        32.5 |reached target block errors
# Iteration 332000/350000: BER = [0.00022006], BLER = [0.00402706]
# Iteration 333000/350000, Eb/No: 6.9784, Loss: -0.7803
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.6375e-04 | 3.2826e-03 |       10416 |    63608832 |           50 |       15232 |        40.1 |reached target block errors
# Iteration 333000/350000: BER = [0.00016375], BLER = [0.00328256]
# Iteration 334000/350000, Eb/No: 2.3515, Loss: -0.5502
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.5198e-04 | 2.8103e-03 |       11292 |    74299392 |           50 |       17792 |        46.7 |reached target block errors
# Iteration 334000/350000: BER = [0.00015198], BLER = [0.00281025]
# Iteration 335000/350000, Eb/No: 0.7285, Loss: -0.4708
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 2.0004e-04 | 3.5511e-03 |       11762 |    58798080 |           50 |       14080 |        36.8 |reached target block errors
# Iteration 335000/350000: BER = [0.00020004], BLER = [0.00355114]
# Iteration 336000/350000, Eb/No: 7.2336, Loss: -0.7897
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.3635e-04 | 3.3387e-03 |        8527 |    62539776 |           50 |       14976 |        39.2 |reached target block errors
# Iteration 336000/350000: BER = [0.00013635], BLER = [0.00333868]
# Iteration 337000/350000, Eb/No: 9.6881, Loss: -0.8796
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 2.3178e-04 | 4.1556e-03 |       11646 |    50245632 |           50 |       12032 |        31.5 |reached target block errors
# Iteration 337000/350000: BER = [0.00023178], BLER = [0.00415559]
# Iteration 338000/350000, Eb/No: 2.2262, Loss: -0.5439
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 2.3340e-04 | 4.1118e-03 |       11852 |    50780160 |           50 |       12160 |        31.9 |reached target block errors
# Iteration 338000/350000: BER = [0.0002334], BLER = [0.00411184]
# Iteration 339000/350000, Eb/No: 7.0357, Loss: -0.7822
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.7671e-04 | 3.2552e-03 |       11335 |    64143360 |           50 |       15360 |        40.3 |reached target block errors
# Iteration 339000/350000: BER = [0.00017671], BLER = [0.00325521]
# Iteration 340000/350000, Eb/No: 8.0096, Loss: -0.8208
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.4671e-04 | 3.1002e-03 |        9881 |    67350528 |           50 |       16128 |        42.3 |reached target block errors
# Iteration 340000/350000: BER = [0.00014671], BLER = [0.0031002]
# Iteration 341000/350000, Eb/No: 6.5243, Loss: -0.7600
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.7837e-04 | 3.4569e-03 |       10774 |    60401664 |           50 |       14464 |        37.9 |reached target block errors
# Iteration 341000/350000: BER = [0.00017837], BLER = [0.00345686]
# Iteration 342000/350000, Eb/No: 9.6349, Loss: -0.8787
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.7805e-04 | 3.7560e-03 |        9898 |    55590912 |           50 |       13312 |        34.9 |reached target block errors
# Iteration 342000/350000: BER = [0.00017805], BLER = [0.00375601]
# Iteration 343000/350000, Eb/No: 0.6127, Loss: -0.4632
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.6827e-04 | 3.1622e-03 |       11333 |    67350528 |           51 |       16128 |        42.1 |reached target block errors
# Iteration 343000/350000: BER = [0.00016827], BLER = [0.0031622]
# Iteration 344000/350000, Eb/No: 7.7266, Loss: -0.8119
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.6571e-04 | 3.0093e-03 |       11958 |    72161280 |           52 |       17280 |        45.1 |reached target block errors
# Iteration 344000/350000: BER = [0.00016571], BLER = [0.00300926]
# Iteration 345000/350000, Eb/No: 5.2287, Loss: -0.6969
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.7388e-04 | 3.0048e-03 |       12083 |    69488640 |           50 |       16640 |        43.5 |reached target block errors
# Iteration 345000/350000: BER = [0.00017388], BLER = [0.00300481]
# Iteration 346000/350000, Eb/No: 1.8214, Loss: -0.5258
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.3954e-04 | 2.4902e-03 |       11934 |    85524480 |           51 |       20480 |        53.8 |reached target block errors
# Iteration 346000/350000: BER = [0.00013954], BLER = [0.00249023]
# Iteration 347000/350000, Eb/No: 7.8402, Loss: -0.8172
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.5908e-04 | 3.3104e-03 |       10034 |    63074304 |           50 |       15104 |        39.6 |reached target block errors
# Iteration 347000/350000: BER = [0.00015908], BLER = [0.00331038]
# Iteration 348000/350000, Eb/No: 9.2396, Loss: -0.8648
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.8226e-04 | 3.6599e-03 |       10814 |    59332608 |           52 |       14208 |        37.3 |reached target block errors
# Iteration 348000/350000: BER = [0.00018226], BLER = [0.00365991]
# Iteration 349000/350000, Eb/No: 5.0287, Loss: -0.6880
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       3.5 | 1.7068e-04 | 2.7704e-03 |       12864 |    75368448 |           50 |       18048 |        47.3 |reached target block errors
# Iteration 349000/350000: BER = [0.00017068], BLER = [0.00277039]

# %%
eval_model = E2ESystem('neural-receiver-trained')

validation_log = open('validation_log7_trained.txt', 'w')

for i in range(300000, 350001, 1000):
    eval_model(1, tf.constant(10.0, tf.float32))
    with open(f'weights_trained/model_weights_{299000}.pkl', 'rb') as f:
        weights = pickle.load(f)
    eval_model.set_weights(weights)
    
    # Validation at 3.5dB
    ber, bler = sim_ber(eval_model, [3.5], batch_size=128, num_target_block_errors=50, max_mc_iter=3000)
    
    # Log validation results
    validation_log_str = f"Iteration {i}/{350000}: BER = {ber.numpy()}, BLER = {bler.numpy()}\n"
    # validation_log.write(validation_log_str)  # Save to log file
    print(validation_log_str, end='\r')

# %%
gradients_log_file = open('gradients_log_150000.txt', 'w')

model = E2ESystem('neural-receiver-trained', training=True)

model(1, tf.constant(10.0, tf.float32))
with open('weights_trained/model_weights_149000.pkl', 'rb') as f:
    weights = pickle.load(f)
model.set_weights(weights)

optimizer = tf.keras.optimizers.Adam()

for i in range(1):
    ebno_db = tf.random.uniform(shape=[], minval=ebno_db_min, maxval=ebno_db_max)
    with tf.GradientTape() as tape:
        rate = model(training_batch_size, ebno_db)
        loss = -rate
    weights = model.trainable_weights
    grads = tape.gradient(loss, weights)
    
    # Check for zero gradients
    zero_gradients = [tf.reduce_all(g == 0) for g in grads if g is not None]
    for idx, zg in enumerate(zero_gradients):
        if zg:
            print(f"Layer {idx} has zero gradients at iteration {i}\n")
            
    for idx, g in enumerate(grads):
        if g is not None:
            gradients_log_file.write(f"Layer {idx} gradients at iteration {i}:\n {g.numpy()}\n")
        else:
            print(f"Layer {idx} has no gradients at iteration {i}")
            
    optimizer.apply_gradients(zip(grads, weights))

weights = model.get_weights()

# %% [markdown]
# ## Evaluation of the Neural Receiver <a class="anchor" id="Evaluation-of-the-Neural-Receiver"></a>

# %% [markdown]
# The next cell evaluates the neural receiver.
#
# **Note:** Evaluation of the system can take a while and requires having the trained weights of the neural receiver. Therefore, we provide pre-computed results at the end of this notebook.

# %%
model = E2ESystem('neural-receiver-standard')

# Run one inference to build the layers and loading the weights
model(1, tf.constant(10.0, tf.float32))
with open("weights_standard/model_weights_299000.pkl", 'rb') as f:
    weights = pickle.load(f)
model.set_weights(weights)

# Evaluations
ber,bler = sim_ber(model, ebno_dbs, batch_size=128, num_target_block_errors=50, max_mc_iter=9000)
BLER['neural-receiver-standard'] = bler.numpy()
BER['neural-receiver-standard'] = ber.numpy()

with open("neural_receiver_results_300000_9000", 'wb') as f:
    pickle.dump((ebno_dbs, BLER, BER), f)
# Out:
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       0.0 | 2.0917e-01 | 1.0000e+00 |      111806 |      534528 |          128 |         128 |         0.4 |reached target block errors
#       0.5 | 1.9672e-01 | 1.0000e+00 |      105155 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.0 | 1.7977e-01 | 1.0000e+00 |       96094 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.5 | 1.5737e-01 | 1.0000e+00 |       84118 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.0 | 1.3003e-01 | 1.0000e+00 |       69504 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.5 | 7.1478e-02 | 1.0000e+00 |       38207 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       3.0 | 7.6198e-03 | 5.0781e-01 |        4073 |      534528 |           65 |         128 |         0.3 |reached target block errors
#       3.5 | 4.1510e-04 | 1.5938e-02 |        5547 |    13363200 |           51 |        3200 |         8.3 |reached target block errors
#       4.0 | 1.3077e-04 | 2.8103e-03 |        9716 |    74299392 |           50 |       17792 |        46.2 |reached target block errors
#       4.5 | 8.5803e-05 | 1.0615e-03 |       16878 |   196706304 |           50 |       47104 |       122.2 |reached target block errors
#       5.0 | 2.9538e-05 | 3.7309e-04 |       16531 |   559650816 |           50 |      134016 |       348.2 |reached target block errors
#       5.5 | 1.3908e-05 | 1.6686e-04 |       17404 |  1251330048 |           50 |      299648 |       778.1 |reached target block errors
#       6.0 | 5.2115e-06 | 7.0055e-05 |       15533 |  2980528128 |           50 |      713728 |      1853.3 |reached target block errors
#       6.5 | 2.5570e-06 | 3.8194e-05 |       12301 |  4810752000 |           44 |     1152000 |      2990.4 |reached max iter
#       7.0 | 2.4510e-06 | 2.8646e-05 |       11791 |  4810752000 |           33 |     1152000 |      2992.2 |reached max iter
#       7.5 | 1.6775e-07 | 6.9444e-06 |         807 |  4810752000 |            8 |     1152000 |      2989.6 |reached max iter
#       8.0 | 2.1494e-07 | 2.6042e-06 |        1034 |  4810752000 |            3 |     1152000 |      2989.9 |reached max iter
#       8.5 | 1.4488e-07 | 8.6806e-07 |         697 |  4810752000 |            1 |     1152000 |      2988.3 |reached max iter
#       9.0 | 3.3675e-08 | 8.6806e-07 |         162 |  4810752000 |            1 |     1152000 |      2987.3 |reached max iter
#       9.5 | 0.0000e+00 | 0.0000e+00 |           0 |  4810752000 |            0 |     1152000 |      2985.4 |reached max iter
#
# Simulation stopped as no error occurred @ EbNo = 9.5 dB.

# %%
tf.random.set_seed(4)
np.random.seed(4)

model = E2ESystem('neural-receiver-trained')

c = model._binary_source([batch_size, 1, 1, n])
x = model._mapper(c)
x_rg = model._rg_mapper(x)
no_ = expand_to_rank(no, tf.rank(x_rg))
y,h = model._channel([x_rg, no_])

# print(c)
# print(y)
# print(h)

# Run one inference to build the layers and loading the weights
# model(1, tf.constant(10.0, tf.float32))
# with open("neural_receiver_weights_trained", 'rb') as f:
#     weights = pickle.load(f)
# model.set_weights(weights)

folders = ['', 'with_loss_term', 'with_loss_term/rerun', 'with_loss_term/rerun2']

for i, folder in enumerate(folders):
    if (folder == ""):
        results_filename = "neural_receiver_weights_trained"
    else:
        results_filename = f"{folder}/neural_receiver_weights_trained"
    fixed_results_filename = f"fixed_results/run_{i}"
    print(fixed_results_filename)
    
    model(1, tf.constant(10.0, tf.float32))
    with open(results_filename, 'rb') as f:
        weights = pickle.load(f)
    model.set_weights(weights)

    # Evaluations
    ber,bler = sim_ber(model, ebno_dbs, batch_size=128, num_target_block_errors=50, max_mc_iter=3000)
    BLER['neural-receiver-trained'] = bler.numpy()
    BER['neural-receiver-trained'] = ber.numpy()  
    
    with open(fixed_results_filename, 'wb') as f:
        pickle.dump((ebno_dbs, BLER, BER), f)
# Out:
# fixed_results/run_0
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#      -5.0 | 3.1870e-01 | 1.0000e+00 |      170353 |      534528 |          128 |         128 |         0.4 |reached target block errors
#      -4.5 | 3.1101e-01 | 1.0000e+00 |      166245 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -4.0 | 2.9890e-01 | 1.0000e+00 |      159772 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -3.5 | 2.8886e-01 | 1.0000e+00 |      154406 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -3.0 | 2.8030e-01 | 1.0000e+00 |      149830 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -2.5 | 2.6774e-01 | 1.0000e+00 |      143116 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -2.0 | 2.5704e-01 | 1.0000e+00 |      137393 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -1.5 | 2.4415e-01 | 1.0000e+00 |      130504 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -1.0 | 2.3180e-01 | 1.0000e+00 |      123906 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -0.5 | 2.1847e-01 | 1.0000e+00 |      116778 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       0.0 | 2.0355e-01 | 1.0000e+00 |      108804 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       0.5 | 1.9017e-01 | 1.0000e+00 |      101652 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.0 | 1.7235e-01 | 1.0000e+00 |       92124 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.5 | 1.4636e-01 | 1.0000e+00 |       78231 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.0 | 9.3468e-02 | 1.0000e+00 |       49961 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.5 | 2.0680e-02 | 8.4375e-01 |       11054 |      534528 |          108 |         128 |         0.3 |reached target block errors
#       3.0 | 1.4623e-03 | 7.1615e-02 |        4690 |     3207168 |           55 |         768 |         2.0 |reached target block errors
#       3.5 | 1.9721e-04 | 4.8828e-03 |        8433 |    42762240 |           50 |       10240 |        27.0 |reached target block errors
#       4.0 | 1.0493e-04 | 1.4576e-03 |       15031 |   143253504 |           50 |       34304 |        90.6 |reached target block errors
#       4.5 | 6.4433e-05 | 6.0282e-04 |       22318 |   346374144 |           50 |       82944 |       218.9 |reached target block errors
#       5.0 | 2.3739e-05 | 3.0375e-04 |       16318 |   687403008 |           50 |      164608 |       434.4 |reached target block errors
#       5.5 | 1.2638e-05 | 1.6693e-04 |       15808 |  1250795520 |           50 |      299520 |       789.9 |reached target block errors
#       6.0 | 1.0068e-05 | 1.1719e-04 |       16145 |  1603584000 |           45 |      384000 |      1012.2 |reached max iter
#       6.5 | 2.0099e-06 | 2.6042e-05 |        3223 |  1603584000 |           10 |      384000 |      1012.4 |reached max iter
#       7.0 | 1.4536e-06 | 2.0833e-05 |        2331 |  1603584000 |            8 |      384000 |      1013.0 |reached max iter
#       7.5 | 1.8109e-06 | 2.3438e-05 |        2904 |  1603584000 |            9 |      384000 |      1011.7 |reached max iter
#       8.0 | 2.8499e-07 | 5.2083e-06 |         457 |  1603584000 |            2 |      384000 |      1011.6 |reached max iter
#       8.5 | 0.0000e+00 | 0.0000e+00 |           0 |  1603584000 |            0 |      384000 |      1006.0 |reached max iter
#
# Simulation stopped as no error occurred @ EbNo = 8.5 dB.
#
# fixed_results/run_1
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#      -5.0 | 3.2306e-01 | 1.0000e+00 |      172684 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -4.5 | 3.1178e-01 | 1.0000e+00 |      166657 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -4.0 | 3.0176e-01 | 1.0000e+00 |      161297 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -3.5 | 2.9085e-01 | 1.0000e+00 |      155470 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -3.0 | 2.8114e-01 | 1.0000e+00 |      150278 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -2.5 | 2.6800e-01 | 1.0000e+00 |      143255 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -2.0 | 2.5742e-01 | 1.0000e+00 |      137596 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -1.5 | 2.4433e-01 | 1.0000e+00 |      130599 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -1.0 | 2.3216e-01 | 1.0000e+00 |      124095 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -0.5 | 2.2007e-01 | 1.0000e+00 |      117632 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       0.0 | 2.0644e-01 | 1.0000e+00 |      110346 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       0.5 | 1.8909e-01 | 1.0000e+00 |      101073 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.0 | 1.7115e-01 | 1.0000e+00 |       91484 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.5 | 1.4773e-01 | 1.0000e+00 |       78967 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.0 | 1.0121e-01 | 1.0000e+00 |       54098 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.5 | 2.5301e-02 | 8.3594e-01 |       13524 |      534528 |          107 |         128 |         0.3 |reached target block errors
#       3.0 | 1.8259e-03 | 1.0156e-01 |        3904 |     2138112 |           52 |         512 |         1.3 |reached target block errors
#       3.5 | 4.1829e-04 | 8.4918e-03 |       10285 |    24588288 |           50 |        5888 |        15.4 |reached target block errors
#       4.0 | 1.2686e-04 | 2.1463e-03 |       12341 |    97284096 |           50 |       23296 |        60.9 |reached target block errors
#       4.5 | 7.6852e-05 | 1.0334e-03 |       15528 |   202051584 |           50 |       48384 |       126.5 |reached target block errors
#       5.0 | 4.5913e-05 | 5.4405e-04 |       17621 |   383791104 |           50 |       91904 |       240.3 |reached target block errors
#       5.5 | 1.9184e-05 | 2.4992e-04 |       16028 |   835467264 |           50 |      200064 |       523.3 |reached target block errors
#       6.0 | 1.4930e-05 | 1.8313e-04 |       17022 |  1140148224 |           50 |      273024 |       714.1 |reached target block errors
#       6.5 | 8.0320e-06 | 1.0938e-04 |       12880 |  1603584000 |           42 |      384000 |      1005.9 |reached max iter
#       7.0 | 3.3774e-06 | 3.9063e-05 |        5416 |  1603584000 |           15 |      384000 |      1006.1 |reached max iter
#       7.5 | 3.6194e-06 | 4.4271e-05 |        5804 |  1603584000 |           17 |      384000 |      1008.0 |reached max iter
#       8.0 | 1.0127e-06 | 1.3021e-05 |        1624 |  1603584000 |            5 |      384000 |      1004.6 |reached max iter
#       8.5 | 6.6601e-07 | 1.0417e-05 |        1068 |  1603584000 |            4 |      384000 |      1004.8 |reached max iter
#       9.0 | 0.0000e+00 | 0.0000e+00 |           0 |  1603584000 |            0 |      384000 |      1005.5 |reached max iter
#
# Simulation stopped as no error occurred @ EbNo = 9.0 dB.
#
# fixed_results/run_2
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#      -5.0 | 3.2251e-01 | 1.0000e+00 |      172389 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -4.5 | 3.1397e-01 | 1.0000e+00 |      167825 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -4.0 | 3.0243e-01 | 1.0000e+00 |      161659 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -3.5 | 2.9206e-01 | 1.0000e+00 |      156116 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -3.0 | 2.8271e-01 | 1.0000e+00 |      151116 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -2.5 | 2.7215e-01 | 1.0000e+00 |      145471 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -2.0 | 2.6043e-01 | 1.0000e+00 |      139208 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -1.5 | 2.4917e-01 | 1.0000e+00 |      133187 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -1.0 | 2.3669e-01 | 1.0000e+00 |      126515 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -0.5 | 2.2356e-01 | 1.0000e+00 |      119500 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       0.0 | 2.1071e-01 | 1.0000e+00 |      112632 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       0.5 | 1.9387e-01 | 1.0000e+00 |      103629 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.0 | 1.7883e-01 | 1.0000e+00 |       95590 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.5 | 1.5582e-01 | 1.0000e+00 |       83292 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.0 | 1.1521e-01 | 1.0000e+00 |       61584 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.5 | 4.2486e-02 | 9.8438e-01 |       22710 |      534528 |          126 |         128 |         0.3 |reached target block errors
#       3.0 | 2.2786e-03 | 1.6927e-01 |        3654 |     1603584 |           65 |         384 |         1.0 |reached target block errors
#       3.5 | 6.2641e-04 | 1.3021e-02 |       10045 |    16035840 |           50 |        3840 |        10.1 |reached target block errors
#       4.0 | 1.8445e-04 | 2.3391e-03 |       16465 |    89266176 |           50 |       21376 |        56.0 |reached target block errors
#       4.5 | 7.8926e-05 | 1.1037e-03 |       15230 |   192964608 |           51 |       46208 |       121.1 |reached target block errors
#       5.0 | 5.9342e-05 | 6.4780e-04 |       19127 |   322320384 |           50 |       77184 |       202.2 |reached target block errors
#       5.5 | 2.3825e-05 | 3.0953e-04 |       16072 |   674574336 |           50 |      161536 |       423.0 |reached target block errors
#       6.0 | 1.2217e-05 | 1.4330e-04 |       17802 |  1457123328 |           50 |      348928 |       913.9 |reached target block errors
#       6.5 | 8.4904e-06 | 8.3333e-05 |       13615 |  1603584000 |           32 |      384000 |      1006.4 |reached max iter
#       7.0 | 2.8680e-06 | 3.9063e-05 |        4599 |  1603584000 |           15 |      384000 |      1005.8 |reached max iter
#       7.5 | 1.4480e-06 | 2.6042e-05 |        2322 |  1603584000 |           10 |      384000 |      1005.4 |reached max iter
#       8.0 | 1.3526e-06 | 1.3021e-05 |        2169 |  1603584000 |            5 |      384000 |      1006.3 |reached max iter
#       8.5 | 1.3283e-06 | 1.3021e-05 |        2130 |  1603584000 |            5 |      384000 |      1005.0 |reached max iter
#       9.0 | 5.0761e-07 | 2.6042e-06 |         814 |  1603584000 |            1 |      384000 |      1003.9 |reached max iter
#       9.5 | 3.6356e-07 | 2.6042e-06 |         583 |  1603584000 |            1 |      384000 |      1004.1 |reached max iter
# fixed_results/run_3
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#      -5.0 | 3.2310e-01 | 1.0000e+00 |      172707 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -4.5 | 3.1092e-01 | 1.0000e+00 |      166196 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -4.0 | 3.0209e-01 | 1.0000e+00 |      161473 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -3.5 | 2.9135e-01 | 1.0000e+00 |      155735 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -3.0 | 2.7964e-01 | 1.0000e+00 |      149477 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -2.5 | 2.6824e-01 | 1.0000e+00 |      143380 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -2.0 | 2.5759e-01 | 1.0000e+00 |      137690 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -1.5 | 2.4435e-01 | 1.0000e+00 |      130614 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -1.0 | 2.3247e-01 | 1.0000e+00 |      124261 |      534528 |          128 |         128 |         0.3 |reached target block errors
#      -0.5 | 2.1938e-01 | 1.0000e+00 |      117265 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       0.0 | 2.0507e-01 | 1.0000e+00 |      109613 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       0.5 | 1.9053e-01 | 1.0000e+00 |      101844 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.0 | 1.6983e-01 | 1.0000e+00 |       90777 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.5 | 1.4794e-01 | 1.0000e+00 |       79080 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.0 | 9.8721e-02 | 1.0000e+00 |       52769 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.5 | 2.2173e-02 | 8.8281e-01 |       11852 |      534528 |          113 |         128 |         0.3 |reached target block errors
#       3.0 | 1.3238e-03 | 8.9063e-02 |        3538 |     2672640 |           57 |         640 |         1.7 |reached target block errors
#       3.5 | 3.7167e-04 | 6.8531e-03 |       11324 |    30468096 |           50 |        7296 |        19.1 |reached target block errors
#       4.0 | 1.2570e-04 | 2.1115e-03 |       12430 |    98887680 |           50 |       23680 |        61.9 |reached target block errors
#       4.5 | 5.6685e-05 | 8.7979e-04 |       13453 |   237330432 |           50 |       56832 |       148.6 |reached target block errors
#       5.0 | 4.2297e-05 | 5.7870e-04 |       15261 |   360806400 |           50 |       86400 |       226.0 |reached target block errors
#       5.5 | 1.9082e-05 | 2.2032e-04 |       18084 |   947718144 |           50 |      226944 |       593.9 |reached target block errors
#       6.0 | 1.1928e-05 | 1.4972e-04 |       16635 |  1394583552 |           50 |      333952 |       875.1 |reached target block errors
#       6.5 | 5.9766e-06 | 9.1146e-05 |        9584 |  1603584000 |           35 |      384000 |      1005.6 |reached max iter
#       7.0 | 4.5005e-06 | 4.9479e-05 |        7217 |  1603584000 |           19 |      384000 |      1004.8 |reached max iter
#       7.5 | 1.7635e-06 | 2.6042e-05 |        2828 |  1603584000 |           10 |      384000 |      1005.0 |reached max iter
#       8.0 | 1.1424e-06 | 1.8229e-05 |        1832 |  1603584000 |            7 |      384000 |      1004.3 |reached max iter
#       8.5 | 8.1131e-07 | 5.2083e-06 |        1301 |  1603584000 |            2 |      384000 |      1004.6 |reached max iter
#       9.0 | 3.2739e-07 | 2.6042e-06 |         525 |  1603584000 |            1 |      384000 |      1004.5 |reached max iter
#       9.5 | 0.0000e+00 | 0.0000e+00 |           0 |  1603584000 |            0 |      384000 |      1005.4 |reached max iter
#
# Simulation stopped as no error occurred @ EbNo = 9.5 dB.

# %%
model = E2ESystem('neural-receiver-trained')
    
model(1, tf.constant(10.0, tf.float32))
with open("weights_trained/model_weights_299000.pkl", 'rb') as f:
    weights = pickle.load(f)
model.set_weights(weights)

# Evaluations
ber,bler = sim_ber(model, ebno_dbs, batch_size=128, num_target_block_errors=50, max_mc_iter=9000)
BLER['neural-receiver-trained'] = bler.numpy()
BER['neural-receiver-trained'] = ber.numpy()  

with open("neural_receiver_results_300000_9000", 'wb') as f:
    pickle.dump((ebno_dbs, BLER, BER), f)
# Out:
# EbNo [dB] |        BER |       BLER |  bit errors |    num bits | block errors |  num blocks | runtime [s] |    status
# ---------------------------------------------------------------------------------------------------------------------------------------
#       0.0 | 2.0081e-01 | 1.0000e+00 |      107341 |      534528 |          128 |         128 |         0.4 |reached target block errors
#       0.5 | 1.8667e-01 | 1.0000e+00 |       99781 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.0 | 1.6322e-01 | 1.0000e+00 |       87246 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       1.5 | 1.3765e-01 | 1.0000e+00 |       73576 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.0 | 7.6467e-02 | 1.0000e+00 |       40874 |      534528 |          128 |         128 |         0.3 |reached target block errors
#       2.5 | 1.1745e-02 | 5.8594e-01 |        6278 |      534528 |           75 |         128 |         0.3 |reached target block errors
#       3.0 | 5.6997e-04 | 2.7083e-02 |        4570 |     8017920 |           52 |        1920 |         5.0 |reached target block errors
#       3.5 | 2.1119e-04 | 3.6169e-03 |       12192 |    57729024 |           50 |       13824 |        35.9 |reached target block errors
#       4.0 | 1.1080e-04 | 1.4648e-03 |       16110 |   145391616 |           51 |       34816 |        90.3 |reached target block errors
#       4.5 | 3.9004e-05 | 5.0080e-04 |       16262 |   416931840 |           50 |       99840 |       259.0 |reached target block errors
#       5.0 | 2.5560e-05 | 3.1002e-04 |       17215 |   673505280 |           50 |      161280 |       418.4 |reached target block errors
#       5.5 | 9.3745e-06 | 1.3378e-04 |       14632 |  1560821760 |           50 |      373760 |       969.5 |reached target block errors
#       6.0 | 4.1057e-06 | 5.4656e-05 |       15685 |  3820271616 |           50 |      914816 |      2373.4 |reached target block errors
#       6.5 | 2.1292e-06 | 2.3438e-05 |       10243 |  4810752000 |           27 |     1152000 |      2989.3 |reached max iter
#       7.0 | 6.0386e-07 | 1.0417e-05 |        2905 |  4810752000 |           12 |     1152000 |      2988.7 |reached max iter
#       7.5 | 2.0475e-07 | 6.0764e-06 |         985 |  4810752000 |            7 |     1152000 |      2991.1 |reached max iter
#       8.0 | 1.2680e-07 | 8.6806e-07 |         610 |  4810752000 |            1 |     1152000 |      2998.9 |reached max iter
#       8.5 | 0.0000e+00 | 0.0000e+00 |           0 |  4810752000 |            0 |     1152000 |      3000.5 |reached max iter
#
# Simulation stopped as no error occurred @ EbNo = 8.5 dB.

# %%
folders = ['neural_receiver_results_9000', 'neural_receiver_results_12000']
colors = ['C0', 'C1', 'C2', 'C3']
linestyles = [':', ':', '-.', '-.', '-.']  

plt.figure(figsize=(10, 6))

for i, folder in enumerate(folders):
    with open(folder, 'rb') as file:
        ebno_dbs, BLER, BER = pickle.load(file)
    plt.semilogy(ebno_dbs, BER['neural-receiver-standard'], marker="x", linestyle="-", c=colors[i], 
                 label=f'Neural receiver standard - {folder}')
    plt.semilogy(ebno_dbs, BER['neural-receiver-trained'], marker="x", linestyle="-", c=colors[i], 
                 label=f'Neural receiver trained - {folder}')
    
plt.xlabel(r"$E_b/N_0$ (dB)")
plt.ylabel("BER")
plt.grid(which="both")
plt.ylim((1e-7, 1.0))
plt.legend()
plt.tight_layout()

# %% [markdown]
# ## Plotting fixed results across runs

# %%
# Define the folders containing the results for the three runs
folders = ['fixed_results/run_0', 'fixed_results/run_1', 'fixed_results/run_2', 'fixed_results/run_3', 'fixed_results/run_4']
colors = ['C0', 'C1', 'C2', 'C3', 'C4', 'C5']
markers = ['x', 'x', 'o', 'o', 'o']  # 'o', 'x', 's', 'd', '*', '^'
linestyles = [':', ':', '-.', '-.', '-.']  

plt.figure(figsize=(10, 6))

for i, folder in enumerate(folders):
    with open(folder, 'rb') as file:
        ebno_dbs, BLER, BER = pickle.load(file)
    plt.semilogy(ebno_dbs, BER['neural-receiver-trained'], marker=markers[i], linestyle=linestyles[i], c=colors[i], 
                 label=f'Run {i+1} - Neural receiver - trained mapper')

plt.xlabel(r"$E_b/N_0$ (dB)")
plt.ylabel("BER")
plt.grid(which="both")
plt.ylim((1e-7, 1.0))
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Finally, we plots the BLERs

# %% [markdown]
# ## Results

# %%
with open("baseline_results_9000", 'rb') as file:
        ebno_dbs, BLER, BER = pickle.load(file)
plt.figure(figsize=(10,6))
# Baseline - Perfect CSI
plt.semilogy(ebno_dbs, BLER['baseline-perfect-csi'], 'o-', c=f'C0', label=f'Baseline - Perfect CSI')
# Baseline - LS Estimation
plt.semilogy(ebno_dbs, BLER['baseline-ls-estimation'], 'x--', c=f'C1', label=f'Baseline - LS Estimation')

with open("neural_receiver_results_9000", 'rb') as file:
        ebno_dbs, BLER, BER = pickle.load(file)
# Neural receiver - standard mapper
plt.semilogy(ebno_dbs, BLER['neural-receiver-standard'], 's-.', c=f'C2', label=f'Neural receiver - standard mapper')
# Neural receiver - trained mapper
plt.semilogy(ebno_dbs, BLER['neural-receiver-trained'], 's-.', c=f'C3', label=f'Neural receiver - trained mapper')

plt.xlabel(r"$E_b/N_0$ (dB)")
plt.ylabel("BLER")
plt.grid(which="both")
plt.ylim((1e-4, 1.0))
plt.legend()
plt.tight_layout()

# %%
with open("baseline_results_12000", 'rb') as file:
        ebno_dbs, BLER, BER = pickle.load(file)
plt.figure(figsize=(10,6))
# Baseline - Perfect CSI
plt.semilogy(ebno_dbs, BER['baseline-perfect-csi'], 'o-', c=f'C0', label=f'Baseline - Perfect CSI')
# Baseline - LS Estimation
plt.semilogy(ebno_dbs, BER['baseline-ls-estimation'], 'x--', c=f'C1', label=f'Baseline - LS Estimation')

with open("neural_receiver_results_12000", 'rb') as file:
        ebno_dbs, BLER, BER = pickle.load(file)
# Neural receiver - standard mapper
plt.semilogy(ebno_dbs, BER['neural-receiver-standard'], 's-.', c=f'C2', label=f'Neural receiver - standard mapper')
# Neural receiver - trained mapper
plt.semilogy(ebno_dbs, BER['neural-receiver-trained'], 's-.', c=f'C3', label=f'Neural receiver - trained mapper')

plt.xlabel(r"$E_b/N_0$ (dB)")
plt.ylabel("BER")
plt.grid(which="both")
plt.ylim((1e-5, 1.0))
plt.legend()
plt.tight_layout()

# %% [markdown]
# ## Learned Constellation <a class="anchor" id="Constellation"></a>

# %%
# Utility function to load and set weights of a mode
def load_weights(model, model_weights_path):
    model(1, tf.constant(10.0, tf.float32))
    with open(model_weights_path, 'rb') as f:
        weights = pickle.load(f)
    model.set_weights(weights)

# %%
model = E2ESystem('neural-receiver-trained', training=True)
load_weights(model, model_weights_path_trained) # model_weights_path_trained

# fig = model.constellation.show()
constellation = model.constellation
figsize=(10,10)
maxval = np.max(np.abs(constellation.points))*1.05
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(111)
plt.xlim(-maxval, maxval)
plt.ylim(-maxval, maxval)
plt.scatter(np.real(constellation.points), np.imag(constellation.points))
ax.set_aspect("equal", adjustable="box")
plt.grid(True, which="both", axis="both")
plt.title("Trained mapper")
plt.xlabel("Real Part")
plt.ylabel("Imaginary Part")
for j, p in enumerate(constellation.points):
    plt.annotate(
        np.binary_repr(j, num_bits_per_symbol),
        (np.real(p), np.imag(p))
    )

# %%
# Define the folders containing the results for the three runs
folders = ['', 'rerun', 'with_loss_term', 'with_loss_term/rerun', 'with_loss_term/rerun2']
colors = ['C0', 'C1', 'C2', 'C3', 'C4', 'C5']  
markers = ['x', 'x', 'o', 'o', 'o']  # 'o', 'x', 's', 'd', '*', '^'
linestyles = [':', ':', '-.', '-.', '-.']  

plt.figure(figsize=(10, 6))

for i, folder in enumerate(folders):
    if (folder == ""):
        results_filename = "neural_receiver_results"
    else:
        results_filename = f"{folder}/neural_receiver_results"  # Adjust the filename if needed
    with open(results_filename, 'rb') as file:
        ebno_dbs, BLER, BER = pickle.load(file)
    
    # # Baseline - Perfect CSI
    # plt.semilogy(ebno_dbs, BER['baseline-perfect-csi'], marker=markers[0], linestyle=linestyles[0], c=colors[i], 
    #              label=f'Run {i+1} - Baseline - Perfect CSI')
    # # Baseline - LS Estimation
    # plt.semilogy(ebno_dbs, BER['baseline-ls-estimation'], marker=markers[1], linestyle=linestyles[1], c=colors[i], 
    #              label=f'Run {i+1} - Baseline - LS Estimation')
    # Neural receiver - standard mapper
    # plt.semilogy(ebno_dbs, BER['neural-receiver-standard'], marker=markers[2], linestyle=linestyles[2], c=colors[i], 
    #              label=f'Run {i+1} - Neural receiver - standard mapper')
    # Neural receiver - trained mapper
    plt.semilogy(ebno_dbs, BER['neural-receiver-standard'], marker=markers[i], linestyle=linestyles[i], c=colors[i], 
                 label=f'Run {i+1} - Neural receiver - standard mapper')

plt.xlabel(r"$E_b/N_0$ (dB)")
plt.ylabel("BER")
plt.grid(which="both")
plt.ylim((1e-9, 1.0))
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Function to read the log file and extract losses
def read_log_file(filename):
    losses = []
    with open(filename, 'r') as file:
        for line in file:
            parts = line.strip().split(', ')
            if len(parts) > 2:
                loss_str = parts[2].split(': ')[1]  # Extract loss value
                losses.append(float(loss_str))
    return losses

def combine_losses(filenames):
    all_losses = []
    for filename in filenames:
        losses = read_log_file(filename)
        all_losses.extend(losses)
    return all_losses

def calculate_cumulative_loss_average(losses, step=1000):
    cumulative_averages = []
    for i in range(step, len(losses) + 1, step):
        avg_loss = np.mean(losses[:i])  # Calculate the average up to this point
        cumulative_averages.append(avg_loss)
    return cumulative_averages

filenames_standard = ['training_log_standard.txt', 'training_log2_standard.txt', 'training_log3_standard.txt', 'training_log4_standard.txt', 'training_log5_standard.txt', 'training_log6_standard.txt', 'training_log7_standard.txt']
losses_standard = combine_losses(filenames_standard)
filenames_trained = ['training_log_trained.txt', 'training_log2_trained.txt', 'training_log3_trained.txt', 'training_log4_trained.txt', 'training_log5_trained.txt', 'training_log6_trained.txt', 'training_log7_trained.txt']
losses_trained = combine_losses(filenames_trained)

cumulative_averages_standard = calculate_cumulative_loss_average(losses_standard, step=1000)
cumulative_averages_trained = calculate_cumulative_loss_average(losses_trained, step=1000)

plt.figure(figsize=(12, 6))

# X-axis values
iterations_standard = range(1000, len(losses_standard) + 1, 1000)
iterations_trained = range(1000, len(losses_trained) + 1, 1000)

plt.plot(iterations_standard, cumulative_averages_standard, marker='.', linestyle='-', color='b', label='QAM mapper + DeepRx')
plt.plot(iterations_trained, cumulative_averages_trained, marker='.', linestyle='-', color='r', label='Trained mapper + DeepRx')
plt.xlabel('Iteration')
plt.ylabel('Averaged Cumulative Loss')
plt.grid(True)
plt.legend()
plt.show()

# %%
def read_validation_log(filename):
    iterations = []
    ber_values = []
    bler_values = []
    with open(filename, 'r') as file:
        for line in file:
            parts = line.strip().split(': ')
            iteration_part = parts[0].split('/')[0].split()[1]  # Extract iteration number
            metrics = parts[1].split(', ')
            ber = float(metrics[0].split('=')[1].strip().strip('[]'))  # Extract BER value
            bler = float(metrics[1].split('=')[1].strip().strip('[]'))  # Extract BLER value
            iterations.append(int(iteration_part))
            ber_values.append(ber)
            bler_values.append(bler)
    return iterations, ber_values, bler_values

def combine_validation_logs(filenames):
    all_iterations = []
    all_ber_values = []
    all_bler_values = []
    for filename in filenames:
        iterations, ber_values, bler_values = read_validation_log(filename)
        all_iterations.extend(iterations)
        all_ber_values.extend(ber_values)
        all_bler_values.extend(bler_values)
    return all_iterations, all_ber_values, all_bler_values

validation_filenames_standard = ['validation_log_standard.txt', 'validation_log2_standard.txt', 'validation_log3_standard.txt', 'validation_log4_standard.txt', 'validation_log5_standard.txt', 'validation_log6_standard.txt', 'validation_log7_standard.txt']
iterations_standard, ber_values_standard, bler_values_standard = combine_validation_logs(validation_filenames_standard)
validation_filenames_trained = ['validation_log_trained.txt', 'validation_log2_trained.txt', 'validation_log3_trained.txt', 'validation_log4_trained.txt', 'validation_log5_trained.txt', 'validation_log6_trained.txt', 'validation_log7_trained.txt']
iterations_trained, ber_values_trained, bler_values_trained = combine_validation_logs(validation_filenames_trained)

plt.figure(figsize=(12, 6))
plt.semilogy(iterations_standard, ber_values_standard, marker='.', linestyle='-', color='r', label='QAM mapper + DeepRx')
plt.semilogy(iterations_trained, ber_values_trained, marker='.', linestyle='-', color='b', label='Trained mapper + DeepRx')
plt.xlabel('Iteration')
plt.ylabel('BER')
plt.grid(True)
plt.legend()
plt.show()

plt.figure(figsize=(12, 6))
plt.semilogy(iterations_standard, bler_values_standard, marker='.', linestyle='-', color='r', label='QAM mapper + DeepRx')
plt.semilogy(iterations_trained, bler_values_trained, marker='.', linestyle='-', color='b', label='Trained mapper + DeepRx')
plt.xlabel('Iteration')
plt.ylabel('BLER')
plt.grid(True)
plt.legend()
plt.show()

# %%
from scipy.stats import gaussian_kde

# model = E2ESystem('neural-receiver-standard')
model = E2ESystem('neural-receiver-trained')

# model(1, tf.constant(10.0, tf.float32))
# with open(model_weights_path_standard, 'rb') as f:
#     weights = pickle.load(f)
# model.set_weights(weights)

model(1, tf.constant(10.0, tf.float32))
with open(model_weights_path_trained, 'rb') as f:
    weights = pickle.load(f)
model.set_weights(weights)

model.summary()

nn_para = np.zeros(1)
for layer in model.layers:
    for weight in layer.weights:
        nn_para = np.concatenate((nn_para, weight.numpy().reshape(-1)), axis=0)

# Gaussian kernel density estimate
data = nn_para  # Replace with your data
kde = gaussian_kde(data[0:1000])

x = np.linspace(min(data), max(data), 1000)

plt.figure(figsize=(8, 6))
plt.plot(x, kde(x), label='PDF')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.title('Probability Density Function')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Model: "e2e_system_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  binary_source_11 (BinarySo  multiple                  0
#  urce)
#
#  ldpc5g_encoder_4 (LDPC5GEn  multiple                  0
#  coder)
#
#  constellation_11 (Constell  multiple                  128
#  ation)
#
#  mapper_11 (Mapper)          multiple                  128
#
#  resource_grid_mapper_9 (Re  multiple                  0
#  sourceGridMapper)
#
#  ofdm_channel_9 (OFDMChanne  multiple                  0
#  l)
#
#  neural_receiver_9 (NeuralR  multiple                  4863494
#  eceiver)
#
#  resource_grid_demapper_9 (  multiple                  0
#  ResourceGridDemapper)
#
#  ldpc5g_decoder_4 (LDPC5GDe  multiple                  0
#  coder)
#
# =================================================================
# Total params: 4863622 (18.55 MB)
# Trainable params: 4863622 (18.55 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## References <a class="anchor" id="References"></a>

# %% [markdown]
# [1] M. Honkala, D. Korpi and J. M. J. Huttunen, "DeepRx: Fully Convolutional Deep Learning Receiver," in IEEE Transactions on Wireless Communications, vol. 20, no. 6, pp. 3925-3940, June 2021, doi: 10.1109/TWC.2021.3054520.
#
# [2] F. Ait Aoudia and J. Hoydis, "End-to-end Learning for OFDM: From Neural Receivers to Pilotless Communication," in IEEE Transactions on Wireless Communications, doi: 10.1109/TWC.2021.3101364.
#
# [3] Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun, "Deep Residual Learning for Image Recognition", Proceedings of the IEEE Conference on Computer Vision and Pattern Recognition (CVPR), 2016, pp. 770-778
#
# [4] G. Böcherer, "Achievable Rates for Probabilistic Shaping", arXiv:1707.01134, 2017.
